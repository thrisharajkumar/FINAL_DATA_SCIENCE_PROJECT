# %% [markdown]
# ## FINAL MODEL - FULL DATA RUN

# %% [markdown]
# Last Execution 12:43:37 AM
#
# Execution Time 141m 49.5s - 2 hrs 35 mins

# %%
# ==================== MULTI-HEAD ANN — Integrated v2 (ringing-focused upgrades) ====================
import os, random, json, pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, regularizers, losses

# -------------------- Settings --------------------
SEED = 42
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)

UNSEEN_PART = 'C2M0040120D'
DATA_CSV = r"C:\Users\pc\Desktop\Neural_Network_Models\merged_train_5_MOSFETs.csv"

BASE_DIR = "Full_Data_Run_MultiHead_ANN"
for sub in ["r2_rmse_tables","train_val_loss_curves","predicted_vs_actual","models","artifacts"]:
    os.makedirs(f"{BASE_DIR}/{sub}", exist_ok=True)

# -------------------- Targets & columns --------------------
TARGET_COLUMNS = [
    'voltage_rise_time_pulse1','voltage_rise_time_pulse2',
    'voltage_fall_time_pulse1','voltage_fall_time_pulse2',
    'current_rise_time_pulse1','current_rise_time_pulse2',
    'current_fall_time_pulse1','current_fall_time_pulse2',
    'overshoot_pulse_1','overshoot_pulse_2',
    'undershoot_pulse_1','undershoot_pulse_2',
    'ringing_frequency_MHz'
]
DROP_COLUMNS = ['DeviceID','MOSFET','Part_Number']

LOG_TARGETS = {
    'voltage_rise_time_pulse1','voltage_rise_time_pulse2',
    'current_rise_time_pulse1','current_rise_time_pulse2',
    'ringing_frequency_MHz'
}

HARD_HEADS = {
    'voltage_rise_time_pulse1','voltage_rise_time_pulse2',
    'current_rise_time_pulse1','current_rise_time_pulse2',
    'ringing_frequency_MHz'
}

# -------------------- Load & split --------------------
df = pd.read_csv(DATA_CSV)
seen_parts = [p for p in df['Part_Number'].unique().tolist() if p != UNSEEN_PART]
train_df = df[df['Part_Number'].isin(seen_parts)].copy()
test_df  = df[df['Part_Number'] == UNSEEN_PART].copy()

# -------------------- Physics features --------------------
def safe(val, eps=1e-15): return max(float(val), eps)

def compute_physics_features(row):
    # Base quantities
    Ls = float(row[['Ls4','Ls5','Ls6','Ls7','Ls8','Ls9','Ls10','Ls11']].sum())
    Coss = float(row.get("Coss", 1e-12))
    L_eq = safe(Ls)
    C_eq = safe(Coss)

    # Resonance & derived helpers
    inv_sqrt_LC = 1.0 / np.sqrt(L_eq*C_eq)
    f_res = (inv_sqrt_LC / (2*np.pi)) / 1e6           # MHz
    sqrt_LC = np.sqrt(L_eq*C_eq)

    # Rough damping proxy (no exact R_total available)
    # Use gate/network resistances as a proxy; clamp to avoid zero/negatives
    Rg = float(row.get("Rg", 0.0))
    R1 = float(row.get("R1", 0.0))
    R_proxy = safe(Rg + R1 + 1e-3)
    # Q ≈ (1/R) * sqrt(L/C)  (dimensionally consistent for proxy)
    Q_est = (np.sqrt(L_eq / C_eq)) / R_proxy

    Vbus = float(row.get("Vbus", 0.0))
    VDS_max = float(row.get("VDS_max", 0.0))
    Vth_min = float(row.get("VGS_th_min", 0.0))
    IDmax   = float(row.get("ID_max_25C", 0.0))
    Tp1 = safe(row.get("Tp1", 1e-9))

    overshoot_est  = VDS_max - Vbus
    undershoot_est = - Vth_min
    dVdt_est = overshoot_est / Tp1
    dIdt_est = IDmax / Tp1

    # Add a couple of interaction terms often useful for ringing
    v_over_L = Vbus / safe(L_eq)
    v_over_C = Vbus / safe(C_eq)

    return pd.Series([
        f_res, overshoot_est, undershoot_est, dVdt_est, dIdt_est,
        L_eq, C_eq, sqrt_LC, inv_sqrt_LC, Q_est, v_over_L, v_over_C
    ])

for d in (train_df, test_df):
    d[['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est',
      'L_eq','C_eq','sqrt_LC','inv_sqrt_LC','Q_est','v_over_L','v_over_C'
     ]] = d.apply(compute_physics_features, axis=1)

physics_features = [
    'f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est',
    'L_eq','C_eq','sqrt_LC','inv_sqrt_LC','Q_est','v_over_L','v_over_C'
]
INPUT_COLUMNS = [c for c in df.columns if c not in TARGET_COLUMNS + DROP_COLUMNS] + physics_features

# -------------------- Scale inputs (fit on TRAIN only) --------------------
input_scaler = StandardScaler()
input_scaler.fit(train_df[INPUT_COLUMNS])

X_train_all = input_scaler.transform(train_df[INPUT_COLUMNS]).astype('float32')
X_test_all  = input_scaler.transform(test_df[INPUT_COLUMNS]).astype('float32')

# Separate physics vs main
phys_idx = [INPUT_COLUMNS.index(c) for c in physics_features]
X_train_phys = X_train_all[:, phys_idx]
X_test_phys  = X_test_all[:, phys_idx]
X_train_main = np.delete(X_train_all, phys_idx, axis=1)
X_test_main  = np.delete(X_test_all,  phys_idx, axis=1)

# -------------------- Scale outputs (per-target; log where configured) --------------------
output_scalers = {}
y_train_scaled_cols, y_test_scaled_cols = [], []

def _prep_target(col, arr):
    if col in LOG_TARGETS:
        arr = np.log1p(np.clip(arr, a_min=0, a_max=None))
    return arr

def _inv_target(col, arr1d, scaler):
    x = scaler.inverse_transform(arr1d.reshape(-1,1)).flatten()
    if col in LOG_TARGETS:
        x = np.expm1(x)
    return x

for col in TARGET_COLUMNS:
    y_tr = train_df[col].values.reshape(-1,1)
    y_te = test_df[col].values.reshape(-1,1)

    y_tr = _prep_target(col, y_tr)
    y_te = _prep_target(col, y_te)

    scaler = MinMaxScaler() if col == 'ringing_frequency_MHz' else StandardScaler()
    scaler.fit(y_tr)
    output_scalers[col] = scaler

    y_train_scaled_cols.append(scaler.transform(y_tr).flatten())
    y_test_scaled_cols.append(scaler.transform(y_te).flatten())

y_train_scaled = np.array(y_train_scaled_cols).T.astype('float32')  # [N, 13]
y_test_scaled  = np.array(y_test_scaled_cols).T.astype('float32')

# -------------------- Train/Val split --------------------
Xtr_main, Xval_main, Xtr_phys, Xval_phys, ytr, yval = train_test_split(
    X_train_main, X_train_phys, y_train_scaled,
    test_size=0.15, random_state=SEED
)

# -------------------- Model (Script #2 backbone + ringing-focused head) --------------------
def build_multihead_ann(input_dim_main, input_dim_phys, output_names,
                        l2_reg=1e-4, dropout_rate=0.2):
    inp_main = layers.Input(shape=(input_dim_main,), name="main_inputs")
    inp_phys = layers.Input(shape=(input_dim_phys,), name="physics_inputs")

    # Backbone: 128 -> 64 with BN + L2 + Dropout (from Script #2)
    x = layers.Dense(128, kernel_regularizer=regularizers.l2(l2_reg), use_bias=False)(inp_main)
    x = layers.BatchNormalization()(x); x = layers.ReLU()(x)
    x = layers.Dropout(dropout_rate)(x)

    x = layers.Dense(64, kernel_regularizer=regularizers.l2(l2_reg), use_bias=False)(x)
    x = layers.BatchNormalization()(x); x = layers.ReLU()(x)
    x = layers.Dropout(dropout_rate)(x)

    # Physics branch (wider now)
    p = layers.Dense(64, activation="relu")(inp_phys)
    p = layers.Dense(48, activation="relu")(p)

    shared = layers.Concatenate()([x, p])

    outputs = []
    for col in output_names:
        if col == 'ringing_frequency_MHz':
            # Gated physics fusion (ringing-focused)
            h = layers.Dense(96, activation="relu")(shared)
            h = layers.Dropout(dropout_rate)(h)
            # physics gate
            gate = layers.Dense(48, activation="sigmoid")(p)
            h = layers.Concatenate()([h, layers.Multiply()([p, gate])])
            h = layers.Dense(48, activation="relu")(h)
            out = layers.Dense(1, activation="linear", name=col)(h)
        else:
            h = layers.Dense(64, activation="relu")(shared)
            h = layers.Dropout(dropout_rate)(h)
            h = layers.Dense(32, activation="relu")(h)
            # physics injection for hard heads (rise family)
            if col in HARD_HEADS:
                h = layers.Concatenate()([h, p])
                h = layers.Dense(32, activation="relu")(h)
            out = layers.Dense(1, activation="linear", name=col)(h)
        outputs.append(out)

    return models.Model(inputs=[inp_main, inp_phys], outputs=outputs)

model = build_multihead_ann(
    Xtr_main.shape[1], Xtr_phys.shape[1], TARGET_COLUMNS,
    l2_reg=1e-4, dropout_rate=0.2
)

# -------------------- Losses & weights --------------------
# Use MSE for most; Huber for ringing (robust on tails)
losses_map = {col: "mse" for col in TARGET_COLUMNS}
losses_map['ringing_frequency_MHz'] = losses.Huber(delta=0.7)

# Warm-up (balanced), then fine-tune (emphasize ringing & rises)
PHASE1_WEIGHTS = {col: 1.0 for col in TARGET_COLUMNS}
PHASE2_WEIGHTS = {col: 1.0 for col in TARGET_COLUMNS}
PHASE2_WEIGHTS.update({
    'ringing_frequency_MHz': 3.0,
    'current_rise_time_pulse2': 1.8,
    'current_rise_time_pulse1': 1.5,
    'voltage_rise_time_pulse1': 1.5,
    'voltage_rise_time_pulse2': 1.5,
})

def weights_dict_to_list(d):
    return [d.get(col, 1.0) for col in TARGET_COLUMNS]

# -------------------- Compile & train (Phase 1) --------------------
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-4),
    loss=[losses_map[c] for c in TARGET_COLUMNS],
    loss_weights=weights_dict_to_list(PHASE1_WEIGHTS),
    metrics=["mae"]*len(TARGET_COLUMNS)
)

early1 = callbacks.EarlyStopping(monitor="val_loss", patience=12, restore_best_weights=True, min_delta=1e-4)
rlr1   = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=6, min_lr=1e-6)

hist1 = model.fit(
    [Xtr_main, Xtr_phys],
    [ytr[:, i] for i in range(len(TARGET_COLUMNS))],
    validation_data=([Xval_main, Xval_phys], [yval[:, i] for i in range(len(TARGET_COLUMNS))]),
    epochs=90, batch_size=256, callbacks=[early1, rlr1], verbose=1
)

# -------------------- Fine-tune (Phase 2) --------------------
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss=[losses_map[c] for c in TARGET_COLUMNS],
    loss_weights=weights_dict_to_list(PHASE2_WEIGHTS),
    metrics=["mae"]*len(TARGET_COLUMNS)
)

early2 = callbacks.EarlyStopping(monitor="val_loss", patience=14, restore_best_weights=True, min_delta=1e-4)
rlr2   = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=7, min_lr=1e-6)

hist2 = model.fit(
    [Xtr_main, Xtr_phys],
    [ytr[:, i] for i in range(len(TARGET_COLUMNS))],
    validation_data=([Xval_main, Xval_phys], [yval[:, i] for i in range(len(TARGET_COLUMNS))]),
    epochs=120, batch_size=256, callbacks=[early2, rlr2], verbose=1
)

model.save(f"{BASE_DIR}/models/multihead_ann_integrated_v2.h5")

# -------------------- Loss curve --------------------
plt.figure()
plt.plot(hist1.history['loss'] + hist2.history['loss'], label='Train Loss')
plt.plot(hist1.history['val_loss'] + hist2.history['val_loss'], label='Val Loss')
plt.xlabel("Epoch"); plt.ylabel("Weighted Loss")
plt.title("Train vs Validation Loss (Integrated v2)")
plt.legend(); plt.savefig(f"{BASE_DIR}/train_val_loss_curves/loss.png"); plt.close()

# -------------------- Evaluation helpers --------------------
def inverse_one(col, arr_1d):
    scaler = output_scalers[col]
    return _inv_target(col, arr_1d, scaler)

def evaluate_and_save(X_main, X_phys, y_scaled, name, positive_only=False, scatter=False):
    y_pred_scaled_list = model.predict([X_main, X_phys], verbose=0)
    rows, y_true_raw, y_pred_raw = [], [], []

    for i, col in enumerate(TARGET_COLUMNS):
        y_true = inverse_one(col, y_scaled[:, i])
        y_pred = inverse_one(col, y_pred_scaled_list[i].reshape(-1))
        y_true_raw.append(y_true); y_pred_raw.append(y_pred)
        r2   = r2_score(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        rows.append((col, r2, rmse))

    df_results = pd.DataFrame(rows, columns=["Target","R2","RMSE"]).sort_values("R2", ascending=False)
    if positive_only:
        df_results = df_results[df_results["R2"] > 0.0]

    print(f"\n{name}:\n", df_results)
    df_results.to_csv(f"{BASE_DIR}/r2_rmse_tables/{name}.csv", index=False)

    if scatter:
        n_cols = 3
        n_rows = int(np.ceil(len(TARGET_COLUMNS) / n_cols))
        plt.figure(figsize=(15, 5*n_rows))
        for i, col in enumerate(TARGET_COLUMNS):
            yt, yp = y_true_raw[i], y_pred_raw[i]
            plt.subplot(n_rows, n_cols, i+1)
            plt.scatter(yt, yp, alpha=0.45, s=10)
            lo, hi = min(yt.min(), yp.min()), max(yt.max(), yp.max())
            plt.plot([lo, hi], [lo, hi], "r--", linewidth=1)
            plt.xlabel("Actual"); plt.ylabel("Predicted"); plt.title(col)
        plt.tight_layout(); plt.savefig(f"{BASE_DIR}/predicted_vs_actual/{name}_scatter.png"); plt.close()

    return df_results

# -------------------- Run evals --------------------
evaluate_and_save(Xtr_main, Xtr_phys, ytr, "train")
evaluate_and_save(Xval_main, Xval_phys, yval, "val")
evaluate_and_save(X_train_main, X_train_phys, y_train_scaled, "test_seen", scatter=True)
evaluate_and_save(X_test_main, X_test_phys, y_test_scaled, "unseen_all", scatter=True)
evaluate_and_save(X_test_main, X_test_phys, y_test_scaled, "unseen_positive_only", positive_only=True)

# -------------------- Artifacts --------------------
with open(f"{BASE_DIR}/artifacts/input_scaler.pkl", "wb") as f:
    pickle.dump(input_scaler, f)
with open(f"{BASE_DIR}/artifacts/output_scalers.pkl", "wb") as f:
    pickle.dump(output_scalers, f)
with open(f"{BASE_DIR}/artifacts/TARGET_COLUMNS.json", "w") as f:
    json.dump(TARGET_COLUMNS, f, indent=2)
with open(f"{BASE_DIR}/artifacts/INPUT_COLUMNS.json", "w") as f:
    json.dump(INPUT_COLUMNS, f, indent=2)
with open(f"{BASE_DIR}/artifacts/PHYSICS_COLUMNS.json", "w") as f:
    json.dump(physics_features, f, indent=2)

# -------------------- Full prediction exports --------------------
def save_full_predictions(X_main, X_phys, y_scaled, df_inputs, name):
    y_pred_scaled_list = model.predict([X_main, X_phys], verbose=0)
    preds_dict, actuals_dict = {}, {}
    for i, col in enumerate(TARGET_COLUMNS):
        y_pred = inverse_one(col, y_pred_scaled_list[i].reshape(-1))
        y_true = inverse_one(col, y_scaled[:, i])
        preds_dict[f"{col}_predicted"] = y_pred
        actuals_dict[f"{col}_actual"] = y_true
    full_df = df_inputs.reset_index(drop=True).copy()
    for col in TARGET_COLUMNS:
        full_df[f"{col}_actual"] = actuals_dict[f"{col}_actual"]
        full_df[f"{col}_predicted"] = preds_dict[f"{col}_predicted"]
    out_path = f"{BASE_DIR}/artifacts/{name}_full_predictions.csv"
    full_df.to_csv(out_path, index=False)
    print(f"Saved {name} predictions → {out_path}")

save_full_predictions(X_train_main, X_train_phys, y_train_scaled,
                      train_df[INPUT_COLUMNS + ['Part_Number']], "seen")
save_full_predictions(X_test_main, X_test_phys, y_test_scaled,
                      test_df[INPUT_COLUMNS + ['Part_Number']], "unseen")
# Out:
# Epoch 1/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 35s 17ms/step - current_fall_time_pulse1_loss: 0.1743 - current_fall_time_pulse1_mae: 0.2824 - current_fall_time_pulse2_loss: 0.2061 - current_fall_time_pulse2_mae: 0.3031 - current_rise_time_pulse1_loss: 0.1574 - current_rise_time_pulse1_mae: 0.2543 - current_rise_time_pulse2_loss: 0.2539 - current_rise_time_pulse2_mae: 0.3494 - loss: 2.6276 - overshoot_pulse_1_loss: 0.3201 - overshoot_pulse_1_mae: 0.4041 - overshoot_pulse_2_loss: 0.2477 - overshoot_pulse_2_mae: 0.3594 - ringing_frequency_MHz_loss: 0.0156 - ringing_frequency_MHz_mae: 0.1037 - undershoot_pulse_1_loss: 0.2916 - undershoot_pulse_1_mae: 0.3565 - undershoot_pulse_2_loss: 0.2547 - undershoot_pulse_2_mae: 0.3479 - voltage_fall_time_pulse1_loss: 0.1468 - voltage_fall_time_pulse1_mae: 0.2388 - voltage_fall_time_pulse2_loss: 0.1297 - voltage_fall_time_pulse2_mae: 0.2243 - voltage_rise_time_pulse1_loss: 0.1224 - voltage_rise_time_pulse1_mae: 0.2182 - voltage_rise_time_pulse2_loss: 0.2948 - voltage_rise_time_pulse2_mae: 0.3178 - val_current_fall_time_pulse1_loss: 0.0310 - val_current_fall_time_pulse1_mae: 0.1398 - val_current_fall_time_pulse2_loss: 0.0285 - val_current_fall_time_pulse2_mae: 0.1354 - val_current_rise_time_pulse1_loss: 0.0693 - val_current_rise_time_pulse1_mae: 0.1544 - val_current_rise_time_pulse2_loss: 0.1085 - val_current_rise_time_pulse2_mae: 0.2029 - val_loss: 0.6994 - val_overshoot_pulse_1_loss: 0.0677 - val_overshoot_pulse_1_mae: 0.1968 - val_overshoot_pulse_2_loss: 0.0902 - val_overshoot_pulse_2_mae: 0.2386 - val_ringing_frequency_MHz_loss: 1.9725e-04 - val_ringing_frequency_MHz_mae: 0.0155 - val_undershoot_pulse_1_loss: 0.0499 - val_undershoot_pulse_1_mae: 0.1648 - val_undershoot_pulse_2_loss: 0.0558 - val_undershoot_pulse_2_mae: 0.1736 - val_voltage_fall_time_pulse1_loss: 0.0283 - val_voltage_fall_time_pulse1_mae: 0.1338 - val_voltage_fall_time_pulse2_loss: 0.0263 - val_voltage_fall_time_pulse2_mae: 0.1389 - val_voltage_rise_time_pulse1_loss: 0.0158 - val_voltage_rise_time_pulse1_mae: 0.0734 - val_voltage_rise_time_pulse2_loss: 0.1162 - val_voltage_rise_time_pulse2_mae: 0.1953 - learning_rate: 5.0000e-04
# Epoch 2/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - current_fall_time_pulse1_loss: 0.0231 - current_fall_time_pulse1_mae: 0.1152 - current_fall_time_pulse2_loss: 0.0242 - current_fall_time_pulse2_mae: 0.1182 - current_rise_time_pulse1_loss: 0.0704 - current_rise_time_pulse1_mae: 0.1618 - current_rise_time_pulse2_loss: 0.1128 - current_rise_time_pulse2_mae: 0.2057 - loss: 0.7242 - overshoot_pulse_1_loss: 0.0979 - overshoot_pulse_1_mae: 0.2325 - overshoot_pulse_2_loss: 0.0918 - overshoot_pulse_2_mae: 0.2333 - ringing_frequency_MHz_loss: 2.1429e-04 - ringing_frequency_MHz_mae: 0.0161 - undershoot_pulse_1_loss: 0.0563 - undershoot_pulse_1_mae: 0.1700 - undershoot_pulse_2_loss: 0.0546 - undershoot_pulse_2_mae: 0.1685 - voltage_fall_time_pulse1_loss: 0.0104 - voltage_fall_time_pulse1_mae: 0.0731 - voltage_fall_time_pulse2_loss: 0.0098 - voltage_fall_time_pulse2_mae: 0.0705 - voltage_rise_time_pulse1_loss: 0.0227 - voltage_rise_time_pulse1_mae: 0.0863 - voltage_rise_time_pulse2_loss: 0.1383 - voltage_rise_time_pulse2_mae: 0.2048 - val_current_fall_time_pulse1_loss: 0.0352 - val_current_fall_time_pulse1_mae: 0.1485 - val_current_fall_time_pulse2_loss: 0.0322 - val_current_fall_time_pulse2_mae: 0.1455 - val_current_rise_time_pulse1_loss: 0.0669 - val_current_rise_time_pulse1_mae: 0.1504 - val_current_rise_time_pulse2_loss: 0.0977 - val_current_rise_time_pulse2_mae: 0.1838 - val_loss: 0.6699 - val_overshoot_pulse_1_loss: 0.0601 - val_overshoot_pulse_1_mae: 0.1878 - val_overshoot_pulse_2_loss: 0.0838 - val_overshoot_pulse_2_mae: 0.2311 - val_ringing_frequency_MHz_loss: 1.2183e-04 - val_ringing_frequency_MHz_mae: 0.0120 - val_undershoot_pulse_1_loss: 0.0578 - val_undershoot_pulse_1_mae: 0.1789 - val_undershoot_pulse_2_loss: 0.0594 - val_undershoot_pulse_2_mae: 0.1770 - val_voltage_fall_time_pulse1_loss: 0.0317 - val_voltage_fall_time_pulse1_mae: 0.1397 - val_voltage_fall_time_pulse2_loss: 0.0274 - val_voltage_fall_time_pulse2_mae: 0.1380 - val_voltage_rise_time_pulse1_loss: 0.0117 - val_voltage_rise_time_pulse1_mae: 0.0624 - val_voltage_rise_time_pulse2_loss: 0.0941 - val_voltage_rise_time_pulse2_mae: 0.1806 - learning_rate: 5.0000e-04
# Epoch 3/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - current_fall_time_pulse1_loss: 0.0161 - current_fall_time_pulse1_mae: 0.0967 - current_fall_time_pulse2_loss: 0.0169 - current_fall_time_pulse2_mae: 0.0989 - current_rise_time_pulse1_loss: 0.0681 - current_rise_time_pulse1_mae: 0.1572 - current_rise_time_pulse2_loss: 0.1039 - current_rise_time_pulse2_mae: 0.1913 - loss: 0.6033 - overshoot_pulse_1_loss: 0.0737 - overshoot_pulse_1_mae: 0.2038 - overshoot_pulse_2_loss: 0.0810 - overshoot_pulse_2_mae: 0.2197 - ringing_frequency_MHz_loss: 1.3781e-04 - ringing_frequency_MHz_mae: 0.0128 - undershoot_pulse_1_loss: 0.0451 - undershoot_pulse_1_mae: 0.1505 - undershoot_pulse_2_loss: 0.0437 - undershoot_pulse_2_mae: 0.1500 - voltage_fall_time_pulse1_loss: 0.0058 - voltage_fall_time_pulse1_mae: 0.0539 - voltage_fall_time_pulse2_loss: 0.0053 - voltage_fall_time_pulse2_mae: 0.0511 - voltage_rise_time_pulse1_loss: 0.0175 - voltage_rise_time_pulse1_mae: 0.0709 - voltage_rise_time_pulse2_loss: 0.1145 - voltage_rise_time_pulse2_mae: 0.1920 - val_current_fall_time_pulse1_loss: 0.0391 - val_current_fall_time_pulse1_mae: 0.1556 - val_current_fall_time_pulse2_loss: 0.0361 - val_current_fall_time_pulse2_mae: 0.1522 - val_current_rise_time_pulse1_loss: 0.0659 - val_current_rise_time_pulse1_mae: 0.1486 - val_current_rise_time_pulse2_loss: 0.0908 - val_current_rise_time_pulse2_mae: 0.1644 - val_loss: 0.6716 - val_overshoot_pulse_1_loss: 0.0511 - val_overshoot_pulse_1_mae: 0.1772 - val_overshoot_pulse_2_loss: 0.0867 - val_overshoot_pulse_2_mae: 0.2378 - val_ringing_frequency_MHz_loss: 1.0187e-04 - val_ringing_frequency_MHz_mae: 0.0109 - val_undershoot_pulse_1_loss: 0.0629 - val_undershoot_pulse_1_mae: 0.1895 - val_undershoot_pulse_2_loss: 0.0608 - val_undershoot_pulse_2_mae: 0.1831 - val_voltage_fall_time_pulse1_loss: 0.0369 - val_voltage_fall_time_pulse1_mae: 0.1508 - val_voltage_fall_time_pulse2_loss: 0.0326 - val_voltage_fall_time_pulse2_mae: 0.1486 - val_voltage_rise_time_pulse1_loss: 0.0103 - val_voltage_rise_time_pulse1_mae: 0.0536 - val_voltage_rise_time_pulse2_loss: 0.0872 - val_voltage_rise_time_pulse2_mae: 0.1769 - learning_rate: 5.0000e-04
# Epoch 4/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - current_fall_time_pulse1_loss: 0.0130 - current_fall_time_pulse1_mae: 0.0870 - current_fall_time_pulse2_loss: 0.0134 - current_fall_time_pulse2_mae: 0.0880 - current_rise_time_pulse1_loss: 0.0668 - current_rise_time_pulse1_mae: 0.1549 - current_rise_time_pulse2_loss: 0.0991 - current_rise_time_pulse2_mae: 0.1820 - loss: 0.5434 - overshoot_pulse_1_loss: 0.0631 - overshoot_pulse_1_mae: 0.1899 - overshoot_pulse_2_loss: 0.0758 - overshoot_pulse_2_mae: 0.2127 - ringing_frequency_MHz_loss: 1.1325e-04 - ringing_frequency_MHz_mae: 0.0116 - undershoot_pulse_1_loss: 0.0387 - undershoot_pulse_1_mae: 0.1404 - undershoot_pulse_2_loss: 0.0371 - undershoot_pulse_2_mae: 0.1392 - voltage_fall_time_pulse1_loss: 0.0037 - voltage_fall_time_pulse1_mae: 0.0430 - voltage_fall_time_pulse2_loss: 0.0035 - voltage_fall_time_pulse2_mae: 0.0411 - voltage_rise_time_pulse1_loss: 0.0151 - voltage_rise_time_pulse1_mae: 0.0630 - voltage_rise_time_pulse2_loss: 0.1030 - voltage_rise_time_pulse2_mae: 0.1861 - val_current_fall_time_pulse1_loss: 0.0346 - val_current_fall_time_pulse1_mae: 0.1455 - val_current_fall_time_pulse2_loss: 0.0340 - val_current_fall_time_pulse2_mae: 0.1466 - val_current_rise_time_pulse1_loss: 0.0648 - val_current_rise_time_pulse1_mae: 0.1486 - val_current_rise_time_pulse2_loss: 0.0863 - val_current_rise_time_pulse2_mae: 0.1538 - val_loss: 0.6674 - val_overshoot_pulse_1_loss: 0.0563 - val_overshoot_pulse_1_mae: 0.1849 - val_overshoot_pulse_2_loss: 0.0918 - val_overshoot_pulse_2_mae: 0.2446 - val_ringing_frequency_MHz_loss: 9.3736e-05 - val_ringing_frequency_MHz_mae: 0.0106 - val_undershoot_pulse_1_loss: 0.0625 - val_undershoot_pulse_1_mae: 0.1878 - val_undershoot_pulse_2_loss: 0.0589 - val_undershoot_pulse_2_mae: 0.1799 - val_voltage_fall_time_pulse1_loss: 0.0385 - val_voltage_fall_time_pulse1_mae: 0.1560 - val_voltage_fall_time_pulse2_loss: 0.0360 - val_voltage_fall_time_pulse2_mae: 0.1527 - val_voltage_rise_time_pulse1_loss: 0.0089 - val_voltage_rise_time_pulse1_mae: 0.0508 - val_voltage_rise_time_pulse2_loss: 0.0840 - val_voltage_rise_time_pulse2_mae: 0.1736 - learning_rate: 5.0000e-04
# Epoch 5/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - current_fall_time_pulse1_loss: 0.0109 - current_fall_time_pulse1_mae: 0.0794 - current_fall_time_pulse2_loss: 0.0111 - current_fall_time_pulse2_mae: 0.0799 - current_rise_time_pulse1_loss: 0.0659 - current_rise_time_pulse1_mae: 0.1531 - current_rise_time_pulse2_loss: 0.0947 - current_rise_time_pulse2_mae: 0.1738 - loss: 0.5041 - overshoot_pulse_1_loss: 0.0562 - overshoot_pulse_1_mae: 0.1797 - overshoot_pulse_2_loss: 0.0730 - overshoot_pulse_2_mae: 0.2088 - ringing_frequency_MHz_loss: 1.0199e-04 - ringing_frequency_MHz_mae: 0.0110 - undershoot_pulse_1_loss: 0.0337 - undershoot_pulse_1_mae: 0.1323 - undershoot_pulse_2_loss: 0.0330 - undershoot_pulse_2_mae: 0.1312 - voltage_fall_time_pulse1_loss: 0.0026 - voltage_fall_time_pulse1_mae: 0.0359 - voltage_fall_time_pulse2_loss: 0.0025 - voltage_fall_time_pulse2_mae: 0.0350 - voltage_rise_time_pulse1_loss: 0.0133 - voltage_rise_time_pulse1_mae: 0.0573 - voltage_rise_time_pulse2_loss: 0.0966 - voltage_rise_time_pulse2_mae: 0.1822 - val_current_fall_time_pulse1_loss: 0.0363 - val_current_fall_time_pulse1_mae: 0.1481 - val_current_fall_time_pulse2_loss: 0.0420 - val_current_fall_time_pulse2_mae: 0.1625 - val_current_rise_time_pulse1_loss: 0.0639 - val_current_rise_time_pulse1_mae: 0.1479 - val_current_rise_time_pulse2_loss: 0.0833 - val_current_rise_time_pulse2_mae: 0.1472 - val_loss: 0.6738 - val_overshoot_pulse_1_loss: 0.0533 - val_overshoot_pulse_1_mae: 0.1824 - val_overshoot_pulse_2_loss: 0.0916 - val_overshoot_pulse_2_mae: 0.2446 - val_ringing_frequency_MHz_loss: 8.3575e-05 - val_ringing_frequency_MHz_mae: 0.0100 - val_undershoot_pulse_1_loss: 0.0636 - val_undershoot_pulse_1_mae: 0.1901 - val_undershoot_pulse_2_loss: 0.0655 - val_undershoot_pulse_2_mae: 0.1863 - val_voltage_fall_time_pulse1_loss: 0.0381 - val_voltage_fall_time_pulse1_mae: 0.1548 - val_voltage_fall_time_pulse2_loss: 0.0380 - val_voltage_fall_time_pulse2_mae: 0.1559 - val_voltage_rise_time_pulse1_loss: 0.0081 - val_voltage_rise_time_pulse1_mae: 0.0474 - val_voltage_rise_time_pulse2_loss: 0.0799 - val_voltage_rise_time_pulse2_mae: 0.1722 - learning_rate: 5.0000e-04
# Epoch 6/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - current_fall_time_pulse1_loss: 0.0094 - current_fall_time_pulse1_mae: 0.0739 - current_fall_time_pulse2_loss: 0.0095 - current_fall_time_pulse2_mae: 0.0737 - current_rise_time_pulse1_loss: 0.0652 - current_rise_time_pulse1_mae: 0.1517 - current_rise_time_pulse2_loss: 0.0930 - current_rise_time_pulse2_mae: 0.1700 - loss: 0.4822 - overshoot_pulse_1_loss: 0.0524 - overshoot_pulse_1_mae: 0.1736 - overshoot_pulse_2_loss: 0.0711 - overshoot_pulse_2_mae: 0.2059 - ringing_frequency_MHz_loss: 9.2850e-05 - ringing_frequency_MHz_mae: 0.0106 - undershoot_pulse_1_loss: 0.0306 - undershoot_pulse_1_mae: 0.1264 - undershoot_pulse_2_loss: 0.0300 - undershoot_pulse_2_mae: 0.1258 - voltage_fall_time_pulse1_loss: 0.0022 - voltage_fall_time_pulse1_mae: 0.0325 - voltage_fall_time_pulse2_loss: 0.0021 - voltage_fall_time_pulse2_mae: 0.0317 - voltage_rise_time_pulse1_loss: 0.0130 - voltage_rise_time_pulse1_mae: 0.0556 - voltage_rise_time_pulse2_loss: 0.0936 - voltage_rise_time_pulse2_mae: 0.1801 - val_current_fall_time_pulse1_loss: 0.0381 - val_current_fall_time_pulse1_mae: 0.1495 - val_current_fall_time_pulse2_loss: 0.0407 - val_current_fall_time_pulse2_mae: 0.1582 - val_current_rise_time_pulse1_loss: 0.0637 - val_current_rise_time_pulse1_mae: 0.1465 - val_current_rise_time_pulse2_loss: 0.0816 - val_current_rise_time_pulse2_mae: 0.1452 - val_loss: 0.6723 - val_overshoot_pulse_1_loss: 0.0581 - val_overshoot_pulse_1_mae: 0.1900 - val_overshoot_pulse_2_loss: 0.0936 - val_overshoot_pulse_2_mae: 0.2468 - val_ringing_frequency_MHz_loss: 6.6423e-05 - val_ringing_frequency_MHz_mae: 0.0091 - val_undershoot_pulse_1_loss: 0.0603 - val_undershoot_pulse_1_mae: 0.1864 - val_undershoot_pulse_2_loss: 0.0641 - val_undershoot_pulse_2_mae: 0.1875 - val_voltage_fall_time_pulse1_loss: 0.0372 - val_voltage_fall_time_pulse1_mae: 0.1542 - val_voltage_fall_time_pulse2_loss: 0.0383 - val_voltage_fall_time_pulse2_mae: 0.1565 - val_voltage_rise_time_pulse1_loss: 0.0076 - val_voltage_rise_time_pulse1_mae: 0.0471 - val_voltage_rise_time_pulse2_loss: 0.0795 - val_voltage_rise_time_pulse2_mae: 0.1704 - learning_rate: 5.0000e-04
# Epoch 7/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - current_fall_time_pulse1_loss: 0.0084 - current_fall_time_pulse1_mae: 0.0695 - current_fall_time_pulse2_loss: 0.0083 - current_fall_time_pulse2_mae: 0.0687 - current_rise_time_pulse1_loss: 0.0648 - current_rise_time_pulse1_mae: 0.1510 - current_rise_time_pulse2_loss: 0.0906 - current_rise_time_pulse2_mae: 0.1656 - loss: 0.4646 - overshoot_pulse_1_loss: 0.0490 - overshoot_pulse_1_mae: 0.1687 - overshoot_pulse_2_loss: 0.0699 - overshoot_pulse_2_mae: 0.2041 - ringing_frequency_MHz_loss: 8.6822e-05 - ringing_frequency_MHz_mae: 0.0102 - undershoot_pulse_1_loss: 0.0285 - undershoot_pulse_1_mae: 0.1225 - undershoot_pulse_2_loss: 0.0281 - undershoot_pulse_2_mae: 0.1215 - voltage_fall_time_pulse1_loss: 0.0018 - voltage_fall_time_pulse1_mae: 0.0294 - voltage_fall_time_pulse2_loss: 0.0018 - voltage_fall_time_pulse2_mae: 0.0292 - voltage_rise_time_pulse1_loss: 0.0120 - voltage_rise_time_pulse1_mae: 0.0524 - voltage_rise_time_pulse2_loss: 0.0918 - voltage_rise_time_pulse2_mae: 0.1782 - val_current_fall_time_pulse1_loss: 0.0376 - val_current_fall_time_pulse1_mae: 0.1477 - val_current_fall_time_pulse2_loss: 0.0420 - val_current_fall_time_pulse2_mae: 0.1580 - val_current_rise_time_pulse1_loss: 0.0633 - val_current_rise_time_pulse1_mae: 0.1466 - val_current_rise_time_pulse2_loss: 0.0797 - val_current_rise_time_pulse2_mae: 0.1413 - val_loss: 0.6718 - val_overshoot_pulse_1_loss: 0.0565 - val_overshoot_pulse_1_mae: 0.1878 - val_overshoot_pulse_2_loss: 0.0948 - val_overshoot_pulse_2_mae: 0.2487 - val_ringing_frequency_MHz_loss: 6.4328e-05 - val_ringing_frequency_MHz_mae: 0.0090 - val_undershoot_pulse_1_loss: 0.0628 - val_undershoot_pulse_1_mae: 0.1895 - val_undershoot_pulse_2_loss: 0.0632 - val_undershoot_pulse_2_mae: 0.1878 - val_voltage_fall_time_pulse1_loss: 0.0403 - val_voltage_fall_time_pulse1_mae: 0.1596 - val_voltage_fall_time_pulse2_loss: 0.0379 - val_voltage_fall_time_pulse2_mae: 0.1555 - val_voltage_rise_time_pulse1_loss: 0.0077 - val_voltage_rise_time_pulse1_mae: 0.0460 - val_voltage_rise_time_pulse2_loss: 0.0771 - val_voltage_rise_time_pulse2_mae: 0.1678 - learning_rate: 5.0000e-04
# Epoch 8/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - current_fall_time_pulse1_loss: 0.0075 - current_fall_time_pulse1_mae: 0.0654 - current_fall_time_pulse2_loss: 0.0074 - current_fall_time_pulse2_mae: 0.0645 - current_rise_time_pulse1_loss: 0.0645 - current_rise_time_pulse1_mae: 0.1505 - current_rise_time_pulse2_loss: 0.0888 - current_rise_time_pulse2_mae: 0.1620 - loss: 0.4497 - overshoot_pulse_1_loss: 0.0463 - overshoot_pulse_1_mae: 0.1642 - overshoot_pulse_2_loss: 0.0689 - overshoot_pulse_2_mae: 0.2024 - ringing_frequency_MHz_loss: 8.1066e-05 - ringing_frequency_MHz_mae: 0.0099 - undershoot_pulse_1_loss: 0.0268 - undershoot_pulse_1_mae: 0.1187 - undershoot_pulse_2_loss: 0.0264 - undershoot_pulse_2_mae: 0.1182 - voltage_fall_time_pulse1_loss: 0.0016 - voltage_fall_time_pulse1_mae: 0.0278 - voltage_fall_time_pulse2_loss: 0.0016 - voltage_fall_time_pulse2_mae: 0.0275 - voltage_rise_time_pulse1_loss: 0.0114 - voltage_rise_time_pulse1_mae: 0.0504 - voltage_rise_time_pulse2_loss: 0.0895 - voltage_rise_time_pulse2_mae: 0.1765 - val_current_fall_time_pulse1_loss: 0.0333 - val_current_fall_time_pulse1_mae: 0.1406 - val_current_fall_time_pulse2_loss: 0.0367 - val_current_fall_time_pulse2_mae: 0.1503 - val_current_rise_time_pulse1_loss: 0.0630 - val_current_rise_time_pulse1_mae: 0.1461 - val_current_rise_time_pulse2_loss: 0.0786 - val_current_rise_time_pulse2_mae: 0.1390 - val_loss: 0.6462 - val_overshoot_pulse_1_loss: 0.0574 - val_overshoot_pulse_1_mae: 0.1897 - val_overshoot_pulse_2_loss: 0.0961 - val_overshoot_pulse_2_mae: 0.2504 - val_ringing_frequency_MHz_loss: 5.7818e-05 - val_ringing_frequency_MHz_mae: 0.0085 - val_undershoot_pulse_1_loss: 0.0579 - val_undershoot_pulse_1_mae: 0.1853 - val_undershoot_pulse_2_loss: 0.0582 - val_undershoot_pulse_2_mae: 0.1813 - val_voltage_fall_time_pulse1_loss: 0.0369 - val_voltage_fall_time_pulse1_mae: 0.1556 - val_voltage_fall_time_pulse2_loss: 0.0333 - val_voltage_fall_time_pulse2_mae: 0.1494 - val_voltage_rise_time_pulse1_loss: 0.0073 - val_voltage_rise_time_pulse1_mae: 0.0429 - val_voltage_rise_time_pulse2_loss: 0.0785 - val_voltage_rise_time_pulse2_mae: 0.1688 - learning_rate: 5.0000e-04
# Epoch 9/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - current_fall_time_pulse1_loss: 0.0067 - current_fall_time_pulse1_mae: 0.0612 - current_fall_time_pulse2_loss: 0.0067 - current_fall_time_pulse2_mae: 0.0608 - current_rise_time_pulse1_loss: 0.0643 - current_rise_time_pulse1_mae: 0.1500 - current_rise_time_pulse2_loss: 0.0876 - current_rise_time_pulse2_mae: 0.1589 - loss: 0.4388 - overshoot_pulse_1_loss: 0.0447 - overshoot_pulse_1_mae: 0.1616 - overshoot_pulse_2_loss: 0.0681 - overshoot_pulse_2_mae: 0.2010 - ringing_frequency_MHz_loss: 7.6252e-05 - ringing_frequency_MHz_mae: 0.0096 - undershoot_pulse_1_loss: 0.0256 - undershoot_pulse_1_mae: 0.1159 - undershoot_pulse_2_loss: 0.0251 - undershoot_pulse_2_mae: 0.1149 - voltage_fall_time_pulse1_loss: 0.0015 - voltage_fall_time_pulse1_mae: 0.0262 - voltage_fall_time_pulse2_loss: 0.0015 - voltage_fall_time_pulse2_mae: 0.0263 - voltage_rise_time_pulse1_loss: 0.0109 - voltage_rise_time_pulse1_mae: 0.0493 - voltage_rise_time_pulse2_loss: 0.0876 - voltage_rise_time_pulse2_mae: 0.1750 - val_current_fall_time_pulse1_loss: 0.0350 - val_current_fall_time_pulse1_mae: 0.1418 - val_current_fall_time_pulse2_loss: 0.0427 - val_current_fall_time_pulse2_mae: 0.1591 - val_current_rise_time_pulse1_loss: 0.0628 - val_current_rise_time_pulse1_mae: 0.1453 - val_current_rise_time_pulse2_loss: 0.0774 - val_current_rise_time_pulse2_mae: 0.1365 - val_loss: 0.6497 - val_overshoot_pulse_1_loss: 0.0550 - val_overshoot_pulse_1_mae: 0.1859 - val_overshoot_pulse_2_loss: 0.0933 - val_overshoot_pulse_2_mae: 0.2471 - val_ringing_frequency_MHz_loss: 5.3896e-05 - val_ringing_frequency_MHz_mae: 0.0082 - val_undershoot_pulse_1_loss: 0.0556 - val_undershoot_pulse_1_mae: 0.1815 - val_undershoot_pulse_2_loss: 0.0579 - val_undershoot_pulse_2_mae: 0.1820 - val_voltage_fall_time_pulse1_loss: 0.0361 - val_voltage_fall_time_pulse1_mae: 0.1552 - val_voltage_fall_time_pulse2_loss: 0.0358 - val_voltage_fall_time_pulse2_mae: 0.1547 - val_voltage_rise_time_pulse1_loss: 0.0074 - val_voltage_rise_time_pulse1_mae: 0.0439 - val_voltage_rise_time_pulse2_loss: 0.0822 - val_voltage_rise_time_pulse2_mae: 0.1712 - learning_rate: 5.0000e-04
# Epoch 10/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - current_fall_time_pulse1_loss: 0.0060 - current_fall_time_pulse1_mae: 0.0581 - current_fall_time_pulse2_loss: 0.0061 - current_fall_time_pulse2_mae: 0.0579 - current_rise_time_pulse1_loss: 0.0639 - current_rise_time_pulse1_mae: 0.1494 - current_rise_time_pulse2_loss: 0.0863 - current_rise_time_pulse2_mae: 0.1568 - loss: 0.4322 - overshoot_pulse_1_loss: 0.0439 - overshoot_pulse_1_mae: 0.1601 - overshoot_pulse_2_loss: 0.0677 - overshoot_pulse_2_mae: 0.2004 - ringing_frequency_MHz_loss: 7.3056e-05 - ringing_frequency_MHz_mae: 0.0094 - undershoot_pulse_1_loss: 0.0245 - undershoot_pulse_1_mae: 0.1132 - undershoot_pulse_2_loss: 0.0236 - undershoot_pulse_2_mae: 0.1117 - voltage_fall_time_pulse1_loss: 0.0014 - voltage_fall_time_pulse1_mae: 0.0255 - voltage_fall_time_pulse2_loss: 0.0014 - voltage_fall_time_pulse2_mae: 0.0254 - voltage_rise_time_pulse1_loss: 0.0109 - voltage_rise_time_pulse1_mae: 0.0483 - voltage_rise_time_pulse2_loss: 0.0882 - voltage_rise_time_pulse2_mae: 0.1747 - val_current_fall_time_pulse1_loss: 0.0353 - val_current_fall_time_pulse1_mae: 0.1428 - val_current_fall_time_pulse2_loss: 0.0411 - val_current_fall_time_pulse2_mae: 0.1542 - val_current_rise_time_pulse1_loss: 0.0627 - val_current_rise_time_pulse1_mae: 0.1447 - val_current_rise_time_pulse2_loss: 0.0765 - val_current_rise_time_pulse2_mae: 0.1341 - val_loss: 0.6356 - val_overshoot_pulse_1_loss: 0.0535 - val_overshoot_pulse_1_mae: 0.1849 - val_overshoot_pulse_2_loss: 0.0952 - val_overshoot_pulse_2_mae: 0.2500 - val_ringing_frequency_MHz_loss: 5.5501e-05 - val_ringing_frequency_MHz_mae: 0.0083 - val_undershoot_pulse_1_loss: 0.0533 - val_undershoot_pulse_1_mae: 0.1770 - val_undershoot_pulse_2_loss: 0.0577 - val_undershoot_pulse_2_mae: 0.1788 - val_voltage_fall_time_pulse1_loss: 0.0360 - val_voltage_fall_time_pulse1_mae: 0.1545 - val_voltage_fall_time_pulse2_loss: 0.0345 - val_voltage_fall_time_pulse2_mae: 0.1534 - val_voltage_rise_time_pulse1_loss: 0.0063 - val_voltage_rise_time_pulse1_mae: 0.0395 - val_voltage_rise_time_pulse2_loss: 0.0757 - val_voltage_rise_time_pulse2_mae: 0.1664 - learning_rate: 5.0000e-04
# Epoch 11/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - current_fall_time_pulse1_loss: 0.0057 - current_fall_time_pulse1_mae: 0.0560 - current_fall_time_pulse2_loss: 0.0057 - current_fall_time_pulse2_mae: 0.0558 - current_rise_time_pulse1_loss: 0.0635 - current_rise_time_pulse1_mae: 0.1489 - current_rise_time_pulse2_loss: 0.0853 - current_rise_time_pulse2_mae: 0.1546 - loss: 0.4236 - overshoot_pulse_1_loss: 0.0423 - overshoot_pulse_1_mae: 0.1577 - overshoot_pulse_2_loss: 0.0672 - overshoot_pulse_2_mae: 0.1997 - ringing_frequency_MHz_loss: 6.9740e-05 - ringing_frequency_MHz_mae: 0.0092 - undershoot_pulse_1_loss: 0.0235 - undershoot_pulse_1_mae: 0.1109 - undershoot_pulse_2_loss: 0.0227 - undershoot_pulse_2_mae: 0.1097 - voltage_fall_time_pulse1_loss: 0.0013 - voltage_fall_time_pulse1_mae: 0.0245 - voltage_fall_time_pulse2_loss: 0.0012 - voltage_fall_time_pulse2_mae: 0.0245 - voltage_rise_time_pulse1_loss: 0.0107 - voltage_rise_time_pulse1_mae: 0.0474 - voltage_rise_time_pulse2_loss: 0.0863 - voltage_rise_time_pulse2_mae: 0.1734 - val_current_fall_time_pulse1_loss: 0.0374 - val_current_fall_time_pulse1_mae: 0.1459 - val_current_fall_time_pulse2_loss: 0.0410 - val_current_fall_time_pulse2_mae: 0.1528 - val_current_rise_time_pulse1_loss: 0.0624 - val_current_rise_time_pulse1_mae: 0.1433 - val_current_rise_time_pulse2_loss: 0.0755 - val_current_rise_time_pulse2_mae: 0.1334 - val_loss: 0.6488 - val_overshoot_pulse_1_loss: 0.0574 - val_overshoot_pulse_1_mae: 0.1910 - val_overshoot_pulse_2_loss: 0.0972 - val_overshoot_pulse_2_mae: 0.2525 - val_ringing_frequency_MHz_loss: 5.5641e-05 - val_ringing_frequency_MHz_mae: 0.0083 - val_undershoot_pulse_1_loss: 0.0558 - val_undershoot_pulse_1_mae: 0.1807 - val_undershoot_pulse_2_loss: 0.0616 - val_undershoot_pulse_2_mae: 0.1878 - val_voltage_fall_time_pulse1_loss: 0.0361 - val_voltage_fall_time_pulse1_mae: 0.1547 - val_voltage_fall_time_pulse2_loss: 0.0345 - val_voltage_fall_time_pulse2_mae: 0.1533 - val_voltage_rise_time_pulse1_loss: 0.0058 - val_voltage_rise_time_pulse1_mae: 0.0388 - val_voltage_rise_time_pulse2_loss: 0.0766 - val_voltage_rise_time_pulse2_mae: 0.1662 - learning_rate: 5.0000e-04
# Epoch 12/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 20s 17ms/step - current_fall_time_pulse1_loss: 0.0053 - current_fall_time_pulse1_mae: 0.0536 - current_fall_time_pulse2_loss: 0.0053 - current_fall_time_pulse2_mae: 0.0535 - current_rise_time_pulse1_loss: 0.0633 - current_rise_time_pulse1_mae: 0.1482 - current_rise_time_pulse2_loss: 0.0848 - current_rise_time_pulse2_mae: 0.1530 - loss: 0.4179 - overshoot_pulse_1_loss: 0.0415 - overshoot_pulse_1_mae: 0.1559 - overshoot_pulse_2_loss: 0.0668 - overshoot_pulse_2_mae: 0.1989 - ringing_frequency_MHz_loss: 6.7223e-05 - ringing_frequency_MHz_mae: 0.0091 - undershoot_pulse_1_loss: 0.0226 - undershoot_pulse_1_mae: 0.1088 - undershoot_pulse_2_loss: 0.0221 - undershoot_pulse_2_mae: 0.1075 - voltage_fall_time_pulse1_loss: 0.0012 - voltage_fall_time_pulse1_mae: 0.0239 - voltage_fall_time_pulse2_loss: 0.0012 - voltage_fall_time_pulse2_mae: 0.0238 - voltage_rise_time_pulse1_loss: 0.0102 - voltage_rise_time_pulse1_mae: 0.0458 - voltage_rise_time_pulse2_loss: 0.0859 - voltage_rise_time_pulse2_mae: 0.1727 - val_current_fall_time_pulse1_loss: 0.0337 - val_current_fall_time_pulse1_mae: 0.1381 - val_current_fall_time_pulse2_loss: 0.0386 - val_current_fall_time_pulse2_mae: 0.1492 - val_current_rise_time_pulse1_loss: 0.0626 - val_current_rise_time_pulse1_mae: 0.1428 - val_current_rise_time_pulse2_loss: 0.0750 - val_current_rise_time_pulse2_mae: 0.1301 - val_loss: 0.6402 - val_overshoot_pulse_1_loss: 0.0596 - val_overshoot_pulse_1_mae: 0.1941 - val_overshoot_pulse_2_loss: 0.0931 - val_overshoot_pulse_2_mae: 0.2460 - val_ringing_frequency_MHz_loss: 5.6445e-05 - val_ringing_frequency_MHz_mae: 0.0083 - val_undershoot_pulse_1_loss: 0.0561 - val_undershoot_pulse_1_mae: 0.1828 - val_undershoot_pulse_2_loss: 0.0619 - val_undershoot_pulse_2_mae: 0.1875 - val_voltage_fall_time_pulse1_loss: 0.0348 - val_voltage_fall_time_pulse1_mae: 0.1538 - val_voltage_fall_time_pulse2_loss: 0.0341 - val_voltage_fall_time_pulse2_mae: 0.1537 - val_voltage_rise_time_pulse1_loss: 0.0062 - val_voltage_rise_time_pulse1_mae: 0.0381 - val_voltage_rise_time_pulse2_loss: 0.0772 - val_voltage_rise_time_pulse2_mae: 0.1663 - learning_rate: 5.0000e-04
# Epoch 13/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - current_fall_time_pulse1_loss: 0.0051 - current_fall_time_pulse1_mae: 0.0523 - current_fall_time_pulse2_loss: 0.0051 - current_fall_time_pulse2_mae: 0.0522 - current_rise_time_pulse1_loss: 0.0631 - current_rise_time_pulse1_mae: 0.1481 - current_rise_time_pulse2_loss: 0.0844 - current_rise_time_pulse2_mae: 0.1519 - loss: 0.4137 - overshoot_pulse_1_loss: 0.0402 - overshoot_pulse_1_mae: 0.1541 - overshoot_pulse_2_loss: 0.0667 - overshoot_pulse_2_mae: 0.1987 - ringing_frequency_MHz_loss: 6.6631e-05 - ringing_frequency_MHz_mae: 0.0090 - undershoot_pulse_1_loss: 0.0222 - undershoot_pulse_1_mae: 0.1074 - undershoot_pulse_2_loss: 0.0215 - undershoot_pulse_2_mae: 0.1062 - voltage_fall_time_pulse1_loss: 0.0012 - voltage_fall_time_pulse1_mae: 0.0232 - voltage_fall_time_pulse2_loss: 0.0012 - voltage_fall_time_pulse2_mae: 0.0236 - voltage_rise_time_pulse1_loss: 0.0100 - voltage_rise_time_pulse1_mae: 0.0452 - voltage_rise_time_pulse2_loss: 0.0856 - voltage_rise_time_pulse2_mae: 0.1725 - val_current_fall_time_pulse1_loss: 0.0340 - val_current_fall_time_pulse1_mae: 0.1396 - val_current_fall_time_pulse2_loss: 0.0386 - val_current_fall_time_pulse2_mae: 0.1511 - val_current_rise_time_pulse1_loss: 0.0624 - val_current_rise_time_pulse1_mae: 0.1426 - val_current_rise_time_pulse2_loss: 0.0746 - val_current_rise_time_pulse2_mae: 0.1302 - val_loss: 0.6251 - val_overshoot_pulse_1_loss: 0.0559 - val_overshoot_pulse_1_mae: 0.1879 - val_overshoot_pulse_2_loss: 0.0937 - val_overshoot_pulse_2_mae: 0.2475 - val_ringing_frequency_MHz_loss: 5.1473e-05 - val_ringing_frequency_MHz_mae: 0.0080 - val_undershoot_pulse_1_loss: 0.0525 - val_undershoot_pulse_1_mae: 0.1763 - val_undershoot_pulse_2_loss: 0.0568 - val_undershoot_pulse_2_mae: 0.1801 - val_voltage_fall_time_pulse1_loss: 0.0347 - val_voltage_fall_time_pulse1_mae: 0.1539 - val_voltage_fall_time_pulse2_loss: 0.0336 - val_voltage_fall_time_pulse2_mae: 0.1523 - val_voltage_rise_time_pulse1_loss: 0.0059 - val_voltage_rise_time_pulse1_mae: 0.0359 - val_voltage_rise_time_pulse2_loss: 0.0753 - val_voltage_rise_time_pulse2_mae: 0.1646 - learning_rate: 5.0000e-04
# Epoch 14/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - current_fall_time_pulse1_loss: 0.0048 - current_fall_time_pulse1_mae: 0.0506 - current_fall_time_pulse2_loss: 0.0048 - current_fall_time_pulse2_mae: 0.0505 - current_rise_time_pulse1_loss: 0.0632 - current_rise_time_pulse1_mae: 0.1479 - current_rise_time_pulse2_loss: 0.0834 - current_rise_time_pulse2_mae: 0.1498 - loss: 0.4104 - overshoot_pulse_1_loss: 0.0395 - overshoot_pulse_1_mae: 0.1526 - overshoot_pulse_2_loss: 0.0664 - overshoot_pulse_2_mae: 0.1983 - ringing_frequency_MHz_loss: 6.4249e-05 - ringing_frequency_MHz_mae: 0.0089 - undershoot_pulse_1_loss: 0.0218 - undershoot_pulse_1_mae: 0.1063 - undershoot_pulse_2_loss: 0.0210 - undershoot_pulse_2_mae: 0.1049 - voltage_fall_time_pulse1_loss: 0.0011 - voltage_fall_time_pulse1_mae: 0.0225 - voltage_fall_time_pulse2_loss: 0.0011 - voltage_fall_time_pulse2_mae: 0.0231 - voltage_rise_time_pulse1_loss: 0.0100 - voltage_rise_time_pulse1_mae: 0.0448 - voltage_rise_time_pulse2_loss: 0.0861 - voltage_rise_time_pulse2_mae: 0.1721 - val_current_fall_time_pulse1_loss: 0.0375 - val_current_fall_time_pulse1_mae: 0.1436 - val_current_fall_time_pulse2_loss: 0.0422 - val_current_fall_time_pulse2_mae: 0.1552 - val_current_rise_time_pulse1_loss: 0.0622 - val_current_rise_time_pulse1_mae: 0.1424 - val_current_rise_time_pulse2_loss: 0.0745 - val_current_rise_time_pulse2_mae: 0.1279 - val_loss: 0.6480 - val_overshoot_pulse_1_loss: 0.0585 - val_overshoot_pulse_1_mae: 0.1927 - val_overshoot_pulse_2_loss: 0.0940 - val_overshoot_pulse_2_mae: 0.2479 - val_ringing_frequency_MHz_loss: 5.1469e-05 - val_ringing_frequency_MHz_mae: 0.0080 - val_undershoot_pulse_1_loss: 0.0566 - val_undershoot_pulse_1_mae: 0.1825 - val_undershoot_pulse_2_loss: 0.0607 - val_undershoot_pulse_2_mae: 0.1858 - val_voltage_fall_time_pulse1_loss: 0.0380 - val_voltage_fall_time_pulse1_mae: 0.1590 - val_voltage_fall_time_pulse2_loss: 0.0352 - val_voltage_fall_time_pulse2_mae: 0.1546 - val_voltage_rise_time_pulse1_loss: 0.0065 - val_voltage_rise_time_pulse1_mae: 0.0408 - val_voltage_rise_time_pulse2_loss: 0.0753 - val_voltage_rise_time_pulse2_mae: 0.1651 - learning_rate: 5.0000e-04
# Epoch 15/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - current_fall_time_pulse1_loss: 0.0046 - current_fall_time_pulse1_mae: 0.0496 - current_fall_time_pulse2_loss: 0.0046 - current_fall_time_pulse2_mae: 0.0496 - current_rise_time_pulse1_loss: 0.0629 - current_rise_time_pulse1_mae: 0.1475 - current_rise_time_pulse2_loss: 0.0826 - current_rise_time_pulse2_mae: 0.1483 - loss: 0.4055 - overshoot_pulse_1_loss: 0.0391 - overshoot_pulse_1_mae: 0.1517 - overshoot_pulse_2_loss: 0.0662 - overshoot_pulse_2_mae: 0.1977 - ringing_frequency_MHz_loss: 6.3426e-05 - ringing_frequency_MHz_mae: 0.0088 - undershoot_pulse_1_loss: 0.0210 - undershoot_pulse_1_mae: 0.1046 - undershoot_pulse_2_loss: 0.0204 - undershoot_pulse_2_mae: 0.1036 - voltage_fall_time_pulse1_loss: 0.0011 - voltage_fall_time_pulse1_mae: 0.0226 - voltage_fall_time_pulse2_loss: 0.0011 - voltage_fall_time_pulse2_mae: 0.0228 - voltage_rise_time_pulse1_loss: 0.0097 - voltage_rise_time_pulse1_mae: 0.0442 - voltage_rise_time_pulse2_loss: 0.0850 - voltage_rise_time_pulse2_mae: 0.1718 - val_current_fall_time_pulse1_loss: 0.0350 - val_current_fall_time_pulse1_mae: 0.1401 - val_current_fall_time_pulse2_loss: 0.0393 - val_current_fall_time_pulse2_mae: 0.1500 - val_current_rise_time_pulse1_loss: 0.0623 - val_current_rise_time_pulse1_mae: 0.1422 - val_current_rise_time_pulse2_loss: 0.0734 - val_current_rise_time_pulse2_mae: 0.1285 - val_loss: 0.6352 - val_overshoot_pulse_1_loss: 0.0614 - val_overshoot_pulse_1_mae: 0.1982 - val_overshoot_pulse_2_loss: 0.0928 - val_overshoot_pulse_2_mae: 0.2463 - val_ringing_frequency_MHz_loss: 4.5817e-05 - val_ringing_frequency_MHz_mae: 0.0075 - val_undershoot_pulse_1_loss: 0.0545 - val_undershoot_pulse_1_mae: 0.1793 - val_undershoot_pulse_2_loss: 0.0596 - val_undershoot_pulse_2_mae: 0.1840 - val_voltage_fall_time_pulse1_loss: 0.0350 - val_voltage_fall_time_pulse1_mae: 0.1546 - val_voltage_fall_time_pulse2_loss: 0.0345 - val_voltage_fall_time_pulse2_mae: 0.1534 - val_voltage_rise_time_pulse1_loss: 0.0056 - val_voltage_rise_time_pulse1_mae: 0.0362 - val_voltage_rise_time_pulse2_loss: 0.0750 - val_voltage_rise_time_pulse2_mae: 0.1649 - learning_rate: 5.0000e-04
# Epoch 16/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - current_fall_time_pulse1_loss: 0.0043 - current_fall_time_pulse1_mae: 0.0479 - current_fall_time_pulse2_loss: 0.0044 - current_fall_time_pulse2_mae: 0.0484 - current_rise_time_pulse1_loss: 0.0628 - current_rise_time_pulse1_mae: 0.1472 - current_rise_time_pulse2_loss: 0.0825 - current_rise_time_pulse2_mae: 0.1477 - loss: 0.4038 - overshoot_pulse_1_loss: 0.0386 - overshoot_pulse_1_mae: 0.1505 - overshoot_pulse_2_loss: 0.0658 - overshoot_pulse_2_mae: 0.1972 - ringing_frequency_MHz_loss: 6.2782e-05 - ringing_frequency_MHz_mae: 0.0088 - undershoot_pulse_1_loss: 0.0207 - undershoot_pulse_1_mae: 0.1038 - undershoot_pulse_2_loss: 0.0201 - undershoot_pulse_2_mae: 0.1027 - voltage_fall_time_pulse1_loss: 0.0010 - voltage_fall_time_pulse1_mae: 0.0220 - voltage_fall_time_pulse2_loss: 0.0010 - voltage_fall_time_pulse2_mae: 0.0223 - voltage_rise_time_pulse1_loss: 0.0096 - voltage_rise_time_pulse1_mae: 0.0434 - voltage_rise_time_pulse2_loss: 0.0859 - voltage_rise_time_pulse2_mae: 0.1715 - val_current_fall_time_pulse1_loss: 0.0322 - val_current_fall_time_pulse1_mae: 0.1331 - val_current_fall_time_pulse2_loss: 0.0422 - val_current_fall_time_pulse2_mae: 0.1556 - val_current_rise_time_pulse1_loss: 0.0624 - val_current_rise_time_pulse1_mae: 0.1427 - val_current_rise_time_pulse2_loss: 0.0734 - val_current_rise_time_pulse2_mae: 0.1284 - val_loss: 0.6384 - val_overshoot_pulse_1_loss: 0.0619 - val_overshoot_pulse_1_mae: 0.1974 - val_overshoot_pulse_2_loss: 0.0923 - val_overshoot_pulse_2_mae: 0.2454 - val_ringing_frequency_MHz_loss: 4.4444e-05 - val_ringing_frequency_MHz_mae: 0.0075 - val_undershoot_pulse_1_loss: 0.0581 - val_undershoot_pulse_1_mae: 0.1862 - val_undershoot_pulse_2_loss: 0.0596 - val_undershoot_pulse_2_mae: 0.1845 - val_voltage_fall_time_pulse1_loss: 0.0353 - val_voltage_fall_time_pulse1_mae: 0.1546 - val_voltage_fall_time_pulse2_loss: 0.0349 - val_voltage_fall_time_pulse2_mae: 0.1541 - val_voltage_rise_time_pulse1_loss: 0.0058 - val_voltage_rise_time_pulse1_mae: 0.0367 - val_voltage_rise_time_pulse2_loss: 0.0736 - val_voltage_rise_time_pulse2_mae: 0.1627 - learning_rate: 5.0000e-04
# Epoch 17/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - current_fall_time_pulse1_loss: 0.0042 - current_fall_time_pulse1_mae: 0.0471 - current_fall_time_pulse2_loss: 0.0043 - current_fall_time_pulse2_mae: 0.0475 - current_rise_time_pulse1_loss: 0.0629 - current_rise_time_pulse1_mae: 0.1472 - current_rise_time_pulse2_loss: 0.0823 - current_rise_time_pulse2_mae: 0.1465 - loss: 0.4008 - overshoot_pulse_1_loss: 0.0380 - overshoot_pulse_1_mae: 0.1499 - overshoot_pulse_2_loss: 0.0660 - overshoot_pulse_2_mae: 0.1972 - ringing_frequency_MHz_loss: 6.1691e-05 - ringing_frequency_MHz_mae: 0.0087 - undershoot_pulse_1_loss: 0.0206 - undershoot_pulse_1_mae: 0.1033 - undershoot_pulse_2_loss: 0.0201 - undershoot_pulse_2_mae: 0.1020 - voltage_fall_time_pulse1_loss: 9.8634e-04 - voltage_fall_time_pulse1_mae: 0.0217 - voltage_fall_time_pulse2_loss: 0.0010 - voltage_fall_time_pulse2_mae: 0.0223 - voltage_rise_time_pulse1_loss: 0.0095 - voltage_rise_time_pulse1_mae: 0.0432 - voltage_rise_time_pulse2_loss: 0.0842 - voltage_rise_time_pulse2_mae: 0.1706 - val_current_fall_time_pulse1_loss: 0.0358 - val_current_fall_time_pulse1_mae: 0.1393 - val_current_fall_time_pulse2_loss: 0.0397 - val_current_fall_time_pulse2_mae: 0.1508 - val_current_rise_time_pulse1_loss: 0.0622 - val_current_rise_time_pulse1_mae: 0.1418 - val_current_rise_time_pulse2_loss: 0.0732 - val_current_rise_time_pulse2_mae: 0.1255 - val_loss: 0.6302 - val_overshoot_pulse_1_loss: 0.0575 - val_overshoot_pulse_1_mae: 0.1917 - val_overshoot_pulse_2_loss: 0.0928 - val_overshoot_pulse_2_mae: 0.2463 - val_ringing_frequency_MHz_loss: 4.5689e-05 - val_ringing_frequency_MHz_mae: 0.0076 - val_undershoot_pulse_1_loss: 0.0546 - val_undershoot_pulse_1_mae: 0.1819 - val_undershoot_pulse_2_loss: 0.0591 - val_undershoot_pulse_2_mae: 0.1843 - val_voltage_fall_time_pulse1_loss: 0.0343 - val_voltage_fall_time_pulse1_mae: 0.1522 - val_voltage_fall_time_pulse2_loss: 0.0354 - val_voltage_fall_time_pulse2_mae: 0.1549 - val_voltage_rise_time_pulse1_loss: 0.0057 - val_voltage_rise_time_pulse1_mae: 0.0359 - val_voltage_rise_time_pulse2_loss: 0.0735 - val_voltage_rise_time_pulse2_mae: 0.1631 - learning_rate: 5.0000e-04
# Epoch 18/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - current_fall_time_pulse1_loss: 0.0041 - current_fall_time_pulse1_mae: 0.0465 - current_fall_time_pulse2_loss: 0.0041 - current_fall_time_pulse2_mae: 0.0468 - current_rise_time_pulse1_loss: 0.0627 - current_rise_time_pulse1_mae: 0.1468 - current_rise_time_pulse2_loss: 0.0817 - current_rise_time_pulse2_mae: 0.1452 - loss: 0.3967 - overshoot_pulse_1_loss: 0.0373 - overshoot_pulse_1_mae: 0.1484 - overshoot_pulse_2_loss: 0.0657 - overshoot_pulse_2_mae: 0.1971 - ringing_frequency_MHz_loss: 6.0355e-05 - ringing_frequency_MHz_mae: 0.0086 - undershoot_pulse_1_loss: 0.0202 - undershoot_pulse_1_mae: 0.1023 - undershoot_pulse_2_loss: 0.0196 - undershoot_pulse_2_mae: 0.1011 - voltage_fall_time_pulse1_loss: 9.8029e-04 - voltage_fall_time_pulse1_mae: 0.0216 - voltage_fall_time_pulse2_loss: 9.9989e-04 - voltage_fall_time_pulse2_mae: 0.0219 - voltage_rise_time_pulse1_loss: 0.0092 - voltage_rise_time_pulse1_mae: 0.0423 - voltage_rise_time_pulse2_loss: 0.0833 - voltage_rise_time_pulse2_mae: 0.1705 - val_current_fall_time_pulse1_loss: 0.0325 - val_current_fall_time_pulse1_mae: 0.1337 - val_current_fall_time_pulse2_loss: 0.0369 - val_current_fall_time_pulse2_mae: 0.1467 - val_current_rise_time_pulse1_loss: 0.0624 - val_current_rise_time_pulse1_mae: 0.1417 - val_current_rise_time_pulse2_loss: 0.0727 - val_current_rise_time_pulse2_mae: 0.1245 - val_loss: 0.6301 - val_overshoot_pulse_1_loss: 0.0608 - val_overshoot_pulse_1_mae: 0.1972 - val_overshoot_pulse_2_loss: 0.0915 - val_overshoot_pulse_2_mae: 0.2443 - val_ringing_frequency_MHz_loss: 4.6100e-05 - val_ringing_frequency_MHz_mae: 0.0077 - val_undershoot_pulse_1_loss: 0.0599 - val_undershoot_pulse_1_mae: 0.1888 - val_undershoot_pulse_2_loss: 0.0607 - val_undershoot_pulse_2_mae: 0.1881 - val_voltage_fall_time_pulse1_loss: 0.0329 - val_voltage_fall_time_pulse1_mae: 0.1496 - val_voltage_fall_time_pulse2_loss: 0.0341 - val_voltage_fall_time_pulse2_mae: 0.1527 - val_voltage_rise_time_pulse1_loss: 0.0057 - val_voltage_rise_time_pulse1_mae: 0.0341 - val_voltage_rise_time_pulse2_loss: 0.0734 - val_voltage_rise_time_pulse2_mae: 0.1641 - learning_rate: 5.0000e-04
# Epoch 19/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - current_fall_time_pulse1_loss: 0.0039 - current_fall_time_pulse1_mae: 0.0450 - current_fall_time_pulse2_loss: 0.0039 - current_fall_time_pulse2_mae: 0.0452 - current_rise_time_pulse1_loss: 0.0626 - current_rise_time_pulse1_mae: 0.1465 - current_rise_time_pulse2_loss: 0.0811 - current_rise_time_pulse2_mae: 0.1442 - loss: 0.3955 - overshoot_pulse_1_loss: 0.0371 - overshoot_pulse_1_mae: 0.1480 - overshoot_pulse_2_loss: 0.0655 - overshoot_pulse_2_mae: 0.1966 - ringing_frequency_MHz_loss: 5.9798e-05 - ringing_frequency_MHz_mae: 0.0086 - undershoot_pulse_1_loss: 0.0198 - undershoot_pulse_1_mae: 0.1013 - undershoot_pulse_2_loss: 0.0192 - undershoot_pulse_2_mae: 0.1002 - voltage_fall_time_pulse1_loss: 9.5766e-04 - voltage_fall_time_pulse1_mae: 0.0213 - voltage_fall_time_pulse2_loss: 9.4706e-04 - voltage_fall_time_pulse2_mae: 0.0213 - voltage_rise_time_pulse1_loss: 0.0091 - voltage_rise_time_pulse1_mae: 0.0418 - voltage_rise_time_pulse2_loss: 0.0848 - voltage_rise_time_pulse2_mae: 0.1707 - val_current_fall_time_pulse1_loss: 0.0308 - val_current_fall_time_pulse1_mae: 0.1304 - val_current_fall_time_pulse2_loss: 0.0372 - val_current_fall_time_pulse2_mae: 0.1463 - val_current_rise_time_pulse1_loss: 0.0623 - val_current_rise_time_pulse1_mae: 0.1417 - val_current_rise_time_pulse2_loss: 0.0727 - val_current_rise_time_pulse2_mae: 0.1254 - val_loss: 0.6112 - val_overshoot_pulse_1_loss: 0.0590 - val_overshoot_pulse_1_mae: 0.1926 - val_overshoot_pulse_2_loss: 0.0904 - val_overshoot_pulse_2_mae: 0.2425 - val_ringing_frequency_MHz_loss: 4.4590e-05 - val_ringing_frequency_MHz_mae: 0.0074 - val_undershoot_pulse_1_loss: 0.0530 - val_undershoot_pulse_1_mae: 0.1803 - val_undershoot_pulse_2_loss: 0.0533 - val_undershoot_pulse_2_mae: 0.1765 - val_voltage_fall_time_pulse1_loss: 0.0324 - val_voltage_fall_time_pulse1_mae: 0.1498 - val_voltage_fall_time_pulse2_loss: 0.0321 - val_voltage_fall_time_pulse2_mae: 0.1491 - val_voltage_rise_time_pulse1_loss: 0.0062 - val_voltage_rise_time_pulse1_mae: 0.0370 - val_voltage_rise_time_pulse2_loss: 0.0755 - val_voltage_rise_time_pulse2_mae: 0.1642 - learning_rate: 5.0000e-04
# Epoch 20/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - current_fall_time_pulse1_loss: 0.0038 - current_fall_time_pulse1_mae: 0.0443 - current_fall_time_pulse2_loss: 0.0038 - current_fall_time_pulse2_mae: 0.0447 - current_rise_time_pulse1_loss: 0.0624 - current_rise_time_pulse1_mae: 0.1462 - current_rise_time_pulse2_loss: 0.0809 - current_rise_time_pulse2_mae: 0.1434 - loss: 0.3924 - overshoot_pulse_1_loss: 0.0368 - overshoot_pulse_1_mae: 0.1474 - overshoot_pulse_2_loss: 0.0653 - overshoot_pulse_2_mae: 0.1963 - ringing_frequency_MHz_loss: 5.9020e-05 - ringing_frequency_MHz_mae: 0.0085 - undershoot_pulse_1_loss: 0.0199 - undershoot_pulse_1_mae: 0.1010 - undershoot_pulse_2_loss: 0.0190 - undershoot_pulse_2_mae: 0.0996 - voltage_fall_time_pulse1_loss: 9.4647e-04 - voltage_fall_time_pulse1_mae: 0.0211 - voltage_fall_time_pulse2_loss: 9.2495e-04 - voltage_fall_time_pulse2_mae: 0.0210 - voltage_rise_time_pulse1_loss: 0.0089 - voltage_rise_time_pulse1_mae: 0.0416 - voltage_rise_time_pulse2_loss: 0.0832 - voltage_rise_time_pulse2_mae: 0.1696 - val_current_fall_time_pulse1_loss: 0.0317 - val_current_fall_time_pulse1_mae: 0.1321 - val_current_fall_time_pulse2_loss: 0.0373 - val_current_fall_time_pulse2_mae: 0.1465 - val_current_rise_time_pulse1_loss: 0.0621 - val_current_rise_time_pulse1_mae: 0.1407 - val_current_rise_time_pulse2_loss: 0.0721 - val_current_rise_time_pulse2_mae: 0.1240 - val_loss: 0.6231 - val_overshoot_pulse_1_loss: 0.0610 - val_overshoot_pulse_1_mae: 0.1985 - val_overshoot_pulse_2_loss: 0.0940 - val_overshoot_pulse_2_mae: 0.2479 - val_ringing_frequency_MHz_loss: 4.5269e-05 - val_ringing_frequency_MHz_mae: 0.0075 - val_undershoot_pulse_1_loss: 0.0568 - val_undershoot_pulse_1_mae: 0.1862 - val_undershoot_pulse_2_loss: 0.0564 - val_undershoot_pulse_2_mae: 0.1816 - val_voltage_fall_time_pulse1_loss: 0.0325 - val_voltage_fall_time_pulse1_mae: 0.1494 - val_voltage_fall_time_pulse2_loss: 0.0334 - val_voltage_fall_time_pulse2_mae: 0.1524 - val_voltage_rise_time_pulse1_loss: 0.0052 - val_voltage_rise_time_pulse1_mae: 0.0352 - val_voltage_rise_time_pulse2_loss: 0.0744 - val_voltage_rise_time_pulse2_mae: 0.1642 - learning_rate: 5.0000e-04
# Epoch 21/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - current_fall_time_pulse1_loss: 0.0037 - current_fall_time_pulse1_mae: 0.0435 - current_fall_time_pulse2_loss: 0.0037 - current_fall_time_pulse2_mae: 0.0438 - current_rise_time_pulse1_loss: 0.0623 - current_rise_time_pulse1_mae: 0.1459 - current_rise_time_pulse2_loss: 0.0807 - current_rise_time_pulse2_mae: 0.1426 - loss: 0.3895 - overshoot_pulse_1_loss: 0.0361 - overshoot_pulse_1_mae: 0.1462 - overshoot_pulse_2_loss: 0.0653 - overshoot_pulse_2_mae: 0.1961 - ringing_frequency_MHz_loss: 5.9052e-05 - ringing_frequency_MHz_mae: 0.0085 - undershoot_pulse_1_loss: 0.0195 - undershoot_pulse_1_mae: 0.1002 - undershoot_pulse_2_loss: 0.0187 - undershoot_pulse_2_mae: 0.0986 - voltage_fall_time_pulse1_loss: 9.4145e-04 - voltage_fall_time_pulse1_mae: 0.0211 - voltage_fall_time_pulse2_loss: 9.1210e-04 - voltage_fall_time_pulse2_mae: 0.0208 - voltage_rise_time_pulse1_loss: 0.0089 - voltage_rise_time_pulse1_mae: 0.0412 - voltage_rise_time_pulse2_loss: 0.0823 - voltage_rise_time_pulse2_mae: 0.1692 - val_current_fall_time_pulse1_loss: 0.0331 - val_current_fall_time_pulse1_mae: 0.1349 - val_current_fall_time_pulse2_loss: 0.0402 - val_current_fall_time_pulse2_mae: 0.1517 - val_current_rise_time_pulse1_loss: 0.0624 - val_current_rise_time_pulse1_mae: 0.1419 - val_current_rise_time_pulse2_loss: 0.0724 - val_current_rise_time_pulse2_mae: 0.1231 - val_loss: 0.6271 - val_overshoot_pulse_1_loss: 0.0605 - val_overshoot_pulse_1_mae: 0.1968 - val_overshoot_pulse_2_loss: 0.0898 - val_overshoot_pulse_2_mae: 0.2420 - val_ringing_frequency_MHz_loss: 4.4520e-05 - val_ringing_frequency_MHz_mae: 0.0074 - val_undershoot_pulse_1_loss: 0.0576 - val_undershoot_pulse_1_mae: 0.1878 - val_undershoot_pulse_2_loss: 0.0569 - val_undershoot_pulse_2_mae: 0.1830 - val_voltage_fall_time_pulse1_loss: 0.0326 - val_voltage_fall_time_pulse1_mae: 0.1497 - val_voltage_fall_time_pulse2_loss: 0.0334 - val_voltage_fall_time_pulse2_mae: 0.1511 - val_voltage_rise_time_pulse1_loss: 0.0057 - val_voltage_rise_time_pulse1_mae: 0.0373 - val_voltage_rise_time_pulse2_loss: 0.0762 - val_voltage_rise_time_pulse2_mae: 0.1655 - learning_rate: 5.0000e-04
# Epoch 22/90
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - current_fall_time_pulse1_loss: 0.0036 - current_fall_time_pulse1_mae: 0.0430 - current_fall_time_pulse2_loss: 0.0036 - current_fall_time_pulse2_mae: 0.0430 - current_rise_time_pulse1_loss: 0.0623 - current_rise_time_pulse1_mae: 0.1460 - current_rise_time_pulse2_loss: 0.0800 - current_rise_time_pulse2_mae: 0.1418 - loss: 0.3890 - overshoot_pulse_1_loss: 0.0361 - overshoot_pulse_1_mae: 0.1459 - overshoot_pulse_2_loss: 0.0652 - overshoot_pulse_2_mae: 0.1960 - ringing_frequency_MHz_loss: 5.8806e-05 - ringing_frequency_MHz_mae: 0.0085 - undershoot_pulse_1_loss: 0.0192 - undershoot_pulse_1_mae: 0.0995 - undershoot_pulse_2_loss: 0.0185 - undershoot_pulse_2_mae: 0.0980 - voltage_fall_time_pulse1_loss: 9.0841e-04 - voltage_fall_time_pulse1_mae: 0.0208 - voltage_fall_time_pulse2_loss: 9.1810e-04 - voltage_fall_time_pulse2_mae: 0.0209 - voltage_rise_time_pulse1_loss: 0.0089 - voltage_rise_time_pulse1_mae: 0.0407 - voltage_rise_time_pulse2_loss: 0.0834 - voltage_rise_time_pulse2_mae: 0.1693 - val_current_fall_time_pulse1_loss: 0.0332 - val_current_fall_time_pulse1_mae: 0.1341 - val_current_fall_time_pulse2_loss: 0.0396 - val_current_fall_time_pulse2_mae: 0.1502 - val_current_rise_time_pulse1_loss: 0.0620 - val_current_rise_time_pulse1_mae: 0.1414 - val_current_rise_time_pulse2_loss: 0.0724 - val_current_rise_time_pulse2_mae: 0.1223 - val_loss: 0.6258 - val_overshoot_pulse_1_loss: 0.0609 - val_overshoot_pulse_1_mae: 0.1974 - val_overshoot_pulse_2_loss: 0.0911 - val_overshoot_pulse_2_mae: 0.2439 - val_ringing_frequency_MHz_loss: 4.4527e-05 - val_ringing_frequency_MHz_mae: 0.0074 - val_undershoot_pulse_1_loss: 0.0589 - val_undershoot_pulse_1_mae: 0.1899 - val_undershoot_pulse_2_loss: 0.0585 - val_undershoot_pulse_2_mae: 0.1851 - val_voltage_fall_time_pulse1_loss: 0.0299 - val_voltage_fall_time_pulse1_mae: 0.1451 - val_voltage_fall_time_pulse2_loss: 0.0330 - val_voltage_fall_time_pulse2_mae: 0.1502 - val_voltage_rise_time_pulse1_loss: 0.0055 - val_voltage_rise_time_pulse1_mae: 0.0330 - val_voltage_rise_time_pulse2_loss: 0.0746 - val_voltage_rise_time_pulse2_mae: 0.1630 - learning_rate: 5.0000e-04
# Epoch 23/90
# ...
# Epoch 39/120
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 170s 148ms/step - current_fall_time_pulse1_loss: 0.0015 - current_fall_time_pulse1_mae: 0.0267 - current_fall_time_pulse2_loss: 0.0015 - current_fall_time_pulse2_mae: 0.0257 - current_rise_time_pulse1_loss: 0.0601 - current_rise_time_pulse1_mae: 0.1410 - current_rise_time_pulse2_loss: 0.0727 - current_rise_time_pulse2_mae: 0.1204 - loss: 0.4704 - overshoot_pulse_1_loss: 0.0289 - overshoot_pulse_1_mae: 0.1310 - overshoot_pulse_2_loss: 0.0621 - overshoot_pulse_2_mae: 0.1905 - ringing_frequency_MHz_loss: 4.4425e-05 - ringing_frequency_MHz_mae: 0.0074 - undershoot_pulse_1_loss: 0.0146 - undershoot_pulse_1_mae: 0.0850 - undershoot_pulse_2_loss: 0.0143 - undershoot_pulse_2_mae: 0.0852 - voltage_fall_time_pulse1_loss: 5.1071e-04 - voltage_fall_time_pulse1_mae: 0.0150 - voltage_fall_time_pulse2_loss: 4.7383e-04 - voltage_fall_time_pulse2_mae: 0.0144 - voltage_rise_time_pulse1_loss: 0.0058 - voltage_rise_time_pulse1_mae: 0.0297 - voltage_rise_time_pulse2_loss: 0.0749 - voltage_rise_time_pulse2_mae: 0.1613 - val_current_fall_time_pulse1_loss: 0.0275 - val_current_fall_time_pulse1_mae: 0.1271 - val_current_fall_time_pulse2_loss: 0.0296 - val_current_fall_time_pulse2_mae: 0.1317 - val_current_rise_time_pulse1_loss: 0.0601 - val_current_rise_time_pulse1_mae: 0.1424 - val_current_rise_time_pulse2_loss: 0.0680 - val_current_rise_time_pulse2_mae: 0.1093 - val_loss: 0.6974 - val_overshoot_pulse_1_loss: 0.0619 - val_overshoot_pulse_1_mae: 0.2008 - val_overshoot_pulse_2_loss: 0.0900 - val_overshoot_pulse_2_mae: 0.2420 - val_ringing_frequency_MHz_loss: 4.1232e-05 - val_ringing_frequency_MHz_mae: 0.0072 - val_undershoot_pulse_1_loss: 0.0464 - val_undershoot_pulse_1_mae: 0.1722 - val_undershoot_pulse_2_loss: 0.0506 - val_undershoot_pulse_2_mae: 0.1752 - val_voltage_fall_time_pulse1_loss: 0.0314 - val_voltage_fall_time_pulse1_mae: 0.1507 - val_voltage_fall_time_pulse2_loss: 0.0305 - val_voltage_fall_time_pulse2_mae: 0.1505 - val_voltage_rise_time_pulse1_loss: 0.0051 - val_voltage_rise_time_pulse1_mae: 0.0293 - val_voltage_rise_time_pulse2_loss: 0.0701 - val_voltage_rise_time_pulse2_mae: 0.1577 - learning_rate: 3.7500e-05
# Epoch 40/120
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 174s 152ms/step - current_fall_time_pulse1_loss: 0.0015 - current_fall_time_pulse1_mae: 0.0267 - current_fall_time_pulse2_loss: 0.0015 - current_fall_time_pulse2_mae: 0.0257 - current_rise_time_pulse1_loss: 0.0602 - current_rise_time_pulse1_mae: 0.1411 - current_rise_time_pulse2_loss: 0.0727 - current_rise_time_pulse2_mae: 0.1204 - loss: 0.4696 - overshoot_pulse_1_loss: 0.0288 - overshoot_pulse_1_mae: 0.1311 - overshoot_pulse_2_loss: 0.0620 - overshoot_pulse_2_mae: 0.1903 - ringing_frequency_MHz_loss: 4.4460e-05 - ringing_frequency_MHz_mae: 0.0074 - undershoot_pulse_1_loss: 0.0145 - undershoot_pulse_1_mae: 0.0849 - undershoot_pulse_2_loss: 0.0144 - undershoot_pulse_2_mae: 0.0854 - voltage_fall_time_pulse1_loss: 5.0710e-04 - voltage_fall_time_pulse1_mae: 0.0150 - voltage_fall_time_pulse2_loss: 4.7106e-04 - voltage_fall_time_pulse2_mae: 0.0144 - voltage_rise_time_pulse1_loss: 0.0057 - voltage_rise_time_pulse1_mae: 0.0295 - voltage_rise_time_pulse2_loss: 0.0744 - voltage_rise_time_pulse2_mae: 0.1614 - val_current_fall_time_pulse1_loss: 0.0277 - val_current_fall_time_pulse1_mae: 0.1273 - val_current_fall_time_pulse2_loss: 0.0294 - val_current_fall_time_pulse2_mae: 0.1313 - val_current_rise_time_pulse1_loss: 0.0601 - val_current_rise_time_pulse1_mae: 0.1423 - val_current_rise_time_pulse2_loss: 0.0681 - val_current_rise_time_pulse2_mae: 0.1095 - val_loss: 0.6987 - val_overshoot_pulse_1_loss: 0.0623 - val_overshoot_pulse_1_mae: 0.2015 - val_overshoot_pulse_2_loss: 0.0906 - val_overshoot_pulse_2_mae: 0.2429 - val_ringing_frequency_MHz_loss: 4.0813e-05 - val_ringing_frequency_MHz_mae: 0.0072 - val_undershoot_pulse_1_loss: 0.0458 - val_undershoot_pulse_1_mae: 0.1711 - val_undershoot_pulse_2_loss: 0.0501 - val_undershoot_pulse_2_mae: 0.1746 - val_voltage_fall_time_pulse1_loss: 0.0315 - val_voltage_fall_time_pulse1_mae: 0.1509 - val_voltage_fall_time_pulse2_loss: 0.0310 - val_voltage_fall_time_pulse2_mae: 0.1516 - val_voltage_rise_time_pulse1_loss: 0.0052 - val_voltage_rise_time_pulse1_mae: 0.0291 - val_voltage_rise_time_pulse2_loss: 0.0705 - val_voltage_rise_time_pulse2_mae: 0.1576 - learning_rate: 3.7500e-05
# Epoch 41/120
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 186s 162ms/step - current_fall_time_pulse1_loss: 0.0015 - current_fall_time_pulse1_mae: 0.0266 - current_fall_time_pulse2_loss: 0.0015 - current_fall_time_pulse2_mae: 0.0256 - current_rise_time_pulse1_loss: 0.0602 - current_rise_time_pulse1_mae: 0.1412 - current_rise_time_pulse2_loss: 0.0724 - current_rise_time_pulse2_mae: 0.1197 - loss: 0.4696 - overshoot_pulse_1_loss: 0.0289 - overshoot_pulse_1_mae: 0.1313 - overshoot_pulse_2_loss: 0.0620 - overshoot_pulse_2_mae: 0.1905 - ringing_frequency_MHz_loss: 4.4211e-05 - ringing_frequency_MHz_mae: 0.0074 - undershoot_pulse_1_loss: 0.0146 - undershoot_pulse_1_mae: 0.0850 - undershoot_pulse_2_loss: 0.0145 - undershoot_pulse_2_mae: 0.0854 - voltage_fall_time_pulse1_loss: 5.0324e-04 - voltage_fall_time_pulse1_mae: 0.0150 - voltage_fall_time_pulse2_loss: 4.7615e-04 - voltage_fall_time_pulse2_mae: 0.0144 - voltage_rise_time_pulse1_loss: 0.0059 - voltage_rise_time_pulse1_mae: 0.0297 - voltage_rise_time_pulse2_loss: 0.0744 - voltage_rise_time_pulse2_mae: 0.1613 - val_current_fall_time_pulse1_loss: 0.0272 - val_current_fall_time_pulse1_mae: 0.1262 - val_current_fall_time_pulse2_loss: 0.0288 - val_current_fall_time_pulse2_mae: 0.1301 - val_current_rise_time_pulse1_loss: 0.0601 - val_current_rise_time_pulse1_mae: 0.1422 - val_current_rise_time_pulse2_loss: 0.0680 - val_current_rise_time_pulse2_mae: 0.1094 - val_loss: 0.6948 - val_overshoot_pulse_1_loss: 0.0616 - val_overshoot_pulse_1_mae: 0.2002 - val_overshoot_pulse_2_loss: 0.0898 - val_overshoot_pulse_2_mae: 0.2420 - val_ringing_frequency_MHz_loss: 4.0764e-05 - val_ringing_frequency_MHz_mae: 0.0071 - val_undershoot_pulse_1_loss: 0.0456 - val_undershoot_pulse_1_mae: 0.1707 - val_undershoot_pulse_2_loss: 0.0505 - val_undershoot_pulse_2_mae: 0.1754 - val_voltage_fall_time_pulse1_loss: 0.0313 - val_voltage_fall_time_pulse1_mae: 0.1505 - val_voltage_fall_time_pulse2_loss: 0.0306 - val_voltage_fall_time_pulse2_mae: 0.1508 - val_voltage_rise_time_pulse1_loss: 0.0051 - val_voltage_rise_time_pulse1_mae: 0.0291 - val_voltage_rise_time_pulse2_loss: 0.0700 - val_voltage_rise_time_pulse2_mae: 0.1578 - learning_rate: 3.7500e-05
# Epoch 42/120
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 195s 170ms/step - current_fall_time_pulse1_loss: 0.0015 - current_fall_time_pulse1_mae: 0.0265 - current_fall_time_pulse2_loss: 0.0015 - current_fall_time_pulse2_mae: 0.0257 - current_rise_time_pulse1_loss: 0.0602 - current_rise_time_pulse1_mae: 0.1411 - current_rise_time_pulse2_loss: 0.0724 - current_rise_time_pulse2_mae: 0.1204 - loss: 0.4679 - overshoot_pulse_1_loss: 0.0286 - overshoot_pulse_1_mae: 0.1309 - overshoot_pulse_2_loss: 0.0619 - overshoot_pulse_2_mae: 0.1903 - ringing_frequency_MHz_loss: 4.4449e-05 - ringing_frequency_MHz_mae: 0.0074 - undershoot_pulse_1_loss: 0.0146 - undershoot_pulse_1_mae: 0.0850 - undershoot_pulse_2_loss: 0.0144 - undershoot_pulse_2_mae: 0.0853 - voltage_fall_time_pulse1_loss: 5.0220e-04 - voltage_fall_time_pulse1_mae: 0.0150 - voltage_fall_time_pulse2_loss: 4.8028e-04 - voltage_fall_time_pulse2_mae: 0.0145 - voltage_rise_time_pulse1_loss: 0.0059 - voltage_rise_time_pulse1_mae: 0.0297 - voltage_rise_time_pulse2_loss: 0.0736 - voltage_rise_time_pulse2_mae: 0.1611 - val_current_fall_time_pulse1_loss: 0.0281 - val_current_fall_time_pulse1_mae: 0.1280 - val_current_fall_time_pulse2_loss: 0.0293 - val_current_fall_time_pulse2_mae: 0.1316 - val_current_rise_time_pulse1_loss: 0.0601 - val_current_rise_time_pulse1_mae: 0.1423 - val_current_rise_time_pulse2_loss: 0.0680 - val_current_rise_time_pulse2_mae: 0.1091 - val_loss: 0.6976 - val_overshoot_pulse_1_loss: 0.0616 - val_overshoot_pulse_1_mae: 0.2004 - val_overshoot_pulse_2_loss: 0.0896 - val_overshoot_pulse_2_mae: 0.2415 - val_ringing_frequency_MHz_loss: 4.0947e-05 - val_ringing_frequency_MHz_mae: 0.0072 - val_undershoot_pulse_1_loss: 0.0467 - val_undershoot_pulse_1_mae: 0.1734 - val_undershoot_pulse_2_loss: 0.0514 - val_undershoot_pulse_2_mae: 0.1766 - val_voltage_fall_time_pulse1_loss: 0.0313 - val_voltage_fall_time_pulse1_mae: 0.1505 - val_voltage_fall_time_pulse2_loss: 0.0307 - val_voltage_fall_time_pulse2_mae: 0.1510 - val_voltage_rise_time_pulse1_loss: 0.0048 - val_voltage_rise_time_pulse1_mae: 0.0289 - val_voltage_rise_time_pulse2_loss: 0.0701 - val_voltage_rise_time_pulse2_mae: 0.1577 - learning_rate: 3.7500e-05
# Epoch 43/120
# 1147/1147 ━━━━━━━━━━━━━━━━━━━━ 188s 164ms/step - current_fall_time_pulse1_loss: 0.0015 - current_fall_time_pulse1_mae: 0.0265 - current_fall_time_pulse2_loss: 0.0015 - current_fall_time_pulse2_mae: 0.0257 - current_rise_time_pulse1_loss: 0.0600 - current_rise_time_pulse1_mae: 0.1410 - current_rise_time_pulse2_loss: 0.0729 - current_rise_time_pulse2_mae: 0.1201 - loss: 0.4697 - overshoot_pulse_1_loss: 0.0285 - overshoot_pulse_1_mae: 0.1308 - overshoot_pulse_2_loss: 0.0620 - overshoot_pulse_2_mae: 0.1904 - ringing_frequency_MHz_loss: 4.4228e-05 - ringing_frequency_MHz_mae: 0.0074 - undershoot_pulse_1_loss: 0.0145 - undershoot_pulse_1_mae: 0.0848 - undershoot_pulse_2_loss: 0.0145 - undershoot_pulse_2_mae: 0.0856 - voltage_fall_time_pulse1_loss: 5.0207e-04 - voltage_fall_time_pulse1_mae: 0.0150 - voltage_fall_time_pulse2_loss: 4.7531e-04 - voltage_fall_time_pulse2_mae: 0.0144 - voltage_rise_time_pulse1_loss: 0.0058 - voltage_rise_time_pulse1_mae: 0.0296 - voltage_rise_time_pulse2_loss: 0.0746 - voltage_rise_time_pulse2_mae: 0.1614 - val_current_fall_time_pulse1_loss: 0.0273 - val_current_fall_time_pulse1_mae: 0.1262 - val_current_fall_time_pulse2_loss: 0.0296 - val_current_fall_time_pulse2_mae: 0.1316 - val_current_rise_time_pulse1_loss: 0.0601 - val_current_rise_time_pulse1_mae: 0.1422 - val_current_rise_time_pulse2_loss: 0.0680 - val_current_rise_time_pulse2_mae: 0.1096 - val_loss: 0.6970 - val_overshoot_pulse_1_loss: 0.0616 - val_overshoot_pulse_1_mae: 0.2000 - val_overshoot_pulse_2_loss: 0.0904 - val_overshoot_pulse_2_mae: 0.2428 - val_ringing_frequency_MHz_loss: 4.1715e-05 - val_ringing_frequency_MHz_mae: 0.0072 - val_undershoot_pulse_1_loss: 0.0457 - val_undershoot_pulse_1_mae: 0.1718 - val_undershoot_pulse_2_loss: 0.0503 - val_undershoot_pulse_2_mae: 0.1749 - val_voltage_fall_time_pulse1_loss: 0.0314 - val_voltage_fall_time_pulse1_mae: 0.1509 - val_voltage_fall_time_pulse2_loss: 0.0306 - val_voltage_fall_time_pulse2_mae: 0.1508 - val_voltage_rise_time_pulse1_loss: 0.0052 - val_voltage_rise_time_pulse1_mae: 0.0297 - val_voltage_rise_time_pulse2_loss: 0.0704 - val_voltage_rise_time_pulse2_mae: 0.1578 - learning_rate: 3.7500e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# train:
#                        Target        R2          RMSE
# 12     ringing_frequency_MHz  0.998615  1.227932e+00
# 0   voltage_rise_time_pulse1  0.995878  2.598011e-10
# 6   current_fall_time_pulse1  0.971739  1.979292e-09
# 7   current_fall_time_pulse2  0.971736  1.973276e-09
# 2   voltage_fall_time_pulse1  0.969873  1.191931e-09
# 3   voltage_fall_time_pulse2  0.969685  1.194123e-09
# 10        undershoot_pulse_1  0.955090  2.896487e+00
# 11        undershoot_pulse_2  0.947827  3.123416e+00
# 4   current_rise_time_pulse1  0.941288  1.186998e-08
# 8          overshoot_pulse_1  0.938532  3.024824e+00
# 5   current_rise_time_pulse2  0.935089  6.389628e-09
# 1   voltage_rise_time_pulse2  0.930873  1.058828e-09
# 9          overshoot_pulse_2  0.911120  7.528735e+00
#
# val:
#                        Target        R2          RMSE
# 12     ringing_frequency_MHz  0.998612  1.228868e+00
# 0   voltage_rise_time_pulse1  0.995359  2.756488e-10
# 7   current_fall_time_pulse2  0.971728  1.975731e-09
# 6   current_fall_time_pulse1  0.971685  1.983687e-09
# 2   voltage_fall_time_pulse1  0.969826  1.194082e-09
# 3   voltage_fall_time_pulse2  0.969676  1.195331e-09
# 10        undershoot_pulse_1  0.955043  2.900926e+00
# 11        undershoot_pulse_2  0.948902  3.090630e+00
# 4   current_rise_time_pulse1  0.939650  1.200673e-08
# 8          overshoot_pulse_1  0.938214  3.026406e+00
# 5   current_rise_time_pulse2  0.932494  6.540061e-09
# 1   voltage_rise_time_pulse2  0.928524  1.067503e-09
# 9          overshoot_pulse_2  0.910959  7.530557e+00
#
# test_seen:
#                        Target        R2          RMSE
# 12     ringing_frequency_MHz  0.998614  1.228073e+00
# 0   voltage_rise_time_pulse1  0.995800  2.622393e-10
# 7   current_fall_time_pulse2  0.971735  1.973644e-09
# 6   current_fall_time_pulse1  0.971731  1.979952e-09
# 2   voltage_fall_time_pulse1  0.969866  1.192254e-09
# 3   voltage_fall_time_pulse2  0.969683  1.194304e-09
# 10        undershoot_pulse_1  0.955083  2.897153e+00
# 11        undershoot_pulse_2  0.947988  3.118520e+00
# 4   current_rise_time_pulse1  0.941044  1.189060e-08
# 8          overshoot_pulse_1  0.938484  3.025061e+00
# 5   current_rise_time_pulse2  0.934698  6.412417e-09
# 1   voltage_rise_time_pulse2  0.930526  1.060134e-09
# 9          overshoot_pulse_2  0.911097  7.529008e+00
#
# unseen_all:
#                        Target        R2          RMSE
# 3   voltage_fall_time_pulse2  0.879880  8.048664e-10
# 2   voltage_fall_time_pulse1  0.857010  8.774244e-10
# 6   current_fall_time_pulse1  0.761117  5.480373e-09
# 7   current_fall_time_pulse2  0.720045  5.893490e-09
# 8          overshoot_pulse_1  0.591975  8.660238e+00
# 1   voltage_rise_time_pulse2  0.583409  3.018979e-09
# 11        undershoot_pulse_2  0.543604  6.590132e+00
# 9          overshoot_pulse_2  0.524878  1.428531e+01
# 10        undershoot_pulse_1  0.517078  6.833168e+00
# 0   voltage_rise_time_pulse1  0.473032  1.246002e-09
# 5   current_rise_time_pulse2  0.419595  1.286029e-08
# 12     ringing_frequency_MHz -0.080588  4.015489e+00
# 4   current_rise_time_pulse1 -0.347894  1.843373e-08
#
# unseen_positive_only:
#                        Target        R2          RMSE
# 3   voltage_fall_time_pulse2  0.879880  8.048664e-10
# 2   voltage_fall_time_pulse1  0.857010  8.774244e-10
# 6   current_fall_time_pulse1  0.761117  5.480373e-09
# 7   current_fall_time_pulse2  0.720045  5.893490e-09
# 8          overshoot_pulse_1  0.591975  8.660238e+00
# 1   voltage_rise_time_pulse2  0.583409  3.018979e-09
# 11        undershoot_pulse_2  0.543604  6.590132e+00
# 9          overshoot_pulse_2  0.524878  1.428531e+01
# 10        undershoot_pulse_1  0.517078  6.833168e+00
# 0   voltage_rise_time_pulse1  0.473032  1.246002e-09
# 5   current_rise_time_pulse2  0.419595  1.286029e-08
# Saved seen predictions → integrated_v2_ringing_boost/artifacts/seen_full_predictions.csv
# Saved unseen predictions → integrated_v2_ringing_boost/artifacts/unseen_full_predictions.csv
