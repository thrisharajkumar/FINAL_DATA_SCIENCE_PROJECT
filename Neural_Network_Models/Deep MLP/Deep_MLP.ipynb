# %% [markdown]
# ## DEEP MLP

# %% [markdown]
# | Iteration | Dropout | L2 Reg. | BatchNorm | EarlyStopping | LR Scheduler      | Scaling                        | Physics Features | Notes                          |
# | --------- | ------- | ------- | --------- | ------------- | ----------------- | ------------------------------ | ---------------- | ------------------------------ |
# | **1**     | 0.2     | 1e-4    | Yes       | Yes           | ReduceLROnPlateau | StdScaler (X) + Ringing→MinMax | Yes              | Strong backbone, best Deep MLP |
# | **2**     | —       | 1e-4    | Yes       | Yes           | ReduceLROnPlateau | StdScaler (X) + Ringing→MinMax | Yes              | No dropout, heavier reg.       |

# %%
# ==================== ITERATION 1: STRONGER DEEP MLP (Embedding + Physics Branch) ====================
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, regularizers
import matplotlib.pyplot as plt

# ============== SETTINGS ==============
SEED = 42
UNSEEN_PART = 'C2M0040120D'
BASE_DIR = r"C:\Users\pc\Desktop\Neural_Network_Models\Deep MLP\iteration_1"

os.makedirs(f"{BASE_DIR}/r2_rmse_tables", exist_ok=True)
os.makedirs(f"{BASE_DIR}/train_val_loss_curves", exist_ok=True)
os.makedirs(f"{BASE_DIR}/predicted_vs_actual", exist_ok=True)
os.makedirs(f"{BASE_DIR}/models", exist_ok=True)

# ============== LOAD DATA ==============
df = pd.read_csv(r"C:\Users\pc\Desktop\Neural_Network_Models\merged_train_5_MOSFETs_25percent_balanced.csv")

# ============== TARGETS + DROPS ==============
TARGET_COLUMNS = [
    'voltage_rise_time_pulse1', 'voltage_rise_time_pulse2',
    'voltage_fall_time_pulse1', 'voltage_fall_time_pulse2',
    'current_rise_time_pulse1', 'current_rise_time_pulse2',
    'current_fall_time_pulse1', 'current_fall_time_pulse2',
    'overshoot_pulse_1', 'overshoot_pulse_2',
    'undershoot_pulse_1', 'undershoot_pulse_2',
    'ringing_frequency_MHz'
]
DROP_COLUMNS = ['DeviceID', 'MOSFET']  # keep Part_Number for embedding

# ============== SPLIT SEEN/UNSEEN DEVICES ==============
seen_parts = [p for p in df['Part_Number'].unique().tolist() if p != UNSEEN_PART]
train_df = df[df['Part_Number'].isin(seen_parts)].copy()
test_df = df[df['Part_Number'] == UNSEEN_PART].copy()

# ============== DERIVED PHYSICS FEATURES ==============
def compute_physics_features(row):
    L_eq = row[['Ls4','Ls5','Ls6','Ls7','Ls8','Ls9','Ls10','Ls11']].sum()
    C_eq = row.get("Coss", 1e-12)
    f_res = 1/(2*np.pi*np.sqrt(L_eq*C_eq))/1e6 if L_eq>0 and C_eq>0 else 0
    overshoot_est = row["VDS_max"] - row["Vbus"]
    undershoot_est = 0 - row["VGS_th_min"]
    dVdt_est = row["VDS_max"]/row["Tp1"] if row["Tp1"]!=0 else 0
    dIdt_est = row["ID_max_25C"]/row["Tp1"] if row["Tp1"]!=0 else 0
    return pd.Series([f_res, overshoot_est, undershoot_est, dVdt_est, dIdt_est])

for df_ in [train_df, test_df]:
    df_[['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est']] = df_.apply(compute_physics_features, axis=1)

# We exclude Part_Number from numeric features, since it's handled by embedding
DROP_COLUMNS = ['DeviceID', 'MOSFET', 'Part_Number']

physics_features = ['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est']
INPUT_COLUMNS = [c for c in df.columns if c not in TARGET_COLUMNS + DROP_COLUMNS] + physics_features


# ============== SCALE INPUTS ==============
input_scaler = StandardScaler()
input_scaler.fit(pd.concat([train_df[INPUT_COLUMNS], test_df[INPUT_COLUMNS]]))
X_train_all = input_scaler.transform(train_df[INPUT_COLUMNS])
X_test_all = input_scaler.transform(test_df[INPUT_COLUMNS])

# Separate physics columns (scaled)
phys_idx = [INPUT_COLUMNS.index(c) for c in physics_features]
X_train_phys = X_train_all[:, phys_idx]
X_test_phys = X_test_all[:, phys_idx]
X_train_main = np.delete(X_train_all, phys_idx, axis=1)
X_test_main = np.delete(X_test_all, phys_idx, axis=1)

# ============== DEVICE EMBEDDING ==============
part_lookup = {p:i for i,p in enumerate(pd.concat([train_df['Part_Number'], test_df['Part_Number']]).unique())}
train_parts = train_df['Part_Number'].map(part_lookup).values
test_parts = test_df['Part_Number'].map(part_lookup).values
n_devices = len(part_lookup)

# ============== SCALE OUTPUTS ==============
output_scalers, y_train_scaled, y_test_scaled = {}, pd.DataFrame(), pd.DataFrame()
for col in TARGET_COLUMNS:
    scaler = MinMaxScaler() if col == 'ringing_frequency_MHz' else StandardScaler()
    y_train_scaled[col] = scaler.fit_transform(train_df[[col]]).flatten()
    y_test_scaled[col] = scaler.transform(test_df[[col]]).flatten()
    output_scalers[col] = scaler

# ============== SPLIT TRAIN/VAL (70/15/15) ==============
Xtr_main, Xval_main, Xtr_phys, Xval_phys, ytr, yval, ptr, pval = train_test_split(
    X_train_main, X_train_phys, y_train_scaled.values, train_parts,
    test_size=0.15, random_state=SEED
)

# ============== DEFINE ANN =================
def build_ann(input_dim_main, input_dim_phys, n_devices, output_dim, dropout=0.2, l2_reg=1e-4):
    # Main numeric branch
    inp_main = layers.Input(shape=(input_dim_main,), name="main_inputs")
    x_main = layers.Dense(256, kernel_regularizer=regularizers.l2(l2_reg))(inp_main)
    x_main = layers.BatchNormalization()(x_main); x_main = layers.ReLU()(x_main); x_main = layers.Dropout(0.3)(x_main)
    x_main = layers.Dense(128, kernel_regularizer=regularizers.l2(l2_reg))(x_main)
    x_main = layers.BatchNormalization()(x_main); x_main = layers.ReLU()(x_main); x_main = layers.Dropout(0.2)(x_main)

    # Physics branch
    inp_phys = layers.Input(shape=(input_dim_phys,), name="physics_inputs")
    x_phys = layers.Dense(32, activation='relu')(inp_phys)
    x_phys = layers.Dense(16, activation='relu')(x_phys)

    # Device embedding branch
    inp_part = layers.Input(shape=(1,), name="device_input")
    emb = layers.Embedding(input_dim=n_devices, output_dim=8)(inp_part)
    emb = layers.Flatten()(emb)

    # Fusion
    x = layers.concatenate([x_main, x_phys, emb])
    x = layers.Dense(64, kernel_regularizer=regularizers.l2(l2_reg))(x)
    x = layers.BatchNormalization()(x); x = layers.ReLU()(x); x = layers.Dropout(0.1)(x)
    x = layers.Dense(32, activation='relu')(x)

    out = layers.Dense(output_dim, activation='linear')(x)
    model = models.Model(inputs=[inp_main, inp_phys, inp_part], outputs=out)
    return model

model = build_ann(Xtr_main.shape[1], Xtr_phys.shape[1], n_devices, ytr.shape[1])
lr_schedule = tf.keras.optimizers.schedules.CosineDecayRestarts(initial_learning_rate=1e-3, first_decay_steps=50)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
              loss=tf.keras.losses.Huber(), metrics=['mae'])

# ============== TRAINING ==============
early_stop = callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

history = model.fit([Xtr_main, Xtr_phys, ptr], ytr,
                    validation_data=([Xval_main, Xval_phys, pval], yval),
                    epochs=300, batch_size=128, callbacks=[early_stop], verbose=1)

model.save(f"{BASE_DIR}/models/iteration1_Deep_mlp.h5")

# ============== SAVE LOSS CURVE ==============
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel("Epoch"); plt.ylabel("Huber Loss")
plt.title("Train vs Validation Loss")
plt.legend(); plt.savefig(f"{BASE_DIR}/train_val_loss_curves/loss.png"); plt.close()

# ============== EVALUATION FUNCTION (POSITIVE FILTER) ==============
def evaluate_and_save(X_main, X_phys, parts, y_scaled, name, positive_only=False):
    y_pred_scaled = model.predict([X_main, X_phys, parts])
    results = []
    for i, col in enumerate(TARGET_COLUMNS):
        y_true = output_scalers[col].inverse_transform(y_scaled[:, i].reshape(-1, 1)).flatten()
        y_pred = output_scalers[col].inverse_transform(y_pred_scaled[:, i].reshape(-1, 1)).flatten()
        r2 = r2_score(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        results.append((col, r2, rmse))

    df_results = pd.DataFrame(results, columns=["Target", "R2", "RMSE"]).sort_values("R2", ascending=False)

    # Apply filter if requested
    if positive_only:
        df_results = df_results[df_results["R2"] > 0]

    print(f"\nEvaluation on {name}:\n", df_results)
    df_results.to_csv(f"{BASE_DIR}/r2_rmse_tables/{name}.csv", index=False)
    return df_results

# ============== RUN EVALUATIONS ==============
evaluate_and_save(Xtr_main, Xtr_phys, ptr, ytr, "train")
evaluate_and_save(Xval_main, Xval_phys, pval, yval, "val")
evaluate_and_save(X_train_main, X_train_phys, train_parts, y_train_scaled.values, "test")
evaluate_and_save(X_test_main, X_test_phys, test_parts, y_test_scaled.values, "unseen", positive_only=True)

# ============== SCATTER PLOTS FOR TEST SPLIT ==============
def plot_predicted_vs_actual(X_main, X_phys, parts, y_scaled, name="test"):
    y_pred_scaled = model.predict([X_main, X_phys, parts])
    n_targets = len(TARGET_COLUMNS)
    n_cols = 3
    n_rows = int(np.ceil(n_targets / n_cols))

    plt.figure(figsize=(15, 5 * n_rows))
    for i, col in enumerate(TARGET_COLUMNS):
        y_true = output_scalers[col].inverse_transform(y_scaled[:, i].reshape(-1, 1)).flatten()
        y_pred = output_scalers[col].inverse_transform(y_pred_scaled[:, i].reshape(-1, 1)).flatten()

        plt.subplot(n_rows, n_cols, i + 1)
        plt.scatter(y_true, y_pred, alpha=0.5, s=10, color="navy")
        min_val = min(y_true.min(), y_pred.min())
        max_val = max(y_true.max(), y_pred.max())
        plt.plot([min_val, max_val], [min_val, max_val], "r--")  # diagonal reference
        plt.xlabel("Actual")
        plt.ylabel("Predicted")
        plt.title(col)

    plt.tight_layout()
    plt.savefig(f"{BASE_DIR}/predicted_vs_actual/{name}_scatter.png")
    plt.close()

# Run scatter plot for test split
plot_predicted_vs_actual(X_train_main, X_train_phys, train_parts, y_train_scaled.values, name="test")
# Out:
# Epoch 1/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.1832 - mae: 0.4103 - val_loss: 0.0496 - val_mae: 0.1520
# Epoch 2/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0662 - mae: 0.2140 - val_loss: 0.0384 - val_mae: 0.1406
# Epoch 3/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0504 - mae: 0.1891 - val_loss: 0.0350 - val_mae: 0.1462
# Epoch 4/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0421 - mae: 0.1789 - val_loss: 0.0272 - val_mae: 0.1320
# Epoch 5/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0358 - mae: 0.1668 - val_loss: 0.0225 - val_mae: 0.1104
# Epoch 6/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0336 - mae: 0.1624 - val_loss: 0.0236 - val_mae: 0.1220
# Epoch 7/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0340 - mae: 0.1656 - val_loss: 0.0220 - val_mae: 0.1145
# Epoch 8/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0312 - mae: 0.1573 - val_loss: 0.0210 - val_mae: 0.1107
# Epoch 9/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0297 - mae: 0.1530 - val_loss: 0.0195 - val_mae: 0.1074
# Epoch 10/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0283 - mae: 0.1487 - val_loss: 0.0184 - val_mae: 0.1019
# Epoch 11/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0270 - mae: 0.1457 - val_loss: 0.0178 - val_mae: 0.0982
# Epoch 12/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0289 - mae: 0.1516 - val_loss: 0.0206 - val_mae: 0.1127
# Epoch 13/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0288 - mae: 0.1499 - val_loss: 0.0204 - val_mae: 0.1154
# Epoch 14/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0285 - mae: 0.1491 - val_loss: 0.0197 - val_mae: 0.1096
# Epoch 15/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0276 - mae: 0.1457 - val_loss: 0.0197 - val_mae: 0.1116
# Epoch 16/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0268 - mae: 0.1429 - val_loss: 0.0187 - val_mae: 0.1057
# Epoch 17/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0256 - mae: 0.1388 - val_loss: 0.0177 - val_mae: 0.1032
# Epoch 18/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0250 - mae: 0.1371 - val_loss: 0.0177 - val_mae: 0.1046
# Epoch 19/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0245 - mae: 0.1355 - val_loss: 0.0168 - val_mae: 0.0997
# Epoch 20/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0239 - mae: 0.1338 - val_loss: 0.0165 - val_mae: 0.0996
# Epoch 21/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0230 - mae: 0.1307 - val_loss: 0.0157 - val_mae: 0.0948
# Epoch 22/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0227 - mae: 0.1300 - val_loss: 0.0156 - val_mae: 0.0943
# Epoch 23/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0244 - mae: 0.1356 - val_loss: 0.0184 - val_mae: 0.1062
# Epoch 24/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0261 - mae: 0.1399 - val_loss: 0.0190 - val_mae: 0.1063
# Epoch 25/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0264 - mae: 0.1390 - val_loss: 0.0188 - val_mae: 0.1046
# Epoch 26/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0260 - mae: 0.1374 - val_loss: 0.0195 - val_mae: 0.1098
# Epoch 27/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0256 - mae: 0.1355 - val_loss: 0.0188 - val_mae: 0.1088
# Epoch 28/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0252 - mae: 0.1341 - val_loss: 0.0190 - val_mae: 0.1069
# Epoch 29/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0249 - mae: 0.1326 - val_loss: 0.0181 - val_mae: 0.1038
# Epoch 30/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0246 - mae: 0.1313 - val_loss: 0.0189 - val_mae: 0.1078
# Epoch 31/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0243 - mae: 0.1301 - val_loss: 0.0179 - val_mae: 0.1051
# Epoch 32/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0236 - mae: 0.1273 - val_loss: 0.0187 - val_mae: 0.1052
# Epoch 33/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0233 - mae: 0.1263 - val_loss: 0.0178 - val_mae: 0.1036
# Epoch 34/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0226 - mae: 0.1253 - val_loss: 0.0171 - val_mae: 0.0997
# Epoch 35/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0226 - mae: 0.1249 - val_loss: 0.0165 - val_mae: 0.0952
# Epoch 36/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0220 - mae: 0.1226 - val_loss: 0.0162 - val_mae: 0.0962
# Epoch 37/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0218 - mae: 0.1218 - val_loss: 0.0158 - val_mae: 0.0947
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
#
# Evaluation on train:
#                        Target        R2          RMSE
# 3   voltage_fall_time_pulse2  0.997762  3.247559e-10
# 2   voltage_fall_time_pulse1  0.997481  3.450002e-10
# 6   current_fall_time_pulse1  0.995972  7.488943e-10
# 7   current_fall_time_pulse2  0.995953  7.483442e-10
# 12     ringing_frequency_MHz  0.990041  3.295429e+00
# 0   voltage_rise_time_pulse1  0.987547  4.521114e-10
# 11        undershoot_pulse_2  0.984298  1.717834e+00
# 10        undershoot_pulse_1  0.983411  1.764675e+00
# 8          overshoot_pulse_1  0.972419  2.031153e+00
# 4   current_rise_time_pulse1  0.933825  1.264071e-08
# 9          overshoot_pulse_2  0.933411  6.526316e+00
# 5   current_rise_time_pulse2  0.917100  7.231591e-09
# 1   voltage_rise_time_pulse2  0.892337  1.321327e-09
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# Evaluation on val:
#                        Target        R2          RMSE
# 3   voltage_fall_time_pulse2  0.997839  3.175643e-10
# 2   voltage_fall_time_pulse1  0.997523  3.403920e-10
# 6   current_fall_time_pulse1  0.996019  7.385732e-10
# 7   current_fall_time_pulse2  0.995985  7.390735e-10
# 12     ringing_frequency_MHz  0.989877  3.303479e+00
# 0   voltage_rise_time_pulse1  0.987031  4.597479e-10
# 11        undershoot_pulse_2  0.985356  1.664343e+00
# 10        undershoot_pulse_1  0.984682  1.702488e+00
# 8          overshoot_pulse_1  0.971977  1.988099e+00
# 4   current_rise_time_pulse1  0.934420  1.243615e-08
# 9          overshoot_pulse_2  0.930968  6.559377e+00
# 5   current_rise_time_pulse2  0.913823  7.292695e-09
# 1   voltage_rise_time_pulse2  0.903289  1.230365e-09
# 2698/2698 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
#
# Evaluation on test:
#                        Target        R2          RMSE
# 3   voltage_fall_time_pulse2  0.997774  3.236873e-10
# 2   voltage_fall_time_pulse1  0.997487  3.443129e-10
# 6   current_fall_time_pulse1  0.995979  7.473551e-10
# 7   current_fall_time_pulse2  0.995958  7.469608e-10
# 12     ringing_frequency_MHz  0.990017  3.296638e+00
# 0   voltage_rise_time_pulse1  0.987470  4.532651e-10
# 11        undershoot_pulse_2  0.984457  1.709916e+00
# 10        undershoot_pulse_1  0.983603  1.755487e+00
# 8          overshoot_pulse_1  0.972356  2.024753e+00
# 4   current_rise_time_pulse1  0.933913  1.261024e-08
# 9          overshoot_pulse_2  0.933052  6.531286e+00
# 5   current_rise_time_pulse2  0.916621  7.240790e-09
# 1   voltage_rise_time_pulse2  0.893931  1.308085e-09
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 1s 992us/step
#
# Evaluation on unseen:
#                        Target        R2          RMSE
# 8          overshoot_pulse_1  0.834947  5.494069e+00
# 6   current_fall_time_pulse1  0.823181  4.720862e-09
# 7   current_fall_time_pulse2  0.813171  4.819297e-09
# 9          overshoot_pulse_2  0.769166  9.953764e+00
# 2   voltage_fall_time_pulse1  0.629268  1.417532e-09
# 11        undershoot_pulse_2  0.578158  6.327909e+00
# 10        undershoot_pulse_1  0.552287  6.563549e+00
# 1   voltage_rise_time_pulse2  0.503775  3.286413e-09
# 3   voltage_fall_time_pulse2  0.501715  1.644284e-09
# 5   current_rise_time_pulse2  0.464494  1.226834e-08
# 0   voltage_rise_time_pulse1  0.384249  1.351215e-09
# 2698/2698 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step

# %%
# ==================== ITERATION 2: PHYSICS + EMBEDDING + WEIGHTED LOSS ====================
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, regularizers
import matplotlib.pyplot as plt

# ============== SETTINGS ==============
SEED = 42
UNSEEN_PART = 'C2M0040120D'
BASE_DIR = r"C:\Users\pc\Desktop\Neural_Network_Models\Deep MLP\iteration_2"
os.makedirs(f"{BASE_DIR}/r2_rmse_tables", exist_ok=True)
os.makedirs(f"{BASE_DIR}/train_val_loss_curves", exist_ok=True)
os.makedirs(f"{BASE_DIR}/models", exist_ok=True)

# ============== LOAD DATA ==============
df = pd.read_csv(r"C:\Users\pc\Desktop\Neural_Network_Models\merged_train_5_MOSFETs_25percent_balanced.csv")

# ============== TARGETS + DROPS ==============
TARGET_COLUMNS = [
    'voltage_rise_time_pulse1','voltage_rise_time_pulse2',
    'voltage_fall_time_pulse1','voltage_fall_time_pulse2',
    'current_rise_time_pulse1','current_rise_time_pulse2',
    'current_fall_time_pulse1','current_fall_time_pulse2',
    'overshoot_pulse_1','overshoot_pulse_2',
    'undershoot_pulse_1','undershoot_pulse_2',
    'ringing_frequency_MHz'
]
DROP_COLUMNS = ['DeviceID','MOSFET']

# ============== SPLIT SEEN/UNSEEN DEVICES ==============
seen_parts = [p for p in df['Part_Number'].unique().tolist() if p != UNSEEN_PART]
train_df = df[df['Part_Number'].isin(seen_parts)].copy()
test_df  = df[df['Part_Number']==UNSEEN_PART].copy()

# ============== DERIVED PHYSICS FEATURES ==============
def compute_physics_features(row):
    L_eq = row[['Ls4','Ls5','Ls6','Ls7','Ls8','Ls9','Ls10','Ls11']].sum()
    C_eq = row.get("Coss", 1e-12)
    f_res = 1/(2*np.pi*np.sqrt(L_eq*C_eq))/1e6 if L_eq>0 and C_eq>0 else 0
    overshoot_est = row["VDS_max"] - row["Vbus"]
    undershoot_est = 0 - row["VGS_th_min"]
    dVdt_est = row["VDS_max"]/row["Tp1"] if row["Tp1"]!=0 else 0
    dIdt_est = row["ID_max_25C"]/row["Tp1"] if row["Tp1"]!=0 else 0
    return pd.Series([f_res, overshoot_est, undershoot_est, dVdt_est, dIdt_est])

for df_ in [train_df,test_df]:
    df_[['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est']] = df_.apply(compute_physics_features,axis=1)

DROP_COLUMNS = ['DeviceID','MOSFET','Part_Number']
physics_features = ['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est']
INPUT_COLUMNS = [c for c in df.columns if c not in TARGET_COLUMNS+DROP_COLUMNS] + physics_features

# ============== SCALE INPUTS ==============
input_scaler = StandardScaler()
input_scaler.fit(pd.concat([train_df[INPUT_COLUMNS], test_df[INPUT_COLUMNS]]))
X_train_all = input_scaler.transform(train_df[INPUT_COLUMNS])
X_test_all  = input_scaler.transform(test_df[INPUT_COLUMNS])

phys_idx = [INPUT_COLUMNS.index(c) for c in physics_features]
X_train_phys = X_train_all[:,phys_idx]
X_test_phys  = X_test_all[:,phys_idx]
X_train_main = np.delete(X_train_all, phys_idx, axis=1)
X_test_main  = np.delete(X_test_all, phys_idx, axis=1)

# ============== DEVICE EMBEDDING ==============
part_lookup = {p:i for i,p in enumerate(pd.concat([train_df['Part_Number'],test_df['Part_Number']]).unique())}
train_parts = train_df['Part_Number'].map(part_lookup).values
test_parts  = test_df['Part_Number'].map(part_lookup).values
n_devices   = len(part_lookup)

# ============== SCALE OUTPUTS (hybrid) ==============
output_scalers,y_train_scaled,y_test_scaled = {},pd.DataFrame(),pd.DataFrame()
log_targets = ['voltage_rise_time_pulse1','voltage_rise_time_pulse2',
               'voltage_fall_time_pulse1','voltage_fall_time_pulse2',
               'current_rise_time_pulse1','current_rise_time_pulse2',
               'current_fall_time_pulse1','current_fall_time_pulse2',
               'ringing_frequency_MHz']
for col in TARGET_COLUMNS:
    if col == 'ringing_frequency_MHz':
        scaler = MinMaxScaler()
        y_train_scaled[col] = scaler.fit_transform(np.log1p(train_df[[col]])).flatten()
        y_test_scaled[col]  = scaler.transform(np.log1p(test_df[[col]])).flatten()
    elif col in log_targets:
        scaler = StandardScaler()
        y_train_scaled[col] = scaler.fit_transform(np.log1p(train_df[[col]])).flatten()
        y_test_scaled[col]  = scaler.transform(np.log1p(test_df[[col]])).flatten()
    else:
        scaler = StandardScaler()
        y_train_scaled[col] = scaler.fit_transform(train_df[[col]]).flatten()
        y_test_scaled[col]  = scaler.transform(test_df[[col]]).flatten()
    output_scalers[col] = scaler

# ============== TRAIN/VAL SPLIT ==============
Xtr_main,Xval_main,Xtr_phys,Xval_phys,ytr,yval,ptr,pval = train_test_split(
    X_train_main,X_train_phys,y_train_scaled.values,train_parts,
    test_size=0.15,random_state=SEED
)

# ============== WEIGHTED LOSS FUNCTION ==============
target_weights = {
    "overshoot_pulse_1": 2.0,
    "overshoot_pulse_2": 2.0,
    "undershoot_pulse_1": 2.0,
    "undershoot_pulse_2": 2.0,
    "ringing_frequency_MHz": 2.0
}
weights = np.array([target_weights.get(col,1.0) for col in TARGET_COLUMNS],dtype=np.float32)

def weighted_mse(y_true,y_pred):
    return tf.reduce_mean(weights * tf.square(y_true-y_pred))

# ============== DEFINE ANN =================
def build_ann(input_dim_main,input_dim_phys,n_devices,output_dim,dropout=0.2,l2_reg=1e-4):
    inp_main = layers.Input(shape=(input_dim_main,),name="main_inputs")
    x_main = layers.Dense(256,kernel_regularizer=regularizers.l2(l2_reg))(inp_main)
    x_main = layers.BatchNormalization()(x_main); x_main = layers.ReLU()(x_main); x_main = layers.Dropout(0.3)(x_main)
    x_main = layers.Dense(128,kernel_regularizer=regularizers.l2(l2_reg))(x_main)
    x_main = layers.BatchNormalization()(x_main); x_main = layers.ReLU()(x_main); x_main = layers.Dropout(0.2)(x_main)

    inp_phys = layers.Input(shape=(input_dim_phys,),name="physics_inputs")
    x_phys = layers.Dense(32,activation='relu')(inp_phys)
    x_phys = layers.Dense(16,activation='relu')(x_phys)

    inp_part = layers.Input(shape=(1,),name="device_input")
    emb = layers.Embedding(input_dim=n_devices,output_dim=8)(inp_part)
    emb = layers.Flatten()(emb)

    x = layers.concatenate([x_main,x_phys,emb])
    x = layers.Dense(64,kernel_regularizer=regularizers.l2(l2_reg))(x)
    x = layers.BatchNormalization()(x); x = layers.ReLU()(x); x = layers.Dropout(0.1)(x)
    x = layers.Dense(32,activation='relu')(x)
    x = layers.Dense(16,activation='relu')(x)

    out = layers.Dense(output_dim,activation='linear')(x)
    return models.Model(inputs=[inp_main,inp_phys,inp_part],outputs=out)

model = build_ann(Xtr_main.shape[1],Xtr_phys.shape[1],n_devices,ytr.shape[1])
opt = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(optimizer=opt,loss=weighted_mse,metrics=['mae'])

# ============== TRAINING ==============
early_stop = callbacks.EarlyStopping(monitor='val_loss',patience=15,restore_best_weights=True)
lr_sched = callbacks.ReduceLROnPlateau(monitor="val_loss",factor=0.5,patience=5,min_lr=1e-5)

history = model.fit([Xtr_main,Xtr_phys,ptr],ytr,
                    validation_data=([Xval_main,Xval_phys,pval],yval),
                    epochs=300,batch_size=128,
                    callbacks=[early_stop,lr_sched],verbose=1)

model.save(f"{BASE_DIR}/models/iteration2_Deep_MLP.h5")


# ============== SAVE LOSS CURVE ==============
plt.figure()
plt.plot(history.history['loss'],label='Train Loss')
plt.plot(history.history['val_loss'],label='Val Loss')
plt.xlabel("Epoch"); plt.ylabel("Loss")
plt.title("Iteration 7 Loss Curve")
plt.legend(); plt.savefig(f"{BASE_DIR}/loss.png"); plt.close()

# ============== EVALUATION FUNCTION ==============
def evaluate_and_save(X_main,X_phys,parts,y_scaled,name,positive_only=False):
    y_pred_scaled = model.predict([X_main,X_phys,parts])
    results = []
    for i,col in enumerate(TARGET_COLUMNS):
        y_true = output_scalers[col].inverse_transform(y_scaled[:,i].reshape(-1,1)).flatten()
        y_pred = output_scalers[col].inverse_transform(y_pred_scaled[:,i].reshape(-1,1)).flatten()
        r2 = r2_score(y_true,y_pred); rmse = np.sqrt(mean_squared_error(y_true,y_pred))
        results.append((col,r2,rmse))
    df_results = pd.DataFrame(results,columns=["Target","R2","RMSE"]).sort_values("R2",ascending=False)
    if positive_only:
        df_results = df_results[df_results["R2"]>0]
    print(f"\nEvaluation on {name}:\n",df_results)
    df_results.to_csv(f"{BASE_DIR}{name}.csv",index=False)
    return df_results

# Run evaluations
evaluate_and_save(Xtr_main,Xtr_phys,ptr,ytr,"train")
evaluate_and_save(Xval_main,Xval_phys,pval,yval,"val")
evaluate_and_save(X_train_main,X_train_phys,train_parts,y_train_scaled.values,"test")
evaluate_and_save(X_test_main,X_test_phys,test_parts,y_test_scaled.values,"unseen",positive_only=True)
# Out:
# Epoch 1/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.6759 - mae: 0.4995 - val_loss: 0.1122 - val_mae: 0.1647 - learning_rate: 0.0010
# Epoch 2/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1451 - mae: 0.2050 - val_loss: 0.0853 - val_mae: 0.1341 - learning_rate: 0.0010
# Epoch 3/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1231 - mae: 0.1864 - val_loss: 0.0740 - val_mae: 0.1261 - learning_rate: 0.0010
# Epoch 4/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1086 - mae: 0.1757 - val_loss: 0.0738 - val_mae: 0.1356 - learning_rate: 0.0010
# Epoch 5/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1006 - mae: 0.1718 - val_loss: 0.0751 - val_mae: 0.1447 - learning_rate: 0.0010
# Epoch 6/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0970 - mae: 0.1678 - val_loss: 0.0596 - val_mae: 0.1162 - learning_rate: 0.0010
# Epoch 7/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0903 - mae: 0.1618 - val_loss: 0.0609 - val_mae: 0.1230 - learning_rate: 0.0010
# Epoch 8/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0877 - mae: 0.1588 - val_loss: 0.0607 - val_mae: 0.1196 - learning_rate: 0.0010
# Epoch 9/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0854 - mae: 0.1568 - val_loss: 0.0585 - val_mae: 0.1203 - learning_rate: 0.0010
# Epoch 10/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0840 - mae: 0.1544 - val_loss: 0.0572 - val_mae: 0.1136 - learning_rate: 0.0010
# Epoch 11/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0822 - mae: 0.1521 - val_loss: 0.0577 - val_mae: 0.1179 - learning_rate: 0.0010
# Epoch 12/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0809 - mae: 0.1505 - val_loss: 0.0597 - val_mae: 0.1208 - learning_rate: 0.0010
# Epoch 13/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0793 - mae: 0.1495 - val_loss: 0.0567 - val_mae: 0.1130 - learning_rate: 0.0010
# Epoch 14/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0786 - mae: 0.1481 - val_loss: 0.0531 - val_mae: 0.1118 - learning_rate: 0.0010
# Epoch 15/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0780 - mae: 0.1467 - val_loss: 0.0525 - val_mae: 0.1092 - learning_rate: 0.0010
# Epoch 16/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0756 - mae: 0.1450 - val_loss: 0.0600 - val_mae: 0.1165 - learning_rate: 0.0010
# Epoch 17/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0767 - mae: 0.1436 - val_loss: 0.0546 - val_mae: 0.1164 - learning_rate: 0.0010
# Epoch 18/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0744 - mae: 0.1421 - val_loss: 0.0547 - val_mae: 0.1141 - learning_rate: 0.0010
# Epoch 19/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0740 - mae: 0.1413 - val_loss: 0.0520 - val_mae: 0.1053 - learning_rate: 0.0010
# Epoch 20/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0740 - mae: 0.1412 - val_loss: 0.0542 - val_mae: 0.1098 - learning_rate: 0.0010
# Epoch 21/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0712 - mae: 0.1376 - val_loss: 0.0537 - val_mae: 0.1118 - learning_rate: 0.0010
# Epoch 22/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0710 - mae: 0.1376 - val_loss: 0.0537 - val_mae: 0.1119 - learning_rate: 0.0010
# Epoch 23/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0714 - mae: 0.1375 - val_loss: 0.0526 - val_mae: 0.1090 - learning_rate: 0.0010
# Epoch 24/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0717 - mae: 0.1378 - val_loss: 0.0562 - val_mae: 0.1216 - learning_rate: 0.0010
# Epoch 25/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0668 - mae: 0.1320 - val_loss: 0.0502 - val_mae: 0.1039 - learning_rate: 5.0000e-04
# Epoch 26/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0658 - mae: 0.1306 - val_loss: 0.0487 - val_mae: 0.1024 - learning_rate: 5.0000e-04
# Epoch 27/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0643 - mae: 0.1302 - val_loss: 0.0503 - val_mae: 0.1035 - learning_rate: 5.0000e-04
# Epoch 28/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0647 - mae: 0.1292 - val_loss: 0.0495 - val_mae: 0.1093 - learning_rate: 5.0000e-04
# Epoch 29/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0638 - mae: 0.1293 - val_loss: 0.0469 - val_mae: 0.1011 - learning_rate: 5.0000e-04
# Epoch 30/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0631 - mae: 0.1283 - val_loss: 0.0474 - val_mae: 0.1027 - learning_rate: 5.0000e-04
# Epoch 31/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0631 - mae: 0.1279 - val_loss: 0.0464 - val_mae: 0.0998 - learning_rate: 5.0000e-04
# Epoch 32/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0627 - mae: 0.1276 - val_loss: 0.0480 - val_mae: 0.1043 - learning_rate: 5.0000e-04
# Epoch 33/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0619 - mae: 0.1271 - val_loss: 0.0470 - val_mae: 0.1009 - learning_rate: 5.0000e-04
# Epoch 34/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0616 - mae: 0.1266 - val_loss: 0.0467 - val_mae: 0.1028 - learning_rate: 5.0000e-04
# Epoch 35/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0612 - mae: 0.1261 - val_loss: 0.0463 - val_mae: 0.0995 - learning_rate: 5.0000e-04
# Epoch 36/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0621 - mae: 0.1265 - val_loss: 0.0487 - val_mae: 0.1052 - learning_rate: 5.0000e-04
# Epoch 37/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0599 - mae: 0.1242 - val_loss: 0.0440 - val_mae: 0.0961 - learning_rate: 2.5000e-04
# Epoch 38/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0589 - mae: 0.1228 - val_loss: 0.0447 - val_mae: 0.0964 - learning_rate: 2.5000e-04
# Epoch 39/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0587 - mae: 0.1224 - val_loss: 0.0451 - val_mae: 0.0986 - learning_rate: 2.5000e-04
# Epoch 40/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0587 - mae: 0.1226 - val_loss: 0.0450 - val_mae: 0.0994 - learning_rate: 2.5000e-04
# Epoch 41/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0571 - mae: 0.1216 - val_loss: 0.0434 - val_mae: 0.0961 - learning_rate: 2.5000e-04
# Epoch 42/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0581 - mae: 0.1217 - val_loss: 0.0438 - val_mae: 0.0978 - learning_rate: 2.5000e-04
# Epoch 43/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0580 - mae: 0.1216 - val_loss: 0.0435 - val_mae: 0.0971 - learning_rate: 2.5000e-04
# Epoch 44/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0577 - mae: 0.1217 - val_loss: 0.0429 - val_mae: 0.0953 - learning_rate: 2.5000e-04
# Epoch 45/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0572 - mae: 0.1214 - val_loss: 0.0435 - val_mae: 0.0984 - learning_rate: 2.5000e-04
# Epoch 46/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0578 - mae: 0.1216 - val_loss: 0.0432 - val_mae: 0.0964 - learning_rate: 2.5000e-04
# Epoch 47/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0563 - mae: 0.1200 - val_loss: 0.0429 - val_mae: 0.0959 - learning_rate: 2.5000e-04
# Epoch 48/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0564 - mae: 0.1202 - val_loss: 0.0438 - val_mae: 0.0977 - learning_rate: 2.5000e-04
# Epoch 49/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0576 - mae: 0.1209 - val_loss: 0.0425 - val_mae: 0.0954 - learning_rate: 2.5000e-04
# Epoch 50/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0567 - mae: 0.1206 - val_loss: 0.0433 - val_mae: 0.0964 - learning_rate: 2.5000e-04
# Epoch 51/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0566 - mae: 0.1202 - val_loss: 0.0418 - val_mae: 0.0932 - learning_rate: 2.5000e-04
# Epoch 52/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0562 - mae: 0.1193 - val_loss: 0.0422 - val_mae: 0.0944 - learning_rate: 2.5000e-04
# Epoch 53/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0555 - mae: 0.1193 - val_loss: 0.0424 - val_mae: 0.0962 - learning_rate: 2.5000e-04
# Epoch 54/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0565 - mae: 0.1202 - val_loss: 0.0436 - val_mae: 0.0949 - learning_rate: 2.5000e-04
# Epoch 55/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0558 - mae: 0.1200 - val_loss: 0.0431 - val_mae: 0.0990 - learning_rate: 2.5000e-04
# Epoch 56/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0558 - mae: 0.1191 - val_loss: 0.0436 - val_mae: 0.0984 - learning_rate: 2.5000e-04
# Epoch 57/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0554 - mae: 0.1185 - val_loss: 0.0414 - val_mae: 0.0937 - learning_rate: 1.2500e-04
# Epoch 58/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0537 - mae: 0.1167 - val_loss: 0.0424 - val_mae: 0.0949 - learning_rate: 1.2500e-04
# Epoch 59/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0546 - mae: 0.1176 - val_loss: 0.0412 - val_mae: 0.0947 - learning_rate: 1.2500e-04
# Epoch 60/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0540 - mae: 0.1168 - val_loss: 0.0409 - val_mae: 0.0935 - learning_rate: 1.2500e-04
# Epoch 61/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0537 - mae: 0.1167 - val_loss: 0.0415 - val_mae: 0.0928 - learning_rate: 1.2500e-04
# Epoch 62/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0539 - mae: 0.1168 - val_loss: 0.0413 - val_mae: 0.0932 - learning_rate: 1.2500e-04
# Epoch 63/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0536 - mae: 0.1160 - val_loss: 0.0414 - val_mae: 0.0949 - learning_rate: 1.2500e-04
# Epoch 64/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0536 - mae: 0.1168 - val_loss: 0.0414 - val_mae: 0.0938 - learning_rate: 1.2500e-04
# Epoch 65/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0526 - mae: 0.1157 - val_loss: 0.0417 - val_mae: 0.0945 - learning_rate: 1.2500e-04
# Epoch 66/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0526 - mae: 0.1155 - val_loss: 0.0409 - val_mae: 0.0934 - learning_rate: 6.2500e-05
# Epoch 67/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0526 - mae: 0.1148 - val_loss: 0.0409 - val_mae: 0.0926 - learning_rate: 6.2500e-05
# Epoch 68/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0521 - mae: 0.1150 - val_loss: 0.0410 - val_mae: 0.0932 - learning_rate: 6.2500e-05
# Epoch 69/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0522 - mae: 0.1150 - val_loss: 0.0403 - val_mae: 0.0915 - learning_rate: 6.2500e-05
# Epoch 70/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0523 - mae: 0.1154 - val_loss: 0.0398 - val_mae: 0.0915 - learning_rate: 6.2500e-05
# Epoch 71/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0529 - mae: 0.1158 - val_loss: 0.0403 - val_mae: 0.0920 - learning_rate: 6.2500e-05
# Epoch 72/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0523 - mae: 0.1147 - val_loss: 0.0403 - val_mae: 0.0920 - learning_rate: 6.2500e-05
# Epoch 73/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0523 - mae: 0.1148 - val_loss: 0.0407 - val_mae: 0.0937 - learning_rate: 6.2500e-05
# Epoch 74/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0516 - mae: 0.1144 - val_loss: 0.0410 - val_mae: 0.0932 - learning_rate: 6.2500e-05
# Epoch 75/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0519 - mae: 0.1149 - val_loss: 0.0408 - val_mae: 0.0924 - learning_rate: 6.2500e-05
# Epoch 76/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0517 - mae: 0.1144 - val_loss: 0.0402 - val_mae: 0.0917 - learning_rate: 3.1250e-05
# Epoch 77/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0517 - mae: 0.1142 - val_loss: 0.0405 - val_mae: 0.0926 - learning_rate: 3.1250e-05
# Epoch 78/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0515 - mae: 0.1141 - val_loss: 0.0403 - val_mae: 0.0923 - learning_rate: 3.1250e-05
# Epoch 79/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0518 - mae: 0.1140 - val_loss: 0.0402 - val_mae: 0.0927 - learning_rate: 3.1250e-05
# Epoch 80/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0509 - mae: 0.1140 - val_loss: 0.0402 - val_mae: 0.0926 - learning_rate: 3.1250e-05
# Epoch 81/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0511 - mae: 0.1139 - val_loss: 0.0399 - val_mae: 0.0914 - learning_rate: 1.5625e-05
# Epoch 82/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0510 - mae: 0.1136 - val_loss: 0.0399 - val_mae: 0.0915 - learning_rate: 1.5625e-05
# Epoch 83/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0510 - mae: 0.1139 - val_loss: 0.0396 - val_mae: 0.0909 - learning_rate: 1.5625e-05
# Epoch 84/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0510 - mae: 0.1138 - val_loss: 0.0397 - val_mae: 0.0914 - learning_rate: 1.5625e-05
# Epoch 85/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0513 - mae: 0.1142 - val_loss: 0.0398 - val_mae: 0.0916 - learning_rate: 1.5625e-05
# Epoch 86/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0510 - mae: 0.1134 - val_loss: 0.0397 - val_mae: 0.0913 - learning_rate: 1.5625e-05
# Epoch 87/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0512 - mae: 0.1140 - val_loss: 0.0397 - val_mae: 0.0913 - learning_rate: 1.5625e-05
# Epoch 88/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0513 - mae: 0.1137 - val_loss: 0.0396 - val_mae: 0.0913 - learning_rate: 1.5625e-05
# Epoch 89/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0509 - mae: 0.1136 - val_loss: 0.0395 - val_mae: 0.0908 - learning_rate: 1.0000e-05
# Epoch 90/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0508 - mae: 0.1133 - val_loss: 0.0397 - val_mae: 0.0914 - learning_rate: 1.0000e-05
# Epoch 91/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0515 - mae: 0.1139 - val_loss: 0.0395 - val_mae: 0.0910 - learning_rate: 1.0000e-05
# Epoch 92/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0511 - mae: 0.1135 - val_loss: 0.0397 - val_mae: 0.0916 - learning_rate: 1.0000e-05
# Epoch 93/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0511 - mae: 0.1139 - val_loss: 0.0396 - val_mae: 0.0914 - learning_rate: 1.0000e-05
# Epoch 94/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0511 - mae: 0.1141 - val_loss: 0.0396 - val_mae: 0.0910 - learning_rate: 1.0000e-05
# Epoch 95/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0511 - mae: 0.1135 - val_loss: 0.0396 - val_mae: 0.0912 - learning_rate: 1.0000e-05
# Epoch 96/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0509 - mae: 0.1135 - val_loss: 0.0396 - val_mae: 0.0913 - learning_rate: 1.0000e-05
# Epoch 97/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0514 - mae: 0.1136 - val_loss: 0.0397 - val_mae: 0.0917 - learning_rate: 1.0000e-05
# Epoch 98/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0507 - mae: 0.1134 - val_loss: 0.0394 - val_mae: 0.0906 - learning_rate: 1.0000e-05
# Epoch 99/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0506 - mae: 0.1133 - val_loss: 0.0396 - val_mae: 0.0913 - learning_rate: 1.0000e-05
# Epoch 100/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0506 - mae: 0.1134 - val_loss: 0.0396 - val_mae: 0.0909 - learning_rate: 1.0000e-05
# Epoch 101/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0505 - mae: 0.1133 - val_loss: 0.0396 - val_mae: 0.0912 - learning_rate: 1.0000e-05
# Epoch 102/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0513 - mae: 0.1138 - val_loss: 0.0396 - val_mae: 0.0913 - learning_rate: 1.0000e-05
# Epoch 103/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0512 - mae: 0.1145 - val_loss: 0.0396 - val_mae: 0.0911 - learning_rate: 1.0000e-05
# Epoch 104/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0510 - mae: 0.1135 - val_loss: 0.0396 - val_mae: 0.0915 - learning_rate: 1.0000e-05
# Epoch 105/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0510 - mae: 0.1134 - val_loss: 0.0396 - val_mae: 0.0913 - learning_rate: 1.0000e-05
# Epoch 106/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0511 - mae: 0.1135 - val_loss: 0.0395 - val_mae: 0.0909 - learning_rate: 1.0000e-05
# Epoch 107/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0506 - mae: 0.1130 - val_loss: 0.0394 - val_mae: 0.0908 - learning_rate: 1.0000e-05
# Epoch 108/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0509 - mae: 0.1132 - val_loss: 0.0394 - val_mae: 0.0913 - learning_rate: 1.0000e-05
# Epoch 109/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0505 - mae: 0.1132 - val_loss: 0.0395 - val_mae: 0.0911 - learning_rate: 1.0000e-05
# Epoch 110/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0507 - mae: 0.1133 - val_loss: 0.0394 - val_mae: 0.0908 - learning_rate: 1.0000e-05
# Epoch 111/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0509 - mae: 0.1138 - val_loss: 0.0395 - val_mae: 0.0911 - learning_rate: 1.0000e-05
# Epoch 112/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0508 - mae: 0.1132 - val_loss: 0.0396 - val_mae: 0.0913 - learning_rate: 1.0000e-05
# Epoch 113/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0506 - mae: 0.1133 - val_loss: 0.0395 - val_mae: 0.0912 - learning_rate: 1.0000e-05
# Epoch 114/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0508 - mae: 0.1135 - val_loss: 0.0396 - val_mae: 0.0910 - learning_rate: 1.0000e-05
# Epoch 115/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0511 - mae: 0.1137 - val_loss: 0.0395 - val_mae: 0.0913 - learning_rate: 1.0000e-05
# Epoch 116/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0509 - mae: 0.1136 - val_loss: 0.0395 - val_mae: 0.0913 - learning_rate: 1.0000e-05
# Epoch 117/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0512 - mae: 0.1138 - val_loss: 0.0394 - val_mae: 0.0910 - learning_rate: 1.0000e-05
# Epoch 118/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0504 - mae: 0.1134 - val_loss: 0.0396 - val_mae: 0.0915 - learning_rate: 1.0000e-05
# Epoch 119/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0506 - mae: 0.1134 - val_loss: 0.0394 - val_mae: 0.0907 - learning_rate: 1.0000e-05
# Epoch 120/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0507 - mae: 0.1129 - val_loss: 0.0395 - val_mae: 0.0911 - learning_rate: 1.0000e-05
# Epoch 121/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0505 - mae: 0.1134 - val_loss: 0.0393 - val_mae: 0.0912 - learning_rate: 1.0000e-05
# Epoch 122/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0510 - mae: 0.1136 - val_loss: 0.0396 - val_mae: 0.0913 - learning_rate: 1.0000e-05
# Epoch 123/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0504 - mae: 0.1132 - val_loss: 0.0394 - val_mae: 0.0910 - learning_rate: 1.0000e-05
# Epoch 124/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0506 - mae: 0.1136 - val_loss: 0.0394 - val_mae: 0.0909 - learning_rate: 1.0000e-05
# Epoch 125/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0505 - mae: 0.1134 - val_loss: 0.0395 - val_mae: 0.0911 - learning_rate: 1.0000e-05
# Epoch 126/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0503 - mae: 0.1128 - val_loss: 0.0395 - val_mae: 0.0913 - learning_rate: 1.0000e-05
# Epoch 127/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0499 - mae: 0.1124 - val_loss: 0.0395 - val_mae: 0.0910 - learning_rate: 1.0000e-05
# Epoch 128/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0508 - mae: 0.1133 - val_loss: 0.0395 - val_mae: 0.0909 - learning_rate: 1.0000e-05
# Epoch 129/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0504 - mae: 0.1132 - val_loss: 0.0395 - val_mae: 0.0910 - learning_rate: 1.0000e-05
# Epoch 130/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0509 - mae: 0.1138 - val_loss: 0.0394 - val_mae: 0.0909 - learning_rate: 1.0000e-05
# Epoch 131/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0506 - mae: 0.1136 - val_loss: 0.0396 - val_mae: 0.0913 - learning_rate: 1.0000e-05
# Epoch 132/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0508 - mae: 0.1134 - val_loss: 0.0393 - val_mae: 0.0909 - learning_rate: 1.0000e-05
# Epoch 133/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0504 - mae: 0.1130 - val_loss: 0.0394 - val_mae: 0.0908 - learning_rate: 1.0000e-05
# Epoch 134/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0503 - mae: 0.1132 - val_loss: 0.0392 - val_mae: 0.0908 - learning_rate: 1.0000e-05
# Epoch 135/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0504 - mae: 0.1127 - val_loss: 0.0395 - val_mae: 0.0914 - learning_rate: 1.0000e-05
# Epoch 136/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0504 - mae: 0.1131 - val_loss: 0.0394 - val_mae: 0.0912 - learning_rate: 1.0000e-05
# Epoch 137/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0505 - mae: 0.1128 - val_loss: 0.0395 - val_mae: 0.0909 - learning_rate: 1.0000e-05
# Epoch 138/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0503 - mae: 0.1130 - val_loss: 0.0395 - val_mae: 0.0915 - learning_rate: 1.0000e-05
# Epoch 139/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0505 - mae: 0.1133 - val_loss: 0.0394 - val_mae: 0.0911 - learning_rate: 1.0000e-05
# Epoch 140/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0504 - mae: 0.1129 - val_loss: 0.0393 - val_mae: 0.0908 - learning_rate: 1.0000e-05
# Epoch 141/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0505 - mae: 0.1132 - val_loss: 0.0393 - val_mae: 0.0911 - learning_rate: 1.0000e-05
# Epoch 142/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0503 - mae: 0.1131 - val_loss: 0.0394 - val_mae: 0.0909 - learning_rate: 1.0000e-05
# Epoch 143/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0500 - mae: 0.1126 - val_loss: 0.0393 - val_mae: 0.0906 - learning_rate: 1.0000e-05
# Epoch 144/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0510 - mae: 0.1138 - val_loss: 0.0393 - val_mae: 0.0907 - learning_rate: 1.0000e-05
# Epoch 145/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0504 - mae: 0.1134 - val_loss: 0.0394 - val_mae: 0.0912 - learning_rate: 1.0000e-05
# Epoch 146/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0506 - mae: 0.1133 - val_loss: 0.0392 - val_mae: 0.0909 - learning_rate: 1.0000e-05
# Epoch 147/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0505 - mae: 0.1133 - val_loss: 0.0394 - val_mae: 0.0912 - learning_rate: 1.0000e-05
# Epoch 148/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0502 - mae: 0.1126 - val_loss: 0.0394 - val_mae: 0.0915 - learning_rate: 1.0000e-05
# Epoch 149/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0505 - mae: 0.1132 - val_loss: 0.0392 - val_mae: 0.0908 - learning_rate: 1.0000e-05
# Epoch 150/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0500 - mae: 0.1129 - val_loss: 0.0394 - val_mae: 0.0914 - learning_rate: 1.0000e-05
# Epoch 151/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0505 - mae: 0.1126 - val_loss: 0.0394 - val_mae: 0.0912 - learning_rate: 1.0000e-05
# Epoch 152/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0496 - mae: 0.1124 - val_loss: 0.0393 - val_mae: 0.0909 - learning_rate: 1.0000e-05
# Epoch 153/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0501 - mae: 0.1129 - val_loss: 0.0394 - val_mae: 0.0915 - learning_rate: 1.0000e-05
# Epoch 154/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0501 - mae: 0.1126 - val_loss: 0.0394 - val_mae: 0.0913 - learning_rate: 1.0000e-05
# Epoch 155/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0502 - mae: 0.1134 - val_loss: 0.0393 - val_mae: 0.0909 - learning_rate: 1.0000e-05
# Epoch 156/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0500 - mae: 0.1123 - val_loss: 0.0394 - val_mae: 0.0911 - learning_rate: 1.0000e-05
# Epoch 157/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0498 - mae: 0.1128 - val_loss: 0.0393 - val_mae: 0.0908 - learning_rate: 1.0000e-05
# Epoch 158/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0501 - mae: 0.1125 - val_loss: 0.0392 - val_mae: 0.0909 - learning_rate: 1.0000e-05
# Epoch 159/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0504 - mae: 0.1130 - val_loss: 0.0392 - val_mae: 0.0910 - learning_rate: 1.0000e-05
# Epoch 160/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0499 - mae: 0.1124 - val_loss: 0.0394 - val_mae: 0.0911 - learning_rate: 1.0000e-05
# Epoch 161/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0508 - mae: 0.1137 - val_loss: 0.0392 - val_mae: 0.0912 - learning_rate: 1.0000e-05
# Epoch 162/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0503 - mae: 0.1134 - val_loss: 0.0392 - val_mae: 0.0908 - learning_rate: 1.0000e-05
# Epoch 163/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0505 - mae: 0.1132 - val_loss: 0.0394 - val_mae: 0.0908 - learning_rate: 1.0000e-05
# Epoch 164/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0509 - mae: 0.1133 - val_loss: 0.0393 - val_mae: 0.0911 - learning_rate: 1.0000e-05
# Epoch 165/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0502 - mae: 0.1133 - val_loss: 0.0391 - val_mae: 0.0902 - learning_rate: 1.0000e-05
# Epoch 166/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0502 - mae: 0.1126 - val_loss: 0.0393 - val_mae: 0.0908 - learning_rate: 1.0000e-05
# Epoch 167/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0499 - mae: 0.1123 - val_loss: 0.0392 - val_mae: 0.0907 - learning_rate: 1.0000e-05
# Epoch 168/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0504 - mae: 0.1131 - val_loss: 0.0392 - val_mae: 0.0908 - learning_rate: 1.0000e-05
# Epoch 169/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0504 - mae: 0.1131 - val_loss: 0.0393 - val_mae: 0.0910 - learning_rate: 1.0000e-05
# Epoch 170/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0503 - mae: 0.1133 - val_loss: 0.0392 - val_mae: 0.0909 - learning_rate: 1.0000e-05
# Epoch 171/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0498 - mae: 0.1127 - val_loss: 0.0391 - val_mae: 0.0904 - learning_rate: 1.0000e-05
# Epoch 172/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0504 - mae: 0.1132 - val_loss: 0.0392 - val_mae: 0.0912 - learning_rate: 1.0000e-05
# Epoch 173/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0499 - mae: 0.1126 - val_loss: 0.0393 - val_mae: 0.0909 - learning_rate: 1.0000e-05
# Epoch 174/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0506 - mae: 0.1133 - val_loss: 0.0391 - val_mae: 0.0907 - learning_rate: 1.0000e-05
# Epoch 175/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0505 - mae: 0.1131 - val_loss: 0.0390 - val_mae: 0.0902 - learning_rate: 1.0000e-05
# Epoch 176/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0500 - mae: 0.1127 - val_loss: 0.0391 - val_mae: 0.0909 - learning_rate: 1.0000e-05
# Epoch 177/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0501 - mae: 0.1131 - val_loss: 0.0391 - val_mae: 0.0905 - learning_rate: 1.0000e-05
# Epoch 178/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0497 - mae: 0.1125 - val_loss: 0.0392 - val_mae: 0.0910 - learning_rate: 1.0000e-05
# Epoch 179/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0499 - mae: 0.1123 - val_loss: 0.0391 - val_mae: 0.0909 - learning_rate: 1.0000e-05
# Epoch 180/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0503 - mae: 0.1124 - val_loss: 0.0390 - val_mae: 0.0905 - learning_rate: 1.0000e-05
# Epoch 181/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0498 - mae: 0.1120 - val_loss: 0.0391 - val_mae: 0.0908 - learning_rate: 1.0000e-05
# Epoch 182/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0501 - mae: 0.1126 - val_loss: 0.0391 - val_mae: 0.0908 - learning_rate: 1.0000e-05
# Epoch 183/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0506 - mae: 0.1132 - val_loss: 0.0391 - val_mae: 0.0908 - learning_rate: 1.0000e-05
# Epoch 184/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0505 - mae: 0.1131 - val_loss: 0.0393 - val_mae: 0.0909 - learning_rate: 1.0000e-05
# Epoch 185/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0503 - mae: 0.1129 - val_loss: 0.0393 - val_mae: 0.0912 - learning_rate: 1.0000e-05
# Epoch 186/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0500 - mae: 0.1126 - val_loss: 0.0391 - val_mae: 0.0905 - learning_rate: 1.0000e-05
# Epoch 187/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0502 - mae: 0.1125 - val_loss: 0.0391 - val_mae: 0.0908 - learning_rate: 1.0000e-05
# Epoch 188/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0502 - mae: 0.1129 - val_loss: 0.0390 - val_mae: 0.0911 - learning_rate: 1.0000e-05
# Epoch 189/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0501 - mae: 0.1127 - val_loss: 0.0391 - val_mae: 0.0909 - learning_rate: 1.0000e-05
# Epoch 190/300
# 574/574 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0504 - mae: 0.1129 - val_loss: 0.0390 - val_mae: 0.0904 - learning_rate: 1.0000e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
#
# Evaluation on train:
#                        Target        R2          RMSE
# 2   voltage_fall_time_pulse1  0.998555  2.612718e-10
# 3   voltage_fall_time_pulse2  0.998549  2.614708e-10
# 6   current_fall_time_pulse1  0.995676  7.758541e-10
# 7   current_fall_time_pulse2  0.995422  7.958998e-10
# 0   voltage_rise_time_pulse1  0.991100  3.822191e-10
# 12     ringing_frequency_MHz  0.990367  3.836925e-02
# 11        undershoot_pulse_2  0.988283  1.483890e+00
# 10        undershoot_pulse_1  0.987324  1.542566e+00
# 8          overshoot_pulse_1  0.975528  1.913226e+00
# 9          overshoot_pulse_2  0.938914  6.250831e+00
# 4   current_rise_time_pulse1  0.934253  1.259904e-08
# 1   voltage_rise_time_pulse2  0.927841  1.081739e-09
# 5   current_rise_time_pulse2  0.922391  6.997019e-09
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# Evaluation on val:
#                        Target        R2          RMSE
# 2   voltage_fall_time_pulse1  0.998557  2.598308e-10
# 3   voltage_fall_time_pulse2  0.998552  2.599730e-10
# 6   current_fall_time_pulse1  0.995586  7.776706e-10
# 7   current_fall_time_pulse2  0.995430  7.885134e-10
# 0   voltage_rise_time_pulse1  0.990532  3.928298e-10
# 12     ringing_frequency_MHz  0.990310  3.828186e-02
# 11        undershoot_pulse_2  0.987740  1.522818e+00
# 10        undershoot_pulse_1  0.986434  1.602206e+00
# 8          overshoot_pulse_1  0.973433  1.935766e+00
# 9          overshoot_pulse_2  0.935501  6.340316e+00
# 4   current_rise_time_pulse1  0.934994  1.238087e-08
# 5   current_rise_time_pulse2  0.918483  7.092777e-09
# 1   voltage_rise_time_pulse2  0.911289  1.178374e-09
# 2698/2698 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step
#
# Evaluation on test:
#                        Target        R2          RMSE
# 2   voltage_fall_time_pulse1  0.998555  2.610562e-10
# 3   voltage_fall_time_pulse2  0.998550  2.612467e-10
# 6   current_fall_time_pulse1  0.995663  7.761268e-10
# 7   current_fall_time_pulse2  0.995423  7.947961e-10
# 0   voltage_rise_time_pulse1  0.991015  3.838295e-10
# 12     ringing_frequency_MHz  0.990359  3.835615e-02
# 11        undershoot_pulse_2  0.988201  1.489794e+00
# 10        undershoot_pulse_1  0.987190  1.551659e+00
# 8          overshoot_pulse_1  0.975230  1.916624e+00
# 9          overshoot_pulse_2  0.938413  6.264336e+00
# 4   current_rise_time_pulse1  0.934362  1.256655e-08
# 1   voltage_rise_time_pulse2  0.925432  1.096778e-09
# 5   current_rise_time_pulse2  0.921818  7.011467e-09
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
#
# Evaluation on unseen:
#                        Target        R2          RMSE
# 6   current_fall_time_pulse1  0.921716  3.141186e-09
# 7   current_fall_time_pulse2  0.915960  3.232239e-09
# 8          overshoot_pulse_1  0.782599  6.305406e+00
# 9          overshoot_pulse_2  0.748130  1.039741e+01
# 1   voltage_rise_time_pulse2  0.477300  3.372944e-09
# 11        undershoot_pulse_2  0.464133  7.132041e+00
# 10        undershoot_pulse_1  0.448310  7.285956e+00
# 5   current_rise_time_pulse2  0.404425  1.293814e-08
#                       Target        R2          RMSE
# 6   current_fall_time_pulse1  0.921716  3.141186e-09
# 7   current_fall_time_pulse2  0.915960  3.232239e-09
# 8          overshoot_pulse_1  0.782599  6.305406e+00
# 9          overshoot_pulse_2  0.748130  1.039741e+01
# 1   voltage_rise_time_pulse2  0.477300  3.372944e-09
# 11        undershoot_pulse_2  0.464133  7.132041e+00
# 10        undershoot_pulse_1  0.448310  7.285956e+00
# 5   current_rise_time_pulse2  0.404425  1.293814e-08
