# %% [markdown]
# ## Attention ANN

# %% [markdown]
# | Iteration | Dropout | L2 Reg. | BatchNorm | EarlyStopping | LR Scheduler      | Scaling                              | Physics Features | Notes                               |
# | --------- | ------- | ------- | --------- | ------------- | ----------------- | ------------------------------------ | ---------------- | ----------------------------------- |
# | **1**     | 0.2     | 1e-4      | Yes        | Yes            | ReduceLROnPlateau     | StdScaler (X) + Ringing→MinMax       | Yes              | Best overall: 11 positive R², interpretable attentionANN                    |

# %% [markdown]
# ### ITERATION 1

# %%
# ==================== ATTENTION ANN (Best Iteration) ====================
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, regularizers
import matplotlib.pyplot as plt

# ============== SETTINGS ==============
SEED = 42
UNSEEN_PART = 'C2M0040120D'
BASE_DIR = "aiteration_2"
os.makedirs(f"{BASE_DIR}/r2_rmse_tables", exist_ok=True)
os.makedirs(f"{BASE_DIR}/train_val_loss_curves", exist_ok=True)
os.makedirs(f"{BASE_DIR}/models", exist_ok=True)

# ============== LOAD DATA ==============
df = pd.read_csv(
    r"C:\Users\pc\Desktop\Neural_Network_Models\merged_train_5_MOSFETs_25percent_balanced.csv"
)

TARGET_COLUMNS = [
    'voltage_rise_time_pulse1', 'voltage_rise_time_pulse2',
    'voltage_fall_time_pulse1', 'voltage_fall_time_pulse2',
    'current_rise_time_pulse1', 'current_rise_time_pulse2',
    'current_fall_time_pulse1', 'current_fall_time_pulse2',
    'overshoot_pulse_1', 'overshoot_pulse_2',
    'undershoot_pulse_1', 'undershoot_pulse_2',
    'ringing_frequency_MHz'
]
DROP_COLUMNS = ['DeviceID', 'MOSFET', 'Part_Number']

# ============== SPLIT SEEN/UNSEEN DEVICES ==============
seen_parts = [p for p in df['Part_Number'].unique().tolist() if p != UNSEEN_PART]
train_df = df[df['Part_Number'].isin(seen_parts)].copy()
test_df  = df[df['Part_Number'] == UNSEEN_PART].copy()

# ============== PHYSICS FEATURES ==============
def compute_physics_features(row):
    L_eq = row[['Ls4','Ls5','Ls6','Ls7','Ls8','Ls9','Ls10','Ls11']].sum()
    C_eq = row.get("Coss", 1e-12)
    f_res = 1/(2*np.pi*np.sqrt(L_eq*C_eq))/1e6 if L_eq>0 and C_eq>0 else 0
    overshoot_est = row.get("VDS_max",0) - row.get("Vbus",0)
    undershoot_est = - row.get("VGS_th_min",0)
    dVdt_est = row.get("VDS_max",0)/row.get("Tp1",1e-9)
    dIdt_est = row.get("ID_max_25C",0)/row.get("Tp1",1e-9)
    return pd.Series([f_res, overshoot_est, undershoot_est, dVdt_est, dIdt_est])

for df_ in [train_df, test_df]:
    df_[['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est']] = \
        df_.apply(compute_physics_features, axis=1)

physics_features = ['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est']
INPUT_COLUMNS = [c for c in df.columns if c not in TARGET_COLUMNS + DROP_COLUMNS] + physics_features

# ============== SCALE INPUTS ==============
input_scaler = StandardScaler()
input_scaler.fit(pd.concat([train_df[INPUT_COLUMNS], test_df[INPUT_COLUMNS]]))
X_train_all = input_scaler.transform(train_df[INPUT_COLUMNS])
X_test_all  = input_scaler.transform(test_df[INPUT_COLUMNS])

# Separate physics cols
phys_idx = [INPUT_COLUMNS.index(c) for c in physics_features]
X_train_phys = X_train_all[:, phys_idx]
X_test_phys  = X_test_all[:, phys_idx]
X_train_main = np.delete(X_train_all, phys_idx, axis=1)
X_test_main  = np.delete(X_test_all, phys_idx, axis=1)

# ============== SCALE OUTPUTS (per target) ==============
output_scalers, y_train_scaled, y_test_scaled = {}, [], []
for col in TARGET_COLUMNS:
    scaler = MinMaxScaler() if col == 'ringing_frequency_MHz' else StandardScaler()
    y_train_scaled.append(scaler.fit_transform(train_df[[col]]).flatten())
    y_test_scaled.append(scaler.transform(test_df[[col]]).flatten())
    output_scalers[col] = scaler
y_train_scaled = np.array(y_train_scaled).T
y_test_scaled  = np.array(y_test_scaled).T

# ============== SPLIT TRAIN/VAL ==============
Xtr_main, Xval_main, Xtr_phys, Xval_phys, ytr, yval = train_test_split(
    X_train_main, X_train_phys, y_train_scaled,
    test_size=0.15, random_state=SEED
)

# ============== BUILD ATTENTION ANN ==============
def build_attention_ann(input_dim_main, input_dim_phys, output_dim, l2_reg=1e-4, dropout_rate=0.2):
    inp_main = layers.Input(shape=(input_dim_main,), name="main_inputs")
    inp_phys = layers.Input(shape=(input_dim_phys,), name="physics_inputs")

    # Main backbone
    x_main = layers.Dense(128, kernel_regularizer=regularizers.l2(l2_reg))(inp_main)
    x_main = layers.BatchNormalization()(x_main); x_main = layers.ReLU()(x_main)
    x_main = layers.Dropout(dropout_rate)(x_main)

    x_main = layers.Dense(64, kernel_regularizer=regularizers.l2(l2_reg))(x_main)
    x_main = layers.BatchNormalization()(x_main); x_main = layers.ReLU()(x_main)
    x_main = layers.Dropout(dropout_rate)(x_main)

    # Physics branch
    x_phys = layers.Dense(32, activation="relu")(inp_phys)

    # Attention mechanism
    concat = layers.Concatenate()([x_main, x_phys])
    attn = layers.Dense(concat.shape[-1], activation="softmax")(concat)
    attended = layers.multiply([concat, attn])

    # Multi-head outputs
    outputs = []
    for col in TARGET_COLUMNS:
        h = layers.Dense(64, activation="relu")(attended)
        h = layers.Dropout(dropout_rate)(h)
        h = layers.Dense(32, activation="relu")(h)
        out = layers.Dense(1, activation="linear", name=col)(h)
        outputs.append(out)

    model = models.Model(inputs=[inp_main, inp_phys], outputs=outputs)
    return model

model = build_attention_ann(Xtr_main.shape[1], Xtr_phys.shape[1], len(TARGET_COLUMNS))

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-4),
    loss=["mse"]*len(TARGET_COLUMNS),
    metrics=["mae"]*len(TARGET_COLUMNS)
)

early_stop = callbacks.EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)
reduce_lr  = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=5)

history = model.fit(
    [Xtr_main, Xtr_phys],
    [ytr[:,i] for i in range(len(TARGET_COLUMNS))],
    validation_data=([Xval_main,Xval_phys],[yval[:,i] for i in range(len(TARGET_COLUMNS))]),
    epochs=120, batch_size=256, callbacks=[early_stop, reduce_lr], verbose=1
)

model.save(f"{BASE_DIR}/models/attention_ann.h5")

# ============== LOSS CURVE ==============
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel("Epoch"); plt.ylabel("MSE Loss")
plt.title("Train vs Validation Loss")
plt.legend(); plt.savefig(f"{BASE_DIR}/train_val_loss_curves/loss.png"); plt.close()

# ============== EVALUATION ==============
def evaluate_and_save(X_main, X_phys, y_scaled, name, positive_only=False):
    y_pred_scaled_list = model.predict([X_main, X_phys])
    results = []
    for i, col in enumerate(TARGET_COLUMNS):
        y_true = output_scalers[col].inverse_transform(y_scaled[:,i].reshape(-1,1)).flatten()
        y_pred = output_scalers[col].inverse_transform(y_pred_scaled_list[i].reshape(-1,1)).flatten()
        r2 = r2_score(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        results.append((col, r2, rmse))
    df_results = pd.DataFrame(results, columns=["Target","R2","RMSE"]).sort_values("R2",ascending=False)
    if positive_only:
        df_results = df_results[df_results["R2"]>0]
    print(f"\n{name}:\n",df_results)
    df_results.to_csv(f"{BASE_DIR}/r2_rmse_tables/{name}.csv", index=False)
    return df_results

evaluate_and_save(Xtr_main,Xtr_phys,ytr,"train")
evaluate_and_save(Xval_main,Xval_phys,yval,"val")
evaluate_and_save(X_train_main,X_train_phys,y_train_scaled,"test")
evaluate_and_save(X_test_main,X_test_phys,y_test_scaled,"unseen",positive_only=True)
# Out:
# Epoch 1/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 36s 14ms/step - current_fall_time_pulse1_loss: 0.6140 - current_fall_time_pulse1_mae: 0.6029 - current_fall_time_pulse2_loss: 0.6242 - current_fall_time_pulse2_mae: 0.6053 - current_rise_time_pulse1_loss: 0.6335 - current_rise_time_pulse1_mae: 0.5989 - current_rise_time_pulse2_loss: 0.6205 - current_rise_time_pulse2_mae: 0.6360 - loss: 7.5962 - overshoot_pulse_1_loss: 0.8112 - overshoot_pulse_1_mae: 0.6854 - overshoot_pulse_2_loss: 0.6921 - overshoot_pulse_2_mae: 0.6360 - ringing_frequency_MHz_loss: 0.0947 - ringing_frequency_MHz_mae: 0.2080 - undershoot_pulse_1_loss: 0.6688 - undershoot_pulse_1_mae: 0.6190 - undershoot_pulse_2_loss: 0.6915 - undershoot_pulse_2_mae: 0.6255 - voltage_fall_time_pulse1_loss: 0.4948 - voltage_fall_time_pulse1_mae: 0.5177 - voltage_fall_time_pulse2_loss: 0.4708 - voltage_fall_time_pulse2_mae: 0.5026 - voltage_rise_time_pulse1_loss: 0.5409 - voltage_rise_time_pulse1_mae: 0.5478 - voltage_rise_time_pulse2_loss: 0.6258 - voltage_rise_time_pulse2_mae: 0.5468 - val_current_fall_time_pulse1_loss: 0.0372 - val_current_fall_time_pulse1_mae: 0.1483 - val_current_fall_time_pulse2_loss: 0.0366 - val_current_fall_time_pulse2_mae: 0.1470 - val_current_rise_time_pulse1_loss: 0.0820 - val_current_rise_time_pulse1_mae: 0.1933 - val_current_rise_time_pulse2_loss: 0.1706 - val_current_rise_time_pulse2_mae: 0.2956 - val_loss: 1.1042 - val_overshoot_pulse_1_loss: 0.1584 - val_overshoot_pulse_1_mae: 0.2957 - val_overshoot_pulse_2_loss: 0.1137 - val_overshoot_pulse_2_mae: 0.2555 - val_ringing_frequency_MHz_loss: 0.0019 - val_ringing_frequency_MHz_mae: 0.0323 - val_undershoot_pulse_1_loss: 0.0866 - val_undershoot_pulse_1_mae: 0.2095 - val_undershoot_pulse_2_loss: 0.0830 - val_undershoot_pulse_2_mae: 0.2013 - val_voltage_fall_time_pulse1_loss: 0.0204 - val_voltage_fall_time_pulse1_mae: 0.1087 - val_voltage_fall_time_pulse2_loss: 0.0217 - val_voltage_fall_time_pulse2_mae: 0.1089 - val_voltage_rise_time_pulse1_loss: 0.0789 - val_voltage_rise_time_pulse1_mae: 0.1868 - val_voltage_rise_time_pulse2_loss: 0.1992 - val_voltage_rise_time_pulse2_mae: 0.2444 - learning_rate: 5.0000e-04
# Epoch 2/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - current_fall_time_pulse1_loss: 0.0754 - current_fall_time_pulse1_mae: 0.2072 - current_fall_time_pulse2_loss: 0.0738 - current_fall_time_pulse2_mae: 0.2051 - current_rise_time_pulse1_loss: 0.1141 - current_rise_time_pulse1_mae: 0.2447 - current_rise_time_pulse2_loss: 0.1832 - current_rise_time_pulse2_mae: 0.3118 - loss: 1.4527 - overshoot_pulse_1_loss: 0.2078 - overshoot_pulse_1_mae: 0.3384 - overshoot_pulse_2_loss: 0.1472 - overshoot_pulse_2_mae: 0.2943 - ringing_frequency_MHz_loss: 0.0044 - ringing_frequency_MHz_mae: 0.0473 - undershoot_pulse_1_loss: 0.1195 - undershoot_pulse_1_mae: 0.2578 - undershoot_pulse_2_loss: 0.1209 - undershoot_pulse_2_mae: 0.2607 - voltage_fall_time_pulse1_loss: 0.0403 - voltage_fall_time_pulse1_mae: 0.1458 - voltage_fall_time_pulse2_loss: 0.0407 - voltage_fall_time_pulse2_mae: 0.1468 - voltage_rise_time_pulse1_loss: 0.0904 - voltage_rise_time_pulse1_mae: 0.2136 - voltage_rise_time_pulse2_loss: 0.2225 - voltage_rise_time_pulse2_mae: 0.2800 - val_current_fall_time_pulse1_loss: 0.0138 - val_current_fall_time_pulse1_mae: 0.0900 - val_current_fall_time_pulse2_loss: 0.0141 - val_current_fall_time_pulse2_mae: 0.0902 - val_current_rise_time_pulse1_loss: 0.0724 - val_current_rise_time_pulse1_mae: 0.1818 - val_current_rise_time_pulse2_loss: 0.1239 - val_current_rise_time_pulse2_mae: 0.2229 - val_loss: 0.7127 - val_overshoot_pulse_1_loss: 0.0868 - val_overshoot_pulse_1_mae: 0.2169 - val_overshoot_pulse_2_loss: 0.0905 - val_overshoot_pulse_2_mae: 0.2326 - val_ringing_frequency_MHz_loss: 0.0012 - val_ringing_frequency_MHz_mae: 0.0251 - val_undershoot_pulse_1_loss: 0.0386 - val_undershoot_pulse_1_mae: 0.1352 - val_undershoot_pulse_2_loss: 0.0375 - val_undershoot_pulse_2_mae: 0.1328 - val_voltage_fall_time_pulse1_loss: 0.0050 - val_voltage_fall_time_pulse1_mae: 0.0556 - val_voltage_fall_time_pulse2_loss: 0.0048 - val_voltage_fall_time_pulse2_mae: 0.0539 - val_voltage_rise_time_pulse1_loss: 0.0485 - val_voltage_rise_time_pulse1_mae: 0.1439 - val_voltage_rise_time_pulse2_loss: 0.1618 - val_voltage_rise_time_pulse2_mae: 0.2303 - learning_rate: 5.0000e-04
# Epoch 3/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - current_fall_time_pulse1_loss: 0.0475 - current_fall_time_pulse1_mae: 0.1645 - current_fall_time_pulse2_loss: 0.0462 - current_fall_time_pulse2_mae: 0.1632 - current_rise_time_pulse1_loss: 0.0936 - current_rise_time_pulse1_mae: 0.2135 - current_rise_time_pulse2_loss: 0.1562 - current_rise_time_pulse2_mae: 0.2675 - loss: 1.1131 - overshoot_pulse_1_loss: 0.1545 - overshoot_pulse_1_mae: 0.2916 - overshoot_pulse_2_loss: 0.1200 - overshoot_pulse_2_mae: 0.2672 - ringing_frequency_MHz_loss: 0.0027 - ringing_frequency_MHz_mae: 0.0375 - undershoot_pulse_1_loss: 0.0837 - undershoot_pulse_1_mae: 0.2134 - undershoot_pulse_2_loss: 0.0852 - undershoot_pulse_2_mae: 0.2158 - voltage_fall_time_pulse1_loss: 0.0243 - voltage_fall_time_pulse1_mae: 0.1143 - voltage_fall_time_pulse2_loss: 0.0235 - voltage_fall_time_pulse2_mae: 0.1124 - voltage_rise_time_pulse1_loss: 0.0661 - voltage_rise_time_pulse1_mae: 0.1787 - voltage_rise_time_pulse2_loss: 0.1972 - voltage_rise_time_pulse2_mae: 0.2574 - val_current_fall_time_pulse1_loss: 0.0087 - val_current_fall_time_pulse1_mae: 0.0716 - val_current_fall_time_pulse2_loss: 0.0090 - val_current_fall_time_pulse2_mae: 0.0729 - val_current_rise_time_pulse1_loss: 0.0695 - val_current_rise_time_pulse1_mae: 0.1699 - val_current_rise_time_pulse2_loss: 0.1166 - val_current_rise_time_pulse2_mae: 0.2075 - val_loss: 0.6129 - val_overshoot_pulse_1_loss: 0.0694 - val_overshoot_pulse_1_mae: 0.1950 - val_overshoot_pulse_2_loss: 0.0823 - val_overshoot_pulse_2_mae: 0.2225 - val_ringing_frequency_MHz_loss: 8.1399e-04 - val_ringing_frequency_MHz_mae: 0.0202 - val_undershoot_pulse_1_loss: 0.0320 - val_undershoot_pulse_1_mae: 0.1226 - val_undershoot_pulse_2_loss: 0.0315 - val_undershoot_pulse_2_mae: 0.1215 - val_voltage_fall_time_pulse1_loss: 0.0041 - val_voltage_fall_time_pulse1_mae: 0.0472 - val_voltage_fall_time_pulse2_loss: 0.0040 - val_voltage_fall_time_pulse2_mae: 0.0452 - val_voltage_rise_time_pulse1_loss: 0.0377 - val_voltage_rise_time_pulse1_mae: 0.1246 - val_voltage_rise_time_pulse2_loss: 0.1339 - val_voltage_rise_time_pulse2_mae: 0.2123 - learning_rate: 5.0000e-04
# Epoch 4/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - current_fall_time_pulse1_loss: 0.0356 - current_fall_time_pulse1_mae: 0.1432 - current_fall_time_pulse2_loss: 0.0347 - current_fall_time_pulse2_mae: 0.1409 - current_rise_time_pulse1_loss: 0.0867 - current_rise_time_pulse1_mae: 0.2003 - current_rise_time_pulse2_loss: 0.1375 - current_rise_time_pulse2_mae: 0.2434 - loss: 0.9636 - overshoot_pulse_1_loss: 0.1311 - overshoot_pulse_1_mae: 0.2683 - overshoot_pulse_2_loss: 0.1092 - overshoot_pulse_2_mae: 0.2543 - ringing_frequency_MHz_loss: 0.0021 - ringing_frequency_MHz_mae: 0.0324 - undershoot_pulse_1_loss: 0.0719 - undershoot_pulse_1_mae: 0.1960 - undershoot_pulse_2_loss: 0.0713 - undershoot_pulse_2_mae: 0.1951 - voltage_fall_time_pulse1_loss: 0.0182 - voltage_fall_time_pulse1_mae: 0.0989 - voltage_fall_time_pulse2_loss: 0.0178 - voltage_fall_time_pulse2_mae: 0.0974 - voltage_rise_time_pulse1_loss: 0.0533 - voltage_rise_time_pulse1_mae: 0.1590 - voltage_rise_time_pulse2_loss: 0.1821 - voltage_rise_time_pulse2_mae: 0.2420 - val_current_fall_time_pulse1_loss: 0.0074 - val_current_fall_time_pulse1_mae: 0.0648 - val_current_fall_time_pulse2_loss: 0.0074 - val_current_fall_time_pulse2_mae: 0.0651 - val_current_rise_time_pulse1_loss: 0.0671 - val_current_rise_time_pulse1_mae: 0.1573 - val_current_rise_time_pulse2_loss: 0.1129 - val_current_rise_time_pulse2_mae: 0.1996 - val_loss: 0.5662 - val_overshoot_pulse_1_loss: 0.0601 - val_overshoot_pulse_1_mae: 0.1820 - val_overshoot_pulse_2_loss: 0.0801 - val_overshoot_pulse_2_mae: 0.2172 - val_ringing_frequency_MHz_loss: 5.4201e-04 - val_ringing_frequency_MHz_mae: 0.0171 - val_undershoot_pulse_1_loss: 0.0262 - val_undershoot_pulse_1_mae: 0.1086 - val_undershoot_pulse_2_loss: 0.0256 - val_undershoot_pulse_2_mae: 0.1073 - val_voltage_fall_time_pulse1_loss: 0.0038 - val_voltage_fall_time_pulse1_mae: 0.0452 - val_voltage_fall_time_pulse2_loss: 0.0037 - val_voltage_fall_time_pulse2_mae: 0.0440 - val_voltage_rise_time_pulse1_loss: 0.0324 - val_voltage_rise_time_pulse1_mae: 0.1143 - val_voltage_rise_time_pulse2_loss: 0.1259 - val_voltage_rise_time_pulse2_mae: 0.1999 - learning_rate: 5.0000e-04
# Epoch 5/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - current_fall_time_pulse1_loss: 0.0297 - current_fall_time_pulse1_mae: 0.1305 - current_fall_time_pulse2_loss: 0.0286 - current_fall_time_pulse2_mae: 0.1289 - current_rise_time_pulse1_loss: 0.0820 - current_rise_time_pulse1_mae: 0.1909 - current_rise_time_pulse2_loss: 0.1317 - current_rise_time_pulse2_mae: 0.2328 - loss: 0.8749 - overshoot_pulse_1_loss: 0.1150 - overshoot_pulse_1_mae: 0.2526 - overshoot_pulse_2_loss: 0.1025 - overshoot_pulse_2_mae: 0.2467 - ringing_frequency_MHz_loss: 0.0016 - ringing_frequency_MHz_mae: 0.0286 - undershoot_pulse_1_loss: 0.0634 - undershoot_pulse_1_mae: 0.1816 - undershoot_pulse_2_loss: 0.0619 - undershoot_pulse_2_mae: 0.1808 - voltage_fall_time_pulse1_loss: 0.0139 - voltage_fall_time_pulse1_mae: 0.0863 - voltage_fall_time_pulse2_loss: 0.0138 - voltage_fall_time_pulse2_mae: 0.0858 - voltage_rise_time_pulse1_loss: 0.0448 - voltage_rise_time_pulse1_mae: 0.1437 - voltage_rise_time_pulse2_loss: 0.1739 - voltage_rise_time_pulse2_mae: 0.2342 - val_current_fall_time_pulse1_loss: 0.0079 - val_current_fall_time_pulse1_mae: 0.0635 - val_current_fall_time_pulse2_loss: 0.0081 - val_current_fall_time_pulse2_mae: 0.0656 - val_current_rise_time_pulse1_loss: 0.0663 - val_current_rise_time_pulse1_mae: 0.1590 - val_current_rise_time_pulse2_loss: 0.1073 - val_current_rise_time_pulse2_mae: 0.1908 - val_loss: 0.5449 - val_overshoot_pulse_1_loss: 0.0533 - val_overshoot_pulse_1_mae: 0.1730 - val_overshoot_pulse_2_loss: 0.0775 - val_overshoot_pulse_2_mae: 0.2152 - val_ringing_frequency_MHz_loss: 4.8707e-04 - val_ringing_frequency_MHz_mae: 0.0160 - val_undershoot_pulse_1_loss: 0.0276 - val_undershoot_pulse_1_mae: 0.1130 - val_undershoot_pulse_2_loss: 0.0270 - val_undershoot_pulse_2_mae: 0.1121 - val_voltage_fall_time_pulse1_loss: 0.0040 - val_voltage_fall_time_pulse1_mae: 0.0454 - val_voltage_fall_time_pulse2_loss: 0.0039 - val_voltage_fall_time_pulse2_mae: 0.0442 - val_voltage_rise_time_pulse1_loss: 0.0277 - val_voltage_rise_time_pulse1_mae: 0.1051 - val_voltage_rise_time_pulse2_loss: 0.1210 - val_voltage_rise_time_pulse2_mae: 0.1981 - learning_rate: 5.0000e-04
# Epoch 6/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - current_fall_time_pulse1_loss: 0.0263 - current_fall_time_pulse1_mae: 0.1231 - current_fall_time_pulse2_loss: 0.0260 - current_fall_time_pulse2_mae: 0.1227 - current_rise_time_pulse1_loss: 0.0799 - current_rise_time_pulse1_mae: 0.1865 - current_rise_time_pulse2_loss: 0.1245 - current_rise_time_pulse2_mae: 0.2228 - loss: 0.8063 - overshoot_pulse_1_loss: 0.1025 - overshoot_pulse_1_mae: 0.2377 - overshoot_pulse_2_loss: 0.0987 - overshoot_pulse_2_mae: 0.2420 - ringing_frequency_MHz_loss: 0.0014 - ringing_frequency_MHz_mae: 0.0260 - undershoot_pulse_1_loss: 0.0591 - undershoot_pulse_1_mae: 0.1760 - undershoot_pulse_2_loss: 0.0581 - undershoot_pulse_2_mae: 0.1750 - voltage_fall_time_pulse1_loss: 0.0115 - voltage_fall_time_pulse1_mae: 0.0779 - voltage_fall_time_pulse2_loss: 0.0118 - voltage_fall_time_pulse2_mae: 0.0793 - voltage_rise_time_pulse1_loss: 0.0405 - voltage_rise_time_pulse1_mae: 0.1343 - voltage_rise_time_pulse2_loss: 0.1539 - voltage_rise_time_pulse2_mae: 0.2273 - val_current_fall_time_pulse1_loss: 0.0053 - val_current_fall_time_pulse1_mae: 0.0554 - val_current_fall_time_pulse2_loss: 0.0053 - val_current_fall_time_pulse2_mae: 0.0558 - val_current_rise_time_pulse1_loss: 0.0657 - val_current_rise_time_pulse1_mae: 0.1542 - val_current_rise_time_pulse2_loss: 0.1060 - val_current_rise_time_pulse2_mae: 0.1848 - val_loss: 0.5252 - val_overshoot_pulse_1_loss: 0.0501 - val_overshoot_pulse_1_mae: 0.1697 - val_overshoot_pulse_2_loss: 0.0774 - val_overshoot_pulse_2_mae: 0.2134 - val_ringing_frequency_MHz_loss: 5.5248e-04 - val_ringing_frequency_MHz_mae: 0.0166 - val_undershoot_pulse_1_loss: 0.0249 - val_undershoot_pulse_1_mae: 0.1044 - val_undershoot_pulse_2_loss: 0.0245 - val_undershoot_pulse_2_mae: 0.1038 - val_voltage_fall_time_pulse1_loss: 0.0026 - val_voltage_fall_time_pulse1_mae: 0.0375 - val_voltage_fall_time_pulse2_loss: 0.0023 - val_voltage_fall_time_pulse2_mae: 0.0343 - val_voltage_rise_time_pulse1_loss: 0.0252 - val_voltage_rise_time_pulse1_mae: 0.0949 - val_voltage_rise_time_pulse2_loss: 0.1224 - val_voltage_rise_time_pulse2_mae: 0.1907 - learning_rate: 5.0000e-04
# Epoch 7/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - current_fall_time_pulse1_loss: 0.0235 - current_fall_time_pulse1_mae: 0.1163 - current_fall_time_pulse2_loss: 0.0232 - current_fall_time_pulse2_mae: 0.1160 - current_rise_time_pulse1_loss: 0.0792 - current_rise_time_pulse1_mae: 0.1839 - current_rise_time_pulse2_loss: 0.1218 - current_rise_time_pulse2_mae: 0.2183 - loss: 0.7460 - overshoot_pulse_1_loss: 0.0935 - overshoot_pulse_1_mae: 0.2287 - overshoot_pulse_2_loss: 0.0947 - overshoot_pulse_2_mae: 0.2377 - ringing_frequency_MHz_loss: 0.0012 - ringing_frequency_MHz_mae: 0.0241 - undershoot_pulse_1_loss: 0.0529 - undershoot_pulse_1_mae: 0.1671 - undershoot_pulse_2_loss: 0.0519 - undershoot_pulse_2_mae: 0.1659 - voltage_fall_time_pulse1_loss: 0.0099 - voltage_fall_time_pulse1_mae: 0.0719 - voltage_fall_time_pulse2_loss: 0.0101 - voltage_fall_time_pulse2_mae: 0.0728 - voltage_rise_time_pulse1_loss: 0.0360 - voltage_rise_time_pulse1_mae: 0.1253 - voltage_rise_time_pulse2_loss: 0.1362 - voltage_rise_time_pulse2_mae: 0.2190 - val_current_fall_time_pulse1_loss: 0.0054 - val_current_fall_time_pulse1_mae: 0.0541 - val_current_fall_time_pulse2_loss: 0.0053 - val_current_fall_time_pulse2_mae: 0.0536 - val_current_rise_time_pulse1_loss: 0.0658 - val_current_rise_time_pulse1_mae: 0.1596 - val_current_rise_time_pulse2_loss: 0.1032 - val_current_rise_time_pulse2_mae: 0.1829 - val_loss: 0.4922 - val_overshoot_pulse_1_loss: 0.0477 - val_overshoot_pulse_1_mae: 0.1655 - val_overshoot_pulse_2_loss: 0.0747 - val_overshoot_pulse_2_mae: 0.2115 - val_ringing_frequency_MHz_loss: 4.8273e-04 - val_ringing_frequency_MHz_mae: 0.0161 - val_undershoot_pulse_1_loss: 0.0222 - val_undershoot_pulse_1_mae: 0.0990 - val_undershoot_pulse_2_loss: 0.0213 - val_undershoot_pulse_2_mae: 0.0965 - val_voltage_fall_time_pulse1_loss: 0.0027 - val_voltage_fall_time_pulse1_mae: 0.0380 - val_voltage_fall_time_pulse2_loss: 0.0028 - val_voltage_fall_time_pulse2_mae: 0.0361 - val_voltage_rise_time_pulse1_loss: 0.0232 - val_voltage_rise_time_pulse1_mae: 0.0911 - val_voltage_rise_time_pulse2_loss: 0.1050 - val_voltage_rise_time_pulse2_mae: 0.1896 - learning_rate: 5.0000e-04
# Epoch 8/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - current_fall_time_pulse1_loss: 0.0213 - current_fall_time_pulse1_mae: 0.1107 - current_fall_time_pulse2_loss: 0.0212 - current_fall_time_pulse2_mae: 0.1103 - current_rise_time_pulse1_loss: 0.0757 - current_rise_time_pulse1_mae: 0.1783 - current_rise_time_pulse2_loss: 0.1178 - current_rise_time_pulse2_mae: 0.2129 - loss: 0.7040 - overshoot_pulse_1_loss: 0.0887 - overshoot_pulse_1_mae: 0.2229 - overshoot_pulse_2_loss: 0.0908 - overshoot_pulse_2_mae: 0.2333 - ringing_frequency_MHz_loss: 9.8542e-04 - ringing_frequency_MHz_mae: 0.0222 - undershoot_pulse_1_loss: 0.0497 - undershoot_pulse_1_mae: 0.1605 - undershoot_pulse_2_loss: 0.0487 - undershoot_pulse_2_mae: 0.1594 - voltage_fall_time_pulse1_loss: 0.0090 - voltage_fall_time_pulse1_mae: 0.0677 - voltage_fall_time_pulse2_loss: 0.0090 - voltage_fall_time_pulse2_mae: 0.0684 - voltage_rise_time_pulse1_loss: 0.0336 - voltage_rise_time_pulse1_mae: 0.1190 - voltage_rise_time_pulse2_loss: 0.1257 - voltage_rise_time_pulse2_mae: 0.2131 - val_current_fall_time_pulse1_loss: 0.0051 - val_current_fall_time_pulse1_mae: 0.0520 - val_current_fall_time_pulse2_loss: 0.0056 - val_current_fall_time_pulse2_mae: 0.0548 - val_current_rise_time_pulse1_loss: 0.0653 - val_current_rise_time_pulse1_mae: 0.1532 - val_current_rise_time_pulse2_loss: 0.1023 - val_current_rise_time_pulse2_mae: 0.1835 - val_loss: 0.4942 - val_overshoot_pulse_1_loss: 0.0458 - val_overshoot_pulse_1_mae: 0.1643 - val_overshoot_pulse_2_loss: 0.0742 - val_overshoot_pulse_2_mae: 0.2115 - val_ringing_frequency_MHz_loss: 4.4238e-04 - val_ringing_frequency_MHz_mae: 0.0156 - val_undershoot_pulse_1_loss: 0.0240 - val_undershoot_pulse_1_mae: 0.1029 - val_undershoot_pulse_2_loss: 0.0234 - val_undershoot_pulse_2_mae: 0.1012 - val_voltage_fall_time_pulse1_loss: 0.0027 - val_voltage_fall_time_pulse1_mae: 0.0379 - val_voltage_fall_time_pulse2_loss: 0.0027 - val_voltage_fall_time_pulse2_mae: 0.0357 - val_voltage_rise_time_pulse1_loss: 0.0228 - val_voltage_rise_time_pulse1_mae: 0.0926 - val_voltage_rise_time_pulse2_loss: 0.1074 - val_voltage_rise_time_pulse2_mae: 0.1925 - learning_rate: 5.0000e-04
# Epoch 9/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - current_fall_time_pulse1_loss: 0.0206 - current_fall_time_pulse1_mae: 0.1084 - current_fall_time_pulse2_loss: 0.0201 - current_fall_time_pulse2_mae: 0.1077 - current_rise_time_pulse1_loss: 0.0747 - current_rise_time_pulse1_mae: 0.1761 - current_rise_time_pulse2_loss: 0.1166 - current_rise_time_pulse2_mae: 0.2090 - loss: 0.6935 - overshoot_pulse_1_loss: 0.0866 - overshoot_pulse_1_mae: 0.2185 - overshoot_pulse_2_loss: 0.0897 - overshoot_pulse_2_mae: 0.2321 - ringing_frequency_MHz_loss: 8.5160e-04 - ringing_frequency_MHz_mae: 0.0208 - undershoot_pulse_1_loss: 0.0480 - undershoot_pulse_1_mae: 0.1575 - undershoot_pulse_2_loss: 0.0473 - undershoot_pulse_2_mae: 0.1571 - voltage_fall_time_pulse1_loss: 0.0079 - voltage_fall_time_pulse1_mae: 0.0637 - voltage_fall_time_pulse2_loss: 0.0084 - voltage_fall_time_pulse2_mae: 0.0655 - voltage_rise_time_pulse1_loss: 0.0306 - voltage_rise_time_pulse1_mae: 0.1129 - voltage_rise_time_pulse2_loss: 0.1303 - voltage_rise_time_pulse2_mae: 0.2112 - val_current_fall_time_pulse1_loss: 0.0047 - val_current_fall_time_pulse1_mae: 0.0487 - val_current_fall_time_pulse2_loss: 0.0045 - val_current_fall_time_pulse2_mae: 0.0491 - val_current_rise_time_pulse1_loss: 0.0645 - val_current_rise_time_pulse1_mae: 0.1509 - val_current_rise_time_pulse2_loss: 0.1008 - val_current_rise_time_pulse2_mae: 0.1782 - val_loss: 0.4762 - val_overshoot_pulse_1_loss: 0.0454 - val_overshoot_pulse_1_mae: 0.1638 - val_overshoot_pulse_2_loss: 0.0735 - val_overshoot_pulse_2_mae: 0.2099 - val_ringing_frequency_MHz_loss: 4.1129e-04 - val_ringing_frequency_MHz_mae: 0.0149 - val_undershoot_pulse_1_loss: 0.0218 - val_undershoot_pulse_1_mae: 0.1000 - val_undershoot_pulse_2_loss: 0.0215 - val_undershoot_pulse_2_mae: 0.0989 - val_voltage_fall_time_pulse1_loss: 0.0028 - val_voltage_fall_time_pulse1_mae: 0.0416 - val_voltage_fall_time_pulse2_loss: 0.0022 - val_voltage_fall_time_pulse2_mae: 0.0342 - val_voltage_rise_time_pulse1_loss: 0.0200 - val_voltage_rise_time_pulse1_mae: 0.0821 - val_voltage_rise_time_pulse2_loss: 0.1018 - val_voltage_rise_time_pulse2_mae: 0.1855 - learning_rate: 5.0000e-04
# Epoch 10/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - current_fall_time_pulse1_loss: 0.0185 - current_fall_time_pulse1_mae: 0.1024 - current_fall_time_pulse2_loss: 0.0185 - current_fall_time_pulse2_mae: 0.1026 - current_rise_time_pulse1_loss: 0.0748 - current_rise_time_pulse1_mae: 0.1747 - current_rise_time_pulse2_loss: 0.1130 - current_rise_time_pulse2_mae: 0.2045 - loss: 0.6619 - overshoot_pulse_1_loss: 0.0799 - overshoot_pulse_1_mae: 0.2120 - overshoot_pulse_2_loss: 0.0888 - overshoot_pulse_2_mae: 0.2305 - ringing_frequency_MHz_loss: 7.3974e-04 - ringing_frequency_MHz_mae: 0.0195 - undershoot_pulse_1_loss: 0.0462 - undershoot_pulse_1_mae: 0.1540 - undershoot_pulse_2_loss: 0.0450 - undershoot_pulse_2_mae: 0.1529 - voltage_fall_time_pulse1_loss: 0.0070 - voltage_fall_time_pulse1_mae: 0.0597 - voltage_fall_time_pulse2_loss: 0.0075 - voltage_fall_time_pulse2_mae: 0.0619 - voltage_rise_time_pulse1_loss: 0.0293 - voltage_rise_time_pulse1_mae: 0.1084 - voltage_rise_time_pulse2_loss: 0.1212 - voltage_rise_time_pulse2_mae: 0.2089 - val_current_fall_time_pulse1_loss: 0.0050 - val_current_fall_time_pulse1_mae: 0.0508 - val_current_fall_time_pulse2_loss: 0.0046 - val_current_fall_time_pulse2_mae: 0.0496 - val_current_rise_time_pulse1_loss: 0.0643 - val_current_rise_time_pulse1_mae: 0.1476 - val_current_rise_time_pulse2_loss: 0.0998 - val_current_rise_time_pulse2_mae: 0.1742 - val_loss: 0.4702 - val_overshoot_pulse_1_loss: 0.0412 - val_overshoot_pulse_1_mae: 0.1545 - val_overshoot_pulse_2_loss: 0.0727 - val_overshoot_pulse_2_mae: 0.2082 - val_ringing_frequency_MHz_loss: 4.9626e-04 - val_ringing_frequency_MHz_mae: 0.0157 - val_undershoot_pulse_1_loss: 0.0195 - val_undershoot_pulse_1_mae: 0.0937 - val_undershoot_pulse_2_loss: 0.0194 - val_undershoot_pulse_2_mae: 0.0935 - val_voltage_fall_time_pulse1_loss: 0.0021 - val_voltage_fall_time_pulse1_mae: 0.0356 - val_voltage_fall_time_pulse2_loss: 0.0021 - val_voltage_fall_time_pulse2_mae: 0.0326 - val_voltage_rise_time_pulse1_loss: 0.0184 - val_voltage_rise_time_pulse1_mae: 0.0750 - val_voltage_rise_time_pulse2_loss: 0.1084 - val_voltage_rise_time_pulse2_mae: 0.1888 - learning_rate: 5.0000e-04
# Epoch 11/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - current_fall_time_pulse1_loss: 0.0185 - current_fall_time_pulse1_mae: 0.1024 - current_fall_time_pulse2_loss: 0.0188 - current_fall_time_pulse2_mae: 0.1031 - current_rise_time_pulse1_loss: 0.0730 - current_rise_time_pulse1_mae: 0.1720 - current_rise_time_pulse2_loss: 0.1140 - current_rise_time_pulse2_mae: 0.2037 - loss: 0.6542 - overshoot_pulse_1_loss: 0.0769 - overshoot_pulse_1_mae: 0.2069 - overshoot_pulse_2_loss: 0.0877 - overshoot_pulse_2_mae: 0.2293 - ringing_frequency_MHz_loss: 6.4504e-04 - ringing_frequency_MHz_mae: 0.0183 - undershoot_pulse_1_loss: 0.0435 - undershoot_pulse_1_mae: 0.1502 - undershoot_pulse_2_loss: 0.0427 - undershoot_pulse_2_mae: 0.1489 - voltage_fall_time_pulse1_loss: 0.0067 - voltage_fall_time_pulse1_mae: 0.0581 - voltage_fall_time_pulse2_loss: 0.0069 - voltage_fall_time_pulse2_mae: 0.0591 - voltage_rise_time_pulse1_loss: 0.0273 - voltage_rise_time_pulse1_mae: 0.1039 - voltage_rise_time_pulse2_loss: 0.1260 - voltage_rise_time_pulse2_mae: 0.2070 - val_current_fall_time_pulse1_loss: 0.0048 - val_current_fall_time_pulse1_mae: 0.0499 - val_current_fall_time_pulse2_loss: 0.0049 - val_current_fall_time_pulse2_mae: 0.0507 - val_current_rise_time_pulse1_loss: 0.0643 - val_current_rise_time_pulse1_mae: 0.1478 - val_current_rise_time_pulse2_loss: 0.0981 - val_current_rise_time_pulse2_mae: 0.1713 - val_loss: 0.4602 - val_overshoot_pulse_1_loss: 0.0415 - val_overshoot_pulse_1_mae: 0.1540 - val_overshoot_pulse_2_loss: 0.0722 - val_overshoot_pulse_2_mae: 0.2074 - val_ringing_frequency_MHz_loss: 3.5328e-04 - val_ringing_frequency_MHz_mae: 0.0140 - val_undershoot_pulse_1_loss: 0.0220 - val_undershoot_pulse_1_mae: 0.1016 - val_undershoot_pulse_2_loss: 0.0210 - val_undershoot_pulse_2_mae: 0.0992 - val_voltage_fall_time_pulse1_loss: 0.0022 - val_voltage_fall_time_pulse1_mae: 0.0361 - val_voltage_fall_time_pulse2_loss: 0.0019 - val_voltage_fall_time_pulse2_mae: 0.0313 - val_voltage_rise_time_pulse1_loss: 0.0177 - val_voltage_rise_time_pulse1_mae: 0.0755 - val_voltage_rise_time_pulse2_loss: 0.0972 - val_voltage_rise_time_pulse2_mae: 0.1839 - learning_rate: 5.0000e-04
# Epoch 12/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - current_fall_time_pulse1_loss: 0.0176 - current_fall_time_pulse1_mae: 0.0998 - current_fall_time_pulse2_loss: 0.0176 - current_fall_time_pulse2_mae: 0.0998 - current_rise_time_pulse1_loss: 0.0724 - current_rise_time_pulse1_mae: 0.1699 - current_rise_time_pulse2_loss: 0.1098 - current_rise_time_pulse2_mae: 0.1983 - loss: 0.6298 - overshoot_pulse_1_loss: 0.0741 - overshoot_pulse_1_mae: 0.2045 - overshoot_pulse_2_loss: 0.0859 - overshoot_pulse_2_mae: 0.2258 - ringing_frequency_MHz_loss: 5.8405e-04 - ringing_frequency_MHz_mae: 0.0176 - undershoot_pulse_1_loss: 0.0412 - undershoot_pulse_1_mae: 0.1470 - undershoot_pulse_2_loss: 0.0402 - undershoot_pulse_2_mae: 0.1464 - voltage_fall_time_pulse1_loss: 0.0062 - voltage_fall_time_pulse1_mae: 0.0558 - voltage_fall_time_pulse2_loss: 0.0065 - voltage_fall_time_pulse2_mae: 0.0572 - voltage_rise_time_pulse1_loss: 0.0259 - voltage_rise_time_pulse1_mae: 0.0999 - voltage_rise_time_pulse2_loss: 0.1205 - voltage_rise_time_pulse2_mae: 0.2049 - val_current_fall_time_pulse1_loss: 0.0037 - val_current_fall_time_pulse1_mae: 0.0451 - val_current_fall_time_pulse2_loss: 0.0038 - val_current_fall_time_pulse2_mae: 0.0462 - val_current_rise_time_pulse1_loss: 0.0643 - val_current_rise_time_pulse1_mae: 0.1548 - val_current_rise_time_pulse2_loss: 0.0979 - val_current_rise_time_pulse2_mae: 0.1712 - val_loss: 0.4523 - val_overshoot_pulse_1_loss: 0.0435 - val_overshoot_pulse_1_mae: 0.1578 - val_overshoot_pulse_2_loss: 0.0725 - val_overshoot_pulse_2_mae: 0.2073 - val_ringing_frequency_MHz_loss: 3.3339e-04 - val_ringing_frequency_MHz_mae: 0.0132 - val_undershoot_pulse_1_loss: 0.0194 - val_undershoot_pulse_1_mae: 0.0950 - val_undershoot_pulse_2_loss: 0.0187 - val_undershoot_pulse_2_mae: 0.0925 - val_voltage_fall_time_pulse1_loss: 0.0019 - val_voltage_fall_time_pulse1_mae: 0.0329 - val_voltage_fall_time_pulse2_loss: 0.0015 - val_voltage_fall_time_pulse2_mae: 0.0276 - val_voltage_rise_time_pulse1_loss: 0.0170 - val_voltage_rise_time_pulse1_mae: 0.0731 - val_voltage_rise_time_pulse2_loss: 0.0958 - val_voltage_rise_time_pulse2_mae: 0.1813 - learning_rate: 5.0000e-04
# Epoch 13/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - current_fall_time_pulse1_loss: 0.0168 - current_fall_time_pulse1_mae: 0.0976 - current_fall_time_pulse2_loss: 0.0166 - current_fall_time_pulse2_mae: 0.0970 - current_rise_time_pulse1_loss: 0.0720 - current_rise_time_pulse1_mae: 0.1691 - current_rise_time_pulse2_loss: 0.1105 - current_rise_time_pulse2_mae: 0.1975 - loss: 0.6074 - overshoot_pulse_1_loss: 0.0725 - overshoot_pulse_1_mae: 0.2022 - overshoot_pulse_2_loss: 0.0839 - overshoot_pulse_2_mae: 0.2243 - ringing_frequency_MHz_loss: 5.2537e-04 - ringing_frequency_MHz_mae: 0.0167 - undershoot_pulse_1_loss: 0.0392 - undershoot_pulse_1_mae: 0.1446 - undershoot_pulse_2_loss: 0.0389 - undershoot_pulse_2_mae: 0.1437 - voltage_fall_time_pulse1_loss: 0.0056 - voltage_fall_time_pulse1_mae: 0.0533 - voltage_fall_time_pulse2_loss: 0.0060 - voltage_fall_time_pulse2_mae: 0.0546 - voltage_rise_time_pulse1_loss: 0.0248 - voltage_rise_time_pulse1_mae: 0.0967 - voltage_rise_time_pulse2_loss: 0.1088 - voltage_rise_time_pulse2_mae: 0.2007 - val_current_fall_time_pulse1_loss: 0.0055 - val_current_fall_time_pulse1_mae: 0.0543 - val_current_fall_time_pulse2_loss: 0.0061 - val_current_fall_time_pulse2_mae: 0.0574 - val_current_rise_time_pulse1_loss: 0.0638 - val_current_rise_time_pulse1_mae: 0.1493 - val_current_rise_time_pulse2_loss: 0.0972 - val_current_rise_time_pulse2_mae: 0.1662 - val_loss: 0.4516 - val_overshoot_pulse_1_loss: 0.0378 - val_overshoot_pulse_1_mae: 0.1496 - val_overshoot_pulse_2_loss: 0.0713 - val_overshoot_pulse_2_mae: 0.2069 - val_ringing_frequency_MHz_loss: 4.6529e-04 - val_ringing_frequency_MHz_mae: 0.0155 - val_undershoot_pulse_1_loss: 0.0228 - val_undershoot_pulse_1_mae: 0.1115 - val_undershoot_pulse_2_loss: 0.0230 - val_undershoot_pulse_2_mae: 0.1134 - val_voltage_fall_time_pulse1_loss: 0.0023 - val_voltage_fall_time_pulse1_mae: 0.0378 - val_voltage_fall_time_pulse2_loss: 0.0020 - val_voltage_fall_time_pulse2_mae: 0.0330 - val_voltage_rise_time_pulse1_loss: 0.0160 - val_voltage_rise_time_pulse1_mae: 0.0713 - val_voltage_rise_time_pulse2_loss: 0.0914 - val_voltage_rise_time_pulse2_mae: 0.1808 - learning_rate: 5.0000e-04
# Epoch 14/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - current_fall_time_pulse1_loss: 0.0160 - current_fall_time_pulse1_mae: 0.0953 - current_fall_time_pulse2_loss: 0.0160 - current_fall_time_pulse2_mae: 0.0956 - current_rise_time_pulse1_loss: 0.0712 - current_rise_time_pulse1_mae: 0.1669 - current_rise_time_pulse2_loss: 0.1101 - current_rise_time_pulse2_mae: 0.1965 - loss: 0.6101 - overshoot_pulse_1_loss: 0.0708 - overshoot_pulse_1_mae: 0.1993 - overshoot_pulse_2_loss: 0.0835 - overshoot_pulse_2_mae: 0.2236 - ringing_frequency_MHz_loss: 4.9374e-04 - ringing_frequency_MHz_mae: 0.0162 - undershoot_pulse_1_loss: 0.0401 - undershoot_pulse_1_mae: 0.1458 - undershoot_pulse_2_loss: 0.0397 - undershoot_pulse_2_mae: 0.1459 - voltage_fall_time_pulse1_loss: 0.0053 - voltage_fall_time_pulse1_mae: 0.0515 - voltage_fall_time_pulse2_loss: 0.0057 - voltage_fall_time_pulse2_mae: 0.0532 - voltage_rise_time_pulse1_loss: 0.0237 - voltage_rise_time_pulse1_mae: 0.0944 - voltage_rise_time_pulse2_loss: 0.1163 - voltage_rise_time_pulse2_mae: 0.1993 - val_current_fall_time_pulse1_loss: 0.0041 - val_current_fall_time_pulse1_mae: 0.0478 - val_current_fall_time_pulse2_loss: 0.0040 - val_current_fall_time_pulse2_mae: 0.0463 - val_current_rise_time_pulse1_loss: 0.0636 - val_current_rise_time_pulse1_mae: 0.1458 - val_current_rise_time_pulse2_loss: 0.0955 - val_current_rise_time_pulse2_mae: 0.1657 - val_loss: 0.4457 - val_overshoot_pulse_1_loss: 0.0430 - val_overshoot_pulse_1_mae: 0.1608 - val_overshoot_pulse_2_loss: 0.0705 - val_overshoot_pulse_2_mae: 0.2064 - val_ringing_frequency_MHz_loss: 3.8473e-04 - val_ringing_frequency_MHz_mae: 0.0148 - val_undershoot_pulse_1_loss: 0.0211 - val_undershoot_pulse_1_mae: 0.0991 - val_undershoot_pulse_2_loss: 0.0202 - val_undershoot_pulse_2_mae: 0.0972 - val_voltage_fall_time_pulse1_loss: 0.0021 - val_voltage_fall_time_pulse1_mae: 0.0340 - val_voltage_fall_time_pulse2_loss: 0.0021 - val_voltage_fall_time_pulse2_mae: 0.0313 - val_voltage_rise_time_pulse1_loss: 0.0160 - val_voltage_rise_time_pulse1_mae: 0.0724 - val_voltage_rise_time_pulse2_loss: 0.0914 - val_voltage_rise_time_pulse2_mae: 0.1828 - learning_rate: 5.0000e-04
# Epoch 15/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - current_fall_time_pulse1_loss: 0.0149 - current_fall_time_pulse1_mae: 0.0921 - current_fall_time_pulse2_loss: 0.0150 - current_fall_time_pulse2_mae: 0.0921 - current_rise_time_pulse1_loss: 0.0702 - current_rise_time_pulse1_mae: 0.1653 - current_rise_time_pulse2_loss: 0.1080 - current_rise_time_pulse2_mae: 0.1932 - loss: 0.5964 - overshoot_pulse_1_loss: 0.0697 - overshoot_pulse_1_mae: 0.1971 - overshoot_pulse_2_loss: 0.0827 - overshoot_pulse_2_mae: 0.2214 - ringing_frequency_MHz_loss: 4.6664e-04 - ringing_frequency_MHz_mae: 0.0158 - undershoot_pulse_1_loss: 0.0379 - undershoot_pulse_1_mae: 0.1409 - undershoot_pulse_2_loss: 0.0373 - undershoot_pulse_2_mae: 0.1399 - voltage_fall_time_pulse1_loss: 0.0050 - voltage_fall_time_pulse1_mae: 0.0494 - voltage_fall_time_pulse2_loss: 0.0053 - voltage_fall_time_pulse2_mae: 0.0512 - voltage_rise_time_pulse1_loss: 0.0239 - voltage_rise_time_pulse1_mae: 0.0928 - voltage_rise_time_pulse2_loss: 0.1150 - voltage_rise_time_pulse2_mae: 0.1987 - val_current_fall_time_pulse1_loss: 0.0039 - val_current_fall_time_pulse1_mae: 0.0455 - val_current_fall_time_pulse2_loss: 0.0039 - val_current_fall_time_pulse2_mae: 0.0451 - val_current_rise_time_pulse1_loss: 0.0641 - val_current_rise_time_pulse1_mae: 0.1463 - val_current_rise_time_pulse2_loss: 0.0941 - val_current_rise_time_pulse2_mae: 0.1640 - val_loss: 0.4310 - val_overshoot_pulse_1_loss: 0.0375 - val_overshoot_pulse_1_mae: 0.1493 - val_overshoot_pulse_2_loss: 0.0689 - val_overshoot_pulse_2_mae: 0.2042 - val_ringing_frequency_MHz_loss: 3.9028e-04 - val_ringing_frequency_MHz_mae: 0.0154 - val_undershoot_pulse_1_loss: 0.0193 - val_undershoot_pulse_1_mae: 0.0934 - val_undershoot_pulse_2_loss: 0.0185 - val_undershoot_pulse_2_mae: 0.0923 - val_voltage_fall_time_pulse1_loss: 0.0019 - val_voltage_fall_time_pulse1_mae: 0.0339 - val_voltage_fall_time_pulse2_loss: 0.0020 - val_voltage_fall_time_pulse2_mae: 0.0324 - val_voltage_rise_time_pulse1_loss: 0.0150 - val_voltage_rise_time_pulse1_mae: 0.0689 - val_voltage_rise_time_pulse2_loss: 0.0899 - val_voltage_rise_time_pulse2_mae: 0.1768 - learning_rate: 5.0000e-04
# Epoch 16/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - current_fall_time_pulse1_loss: 0.0142 - current_fall_time_pulse1_mae: 0.0896 - current_fall_time_pulse2_loss: 0.0142 - current_fall_time_pulse2_mae: 0.0894 - current_rise_time_pulse1_loss: 0.0701 - current_rise_time_pulse1_mae: 0.1647 - current_rise_time_pulse2_loss: 0.1071 - current_rise_time_pulse2_mae: 0.1921 - loss: 0.5782 - overshoot_pulse_1_loss: 0.0671 - overshoot_pulse_1_mae: 0.1947 - overshoot_pulse_2_loss: 0.0813 - overshoot_pulse_2_mae: 0.2206 - ringing_frequency_MHz_loss: 4.5606e-04 - ringing_frequency_MHz_mae: 0.0155 - undershoot_pulse_1_loss: 0.0366 - undershoot_pulse_1_mae: 0.1392 - undershoot_pulse_2_loss: 0.0360 - undershoot_pulse_2_mae: 0.1378 - voltage_fall_time_pulse1_loss: 0.0046 - voltage_fall_time_pulse1_mae: 0.0484 - voltage_fall_time_pulse2_loss: 0.0049 - voltage_fall_time_pulse2_mae: 0.0495 - voltage_rise_time_pulse1_loss: 0.0231 - voltage_rise_time_pulse1_mae: 0.0907 - voltage_rise_time_pulse2_loss: 0.1077 - voltage_rise_time_pulse2_mae: 0.1958 - val_current_fall_time_pulse1_loss: 0.0032 - val_current_fall_time_pulse1_mae: 0.0423 - val_current_fall_time_pulse2_loss: 0.0033 - val_current_fall_time_pulse2_mae: 0.0429 - val_current_rise_time_pulse1_loss: 0.0631 - val_current_rise_time_pulse1_mae: 0.1487 - val_current_rise_time_pulse2_loss: 0.0945 - val_current_rise_time_pulse2_mae: 0.1655 - val_loss: 0.4337 - val_overshoot_pulse_1_loss: 0.0387 - val_overshoot_pulse_1_mae: 0.1519 - val_overshoot_pulse_2_loss: 0.0699 - val_overshoot_pulse_2_mae: 0.2047 - val_ringing_frequency_MHz_loss: 3.3747e-04 - val_ringing_frequency_MHz_mae: 0.0141 - val_undershoot_pulse_1_loss: 0.0211 - val_undershoot_pulse_1_mae: 0.0991 - val_undershoot_pulse_2_loss: 0.0204 - val_undershoot_pulse_2_mae: 0.0977 - val_voltage_fall_time_pulse1_loss: 0.0019 - val_voltage_fall_time_pulse1_mae: 0.0349 - val_voltage_fall_time_pulse2_loss: 0.0014 - val_voltage_fall_time_pulse2_mae: 0.0275 - val_voltage_rise_time_pulse1_loss: 0.0141 - val_voltage_rise_time_pulse1_mae: 0.0632 - val_voltage_rise_time_pulse2_loss: 0.0903 - val_voltage_rise_time_pulse2_mae: 0.1799 - learning_rate: 5.0000e-04
# Epoch 17/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - current_fall_time_pulse1_loss: 0.0138 - current_fall_time_pulse1_mae: 0.0881 - current_fall_time_pulse2_loss: 0.0139 - current_fall_time_pulse2_mae: 0.0886 - current_rise_time_pulse1_loss: 0.0685 - current_rise_time_pulse1_mae: 0.1618 - current_rise_time_pulse2_loss: 0.1087 - current_rise_time_pulse2_mae: 0.1916 - loss: 0.5691 - overshoot_pulse_1_loss: 0.0647 - overshoot_pulse_1_mae: 0.1914 - overshoot_pulse_2_loss: 0.0809 - overshoot_pulse_2_mae: 0.2203 - ringing_frequency_MHz_loss: 4.3778e-04 - ringing_frequency_MHz_mae: 0.0152 - undershoot_pulse_1_loss: 0.0360 - undershoot_pulse_1_mae: 0.1373 - undershoot_pulse_2_loss: 0.0356 - undershoot_pulse_2_mae: 0.1365 - voltage_fall_time_pulse1_loss: 0.0044 - voltage_fall_time_pulse1_mae: 0.0470 - voltage_fall_time_pulse2_loss: 0.0047 - voltage_fall_time_pulse2_mae: 0.0483 - voltage_rise_time_pulse1_loss: 0.0223 - voltage_rise_time_pulse1_mae: 0.0889 - voltage_rise_time_pulse2_loss: 0.1041 - voltage_rise_time_pulse2_mae: 0.1948 - val_current_fall_time_pulse1_loss: 0.0059 - val_current_fall_time_pulse1_mae: 0.0553 - val_current_fall_time_pulse2_loss: 0.0059 - val_current_fall_time_pulse2_mae: 0.0557 - val_current_rise_time_pulse1_loss: 0.0632 - val_current_rise_time_pulse1_mae: 0.1526 - val_current_rise_time_pulse2_loss: 0.0942 - val_current_rise_time_pulse2_mae: 0.1586 - val_loss: 0.4379 - val_overshoot_pulse_1_loss: 0.0409 - val_overshoot_pulse_1_mae: 0.1545 - val_overshoot_pulse_2_loss: 0.0698 - val_overshoot_pulse_2_mae: 0.2045 - val_ringing_frequency_MHz_loss: 4.7071e-04 - val_ringing_frequency_MHz_mae: 0.0163 - val_undershoot_pulse_1_loss: 0.0203 - val_undershoot_pulse_1_mae: 0.1050 - val_undershoot_pulse_2_loss: 0.0198 - val_undershoot_pulse_2_mae: 0.1035 - val_voltage_fall_time_pulse1_loss: 0.0019 - val_voltage_fall_time_pulse1_mae: 0.0345 - val_voltage_fall_time_pulse2_loss: 0.0017 - val_voltage_fall_time_pulse2_mae: 0.0296 - val_voltage_rise_time_pulse1_loss: 0.0138 - val_voltage_rise_time_pulse1_mae: 0.0635 - val_voltage_rise_time_pulse2_loss: 0.0889 - val_voltage_rise_time_pulse2_mae: 0.1763 - learning_rate: 5.0000e-04
# Epoch 18/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 12s 43ms/step - current_fall_time_pulse1_loss: 0.0133 - current_fall_time_pulse1_mae: 0.0866 - current_fall_time_pulse2_loss: 0.0136 - current_fall_time_pulse2_mae: 0.0874 - current_rise_time_pulse1_loss: 0.0693 - current_rise_time_pulse1_mae: 0.1630 - current_rise_time_pulse2_loss: 0.1058 - current_rise_time_pulse2_mae: 0.1897 - loss: 0.5642 - overshoot_pulse_1_loss: 0.0654 - overshoot_pulse_1_mae: 0.1914 - overshoot_pulse_2_loss: 0.0812 - overshoot_pulse_2_mae: 0.2195 - ringing_frequency_MHz_loss: 4.1692e-04 - ringing_frequency_MHz_mae: 0.0149 - undershoot_pulse_1_loss: 0.0352 - undershoot_pulse_1_mae: 0.1360 - undershoot_pulse_2_loss: 0.0349 - undershoot_pulse_2_mae: 0.1356 - voltage_fall_time_pulse1_loss: 0.0044 - voltage_fall_time_pulse1_mae: 0.0470 - voltage_fall_time_pulse2_loss: 0.0047 - voltage_fall_time_pulse2_mae: 0.0480 - voltage_rise_time_pulse1_loss: 0.0212 - voltage_rise_time_pulse1_mae: 0.0865 - voltage_rise_time_pulse2_loss: 0.1043 - voltage_rise_time_pulse2_mae: 0.1944 - val_current_fall_time_pulse1_loss: 0.0042 - val_current_fall_time_pulse1_mae: 0.0448 - val_current_fall_time_pulse2_loss: 0.0041 - val_current_fall_time_pulse2_mae: 0.0439 - val_current_rise_time_pulse1_loss: 0.0639 - val_current_rise_time_pulse1_mae: 0.1450 - val_current_rise_time_pulse2_loss: 0.0943 - val_current_rise_time_pulse2_mae: 0.1611 - val_loss: 0.4333 - val_overshoot_pulse_1_loss: 0.0386 - val_overshoot_pulse_1_mae: 0.1489 - val_overshoot_pulse_2_loss: 0.0712 - val_overshoot_pulse_2_mae: 0.2053 - val_ringing_frequency_MHz_loss: 3.8601e-04 - val_ringing_frequency_MHz_mae: 0.0148 - val_undershoot_pulse_1_loss: 0.0197 - val_undershoot_pulse_1_mae: 0.0952 - val_undershoot_pulse_2_loss: 0.0185 - val_undershoot_pulse_2_mae: 0.0921 - val_voltage_fall_time_pulse1_loss: 0.0016 - val_voltage_fall_time_pulse1_mae: 0.0319 - val_voltage_fall_time_pulse2_loss: 0.0014 - val_voltage_fall_time_pulse2_mae: 0.0278 - val_voltage_rise_time_pulse1_loss: 0.0135 - val_voltage_rise_time_pulse1_mae: 0.0633 - val_voltage_rise_time_pulse2_loss: 0.0908 - val_voltage_rise_time_pulse2_mae: 0.1788 - learning_rate: 5.0000e-04
# Epoch 19/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - current_fall_time_pulse1_loss: 0.0131 - current_fall_time_pulse1_mae: 0.0859 - current_fall_time_pulse2_loss: 0.0132 - current_fall_time_pulse2_mae: 0.0862 - current_rise_time_pulse1_loss: 0.0711 - current_rise_time_pulse1_mae: 0.1648 - current_rise_time_pulse2_loss: 0.1071 - current_rise_time_pulse2_mae: 0.1897 - loss: 0.5611 - overshoot_pulse_1_loss: 0.0650 - overshoot_pulse_1_mae: 0.1914 - overshoot_pulse_2_loss: 0.0795 - overshoot_pulse_2_mae: 0.2182 - ringing_frequency_MHz_loss: 4.0552e-04 - ringing_frequency_MHz_mae: 0.0146 - undershoot_pulse_1_loss: 0.0357 - undershoot_pulse_1_mae: 0.1356 - undershoot_pulse_2_loss: 0.0345 - undershoot_pulse_2_mae: 0.1343 - voltage_fall_time_pulse1_loss: 0.0042 - voltage_fall_time_pulse1_mae: 0.0453 - voltage_fall_time_pulse2_loss: 0.0044 - voltage_fall_time_pulse2_mae: 0.0464 - voltage_rise_time_pulse1_loss: 0.0214 - voltage_rise_time_pulse1_mae: 0.0863 - voltage_rise_time_pulse2_loss: 0.1008 - voltage_rise_time_pulse2_mae: 0.1925 - val_current_fall_time_pulse1_loss: 0.0041 - val_current_fall_time_pulse1_mae: 0.0470 - val_current_fall_time_pulse2_loss: 0.0041 - val_current_fall_time_pulse2_mae: 0.0461 - val_current_rise_time_pulse1_loss: 0.0634 - val_current_rise_time_pulse1_mae: 0.1474 - val_current_rise_time_pulse2_loss: 0.0942 - val_current_rise_time_pulse2_mae: 0.1659 - val_loss: 0.4423 - val_overshoot_pulse_1_loss: 0.0392 - val_overshoot_pulse_1_mae: 0.1495 - val_overshoot_pulse_2_loss: 0.0721 - val_overshoot_pulse_2_mae: 0.2059 - val_ringing_frequency_MHz_loss: 3.7260e-04 - val_ringing_frequency_MHz_mae: 0.0144 - val_undershoot_pulse_1_loss: 0.0201 - val_undershoot_pulse_1_mae: 0.0959 - val_undershoot_pulse_2_loss: 0.0201 - val_undershoot_pulse_2_mae: 0.0971 - val_voltage_fall_time_pulse1_loss: 0.0018 - val_voltage_fall_time_pulse1_mae: 0.0317 - val_voltage_fall_time_pulse2_loss: 0.0017 - val_voltage_fall_time_pulse2_mae: 0.0286 - val_voltage_rise_time_pulse1_loss: 0.0126 - val_voltage_rise_time_pulse1_mae: 0.0613 - val_voltage_rise_time_pulse2_loss: 0.0971 - val_voltage_rise_time_pulse2_mae: 0.1788 - learning_rate: 5.0000e-04
# Epoch 20/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - current_fall_time_pulse1_loss: 0.0126 - current_fall_time_pulse1_mae: 0.0841 - current_fall_time_pulse2_loss: 0.0126 - current_fall_time_pulse2_mae: 0.0834 - current_rise_time_pulse1_loss: 0.0691 - current_rise_time_pulse1_mae: 0.1623 - current_rise_time_pulse2_loss: 0.1045 - current_rise_time_pulse2_mae: 0.1864 - loss: 0.5540 - overshoot_pulse_1_loss: 0.0635 - overshoot_pulse_1_mae: 0.1887 - overshoot_pulse_2_loss: 0.0793 - overshoot_pulse_2_mae: 0.2172 - ringing_frequency_MHz_loss: 3.8472e-04 - ringing_frequency_MHz_mae: 0.0143 - undershoot_pulse_1_loss: 0.0334 - undershoot_pulse_1_mae: 0.1329 - undershoot_pulse_2_loss: 0.0332 - undershoot_pulse_2_mae: 0.1327 - voltage_fall_time_pulse1_loss: 0.0039 - voltage_fall_time_pulse1_mae: 0.0438 - voltage_fall_time_pulse2_loss: 0.0042 - voltage_fall_time_pulse2_mae: 0.0454 - voltage_rise_time_pulse1_loss: 0.0201 - voltage_rise_time_pulse1_mae: 0.0838 - voltage_rise_time_pulse2_loss: 0.1066 - voltage_rise_time_pulse2_mae: 0.1928 - val_current_fall_time_pulse1_loss: 0.0052 - val_current_fall_time_pulse1_mae: 0.0516 - val_current_fall_time_pulse2_loss: 0.0050 - val_current_fall_time_pulse2_mae: 0.0509 - val_current_rise_time_pulse1_loss: 0.0631 - val_current_rise_time_pulse1_mae: 0.1494 - val_current_rise_time_pulse2_loss: 0.0933 - val_current_rise_time_pulse2_mae: 0.1564 - val_loss: 0.4412 - val_overshoot_pulse_1_loss: 0.0394 - val_overshoot_pulse_1_mae: 0.1511 - val_overshoot_pulse_2_loss: 0.0712 - val_overshoot_pulse_2_mae: 0.2055 - val_ringing_frequency_MHz_loss: 3.2974e-04 - val_ringing_frequency_MHz_mae: 0.0139 - val_undershoot_pulse_1_loss: 0.0210 - val_undershoot_pulse_1_mae: 0.0997 - val_undershoot_pulse_2_loss: 0.0203 - val_undershoot_pulse_2_mae: 0.0978 - val_voltage_fall_time_pulse1_loss: 0.0020 - val_voltage_fall_time_pulse1_mae: 0.0349 - val_voltage_fall_time_pulse2_loss: 0.0017 - val_voltage_fall_time_pulse2_mae: 0.0314 - val_voltage_rise_time_pulse1_loss: 0.0130 - val_voltage_rise_time_pulse1_mae: 0.0619 - val_voltage_rise_time_pulse2_loss: 0.0946 - val_voltage_rise_time_pulse2_mae: 0.1777 - learning_rate: 5.0000e-04
# Epoch 21/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - current_fall_time_pulse1_loss: 0.0122 - current_fall_time_pulse1_mae: 0.0826 - current_fall_time_pulse2_loss: 0.0123 - current_fall_time_pulse2_mae: 0.0828 - current_rise_time_pulse1_loss: 0.0688 - current_rise_time_pulse1_mae: 0.1619 - current_rise_time_pulse2_loss: 0.1033 - current_rise_time_pulse2_mae: 0.1841 - loss: 0.5365 - overshoot_pulse_1_loss: 0.0598 - overshoot_pulse_1_mae: 0.1831 - overshoot_pulse_2_loss: 0.0769 - overshoot_pulse_2_mae: 0.2144 - ringing_frequency_MHz_loss: 3.7030e-04 - ringing_frequency_MHz_mae: 0.0139 - undershoot_pulse_1_loss: 0.0329 - undershoot_pulse_1_mae: 0.1312 - undershoot_pulse_2_loss: 0.0315 - undershoot_pulse_2_mae: 0.1290 - voltage_fall_time_pulse1_loss: 0.0037 - voltage_fall_time_pulse1_mae: 0.0424 - voltage_fall_time_pulse2_loss: 0.0039 - voltage_fall_time_pulse2_mae: 0.0435 - voltage_rise_time_pulse1_loss: 0.0192 - voltage_rise_time_pulse1_mae: 0.0811 - voltage_rise_time_pulse2_loss: 0.1012 - voltage_rise_time_pulse2_mae: 0.1897 - val_current_fall_time_pulse1_loss: 0.0033 - val_current_fall_time_pulse1_mae: 0.0413 - val_current_fall_time_pulse2_loss: 0.0032 - val_current_fall_time_pulse2_mae: 0.0403 - val_current_rise_time_pulse1_loss: 0.0626 - val_current_rise_time_pulse1_mae: 0.1472 - val_current_rise_time_pulse2_loss: 0.0916 - val_current_rise_time_pulse2_mae: 0.1563 - val_loss: 0.4160 - val_overshoot_pulse_1_loss: 0.0358 - val_overshoot_pulse_1_mae: 0.1452 - val_overshoot_pulse_2_loss: 0.0684 - val_overshoot_pulse_2_mae: 0.2023 - val_ringing_frequency_MHz_loss: 3.9670e-04 - val_ringing_frequency_MHz_mae: 0.0148 - val_undershoot_pulse_1_loss: 0.0177 - val_undershoot_pulse_1_mae: 0.0915 - val_undershoot_pulse_2_loss: 0.0176 - val_undershoot_pulse_2_mae: 0.0923 - val_voltage_fall_time_pulse1_loss: 0.0015 - val_voltage_fall_time_pulse1_mae: 0.0301 - val_voltage_fall_time_pulse2_loss: 0.0015 - val_voltage_fall_time_pulse2_mae: 0.0289 - val_voltage_rise_time_pulse1_loss: 0.0122 - val_voltage_rise_time_pulse1_mae: 0.0604 - val_voltage_rise_time_pulse2_loss: 0.0891 - val_voltage_rise_time_pulse2_mae: 0.1749 - learning_rate: 1.5000e-04
# Epoch 22/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 15s 52ms/step - current_fall_time_pulse1_loss: 0.0119 - current_fall_time_pulse1_mae: 0.0814 - current_fall_time_pulse2_loss: 0.0120 - current_fall_time_pulse2_mae: 0.0817 - current_rise_time_pulse1_loss: 0.0692 - current_rise_time_pulse1_mae: 0.1616 - current_rise_time_pulse2_loss: 0.1022 - current_rise_time_pulse2_mae: 0.1824 - loss: 0.5399 - overshoot_pulse_1_loss: 0.0601 - overshoot_pulse_1_mae: 0.1841 - overshoot_pulse_2_loss: 0.0780 - overshoot_pulse_2_mae: 0.2154 - ringing_frequency_MHz_loss: 3.6522e-04 - ringing_frequency_MHz_mae: 0.0138 - undershoot_pulse_1_loss: 0.0330 - undershoot_pulse_1_mae: 0.1311 - undershoot_pulse_2_loss: 0.0317 - undershoot_pulse_2_mae: 0.1293 - voltage_fall_time_pulse1_loss: 0.0037 - voltage_fall_time_pulse1_mae: 0.0425 - voltage_fall_time_pulse2_loss: 0.0039 - voltage_fall_time_pulse2_mae: 0.0438 - voltage_rise_time_pulse1_loss: 0.0191 - voltage_rise_time_pulse1_mae: 0.0810 - voltage_rise_time_pulse2_loss: 0.1043 - voltage_rise_time_pulse2_mae: 0.1919 - val_current_fall_time_pulse1_loss: 0.0030 - val_current_fall_time_pulse1_mae: 0.0391 - val_current_fall_time_pulse2_loss: 0.0029 - val_current_fall_time_pulse2_mae: 0.0386 - val_current_rise_time_pulse1_loss: 0.0628 - val_current_rise_time_pulse1_mae: 0.1431 - val_current_rise_time_pulse2_loss: 0.0919 - val_current_rise_time_pulse2_mae: 0.1536 - val_loss: 0.4153 - val_overshoot_pulse_1_loss: 0.0354 - val_overshoot_pulse_1_mae: 0.1441 - val_overshoot_pulse_2_loss: 0.0688 - val_overshoot_pulse_2_mae: 0.2026 - val_ringing_frequency_MHz_loss: 4.0012e-04 - val_ringing_frequency_MHz_mae: 0.0147 - val_undershoot_pulse_1_loss: 0.0184 - val_undershoot_pulse_1_mae: 0.0933 - val_undershoot_pulse_2_loss: 0.0179 - val_undershoot_pulse_2_mae: 0.0926 - val_voltage_fall_time_pulse1_loss: 0.0013 - val_voltage_fall_time_pulse1_mae: 0.0282 - val_voltage_fall_time_pulse2_loss: 0.0013 - val_voltage_fall_time_pulse2_mae: 0.0262 - val_voltage_rise_time_pulse1_loss: 0.0126 - val_voltage_rise_time_pulse1_mae: 0.0613 - val_voltage_rise_time_pulse2_loss: 0.0876 - val_voltage_rise_time_pulse2_mae: 0.1732 - learning_rate: 1.5000e-04
# Epoch 23/120
# ...
# Epoch 60/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 17s 58ms/step - current_fall_time_pulse1_loss: 0.0097 - current_fall_time_pulse1_mae: 0.0733 - current_fall_time_pulse2_loss: 0.0094 - current_fall_time_pulse2_mae: 0.0716 - current_rise_time_pulse1_loss: 0.0675 - current_rise_time_pulse1_mae: 0.1580 - current_rise_time_pulse2_loss: 0.0990 - current_rise_time_pulse2_mae: 0.1751 - loss: 0.4924 - overshoot_pulse_1_loss: 0.0542 - overshoot_pulse_1_mae: 0.1755 - overshoot_pulse_2_loss: 0.0743 - overshoot_pulse_2_mae: 0.2105 - ringing_frequency_MHz_loss: 3.0236e-04 - ringing_frequency_MHz_mae: 0.0126 - undershoot_pulse_1_loss: 0.0290 - undershoot_pulse_1_mae: 0.1231 - undershoot_pulse_2_loss: 0.0278 - undershoot_pulse_2_mae: 0.1215 - voltage_fall_time_pulse1_loss: 0.0028 - voltage_fall_time_pulse1_mae: 0.0367 - voltage_fall_time_pulse2_loss: 0.0030 - voltage_fall_time_pulse2_mae: 0.0378 - voltage_rise_time_pulse1_loss: 0.0171 - voltage_rise_time_pulse1_mae: 0.0749 - voltage_rise_time_pulse2_loss: 0.0888 - voltage_rise_time_pulse2_mae: 0.1834 - val_current_fall_time_pulse1_loss: 0.0032 - val_current_fall_time_pulse1_mae: 0.0396 - val_current_fall_time_pulse2_loss: 0.0030 - val_current_fall_time_pulse2_mae: 0.0380 - val_current_rise_time_pulse1_loss: 0.0618 - val_current_rise_time_pulse1_mae: 0.1437 - val_current_rise_time_pulse2_loss: 0.0883 - val_current_rise_time_pulse2_mae: 0.1488 - val_loss: 0.4013 - val_overshoot_pulse_1_loss: 0.0341 - val_overshoot_pulse_1_mae: 0.1421 - val_overshoot_pulse_2_loss: 0.0673 - val_overshoot_pulse_2_mae: 0.2003 - val_ringing_frequency_MHz_loss: 3.9128e-04 - val_ringing_frequency_MHz_mae: 0.0147 - val_undershoot_pulse_1_loss: 0.0173 - val_undershoot_pulse_1_mae: 0.0912 - val_undershoot_pulse_2_loss: 0.0174 - val_undershoot_pulse_2_mae: 0.0925 - val_voltage_fall_time_pulse1_loss: 0.0011 - val_voltage_fall_time_pulse1_mae: 0.0255 - val_voltage_fall_time_pulse2_loss: 0.0011 - val_voltage_fall_time_pulse2_mae: 0.0239 - val_voltage_rise_time_pulse1_loss: 0.0106 - val_voltage_rise_time_pulse1_mae: 0.0560 - val_voltage_rise_time_pulse2_loss: 0.0855 - val_voltage_rise_time_pulse2_mae: 0.1714 - learning_rate: 1.3500e-05
# Epoch 61/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 17s 57ms/step - current_fall_time_pulse1_loss: 0.0096 - current_fall_time_pulse1_mae: 0.0727 - current_fall_time_pulse2_loss: 0.0094 - current_fall_time_pulse2_mae: 0.0713 - current_rise_time_pulse1_loss: 0.0672 - current_rise_time_pulse1_mae: 0.1578 - current_rise_time_pulse2_loss: 0.0972 - current_rise_time_pulse2_mae: 0.1735 - loss: 0.4884 - overshoot_pulse_1_loss: 0.0528 - overshoot_pulse_1_mae: 0.1753 - overshoot_pulse_2_loss: 0.0732 - overshoot_pulse_2_mae: 0.2083 - ringing_frequency_MHz_loss: 2.8976e-04 - ringing_frequency_MHz_mae: 0.0124 - undershoot_pulse_1_loss: 0.0288 - undershoot_pulse_1_mae: 0.1214 - undershoot_pulse_2_loss: 0.0277 - undershoot_pulse_2_mae: 0.1205 - voltage_fall_time_pulse1_loss: 0.0028 - voltage_fall_time_pulse1_mae: 0.0365 - voltage_fall_time_pulse2_loss: 0.0029 - voltage_fall_time_pulse2_mae: 0.0376 - voltage_rise_time_pulse1_loss: 0.0172 - voltage_rise_time_pulse1_mae: 0.0746 - voltage_rise_time_pulse2_loss: 0.0898 - voltage_rise_time_pulse2_mae: 0.1841 - val_current_fall_time_pulse1_loss: 0.0033 - val_current_fall_time_pulse1_mae: 0.0400 - val_current_fall_time_pulse2_loss: 0.0030 - val_current_fall_time_pulse2_mae: 0.0380 - val_current_rise_time_pulse1_loss: 0.0619 - val_current_rise_time_pulse1_mae: 0.1437 - val_current_rise_time_pulse2_loss: 0.0884 - val_current_rise_time_pulse2_mae: 0.1494 - val_loss: 0.4019 - val_overshoot_pulse_1_loss: 0.0343 - val_overshoot_pulse_1_mae: 0.1425 - val_overshoot_pulse_2_loss: 0.0672 - val_overshoot_pulse_2_mae: 0.2000 - val_ringing_frequency_MHz_loss: 3.8053e-04 - val_ringing_frequency_MHz_mae: 0.0145 - val_undershoot_pulse_1_loss: 0.0174 - val_undershoot_pulse_1_mae: 0.0917 - val_undershoot_pulse_2_loss: 0.0175 - val_undershoot_pulse_2_mae: 0.0929 - val_voltage_fall_time_pulse1_loss: 0.0012 - val_voltage_fall_time_pulse1_mae: 0.0262 - val_voltage_fall_time_pulse2_loss: 0.0012 - val_voltage_fall_time_pulse2_mae: 0.0244 - val_voltage_rise_time_pulse1_loss: 0.0106 - val_voltage_rise_time_pulse1_mae: 0.0559 - val_voltage_rise_time_pulse2_loss: 0.0855 - val_voltage_rise_time_pulse2_mae: 0.1713 - learning_rate: 1.3500e-05
# Epoch 62/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 15s 53ms/step - current_fall_time_pulse1_loss: 0.0095 - current_fall_time_pulse1_mae: 0.0724 - current_fall_time_pulse2_loss: 0.0093 - current_fall_time_pulse2_mae: 0.0709 - current_rise_time_pulse1_loss: 0.0665 - current_rise_time_pulse1_mae: 0.1571 - current_rise_time_pulse2_loss: 0.0985 - current_rise_time_pulse2_mae: 0.1740 - loss: 0.4951 - overshoot_pulse_1_loss: 0.0530 - overshoot_pulse_1_mae: 0.1747 - overshoot_pulse_2_loss: 0.0732 - overshoot_pulse_2_mae: 0.2094 - ringing_frequency_MHz_loss: 2.9859e-04 - ringing_frequency_MHz_mae: 0.0125 - undershoot_pulse_1_loss: 0.0292 - undershoot_pulse_1_mae: 0.1227 - undershoot_pulse_2_loss: 0.0284 - undershoot_pulse_2_mae: 0.1218 - voltage_fall_time_pulse1_loss: 0.0027 - voltage_fall_time_pulse1_mae: 0.0363 - voltage_fall_time_pulse2_loss: 0.0029 - voltage_fall_time_pulse2_mae: 0.0377 - voltage_rise_time_pulse1_loss: 0.0163 - voltage_rise_time_pulse1_mae: 0.0735 - voltage_rise_time_pulse2_loss: 0.0955 - voltage_rise_time_pulse2_mae: 0.1850 - val_current_fall_time_pulse1_loss: 0.0030 - val_current_fall_time_pulse1_mae: 0.0387 - val_current_fall_time_pulse2_loss: 0.0027 - val_current_fall_time_pulse2_mae: 0.0368 - val_current_rise_time_pulse1_loss: 0.0618 - val_current_rise_time_pulse1_mae: 0.1436 - val_current_rise_time_pulse2_loss: 0.0883 - val_current_rise_time_pulse2_mae: 0.1492 - val_loss: 0.4013 - val_overshoot_pulse_1_loss: 0.0345 - val_overshoot_pulse_1_mae: 0.1430 - val_overshoot_pulse_2_loss: 0.0673 - val_overshoot_pulse_2_mae: 0.2002 - val_ringing_frequency_MHz_loss: 3.9672e-04 - val_ringing_frequency_MHz_mae: 0.0148 - val_undershoot_pulse_1_loss: 0.0174 - val_undershoot_pulse_1_mae: 0.0913 - val_undershoot_pulse_2_loss: 0.0175 - val_undershoot_pulse_2_mae: 0.0923 - val_voltage_fall_time_pulse1_loss: 0.0011 - val_voltage_fall_time_pulse1_mae: 0.0255 - val_voltage_fall_time_pulse2_loss: 0.0011 - val_voltage_fall_time_pulse2_mae: 0.0236 - val_voltage_rise_time_pulse1_loss: 0.0105 - val_voltage_rise_time_pulse1_mae: 0.0557 - val_voltage_rise_time_pulse2_loss: 0.0855 - val_voltage_rise_time_pulse2_mae: 0.1714 - learning_rate: 1.3500e-05
# Epoch 63/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 17s 58ms/step - current_fall_time_pulse1_loss: 0.0096 - current_fall_time_pulse1_mae: 0.0727 - current_fall_time_pulse2_loss: 0.0095 - current_fall_time_pulse2_mae: 0.0717 - current_rise_time_pulse1_loss: 0.0670 - current_rise_time_pulse1_mae: 0.1574 - current_rise_time_pulse2_loss: 0.0967 - current_rise_time_pulse2_mae: 0.1741 - loss: 0.4911 - overshoot_pulse_1_loss: 0.0536 - overshoot_pulse_1_mae: 0.1739 - overshoot_pulse_2_loss: 0.0740 - overshoot_pulse_2_mae: 0.2096 - ringing_frequency_MHz_loss: 2.9921e-04 - ringing_frequency_MHz_mae: 0.0125 - undershoot_pulse_1_loss: 0.0286 - undershoot_pulse_1_mae: 0.1222 - undershoot_pulse_2_loss: 0.0279 - undershoot_pulse_2_mae: 0.1212 - voltage_fall_time_pulse1_loss: 0.0027 - voltage_fall_time_pulse1_mae: 0.0364 - voltage_fall_time_pulse2_loss: 0.0029 - voltage_fall_time_pulse2_mae: 0.0375 - voltage_rise_time_pulse1_loss: 0.0172 - voltage_rise_time_pulse1_mae: 0.0743 - voltage_rise_time_pulse2_loss: 0.0915 - voltage_rise_time_pulse2_mae: 0.1838 - val_current_fall_time_pulse1_loss: 0.0033 - val_current_fall_time_pulse1_mae: 0.0403 - val_current_fall_time_pulse2_loss: 0.0030 - val_current_fall_time_pulse2_mae: 0.0383 - val_current_rise_time_pulse1_loss: 0.0618 - val_current_rise_time_pulse1_mae: 0.1441 - val_current_rise_time_pulse2_loss: 0.0883 - val_current_rise_time_pulse2_mae: 0.1491 - val_loss: 0.4012 - val_overshoot_pulse_1_loss: 0.0341 - val_overshoot_pulse_1_mae: 0.1421 - val_overshoot_pulse_2_loss: 0.0673 - val_overshoot_pulse_2_mae: 0.2004 - val_ringing_frequency_MHz_loss: 3.8369e-04 - val_ringing_frequency_MHz_mae: 0.0145 - val_undershoot_pulse_1_loss: 0.0174 - val_undershoot_pulse_1_mae: 0.0918 - val_undershoot_pulse_2_loss: 0.0173 - val_undershoot_pulse_2_mae: 0.0925 - val_voltage_fall_time_pulse1_loss: 0.0011 - val_voltage_fall_time_pulse1_mae: 0.0256 - val_voltage_fall_time_pulse2_loss: 0.0011 - val_voltage_fall_time_pulse2_mae: 0.0239 - val_voltage_rise_time_pulse1_loss: 0.0104 - val_voltage_rise_time_pulse1_mae: 0.0554 - val_voltage_rise_time_pulse2_loss: 0.0855 - val_voltage_rise_time_pulse2_mae: 0.1713 - learning_rate: 1.3500e-05
# Epoch 64/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - current_fall_time_pulse1_loss: 0.0095 - current_fall_time_pulse1_mae: 0.0722 - current_fall_time_pulse2_loss: 0.0094 - current_fall_time_pulse2_mae: 0.0715 - current_rise_time_pulse1_loss: 0.0669 - current_rise_time_pulse1_mae: 0.1565 - current_rise_time_pulse2_loss: 0.0976 - current_rise_time_pulse2_mae: 0.1740 - loss: 0.4900 - overshoot_pulse_1_loss: 0.0532 - overshoot_pulse_1_mae: 0.1751 - overshoot_pulse_2_loss: 0.0734 - overshoot_pulse_2_mae: 0.2086 - ringing_frequency_MHz_loss: 2.9687e-04 - ringing_frequency_MHz_mae: 0.0125 - undershoot_pulse_1_loss: 0.0283 - undershoot_pulse_1_mae: 0.1225 - undershoot_pulse_2_loss: 0.0273 - undershoot_pulse_2_mae: 0.1215 - voltage_fall_time_pulse1_loss: 0.0028 - voltage_fall_time_pulse1_mae: 0.0364 - voltage_fall_time_pulse2_loss: 0.0028 - voltage_fall_time_pulse2_mae: 0.0371 - voltage_rise_time_pulse1_loss: 0.0169 - voltage_rise_time_pulse1_mae: 0.0738 - voltage_rise_time_pulse2_loss: 0.0921 - voltage_rise_time_pulse2_mae: 0.1828 - val_current_fall_time_pulse1_loss: 0.0032 - val_current_fall_time_pulse1_mae: 0.0396 - val_current_fall_time_pulse2_loss: 0.0029 - val_current_fall_time_pulse2_mae: 0.0374 - val_current_rise_time_pulse1_loss: 0.0618 - val_current_rise_time_pulse1_mae: 0.1435 - val_current_rise_time_pulse2_loss: 0.0882 - val_current_rise_time_pulse2_mae: 0.1484 - val_loss: 0.4015 - val_overshoot_pulse_1_loss: 0.0343 - val_overshoot_pulse_1_mae: 0.1425 - val_overshoot_pulse_2_loss: 0.0672 - val_overshoot_pulse_2_mae: 0.2004 - val_ringing_frequency_MHz_loss: 3.8477e-04 - val_ringing_frequency_MHz_mae: 0.0145 - val_undershoot_pulse_1_loss: 0.0177 - val_undershoot_pulse_1_mae: 0.0924 - val_undershoot_pulse_2_loss: 0.0176 - val_undershoot_pulse_2_mae: 0.0929 - val_voltage_fall_time_pulse1_loss: 0.0011 - val_voltage_fall_time_pulse1_mae: 0.0258 - val_voltage_fall_time_pulse2_loss: 0.0011 - val_voltage_fall_time_pulse2_mae: 0.0240 - val_voltage_rise_time_pulse1_loss: 0.0105 - val_voltage_rise_time_pulse1_mae: 0.0558 - val_voltage_rise_time_pulse2_loss: 0.0854 - val_voltage_rise_time_pulse2_mae: 0.1716 - learning_rate: 1.3500e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step
#
# train:
#                        Target        R2          RMSE
# 3   voltage_fall_time_pulse2  0.998891  2.286280e-10
# 2   voltage_fall_time_pulse1  0.998857  2.324009e-10
# 7   current_fall_time_pulse2  0.997369  6.034028e-10
# 6   current_fall_time_pulse1  0.997121  6.331242e-10
# 12     ringing_frequency_MHz  0.995332  2.256086e+00
# 0   voltage_rise_time_pulse1  0.989917  4.068335e-10
# 10        undershoot_pulse_1  0.983050  1.783756e+00
# 11        undershoot_pulse_2  0.982822  1.796712e+00
# 8          overshoot_pulse_1  0.966527  2.237598e+00
# 4   current_rise_time_pulse1  0.936372  1.239511e-08
# 9          overshoot_pulse_2  0.935248  6.435629e+00
# 1   voltage_rise_time_pulse2  0.921194  1.130460e-09
# 5   current_rise_time_pulse2  0.912721  7.420115e-09
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
#
# val:
#                        Target        R2          RMSE
# 3   voltage_fall_time_pulse2  0.998885  2.281617e-10
# 2   voltage_fall_time_pulse1  0.998862  2.306908e-10
# 7   current_fall_time_pulse2  0.997321  6.037692e-10
# 6   current_fall_time_pulse1  0.997048  6.360146e-10
# 12     ringing_frequency_MHz  0.995208  2.272741e+00
# 0   voltage_rise_time_pulse1  0.989490  4.138779e-10
# 10        undershoot_pulse_1  0.982808  1.803650e+00
# 11        undershoot_pulse_2  0.982663  1.810912e+00
# 8          overshoot_pulse_1  0.964249  2.245563e+00
# 4   current_rise_time_pulse1  0.936853  1.220332e-08
# 9          overshoot_pulse_2  0.931445  6.536652e+00
# 1   voltage_rise_time_pulse2  0.911553  1.176624e-09
# 5   current_rise_time_pulse2  0.909705  7.464889e-09
# 2698/2698 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step
#
# test:
#                        Target        R2          RMSE
# 3   voltage_fall_time_pulse2  0.998890  2.285581e-10
# 2   voltage_fall_time_pulse1  0.998858  2.321452e-10
# 7   current_fall_time_pulse2  0.997362  6.034578e-10
# 6   current_fall_time_pulse1  0.997110  6.335586e-10
# 12     ringing_frequency_MHz  0.995314  2.258592e+00
# 0   voltage_rise_time_pulse1  0.989853  4.078979e-10
# 10        undershoot_pulse_1  0.983014  1.786755e+00
# 11        undershoot_pulse_2  0.982798  1.798849e+00
# 8          overshoot_pulse_1  0.966203  2.238795e+00
# 4   current_rise_time_pulse1  0.936443  1.236653e-08
# 9          overshoot_pulse_2  0.934691  6.450884e+00
# 1   voltage_rise_time_pulse2  0.919791  1.137504e-09
# 5   current_rise_time_pulse2  0.912281  7.426848e-09
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# unseen:
#                        Target        R2          RMSE
# 7   current_fall_time_pulse2  0.903889  3.456598e-09
# 6   current_fall_time_pulse1  0.897723  3.590420e-09
# 8          overshoot_pulse_1  0.718871  7.170268e+00
# 9          overshoot_pulse_2  0.642172  1.239294e+01
# 11        undershoot_pulse_2  0.570570  6.384569e+00
# 10        undershoot_pulse_1  0.556023  6.536107e+00
# 5   current_rise_time_pulse2  0.461157  1.230650e-08
# 1   voltage_rise_time_pulse2  0.371650  3.698144e-09
# 0   voltage_rise_time_pulse1  0.191292  1.548524e-09
#                       Target        R2          RMSE
# 7   current_fall_time_pulse2  0.903889  3.456598e-09
# 6   current_fall_time_pulse1  0.897723  3.590420e-09
# 8          overshoot_pulse_1  0.718871  7.170268e+00
# 9          overshoot_pulse_2  0.642172  1.239294e+01
# 11        undershoot_pulse_2  0.570570  6.384569e+00
# 10        undershoot_pulse_1  0.556023  6.536107e+00
# 5   current_rise_time_pulse2  0.461157  1.230650e-08
# 1   voltage_rise_time_pulse2  0.371650  3.698144e-09
# 0   voltage_rise_time_pulse1  0.191292  1.548524e-09

# %%
# ==================== ATTENTION ANN (Best Iteration) ====================
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, regularizers
import matplotlib.pyplot as plt

# ============== SETTINGS ==============
SEED = 42
UNSEEN_PART = 'C2M0040120D'
BASE_DIR = "iteration_1"
os.makedirs(f"{BASE_DIR}/r2_rmse_tables", exist_ok=True)
os.makedirs(f"{BASE_DIR}/train_val_loss_curves", exist_ok=True)
os.makedirs(f"{BASE_DIR}/models", exist_ok=True)

# ============== LOAD DATA ==============
df = pd.read_csv(
    r"C:\Users\pc\Desktop\Neural_Network_Models\merged_train_5_MOSFETs_10percent_balanced.csv"
)

TARGET_COLUMNS = [
    'voltage_rise_time_pulse1', 'voltage_rise_time_pulse2',
    'voltage_fall_time_pulse1', 'voltage_fall_time_pulse2',
    'current_rise_time_pulse1', 'current_rise_time_pulse2',
    'current_fall_time_pulse1', 'current_fall_time_pulse2',
    'overshoot_pulse_1', 'overshoot_pulse_2',
    'undershoot_pulse_1', 'undershoot_pulse_2',
    'ringing_frequency_MHz'
]
DROP_COLUMNS = ['DeviceID', 'MOSFET', 'Part_Number']

# ============== SPLIT SEEN/UNSEEN DEVICES ==============
seen_parts = [p for p in df['Part_Number'].unique().tolist() if p != UNSEEN_PART]
train_df = df[df['Part_Number'].isin(seen_parts)].copy()
test_df  = df[df['Part_Number'] == UNSEEN_PART].copy()

# ============== PHYSICS FEATURES ==============
def compute_physics_features(row):
    L_eq = row[['Ls4','Ls5','Ls6','Ls7','Ls8','Ls9','Ls10','Ls11']].sum()
    C_eq = row.get("Coss", 1e-12)
    f_res = 1/(2*np.pi*np.sqrt(L_eq*C_eq))/1e6 if L_eq>0 and C_eq>0 else 0
    overshoot_est = row.get("VDS_max",0) - row.get("Vbus",0)
    undershoot_est = - row.get("VGS_th_min",0)
    dVdt_est = row.get("VDS_max",0)/row.get("Tp1",1e-9)
    dIdt_est = row.get("ID_max_25C",0)/row.get("Tp1",1e-9)
    return pd.Series([f_res, overshoot_est, undershoot_est, dVdt_est, dIdt_est])

for df_ in [train_df, test_df]:
    df_[['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est']] = \
        df_.apply(compute_physics_features, axis=1)

physics_features = ['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est']
INPUT_COLUMNS = [c for c in df.columns if c not in TARGET_COLUMNS + DROP_COLUMNS] + physics_features

# ============== SCALE INPUTS ==============
input_scaler = StandardScaler()
input_scaler.fit(pd.concat([train_df[INPUT_COLUMNS], test_df[INPUT_COLUMNS]]))
X_train_all = input_scaler.transform(train_df[INPUT_COLUMNS])
X_test_all  = input_scaler.transform(test_df[INPUT_COLUMNS])

# Separate physics cols
phys_idx = [INPUT_COLUMNS.index(c) for c in physics_features]
X_train_phys = X_train_all[:, phys_idx]
X_test_phys  = X_test_all[:, phys_idx]
X_train_main = np.delete(X_train_all, phys_idx, axis=1)
X_test_main  = np.delete(X_test_all, phys_idx, axis=1)

# ============== SCALE OUTPUTS (per target) ==============
output_scalers, y_train_scaled, y_test_scaled = {}, [], []
for col in TARGET_COLUMNS:
    scaler = MinMaxScaler() if col == 'ringing_frequency_MHz' else StandardScaler()
    y_train_scaled.append(scaler.fit_transform(train_df[[col]]).flatten())
    y_test_scaled.append(scaler.transform(test_df[[col]]).flatten())
    output_scalers[col] = scaler
y_train_scaled = np.array(y_train_scaled).T
y_test_scaled  = np.array(y_test_scaled).T

# ============== SPLIT TRAIN/VAL ==============
Xtr_main, Xval_main, Xtr_phys, Xval_phys, ytr, yval = train_test_split(
    X_train_main, X_train_phys, y_train_scaled,
    test_size=0.15, random_state=SEED
)

# ============== BUILD ATTENTION ANN ==============
def build_attention_ann(input_dim_main, input_dim_phys, output_dim, l2_reg=1e-4, dropout_rate=0.2):
    inp_main = layers.Input(shape=(input_dim_main,), name="main_inputs")
    inp_phys = layers.Input(shape=(input_dim_phys,), name="physics_inputs")

    # Main backbone
    x_main = layers.Dense(128, kernel_regularizer=regularizers.l2(l2_reg))(inp_main)
    x_main = layers.BatchNormalization()(x_main); x_main = layers.ReLU()(x_main)
    x_main = layers.Dropout(dropout_rate)(x_main)

    x_main = layers.Dense(64, kernel_regularizer=regularizers.l2(l2_reg))(x_main)
    x_main = layers.BatchNormalization()(x_main); x_main = layers.ReLU()(x_main)
    x_main = layers.Dropout(dropout_rate)(x_main)

    # Physics branch
    x_phys = layers.Dense(32, activation="relu")(inp_phys)

    # Attention mechanism
    concat = layers.Concatenate()([x_main, x_phys])
    attn = layers.Dense(concat.shape[-1], activation="softmax")(concat)
    attended = layers.multiply([concat, attn])

    # Multi-head outputs
    outputs = []
    for col in TARGET_COLUMNS:
        h = layers.Dense(64, activation="relu")(attended)
        h = layers.Dropout(dropout_rate)(h)
        h = layers.Dense(32, activation="relu")(h)
        out = layers.Dense(1, activation="linear", name=col)(h)
        outputs.append(out)

    model = models.Model(inputs=[inp_main, inp_phys], outputs=outputs)
    return model

model = build_attention_ann(Xtr_main.shape[1], Xtr_phys.shape[1], len(TARGET_COLUMNS))

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-4),
    loss=["mse"]*len(TARGET_COLUMNS),
    metrics=["mae"]*len(TARGET_COLUMNS)
)

early_stop = callbacks.EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)
reduce_lr  = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=5)

history = model.fit(
    [Xtr_main, Xtr_phys],
    [ytr[:,i] for i in range(len(TARGET_COLUMNS))],
    validation_data=([Xval_main,Xval_phys],[yval[:,i] for i in range(len(TARGET_COLUMNS))]),
    epochs=120, batch_size=256, callbacks=[early_stop, reduce_lr], verbose=1
)

model.save(f"{BASE_DIR}/models/attention_ann.h5")

# ============== LOSS CURVE ==============
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel("Epoch"); plt.ylabel("MSE Loss")
plt.title("Train vs Validation Loss")
plt.legend(); plt.savefig(f"{BASE_DIR}/train_val_loss_curves/loss.png"); plt.close()

# ============== EVALUATION ==============
def evaluate_and_save(X_main, X_phys, y_scaled, name, positive_only=False):
    y_pred_scaled_list = model.predict([X_main, X_phys])
    results = []
    for i, col in enumerate(TARGET_COLUMNS):
        y_true = output_scalers[col].inverse_transform(y_scaled[:,i].reshape(-1,1)).flatten()
        y_pred = output_scalers[col].inverse_transform(y_pred_scaled_list[i].reshape(-1,1)).flatten()
        r2 = r2_score(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        results.append((col, r2, rmse))
    df_results = pd.DataFrame(results, columns=["Target","R2","RMSE"]).sort_values("R2",ascending=False)
    if positive_only:
        df_results = df_results[df_results["R2"]>0]
    print(f"\n{name}:\n",df_results)
    df_results.to_csv(f"{BASE_DIR}/r2_rmse_tables/{name}.csv", index=False)
    return df_results

evaluate_and_save(Xtr_main,Xtr_phys,ytr,"train")
evaluate_and_save(Xval_main,Xval_phys,yval,"val")
evaluate_and_save(X_train_main,X_train_phys,y_train_scaled,"test")
evaluate_and_save(X_test_main,X_test_phys,y_test_scaled,"unseen",positive_only=True)
# Out:
# Epoch 1/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 15s 67ms/step - current_fall_time_pulse1_loss: 0.9641 - current_fall_time_pulse1_mae: 0.7834 - current_fall_time_pulse2_loss: 0.9693 - current_fall_time_pulse2_mae: 0.7897 - current_rise_time_pulse1_loss: 0.9819 - current_rise_time_pulse1_mae: 0.7920 - current_rise_time_pulse2_loss: 0.9802 - current_rise_time_pulse2_mae: 0.8353 - loss: 11.8487 - overshoot_pulse_1_loss: 0.9565 - overshoot_pulse_1_mae: 0.7655 - overshoot_pulse_2_loss: 0.9685 - overshoot_pulse_2_mae: 0.7827 - ringing_frequency_MHz_loss: 0.2386 - ringing_frequency_MHz_mae: 0.3981 - undershoot_pulse_1_loss: 0.9566 - undershoot_pulse_1_mae: 0.7757 - undershoot_pulse_2_loss: 0.9663 - undershoot_pulse_2_mae: 0.7813 - voltage_fall_time_pulse1_loss: 0.9705 - voltage_fall_time_pulse1_mae: 0.8106 - voltage_fall_time_pulse2_loss: 0.9654 - voltage_fall_time_pulse2_mae: 0.8119 - voltage_rise_time_pulse1_loss: 0.9694 - voltage_rise_time_pulse1_mae: 0.7898 - voltage_rise_time_pulse2_loss: 0.9461 - voltage_rise_time_pulse2_mae: 0.7637 - val_current_fall_time_pulse1_loss: 0.9864 - val_current_fall_time_pulse1_mae: 0.7637 - val_current_fall_time_pulse2_loss: 0.9872 - val_current_fall_time_pulse2_mae: 0.7820 - val_current_rise_time_pulse1_loss: 0.9293 - val_current_rise_time_pulse1_mae: 0.7503 - val_current_rise_time_pulse2_loss: 0.9344 - val_current_rise_time_pulse2_mae: 0.8125 - val_loss: 11.5026 - val_overshoot_pulse_1_loss: 0.9964 - val_overshoot_pulse_1_mae: 0.7792 - val_overshoot_pulse_2_loss: 0.9571 - val_overshoot_pulse_2_mae: 0.7777 - val_ringing_frequency_MHz_loss: 0.1612 - val_ringing_frequency_MHz_mae: 0.3244 - val_undershoot_pulse_1_loss: 0.8336 - val_undershoot_pulse_1_mae: 0.7332 - val_undershoot_pulse_2_loss: 0.8630 - val_undershoot_pulse_2_mae: 0.7436 - val_voltage_fall_time_pulse1_loss: 1.0625 - val_voltage_fall_time_pulse1_mae: 0.7935 - val_voltage_fall_time_pulse2_loss: 1.0421 - val_voltage_fall_time_pulse2_mae: 0.8042 - val_voltage_rise_time_pulse1_loss: 0.9537 - val_voltage_rise_time_pulse1_mae: 0.7562 - val_voltage_rise_time_pulse2_loss: 1.1265 - val_voltage_rise_time_pulse2_mae: 0.7522 - learning_rate: 5.0000e-04
# Epoch 2/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - current_fall_time_pulse1_loss: 0.8099 - current_fall_time_pulse1_mae: 0.7086 - current_fall_time_pulse2_loss: 0.8362 - current_fall_time_pulse2_mae: 0.7433 - current_rise_time_pulse1_loss: 0.7407 - current_rise_time_pulse1_mae: 0.6775 - current_rise_time_pulse2_loss: 0.7260 - current_rise_time_pulse2_mae: 0.7156 - loss: 9.6329 - overshoot_pulse_1_loss: 0.8444 - overshoot_pulse_1_mae: 0.7179 - overshoot_pulse_2_loss: 0.8050 - overshoot_pulse_2_mae: 0.7072 - ringing_frequency_MHz_loss: 0.1265 - ringing_frequency_MHz_mae: 0.2788 - undershoot_pulse_1_loss: 0.7678 - undershoot_pulse_1_mae: 0.7001 - undershoot_pulse_2_loss: 0.8260 - undershoot_pulse_2_mae: 0.7267 - voltage_fall_time_pulse1_loss: 0.8125 - voltage_fall_time_pulse1_mae: 0.7183 - voltage_fall_time_pulse2_loss: 0.7513 - voltage_fall_time_pulse2_mae: 0.7159 - voltage_rise_time_pulse1_loss: 0.7543 - voltage_rise_time_pulse1_mae: 0.6558 - voltage_rise_time_pulse2_loss: 0.8177 - voltage_rise_time_pulse2_mae: 0.6888 - val_current_fall_time_pulse1_loss: 0.5045 - val_current_fall_time_pulse1_mae: 0.5591 - val_current_fall_time_pulse2_loss: 0.4978 - val_current_fall_time_pulse2_mae: 0.6172 - val_current_rise_time_pulse1_loss: 0.3059 - val_current_rise_time_pulse1_mae: 0.4378 - val_current_rise_time_pulse2_loss: 0.3989 - val_current_rise_time_pulse2_mae: 0.5152 - val_loss: 5.7369 - val_overshoot_pulse_1_loss: 0.8559 - val_overshoot_pulse_1_mae: 0.7085 - val_overshoot_pulse_2_loss: 0.5047 - val_overshoot_pulse_2_mae: 0.5488 - val_ringing_frequency_MHz_loss: 0.0133 - val_ringing_frequency_MHz_mae: 0.0923 - val_undershoot_pulse_1_loss: 0.4271 - val_undershoot_pulse_1_mae: 0.5329 - val_undershoot_pulse_2_loss: 0.4578 - val_undershoot_pulse_2_mae: 0.5580 - val_voltage_fall_time_pulse1_loss: 0.4846 - val_voltage_fall_time_pulse1_mae: 0.4607 - val_voltage_fall_time_pulse2_loss: 0.1673 - val_voltage_fall_time_pulse2_mae: 0.3247 - val_voltage_rise_time_pulse1_loss: 0.4520 - val_voltage_rise_time_pulse1_mae: 0.4663 - val_voltage_rise_time_pulse2_loss: 0.6321 - val_voltage_rise_time_pulse2_mae: 0.5486 - learning_rate: 5.0000e-04
# Epoch 3/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - current_fall_time_pulse1_loss: 0.5371 - current_fall_time_pulse1_mae: 0.5773 - current_fall_time_pulse2_loss: 0.6168 - current_fall_time_pulse2_mae: 0.6372 - current_rise_time_pulse1_loss: 0.3964 - current_rise_time_pulse1_mae: 0.4760 - current_rise_time_pulse2_loss: 0.4517 - current_rise_time_pulse2_mae: 0.5573 - loss: 6.0068 - overshoot_pulse_1_loss: 0.7818 - overshoot_pulse_1_mae: 0.6934 - overshoot_pulse_2_loss: 0.5065 - overshoot_pulse_2_mae: 0.5581 - ringing_frequency_MHz_loss: 0.0270 - ringing_frequency_MHz_mae: 0.1224 - undershoot_pulse_1_loss: 0.5141 - undershoot_pulse_1_mae: 0.5703 - undershoot_pulse_2_loss: 0.5588 - undershoot_pulse_2_mae: 0.5914 - voltage_fall_time_pulse1_loss: 0.4226 - voltage_fall_time_pulse1_mae: 0.4915 - voltage_fall_time_pulse2_loss: 0.2907 - voltage_fall_time_pulse2_mae: 0.4168 - voltage_rise_time_pulse1_loss: 0.3978 - voltage_rise_time_pulse1_mae: 0.4533 - voltage_rise_time_pulse2_loss: 0.4915 - voltage_rise_time_pulse2_mae: 0.5202 - val_current_fall_time_pulse1_loss: 0.3747 - val_current_fall_time_pulse1_mae: 0.5043 - val_current_fall_time_pulse2_loss: 0.4282 - val_current_fall_time_pulse2_mae: 0.5598 - val_current_rise_time_pulse1_loss: 0.2472 - val_current_rise_time_pulse1_mae: 0.3962 - val_current_rise_time_pulse2_loss: 0.3086 - val_current_rise_time_pulse2_mae: 0.4611 - val_loss: 4.2336 - val_overshoot_pulse_1_loss: 0.8165 - val_overshoot_pulse_1_mae: 0.6907 - val_overshoot_pulse_2_loss: 0.4207 - val_overshoot_pulse_2_mae: 0.4926 - val_ringing_frequency_MHz_loss: 0.0050 - val_ringing_frequency_MHz_mae: 0.0567 - val_undershoot_pulse_1_loss: 0.3441 - val_undershoot_pulse_1_mae: 0.4738 - val_undershoot_pulse_2_loss: 0.3748 - val_undershoot_pulse_2_mae: 0.4923 - val_voltage_fall_time_pulse1_loss: 0.1504 - val_voltage_fall_time_pulse1_mae: 0.2672 - val_voltage_fall_time_pulse2_loss: 0.0563 - val_voltage_fall_time_pulse2_mae: 0.1959 - val_voltage_rise_time_pulse1_loss: 0.1629 - val_voltage_rise_time_pulse1_mae: 0.2841 - val_voltage_rise_time_pulse2_loss: 0.3794 - val_voltage_rise_time_pulse2_mae: 0.3926 - learning_rate: 5.0000e-04
# Epoch 4/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - current_fall_time_pulse1_loss: 0.4174 - current_fall_time_pulse1_mae: 0.5037 - current_fall_time_pulse2_loss: 0.4859 - current_fall_time_pulse2_mae: 0.5564 - current_rise_time_pulse1_loss: 0.2877 - current_rise_time_pulse1_mae: 0.4130 - current_rise_time_pulse2_loss: 0.3560 - current_rise_time_pulse2_mae: 0.4979 - loss: 4.2636 - overshoot_pulse_1_loss: 0.7227 - overshoot_pulse_1_mae: 0.6639 - overshoot_pulse_2_loss: 0.3838 - overshoot_pulse_2_mae: 0.4856 - ringing_frequency_MHz_loss: 0.0161 - ringing_frequency_MHz_mae: 0.0944 - undershoot_pulse_1_loss: 0.3421 - undershoot_pulse_1_mae: 0.4657 - undershoot_pulse_2_loss: 0.3730 - undershoot_pulse_2_mae: 0.4857 - voltage_fall_time_pulse1_loss: 0.1871 - voltage_fall_time_pulse1_mae: 0.3179 - voltage_fall_time_pulse2_loss: 0.1559 - voltage_fall_time_pulse2_mae: 0.2920 - voltage_rise_time_pulse1_loss: 0.2178 - voltage_rise_time_pulse1_mae: 0.3315 - voltage_rise_time_pulse2_loss: 0.3050 - voltage_rise_time_pulse2_mae: 0.3839 - val_current_fall_time_pulse1_loss: 0.3162 - val_current_fall_time_pulse1_mae: 0.4344 - val_current_fall_time_pulse2_loss: 0.3584 - val_current_fall_time_pulse2_mae: 0.4899 - val_current_rise_time_pulse1_loss: 0.1676 - val_current_rise_time_pulse1_mae: 0.3299 - val_current_rise_time_pulse2_loss: 0.2575 - val_current_rise_time_pulse2_mae: 0.4180 - val_loss: 3.4434 - val_overshoot_pulse_1_loss: 0.7785 - val_overshoot_pulse_1_mae: 0.6742 - val_overshoot_pulse_2_loss: 0.3636 - val_overshoot_pulse_2_mae: 0.4440 - val_ringing_frequency_MHz_loss: 0.0035 - val_ringing_frequency_MHz_mae: 0.0478 - val_undershoot_pulse_1_loss: 0.2617 - val_undershoot_pulse_1_mae: 0.4069 - val_undershoot_pulse_2_loss: 0.2912 - val_undershoot_pulse_2_mae: 0.4327 - val_voltage_fall_time_pulse1_loss: 0.0611 - val_voltage_fall_time_pulse1_mae: 0.1853 - val_voltage_fall_time_pulse2_loss: 0.0557 - val_voltage_fall_time_pulse2_mae: 0.1832 - val_voltage_rise_time_pulse1_loss: 0.1043 - val_voltage_rise_time_pulse1_mae: 0.2509 - val_voltage_rise_time_pulse2_loss: 0.3204 - val_voltage_rise_time_pulse2_mae: 0.3281 - learning_rate: 5.0000e-04
# Epoch 5/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - current_fall_time_pulse1_loss: 0.2741 - current_fall_time_pulse1_mae: 0.3957 - current_fall_time_pulse2_loss: 0.3136 - current_fall_time_pulse2_mae: 0.4424 - current_rise_time_pulse1_loss: 0.1898 - current_rise_time_pulse1_mae: 0.3398 - current_rise_time_pulse2_loss: 0.3096 - current_rise_time_pulse2_mae: 0.4526 - loss: 3.2400 - overshoot_pulse_1_loss: 0.6742 - overshoot_pulse_1_mae: 0.6368 - overshoot_pulse_2_loss: 0.3140 - overshoot_pulse_2_mae: 0.4358 - ringing_frequency_MHz_loss: 0.0101 - ringing_frequency_MHz_mae: 0.0739 - undershoot_pulse_1_loss: 0.2523 - undershoot_pulse_1_mae: 0.3905 - undershoot_pulse_2_loss: 0.2684 - undershoot_pulse_2_mae: 0.4052 - voltage_fall_time_pulse1_loss: 0.0956 - voltage_fall_time_pulse1_mae: 0.2343 - voltage_fall_time_pulse2_loss: 0.0922 - voltage_fall_time_pulse2_mae: 0.2322 - voltage_rise_time_pulse1_loss: 0.1507 - voltage_rise_time_pulse1_mae: 0.2877 - voltage_rise_time_pulse2_loss: 0.2822 - voltage_rise_time_pulse2_mae: 0.3462 - val_current_fall_time_pulse1_loss: 0.2271 - val_current_fall_time_pulse1_mae: 0.3345 - val_current_fall_time_pulse2_loss: 0.2554 - val_current_fall_time_pulse2_mae: 0.3846 - val_current_rise_time_pulse1_loss: 0.1368 - val_current_rise_time_pulse1_mae: 0.2871 - val_current_rise_time_pulse2_loss: 0.2400 - val_current_rise_time_pulse2_mae: 0.3910 - val_loss: 2.9256 - val_overshoot_pulse_1_loss: 0.7091 - val_overshoot_pulse_1_mae: 0.6416 - val_overshoot_pulse_2_loss: 0.3035 - val_overshoot_pulse_2_mae: 0.4093 - val_ringing_frequency_MHz_loss: 0.0044 - val_ringing_frequency_MHz_mae: 0.0525 - val_undershoot_pulse_1_loss: 0.2084 - val_undershoot_pulse_1_mae: 0.3606 - val_undershoot_pulse_2_loss: 0.2236 - val_undershoot_pulse_2_mae: 0.3775 - val_voltage_fall_time_pulse1_loss: 0.0646 - val_voltage_fall_time_pulse1_mae: 0.1766 - val_voltage_fall_time_pulse2_loss: 0.0641 - val_voltage_fall_time_pulse2_mae: 0.1813 - val_voltage_rise_time_pulse1_loss: 0.1033 - val_voltage_rise_time_pulse1_mae: 0.2368 - val_voltage_rise_time_pulse2_loss: 0.3275 - val_voltage_rise_time_pulse2_mae: 0.3150 - learning_rate: 5.0000e-04
# Epoch 6/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - current_fall_time_pulse1_loss: 0.1757 - current_fall_time_pulse1_mae: 0.3123 - current_fall_time_pulse2_loss: 0.1878 - current_fall_time_pulse2_mae: 0.3333 - current_rise_time_pulse1_loss: 0.1579 - current_rise_time_pulse1_mae: 0.3065 - current_rise_time_pulse2_loss: 0.2727 - current_rise_time_pulse2_mae: 0.4156 - loss: 2.6590 - overshoot_pulse_1_loss: 0.5854 - overshoot_pulse_1_mae: 0.5957 - overshoot_pulse_2_loss: 0.2593 - overshoot_pulse_2_mae: 0.3937 - ringing_frequency_MHz_loss: 0.0088 - ringing_frequency_MHz_mae: 0.0690 - undershoot_pulse_1_loss: 0.2235 - undershoot_pulse_1_mae: 0.3617 - undershoot_pulse_2_loss: 0.2287 - undershoot_pulse_2_mae: 0.3680 - voltage_fall_time_pulse1_loss: 0.0838 - voltage_fall_time_pulse1_mae: 0.2155 - voltage_fall_time_pulse2_loss: 0.0793 - voltage_fall_time_pulse2_mae: 0.2127 - voltage_rise_time_pulse1_loss: 0.1323 - voltage_rise_time_pulse1_mae: 0.2702 - voltage_rise_time_pulse2_loss: 0.2508 - voltage_rise_time_pulse2_mae: 0.3198 - val_current_fall_time_pulse1_loss: 0.1293 - val_current_fall_time_pulse1_mae: 0.2579 - val_current_fall_time_pulse2_loss: 0.1210 - val_current_fall_time_pulse2_mae: 0.2626 - val_current_rise_time_pulse1_loss: 0.1148 - val_current_rise_time_pulse1_mae: 0.2610 - val_current_rise_time_pulse2_loss: 0.2116 - val_current_rise_time_pulse2_mae: 0.3589 - val_loss: 2.3110 - val_overshoot_pulse_1_loss: 0.5479 - val_overshoot_pulse_1_mae: 0.5629 - val_overshoot_pulse_2_loss: 0.2345 - val_overshoot_pulse_2_mae: 0.3563 - val_ringing_frequency_MHz_loss: 0.0036 - val_ringing_frequency_MHz_mae: 0.0465 - val_undershoot_pulse_1_loss: 0.1749 - val_undershoot_pulse_1_mae: 0.3239 - val_undershoot_pulse_2_loss: 0.1796 - val_undershoot_pulse_2_mae: 0.3322 - val_voltage_fall_time_pulse1_loss: 0.0567 - val_voltage_fall_time_pulse1_mae: 0.1570 - val_voltage_fall_time_pulse2_loss: 0.0460 - val_voltage_fall_time_pulse2_mae: 0.1503 - val_voltage_rise_time_pulse1_loss: 0.0989 - val_voltage_rise_time_pulse1_mae: 0.2226 - val_voltage_rise_time_pulse2_loss: 0.3210 - val_voltage_rise_time_pulse2_mae: 0.3061 - learning_rate: 5.0000e-04
# Epoch 7/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - current_fall_time_pulse1_loss: 0.1276 - current_fall_time_pulse1_mae: 0.2684 - current_fall_time_pulse2_loss: 0.1216 - current_fall_time_pulse2_mae: 0.2658 - current_rise_time_pulse1_loss: 0.1387 - current_rise_time_pulse1_mae: 0.2829 - current_rise_time_pulse2_loss: 0.2435 - current_rise_time_pulse2_mae: 0.3833 - loss: 2.1777 - overshoot_pulse_1_loss: 0.4490 - overshoot_pulse_1_mae: 0.5155 - overshoot_pulse_2_loss: 0.2079 - overshoot_pulse_2_mae: 0.3502 - ringing_frequency_MHz_loss: 0.0072 - ringing_frequency_MHz_mae: 0.0637 - undershoot_pulse_1_loss: 0.1953 - undershoot_pulse_1_mae: 0.3401 - undershoot_pulse_2_loss: 0.1984 - undershoot_pulse_2_mae: 0.3437 - voltage_fall_time_pulse1_loss: 0.0704 - voltage_fall_time_pulse1_mae: 0.1980 - voltage_fall_time_pulse2_loss: 0.0615 - voltage_fall_time_pulse2_mae: 0.1865 - voltage_rise_time_pulse1_loss: 0.1231 - voltage_rise_time_pulse1_mae: 0.2530 - voltage_rise_time_pulse2_loss: 0.2212 - voltage_rise_time_pulse2_mae: 0.3084 - val_current_fall_time_pulse1_loss: 0.0802 - val_current_fall_time_pulse1_mae: 0.2036 - val_current_fall_time_pulse2_loss: 0.0800 - val_current_fall_time_pulse2_mae: 0.2075 - val_current_rise_time_pulse1_loss: 0.1071 - val_current_rise_time_pulse1_mae: 0.2520 - val_current_rise_time_pulse2_loss: 0.1952 - val_current_rise_time_pulse2_mae: 0.3334 - val_loss: 1.8780 - val_overshoot_pulse_1_loss: 0.4079 - val_overshoot_pulse_1_mae: 0.4750 - val_overshoot_pulse_2_loss: 0.1939 - val_overshoot_pulse_2_mae: 0.3244 - val_ringing_frequency_MHz_loss: 0.0031 - val_ringing_frequency_MHz_mae: 0.0429 - val_undershoot_pulse_1_loss: 0.1334 - val_undershoot_pulse_1_mae: 0.2766 - val_undershoot_pulse_2_loss: 0.1367 - val_undershoot_pulse_2_mae: 0.2852 - val_voltage_fall_time_pulse1_loss: 0.0377 - val_voltage_fall_time_pulse1_mae: 0.1261 - val_voltage_fall_time_pulse2_loss: 0.0312 - val_voltage_fall_time_pulse2_mae: 0.1200 - val_voltage_rise_time_pulse1_loss: 0.0937 - val_voltage_rise_time_pulse1_mae: 0.2114 - val_voltage_rise_time_pulse2_loss: 0.3082 - val_voltage_rise_time_pulse2_mae: 0.2973 - learning_rate: 5.0000e-04
# Epoch 8/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - current_fall_time_pulse1_loss: 0.1038 - current_fall_time_pulse1_mae: 0.2403 - current_fall_time_pulse2_loss: 0.1057 - current_fall_time_pulse2_mae: 0.2475 - current_rise_time_pulse1_loss: 0.1248 - current_rise_time_pulse1_mae: 0.2620 - current_rise_time_pulse2_loss: 0.2205 - current_rise_time_pulse2_mae: 0.3602 - loss: 1.8611 - overshoot_pulse_1_loss: 0.3545 - overshoot_pulse_1_mae: 0.4608 - overshoot_pulse_2_loss: 0.1809 - overshoot_pulse_2_mae: 0.3277 - ringing_frequency_MHz_loss: 0.0061 - ringing_frequency_MHz_mae: 0.0574 - undershoot_pulse_1_loss: 0.1594 - undershoot_pulse_1_mae: 0.3088 - undershoot_pulse_2_loss: 0.1647 - undershoot_pulse_2_mae: 0.3120 - voltage_fall_time_pulse1_loss: 0.0551 - voltage_fall_time_pulse1_mae: 0.1729 - voltage_fall_time_pulse2_loss: 0.0494 - voltage_fall_time_pulse2_mae: 0.1652 - voltage_rise_time_pulse1_loss: 0.1128 - voltage_rise_time_pulse1_mae: 0.2424 - voltage_rise_time_pulse2_loss: 0.2106 - voltage_rise_time_pulse2_mae: 0.2994 - val_current_fall_time_pulse1_loss: 0.0615 - val_current_fall_time_pulse1_mae: 0.1790 - val_current_fall_time_pulse2_loss: 0.0656 - val_current_fall_time_pulse2_mae: 0.1858 - val_current_rise_time_pulse1_loss: 0.0980 - val_current_rise_time_pulse1_mae: 0.2384 - val_current_rise_time_pulse2_loss: 0.1671 - val_current_rise_time_pulse2_mae: 0.2982 - val_loss: 1.6076 - val_overshoot_pulse_1_loss: 0.2904 - val_overshoot_pulse_1_mae: 0.3924 - val_overshoot_pulse_2_loss: 0.1794 - val_overshoot_pulse_2_mae: 0.3084 - val_ringing_frequency_MHz_loss: 0.0027 - val_ringing_frequency_MHz_mae: 0.0395 - val_undershoot_pulse_1_loss: 0.1201 - val_undershoot_pulse_1_mae: 0.2606 - val_undershoot_pulse_2_loss: 0.1243 - val_undershoot_pulse_2_mae: 0.2691 - val_voltage_fall_time_pulse1_loss: 0.0364 - val_voltage_fall_time_pulse1_mae: 0.1212 - val_voltage_fall_time_pulse2_loss: 0.0272 - val_voltage_fall_time_pulse2_mae: 0.1093 - val_voltage_rise_time_pulse1_loss: 0.0897 - val_voltage_rise_time_pulse1_mae: 0.2035 - val_voltage_rise_time_pulse2_loss: 0.2940 - val_voltage_rise_time_pulse2_mae: 0.2882 - learning_rate: 5.0000e-04
# Epoch 9/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - current_fall_time_pulse1_loss: 0.0902 - current_fall_time_pulse1_mae: 0.2250 - current_fall_time_pulse2_loss: 0.0933 - current_fall_time_pulse2_mae: 0.2342 - current_rise_time_pulse1_loss: 0.1216 - current_rise_time_pulse1_mae: 0.2532 - current_rise_time_pulse2_loss: 0.2052 - current_rise_time_pulse2_mae: 0.3399 - loss: 1.6882 - overshoot_pulse_1_loss: 0.3082 - overshoot_pulse_1_mae: 0.4236 - overshoot_pulse_2_loss: 0.1691 - overshoot_pulse_2_mae: 0.3181 - ringing_frequency_MHz_loss: 0.0055 - ringing_frequency_MHz_mae: 0.0539 - undershoot_pulse_1_loss: 0.1446 - undershoot_pulse_1_mae: 0.2926 - undershoot_pulse_2_loss: 0.1406 - undershoot_pulse_2_mae: 0.2883 - voltage_fall_time_pulse1_loss: 0.0474 - voltage_fall_time_pulse1_mae: 0.1610 - voltage_fall_time_pulse2_loss: 0.0451 - voltage_fall_time_pulse2_mae: 0.1562 - voltage_rise_time_pulse1_loss: 0.0975 - voltage_rise_time_pulse1_mae: 0.2236 - voltage_rise_time_pulse2_loss: 0.2075 - voltage_rise_time_pulse2_mae: 0.2951 - val_current_fall_time_pulse1_loss: 0.0438 - val_current_fall_time_pulse1_mae: 0.1482 - val_current_fall_time_pulse2_loss: 0.0470 - val_current_fall_time_pulse2_mae: 0.1570 - val_current_rise_time_pulse1_loss: 0.0838 - val_current_rise_time_pulse1_mae: 0.2133 - val_current_rise_time_pulse2_loss: 0.1595 - val_current_rise_time_pulse2_mae: 0.2840 - val_loss: 1.3966 - val_overshoot_pulse_1_loss: 0.2353 - val_overshoot_pulse_1_mae: 0.3436 - val_overshoot_pulse_2_loss: 0.1546 - val_overshoot_pulse_2_mae: 0.2842 - val_ringing_frequency_MHz_loss: 0.0022 - val_ringing_frequency_MHz_mae: 0.0353 - val_undershoot_pulse_1_loss: 0.0923 - val_undershoot_pulse_1_mae: 0.2223 - val_undershoot_pulse_2_loss: 0.0956 - val_undershoot_pulse_2_mae: 0.2277 - val_voltage_fall_time_pulse1_loss: 0.0300 - val_voltage_fall_time_pulse1_mae: 0.1045 - val_voltage_fall_time_pulse2_loss: 0.0262 - val_voltage_fall_time_pulse2_mae: 0.0994 - val_voltage_rise_time_pulse1_loss: 0.0823 - val_voltage_rise_time_pulse1_mae: 0.1914 - val_voltage_rise_time_pulse2_loss: 0.2866 - val_voltage_rise_time_pulse2_mae: 0.2814 - learning_rate: 5.0000e-04
# Epoch 10/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - current_fall_time_pulse1_loss: 0.0789 - current_fall_time_pulse1_mae: 0.2109 - current_fall_time_pulse2_loss: 0.0778 - current_fall_time_pulse2_mae: 0.2140 - current_rise_time_pulse1_loss: 0.1106 - current_rise_time_pulse1_mae: 0.2411 - current_rise_time_pulse2_loss: 0.2004 - current_rise_time_pulse2_mae: 0.3299 - loss: 1.5203 - overshoot_pulse_1_loss: 0.2468 - overshoot_pulse_1_mae: 0.3735 - overshoot_pulse_2_loss: 0.1578 - overshoot_pulse_2_mae: 0.3076 - ringing_frequency_MHz_loss: 0.0051 - ringing_frequency_MHz_mae: 0.0517 - undershoot_pulse_1_loss: 0.1293 - undershoot_pulse_1_mae: 0.2747 - undershoot_pulse_2_loss: 0.1308 - undershoot_pulse_2_mae: 0.2744 - voltage_fall_time_pulse1_loss: 0.0408 - voltage_fall_time_pulse1_mae: 0.1486 - voltage_fall_time_pulse2_loss: 0.0382 - voltage_fall_time_pulse2_mae: 0.1450 - voltage_rise_time_pulse1_loss: 0.0950 - voltage_rise_time_pulse1_mae: 0.2216 - voltage_rise_time_pulse2_loss: 0.1962 - voltage_rise_time_pulse2_mae: 0.2852 - val_current_fall_time_pulse1_loss: 0.0362 - val_current_fall_time_pulse1_mae: 0.1341 - val_current_fall_time_pulse2_loss: 0.0363 - val_current_fall_time_pulse2_mae: 0.1398 - val_current_rise_time_pulse1_loss: 0.0864 - val_current_rise_time_pulse1_mae: 0.2202 - val_current_rise_time_pulse2_loss: 0.1474 - val_current_rise_time_pulse2_mae: 0.2699 - val_loss: 1.2526 - val_overshoot_pulse_1_loss: 0.1951 - val_overshoot_pulse_1_mae: 0.3077 - val_overshoot_pulse_2_loss: 0.1487 - val_overshoot_pulse_2_mae: 0.2769 - val_ringing_frequency_MHz_loss: 0.0022 - val_ringing_frequency_MHz_mae: 0.0348 - val_undershoot_pulse_1_loss: 0.0747 - val_undershoot_pulse_1_mae: 0.1975 - val_undershoot_pulse_2_loss: 0.0767 - val_undershoot_pulse_2_mae: 0.2010 - val_voltage_fall_time_pulse1_loss: 0.0202 - val_voltage_fall_time_pulse1_mae: 0.0913 - val_voltage_fall_time_pulse2_loss: 0.0167 - val_voltage_fall_time_pulse2_mae: 0.0852 - val_voltage_rise_time_pulse1_loss: 0.0727 - val_voltage_rise_time_pulse1_mae: 0.1834 - val_voltage_rise_time_pulse2_loss: 0.2706 - val_voltage_rise_time_pulse2_mae: 0.2720 - learning_rate: 5.0000e-04
# Epoch 11/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - current_fall_time_pulse1_loss: 0.0730 - current_fall_time_pulse1_mae: 0.2060 - current_fall_time_pulse2_loss: 0.0759 - current_fall_time_pulse2_mae: 0.2105 - current_rise_time_pulse1_loss: 0.1062 - current_rise_time_pulse1_mae: 0.2335 - current_rise_time_pulse2_loss: 0.2001 - current_rise_time_pulse2_mae: 0.3259 - loss: 1.4330 - overshoot_pulse_1_loss: 0.2286 - overshoot_pulse_1_mae: 0.3593 - overshoot_pulse_2_loss: 0.1502 - overshoot_pulse_2_mae: 0.2997 - ringing_frequency_MHz_loss: 0.0051 - ringing_frequency_MHz_mae: 0.0509 - undershoot_pulse_1_loss: 0.1162 - undershoot_pulse_1_mae: 0.2586 - undershoot_pulse_2_loss: 0.1143 - undershoot_pulse_2_mae: 0.2581 - voltage_fall_time_pulse1_loss: 0.0378 - voltage_fall_time_pulse1_mae: 0.1464 - voltage_fall_time_pulse2_loss: 0.0372 - voltage_fall_time_pulse2_mae: 0.1431 - voltage_rise_time_pulse1_loss: 0.0842 - voltage_rise_time_pulse1_mae: 0.2115 - voltage_rise_time_pulse2_loss: 0.1917 - voltage_rise_time_pulse2_mae: 0.2853 - val_current_fall_time_pulse1_loss: 0.0325 - val_current_fall_time_pulse1_mae: 0.1259 - val_current_fall_time_pulse2_loss: 0.0348 - val_current_fall_time_pulse2_mae: 0.1332 - val_current_rise_time_pulse1_loss: 0.0734 - val_current_rise_time_pulse1_mae: 0.1923 - val_current_rise_time_pulse2_loss: 0.1424 - val_current_rise_time_pulse2_mae: 0.2590 - val_loss: 1.1589 - val_overshoot_pulse_1_loss: 0.1725 - val_overshoot_pulse_1_mae: 0.2857 - val_overshoot_pulse_2_loss: 0.1367 - val_overshoot_pulse_2_mae: 0.2619 - val_ringing_frequency_MHz_loss: 0.0017 - val_ringing_frequency_MHz_mae: 0.0306 - val_undershoot_pulse_1_loss: 0.0645 - val_undershoot_pulse_1_mae: 0.1819 - val_undershoot_pulse_2_loss: 0.0668 - val_undershoot_pulse_2_mae: 0.1861 - val_voltage_fall_time_pulse1_loss: 0.0187 - val_voltage_fall_time_pulse1_mae: 0.0845 - val_voltage_fall_time_pulse2_loss: 0.0178 - val_voltage_fall_time_pulse2_mae: 0.0818 - val_voltage_rise_time_pulse1_loss: 0.0680 - val_voltage_rise_time_pulse1_mae: 0.1747 - val_voltage_rise_time_pulse2_loss: 0.2672 - val_voltage_rise_time_pulse2_mae: 0.2679 - learning_rate: 5.0000e-04
# Epoch 12/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - current_fall_time_pulse1_loss: 0.0668 - current_fall_time_pulse1_mae: 0.1982 - current_fall_time_pulse2_loss: 0.0687 - current_fall_time_pulse2_mae: 0.2011 - current_rise_time_pulse1_loss: 0.1085 - current_rise_time_pulse1_mae: 0.2361 - current_rise_time_pulse2_loss: 0.1846 - current_rise_time_pulse2_mae: 0.3126 - loss: 1.3644 - overshoot_pulse_1_loss: 0.2185 - overshoot_pulse_1_mae: 0.3513 - overshoot_pulse_2_loss: 0.1443 - overshoot_pulse_2_mae: 0.2957 - ringing_frequency_MHz_loss: 0.0043 - ringing_frequency_MHz_mae: 0.0474 - undershoot_pulse_1_loss: 0.1096 - undershoot_pulse_1_mae: 0.2496 - undershoot_pulse_2_loss: 0.1085 - undershoot_pulse_2_mae: 0.2493 - voltage_fall_time_pulse1_loss: 0.0376 - voltage_fall_time_pulse1_mae: 0.1431 - voltage_fall_time_pulse2_loss: 0.0359 - voltage_fall_time_pulse2_mae: 0.1414 - voltage_rise_time_pulse1_loss: 0.0857 - voltage_rise_time_pulse1_mae: 0.2126 - voltage_rise_time_pulse2_loss: 0.1791 - voltage_rise_time_pulse2_mae: 0.2734 - val_current_fall_time_pulse1_loss: 0.0314 - val_current_fall_time_pulse1_mae: 0.1279 - val_current_fall_time_pulse2_loss: 0.0315 - val_current_fall_time_pulse2_mae: 0.1295 - val_current_rise_time_pulse1_loss: 0.0711 - val_current_rise_time_pulse1_mae: 0.1856 - val_current_rise_time_pulse2_loss: 0.1394 - val_current_rise_time_pulse2_mae: 0.2584 - val_loss: 1.1194 - val_overshoot_pulse_1_loss: 0.1753 - val_overshoot_pulse_1_mae: 0.2900 - val_overshoot_pulse_2_loss: 0.1333 - val_overshoot_pulse_2_mae: 0.2565 - val_ringing_frequency_MHz_loss: 0.0016 - val_ringing_frequency_MHz_mae: 0.0300 - val_undershoot_pulse_1_loss: 0.0545 - val_undershoot_pulse_1_mae: 0.1666 - val_undershoot_pulse_2_loss: 0.0566 - val_undershoot_pulse_2_mae: 0.1702 - val_voltage_fall_time_pulse1_loss: 0.0210 - val_voltage_fall_time_pulse1_mae: 0.0876 - val_voltage_fall_time_pulse2_loss: 0.0176 - val_voltage_fall_time_pulse2_mae: 0.0822 - val_voltage_rise_time_pulse1_loss: 0.0649 - val_voltage_rise_time_pulse1_mae: 0.1694 - val_voltage_rise_time_pulse2_loss: 0.2623 - val_voltage_rise_time_pulse2_mae: 0.2618 - learning_rate: 5.0000e-04
# Epoch 13/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - current_fall_time_pulse1_loss: 0.0649 - current_fall_time_pulse1_mae: 0.1914 - current_fall_time_pulse2_loss: 0.0641 - current_fall_time_pulse2_mae: 0.1933 - current_rise_time_pulse1_loss: 0.1090 - current_rise_time_pulse1_mae: 0.2350 - current_rise_time_pulse2_loss: 0.1905 - current_rise_time_pulse2_mae: 0.3152 - loss: 1.3497 - overshoot_pulse_1_loss: 0.1990 - overshoot_pulse_1_mae: 0.3341 - overshoot_pulse_2_loss: 0.1484 - overshoot_pulse_2_mae: 0.2973 - ringing_frequency_MHz_loss: 0.0041 - ringing_frequency_MHz_mae: 0.0461 - undershoot_pulse_1_loss: 0.1037 - undershoot_pulse_1_mae: 0.2446 - undershoot_pulse_2_loss: 0.1037 - undershoot_pulse_2_mae: 0.2441 - voltage_fall_time_pulse1_loss: 0.0351 - voltage_fall_time_pulse1_mae: 0.1368 - voltage_fall_time_pulse2_loss: 0.0322 - voltage_fall_time_pulse2_mae: 0.1319 - voltage_rise_time_pulse1_loss: 0.0824 - voltage_rise_time_pulse1_mae: 0.2032 - voltage_rise_time_pulse2_loss: 0.2002 - voltage_rise_time_pulse2_mae: 0.2802 - val_current_fall_time_pulse1_loss: 0.0209 - val_current_fall_time_pulse1_mae: 0.1094 - val_current_fall_time_pulse2_loss: 0.0202 - val_current_fall_time_pulse2_mae: 0.1077 - val_current_rise_time_pulse1_loss: 0.0706 - val_current_rise_time_pulse1_mae: 0.1873 - val_current_rise_time_pulse2_loss: 0.1343 - val_current_rise_time_pulse2_mae: 0.2501 - val_loss: 1.0494 - val_overshoot_pulse_1_loss: 0.1571 - val_overshoot_pulse_1_mae: 0.2592 - val_overshoot_pulse_2_loss: 0.1230 - val_overshoot_pulse_2_mae: 0.2477 - val_ringing_frequency_MHz_loss: 0.0014 - val_ringing_frequency_MHz_mae: 0.0280 - val_undershoot_pulse_1_loss: 0.0586 - val_undershoot_pulse_1_mae: 0.1715 - val_undershoot_pulse_2_loss: 0.0635 - val_undershoot_pulse_2_mae: 0.1781 - val_voltage_fall_time_pulse1_loss: 0.0104 - val_voltage_fall_time_pulse1_mae: 0.0695 - val_voltage_fall_time_pulse2_loss: 0.0085 - val_voltage_fall_time_pulse2_mae: 0.0645 - val_voltage_rise_time_pulse1_loss: 0.0609 - val_voltage_rise_time_pulse1_mae: 0.1643 - val_voltage_rise_time_pulse2_loss: 0.2510 - val_voltage_rise_time_pulse2_mae: 0.2500 - learning_rate: 5.0000e-04
# Epoch 14/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - current_fall_time_pulse1_loss: 0.0623 - current_fall_time_pulse1_mae: 0.1887 - current_fall_time_pulse2_loss: 0.0630 - current_fall_time_pulse2_mae: 0.1911 - current_rise_time_pulse1_loss: 0.1034 - current_rise_time_pulse1_mae: 0.2259 - current_rise_time_pulse2_loss: 0.1788 - current_rise_time_pulse2_mae: 0.3018 - loss: 1.2738 - overshoot_pulse_1_loss: 0.1856 - overshoot_pulse_1_mae: 0.3225 - overshoot_pulse_2_loss: 0.1402 - overshoot_pulse_2_mae: 0.2908 - ringing_frequency_MHz_loss: 0.0039 - ringing_frequency_MHz_mae: 0.0440 - undershoot_pulse_1_loss: 0.1030 - undershoot_pulse_1_mae: 0.2370 - undershoot_pulse_2_loss: 0.1026 - undershoot_pulse_2_mae: 0.2379 - voltage_fall_time_pulse1_loss: 0.0303 - voltage_fall_time_pulse1_mae: 0.1286 - voltage_fall_time_pulse2_loss: 0.0313 - voltage_fall_time_pulse2_mae: 0.1287 - voltage_rise_time_pulse1_loss: 0.0805 - voltage_rise_time_pulse1_mae: 0.1989 - voltage_rise_time_pulse2_loss: 0.1764 - voltage_rise_time_pulse2_mae: 0.2713 - val_current_fall_time_pulse1_loss: 0.0178 - val_current_fall_time_pulse1_mae: 0.0994 - val_current_fall_time_pulse2_loss: 0.0175 - val_current_fall_time_pulse2_mae: 0.0993 - val_current_rise_time_pulse1_loss: 0.0712 - val_current_rise_time_pulse1_mae: 0.1906 - val_current_rise_time_pulse2_loss: 0.1283 - val_current_rise_time_pulse2_mae: 0.2416 - val_loss: 0.9890 - val_overshoot_pulse_1_loss: 0.1441 - val_overshoot_pulse_1_mae: 0.2634 - val_overshoot_pulse_2_loss: 0.1237 - val_overshoot_pulse_2_mae: 0.2492 - val_ringing_frequency_MHz_loss: 0.0013 - val_ringing_frequency_MHz_mae: 0.0270 - val_undershoot_pulse_1_loss: 0.0453 - val_undershoot_pulse_1_mae: 0.1521 - val_undershoot_pulse_2_loss: 0.0476 - val_undershoot_pulse_2_mae: 0.1542 - val_voltage_fall_time_pulse1_loss: 0.0097 - val_voltage_fall_time_pulse1_mae: 0.0683 - val_voltage_fall_time_pulse2_loss: 0.0077 - val_voltage_fall_time_pulse2_mae: 0.0606 - val_voltage_rise_time_pulse1_loss: 0.0566 - val_voltage_rise_time_pulse1_mae: 0.1597 - val_voltage_rise_time_pulse2_loss: 0.2445 - val_voltage_rise_time_pulse2_mae: 0.2465 - learning_rate: 5.0000e-04
# Epoch 15/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - current_fall_time_pulse1_loss: 0.0585 - current_fall_time_pulse1_mae: 0.1826 - current_fall_time_pulse2_loss: 0.0570 - current_fall_time_pulse2_mae: 0.1823 - current_rise_time_pulse1_loss: 0.0996 - current_rise_time_pulse1_mae: 0.2248 - current_rise_time_pulse2_loss: 0.1702 - current_rise_time_pulse2_mae: 0.2948 - loss: 1.2196 - overshoot_pulse_1_loss: 0.1797 - overshoot_pulse_1_mae: 0.3199 - overshoot_pulse_2_loss: 0.1381 - overshoot_pulse_2_mae: 0.2864 - ringing_frequency_MHz_loss: 0.0040 - ringing_frequency_MHz_mae: 0.0446 - undershoot_pulse_1_loss: 0.0929 - undershoot_pulse_1_mae: 0.2287 - undershoot_pulse_2_loss: 0.0976 - undershoot_pulse_2_mae: 0.2338 - voltage_fall_time_pulse1_loss: 0.0295 - voltage_fall_time_pulse1_mae: 0.1264 - voltage_fall_time_pulse2_loss: 0.0267 - voltage_fall_time_pulse2_mae: 0.1216 - voltage_rise_time_pulse1_loss: 0.0728 - voltage_rise_time_pulse1_mae: 0.1913 - voltage_rise_time_pulse2_loss: 0.1809 - voltage_rise_time_pulse2_mae: 0.2662 - val_current_fall_time_pulse1_loss: 0.0163 - val_current_fall_time_pulse1_mae: 0.0957 - val_current_fall_time_pulse2_loss: 0.0167 - val_current_fall_time_pulse2_mae: 0.0972 - val_current_rise_time_pulse1_loss: 0.0698 - val_current_rise_time_pulse1_mae: 0.1851 - val_current_rise_time_pulse2_loss: 0.1270 - val_current_rise_time_pulse2_mae: 0.2377 - val_loss: 0.9551 - val_overshoot_pulse_1_loss: 0.1397 - val_overshoot_pulse_1_mae: 0.2512 - val_overshoot_pulse_2_loss: 0.1199 - val_overshoot_pulse_2_mae: 0.2424 - val_ringing_frequency_MHz_loss: 0.0012 - val_ringing_frequency_MHz_mae: 0.0255 - val_undershoot_pulse_1_loss: 0.0421 - val_undershoot_pulse_1_mae: 0.1467 - val_undershoot_pulse_2_loss: 0.0431 - val_undershoot_pulse_2_mae: 0.1467 - val_voltage_fall_time_pulse1_loss: 0.0081 - val_voltage_fall_time_pulse1_mae: 0.0623 - val_voltage_fall_time_pulse2_loss: 0.0068 - val_voltage_fall_time_pulse2_mae: 0.0573 - val_voltage_rise_time_pulse1_loss: 0.0538 - val_voltage_rise_time_pulse1_mae: 0.1542 - val_voltage_rise_time_pulse2_loss: 0.2409 - val_voltage_rise_time_pulse2_mae: 0.2436 - learning_rate: 5.0000e-04
# Epoch 16/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - current_fall_time_pulse1_loss: 0.0542 - current_fall_time_pulse1_mae: 0.1779 - current_fall_time_pulse2_loss: 0.0528 - current_fall_time_pulse2_mae: 0.1752 - current_rise_time_pulse1_loss: 0.0959 - current_rise_time_pulse1_mae: 0.2183 - current_rise_time_pulse2_loss: 0.1703 - current_rise_time_pulse2_mae: 0.2917 - loss: 1.1687 - overshoot_pulse_1_loss: 0.1782 - overshoot_pulse_1_mae: 0.3167 - overshoot_pulse_2_loss: 0.1259 - overshoot_pulse_2_mae: 0.2756 - ringing_frequency_MHz_loss: 0.0036 - ringing_frequency_MHz_mae: 0.0424 - undershoot_pulse_1_loss: 0.0917 - undershoot_pulse_1_mae: 0.2297 - undershoot_pulse_2_loss: 0.0913 - undershoot_pulse_2_mae: 0.2275 - voltage_fall_time_pulse1_loss: 0.0273 - voltage_fall_time_pulse1_mae: 0.1240 - voltage_fall_time_pulse2_loss: 0.0257 - voltage_fall_time_pulse2_mae: 0.1185 - voltage_rise_time_pulse1_loss: 0.0719 - voltage_rise_time_pulse1_mae: 0.1908 - voltage_rise_time_pulse2_loss: 0.1676 - voltage_rise_time_pulse2_mae: 0.2585 - val_current_fall_time_pulse1_loss: 0.0163 - val_current_fall_time_pulse1_mae: 0.0968 - val_current_fall_time_pulse2_loss: 0.0158 - val_current_fall_time_pulse2_mae: 0.0958 - val_current_rise_time_pulse1_loss: 0.0664 - val_current_rise_time_pulse1_mae: 0.1707 - val_current_rise_time_pulse2_loss: 0.1251 - val_current_rise_time_pulse2_mae: 0.2358 - val_loss: 0.9609 - val_overshoot_pulse_1_loss: 0.1317 - val_overshoot_pulse_1_mae: 0.2425 - val_overshoot_pulse_2_loss: 0.1163 - val_overshoot_pulse_2_mae: 0.2376 - val_ringing_frequency_MHz_loss: 0.0010 - val_ringing_frequency_MHz_mae: 0.0236 - val_undershoot_pulse_1_loss: 0.0532 - val_undershoot_pulse_1_mae: 0.1655 - val_undershoot_pulse_2_loss: 0.0549 - val_undershoot_pulse_2_mae: 0.1686 - val_voltage_fall_time_pulse1_loss: 0.0085 - val_voltage_fall_time_pulse1_mae: 0.0618 - val_voltage_fall_time_pulse2_loss: 0.0075 - val_voltage_fall_time_pulse2_mae: 0.0592 - val_voltage_rise_time_pulse1_loss: 0.0535 - val_voltage_rise_time_pulse1_mae: 0.1507 - val_voltage_rise_time_pulse2_loss: 0.2389 - val_voltage_rise_time_pulse2_mae: 0.2404 - learning_rate: 5.0000e-04
# Epoch 17/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.0525 - current_fall_time_pulse1_mae: 0.1763 - current_fall_time_pulse2_loss: 0.0525 - current_fall_time_pulse2_mae: 0.1764 - current_rise_time_pulse1_loss: 0.0953 - current_rise_time_pulse1_mae: 0.2178 - current_rise_time_pulse2_loss: 0.1636 - current_rise_time_pulse2_mae: 0.2851 - loss: 1.1470 - overshoot_pulse_1_loss: 0.1694 - overshoot_pulse_1_mae: 0.3039 - overshoot_pulse_2_loss: 0.1287 - overshoot_pulse_2_mae: 0.2759 - ringing_frequency_MHz_loss: 0.0033 - ringing_frequency_MHz_mae: 0.0410 - undershoot_pulse_1_loss: 0.0894 - undershoot_pulse_1_mae: 0.2249 - undershoot_pulse_2_loss: 0.0901 - undershoot_pulse_2_mae: 0.2258 - voltage_fall_time_pulse1_loss: 0.0267 - voltage_fall_time_pulse1_mae: 0.1199 - voltage_fall_time_pulse2_loss: 0.0243 - voltage_fall_time_pulse2_mae: 0.1150 - voltage_rise_time_pulse1_loss: 0.0680 - voltage_rise_time_pulse1_mae: 0.1846 - voltage_rise_time_pulse2_loss: 0.1710 - voltage_rise_time_pulse2_mae: 0.2596 - val_current_fall_time_pulse1_loss: 0.0149 - val_current_fall_time_pulse1_mae: 0.0927 - val_current_fall_time_pulse2_loss: 0.0146 - val_current_fall_time_pulse2_mae: 0.0912 - val_current_rise_time_pulse1_loss: 0.0671 - val_current_rise_time_pulse1_mae: 0.1777 - val_current_rise_time_pulse2_loss: 0.1241 - val_current_rise_time_pulse2_mae: 0.2325 - val_loss: 0.9251 - val_overshoot_pulse_1_loss: 0.1320 - val_overshoot_pulse_1_mae: 0.2412 - val_overshoot_pulse_2_loss: 0.1162 - val_overshoot_pulse_2_mae: 0.2355 - val_ringing_frequency_MHz_loss: 9.6818e-04 - val_ringing_frequency_MHz_mae: 0.0230 - val_undershoot_pulse_1_loss: 0.0420 - val_undershoot_pulse_1_mae: 0.1457 - val_undershoot_pulse_2_loss: 0.0444 - val_undershoot_pulse_2_mae: 0.1489 - val_voltage_fall_time_pulse1_loss: 0.0067 - val_voltage_fall_time_pulse1_mae: 0.0561 - val_voltage_fall_time_pulse2_loss: 0.0062 - val_voltage_fall_time_pulse2_mae: 0.0539 - val_voltage_rise_time_pulse1_loss: 0.0514 - val_voltage_rise_time_pulse1_mae: 0.1463 - val_voltage_rise_time_pulse2_loss: 0.2322 - val_voltage_rise_time_pulse2_mae: 0.2385 - learning_rate: 5.0000e-04
# Epoch 18/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - current_fall_time_pulse1_loss: 0.0509 - current_fall_time_pulse1_mae: 0.1696 - current_fall_time_pulse2_loss: 0.0505 - current_fall_time_pulse2_mae: 0.1704 - current_rise_time_pulse1_loss: 0.0906 - current_rise_time_pulse1_mae: 0.2125 - current_rise_time_pulse2_loss: 0.1617 - current_rise_time_pulse2_mae: 0.2822 - loss: 1.1158 - overshoot_pulse_1_loss: 0.1667 - overshoot_pulse_1_mae: 0.3013 - overshoot_pulse_2_loss: 0.1265 - overshoot_pulse_2_mae: 0.2750 - ringing_frequency_MHz_loss: 0.0033 - ringing_frequency_MHz_mae: 0.0410 - undershoot_pulse_1_loss: 0.0859 - undershoot_pulse_1_mae: 0.2195 - undershoot_pulse_2_loss: 0.0871 - undershoot_pulse_2_mae: 0.2218 - voltage_fall_time_pulse1_loss: 0.0252 - voltage_fall_time_pulse1_mae: 0.1192 - voltage_fall_time_pulse2_loss: 0.0237 - voltage_fall_time_pulse2_mae: 0.1147 - voltage_rise_time_pulse1_loss: 0.0669 - voltage_rise_time_pulse1_mae: 0.1802 - voltage_rise_time_pulse2_loss: 0.1643 - voltage_rise_time_pulse2_mae: 0.2571 - val_current_fall_time_pulse1_loss: 0.0138 - val_current_fall_time_pulse1_mae: 0.0895 - val_current_fall_time_pulse2_loss: 0.0134 - val_current_fall_time_pulse2_mae: 0.0877 - val_current_rise_time_pulse1_loss: 0.0658 - val_current_rise_time_pulse1_mae: 0.1715 - val_current_rise_time_pulse2_loss: 0.1205 - val_current_rise_time_pulse2_mae: 0.2281 - val_loss: 0.8948 - val_overshoot_pulse_1_loss: 0.1233 - val_overshoot_pulse_1_mae: 0.2389 - val_overshoot_pulse_2_loss: 0.1090 - val_overshoot_pulse_2_mae: 0.2284 - val_ringing_frequency_MHz_loss: 9.1874e-04 - val_ringing_frequency_MHz_mae: 0.0225 - val_undershoot_pulse_1_loss: 0.0394 - val_undershoot_pulse_1_mae: 0.1413 - val_undershoot_pulse_2_loss: 0.0420 - val_undershoot_pulse_2_mae: 0.1444 - val_voltage_fall_time_pulse1_loss: 0.0074 - val_voltage_fall_time_pulse1_mae: 0.0594 - val_voltage_fall_time_pulse2_loss: 0.0066 - val_voltage_fall_time_pulse2_mae: 0.0557 - val_voltage_rise_time_pulse1_loss: 0.0497 - val_voltage_rise_time_pulse1_mae: 0.1448 - val_voltage_rise_time_pulse2_loss: 0.2297 - val_voltage_rise_time_pulse2_mae: 0.2382 - learning_rate: 5.0000e-04
# Epoch 19/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - current_fall_time_pulse1_loss: 0.0488 - current_fall_time_pulse1_mae: 0.1691 - current_fall_time_pulse2_loss: 0.0487 - current_fall_time_pulse2_mae: 0.1686 - current_rise_time_pulse1_loss: 0.0945 - current_rise_time_pulse1_mae: 0.2140 - current_rise_time_pulse2_loss: 0.1593 - current_rise_time_pulse2_mae: 0.2785 - loss: 1.0736 - overshoot_pulse_1_loss: 0.1532 - overshoot_pulse_1_mae: 0.2957 - overshoot_pulse_2_loss: 0.1194 - overshoot_pulse_2_mae: 0.2694 - ringing_frequency_MHz_loss: 0.0032 - ringing_frequency_MHz_mae: 0.0393 - undershoot_pulse_1_loss: 0.0786 - undershoot_pulse_1_mae: 0.2103 - undershoot_pulse_2_loss: 0.0812 - undershoot_pulse_2_mae: 0.2126 - voltage_fall_time_pulse1_loss: 0.0240 - voltage_fall_time_pulse1_mae: 0.1147 - voltage_fall_time_pulse2_loss: 0.0221 - voltage_fall_time_pulse2_mae: 0.1100 - voltage_rise_time_pulse1_loss: 0.0637 - voltage_rise_time_pulse1_mae: 0.1766 - voltage_rise_time_pulse2_loss: 0.1647 - voltage_rise_time_pulse2_mae: 0.2577 - val_current_fall_time_pulse1_loss: 0.0139 - val_current_fall_time_pulse1_mae: 0.0882 - val_current_fall_time_pulse2_loss: 0.0151 - val_current_fall_time_pulse2_mae: 0.0923 - val_current_rise_time_pulse1_loss: 0.0653 - val_current_rise_time_pulse1_mae: 0.1664 - val_current_rise_time_pulse2_loss: 0.1201 - val_current_rise_time_pulse2_mae: 0.2250 - val_loss: 0.8933 - val_overshoot_pulse_1_loss: 0.1244 - val_overshoot_pulse_1_mae: 0.2322 - val_overshoot_pulse_2_loss: 0.1086 - val_overshoot_pulse_2_mae: 0.2275 - val_ringing_frequency_MHz_loss: 8.6676e-04 - val_ringing_frequency_MHz_mae: 0.0222 - val_undershoot_pulse_1_loss: 0.0367 - val_undershoot_pulse_1_mae: 0.1386 - val_undershoot_pulse_2_loss: 0.0377 - val_undershoot_pulse_2_mae: 0.1384 - val_voltage_fall_time_pulse1_loss: 0.0078 - val_voltage_fall_time_pulse1_mae: 0.0597 - val_voltage_fall_time_pulse2_loss: 0.0074 - val_voltage_fall_time_pulse2_mae: 0.0579 - val_voltage_rise_time_pulse1_loss: 0.0493 - val_voltage_rise_time_pulse1_mae: 0.1428 - val_voltage_rise_time_pulse2_loss: 0.2327 - val_voltage_rise_time_pulse2_mae: 0.2358 - learning_rate: 5.0000e-04
# Epoch 20/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - current_fall_time_pulse1_loss: 0.0497 - current_fall_time_pulse1_mae: 0.1684 - current_fall_time_pulse2_loss: 0.0468 - current_fall_time_pulse2_mae: 0.1656 - current_rise_time_pulse1_loss: 0.0915 - current_rise_time_pulse1_mae: 0.2093 - current_rise_time_pulse2_loss: 0.1547 - current_rise_time_pulse2_mae: 0.2722 - loss: 1.0736 - overshoot_pulse_1_loss: 0.1540 - overshoot_pulse_1_mae: 0.2933 - overshoot_pulse_2_loss: 0.1178 - overshoot_pulse_2_mae: 0.2692 - ringing_frequency_MHz_loss: 0.0030 - ringing_frequency_MHz_mae: 0.0389 - undershoot_pulse_1_loss: 0.0821 - undershoot_pulse_1_mae: 0.2159 - undershoot_pulse_2_loss: 0.0844 - undershoot_pulse_2_mae: 0.2172 - voltage_fall_time_pulse1_loss: 0.0231 - voltage_fall_time_pulse1_mae: 0.1126 - voltage_fall_time_pulse2_loss: 0.0215 - voltage_fall_time_pulse2_mae: 0.1096 - voltage_rise_time_pulse1_loss: 0.0620 - voltage_rise_time_pulse1_mae: 0.1745 - voltage_rise_time_pulse2_loss: 0.1709 - voltage_rise_time_pulse2_mae: 0.2568 - val_current_fall_time_pulse1_loss: 0.0121 - val_current_fall_time_pulse1_mae: 0.0822 - val_current_fall_time_pulse2_loss: 0.0122 - val_current_fall_time_pulse2_mae: 0.0833 - val_current_rise_time_pulse1_loss: 0.0664 - val_current_rise_time_pulse1_mae: 0.1749 - val_current_rise_time_pulse2_loss: 0.1182 - val_current_rise_time_pulse2_mae: 0.2217 - val_loss: 0.8688 - val_overshoot_pulse_1_loss: 0.1179 - val_overshoot_pulse_1_mae: 0.2326 - val_overshoot_pulse_2_loss: 0.1084 - val_overshoot_pulse_2_mae: 0.2282 - val_ringing_frequency_MHz_loss: 9.1674e-04 - val_ringing_frequency_MHz_mae: 0.0227 - val_undershoot_pulse_1_loss: 0.0346 - val_undershoot_pulse_1_mae: 0.1325 - val_undershoot_pulse_2_loss: 0.0355 - val_undershoot_pulse_2_mae: 0.1340 - val_voltage_fall_time_pulse1_loss: 0.0061 - val_voltage_fall_time_pulse1_mae: 0.0553 - val_voltage_fall_time_pulse2_loss: 0.0062 - val_voltage_fall_time_pulse2_mae: 0.0547 - val_voltage_rise_time_pulse1_loss: 0.0480 - val_voltage_rise_time_pulse1_mae: 0.1424 - val_voltage_rise_time_pulse2_loss: 0.2255 - val_voltage_rise_time_pulse2_mae: 0.2321 - learning_rate: 5.0000e-04
# Epoch 21/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - current_fall_time_pulse1_loss: 0.0450 - current_fall_time_pulse1_mae: 0.1618 - current_fall_time_pulse2_loss: 0.0463 - current_fall_time_pulse2_mae: 0.1652 - current_rise_time_pulse1_loss: 0.0892 - current_rise_time_pulse1_mae: 0.2074 - current_rise_time_pulse2_loss: 0.1586 - current_rise_time_pulse2_mae: 0.2760 - loss: 1.0687 - overshoot_pulse_1_loss: 0.1527 - overshoot_pulse_1_mae: 0.2930 - overshoot_pulse_2_loss: 0.1198 - overshoot_pulse_2_mae: 0.2693 - ringing_frequency_MHz_loss: 0.0029 - ringing_frequency_MHz_mae: 0.0379 - undershoot_pulse_1_loss: 0.0770 - undershoot_pulse_1_mae: 0.2107 - undershoot_pulse_2_loss: 0.0804 - undershoot_pulse_2_mae: 0.2148 - voltage_fall_time_pulse1_loss: 0.0226 - voltage_fall_time_pulse1_mae: 0.1113 - voltage_fall_time_pulse2_loss: 0.0212 - voltage_fall_time_pulse2_mae: 0.1075 - voltage_rise_time_pulse1_loss: 0.0647 - voltage_rise_time_pulse1_mae: 0.1766 - voltage_rise_time_pulse2_loss: 0.1762 - voltage_rise_time_pulse2_mae: 0.2561 - val_current_fall_time_pulse1_loss: 0.0129 - val_current_fall_time_pulse1_mae: 0.0855 - val_current_fall_time_pulse2_loss: 0.0126 - val_current_fall_time_pulse2_mae: 0.0851 - val_current_rise_time_pulse1_loss: 0.0655 - val_current_rise_time_pulse1_mae: 0.1673 - val_current_rise_time_pulse2_loss: 0.1186 - val_current_rise_time_pulse2_mae: 0.2226 - val_loss: 0.8862 - val_overshoot_pulse_1_loss: 0.1167 - val_overshoot_pulse_1_mae: 0.2283 - val_overshoot_pulse_2_loss: 0.1097 - val_overshoot_pulse_2_mae: 0.2296 - val_ringing_frequency_MHz_loss: 7.7601e-04 - val_ringing_frequency_MHz_mae: 0.0212 - val_undershoot_pulse_1_loss: 0.0401 - val_undershoot_pulse_1_mae: 0.1431 - val_undershoot_pulse_2_loss: 0.0423 - val_undershoot_pulse_2_mae: 0.1461 - val_voltage_fall_time_pulse1_loss: 0.0065 - val_voltage_fall_time_pulse1_mae: 0.0563 - val_voltage_fall_time_pulse2_loss: 0.0069 - val_voltage_fall_time_pulse2_mae: 0.0581 - val_voltage_rise_time_pulse1_loss: 0.0480 - val_voltage_rise_time_pulse1_mae: 0.1389 - val_voltage_rise_time_pulse2_loss: 0.2282 - val_voltage_rise_time_pulse2_mae: 0.2284 - learning_rate: 5.0000e-04
# Epoch 22/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - current_fall_time_pulse1_loss: 0.0426 - current_fall_time_pulse1_mae: 0.1563 - current_fall_time_pulse2_loss: 0.0446 - current_fall_time_pulse2_mae: 0.1598 - current_rise_time_pulse1_loss: 0.0882 - current_rise_time_pulse1_mae: 0.2082 - current_rise_time_pulse2_loss: 0.1552 - current_rise_time_pulse2_mae: 0.2700 - loss: 1.0286 - overshoot_pulse_1_loss: 0.1423 - overshoot_pulse_1_mae: 0.2836 - overshoot_pulse_2_loss: 0.1164 - overshoot_pulse_2_mae: 0.2661 - ringing_frequency_MHz_loss: 0.0028 - ringing_frequency_MHz_mae: 0.0376 - undershoot_pulse_1_loss: 0.0805 - undershoot_pulse_1_mae: 0.2101 - undershoot_pulse_2_loss: 0.0815 - undershoot_pulse_2_mae: 0.2117 - voltage_fall_time_pulse1_loss: 0.0204 - voltage_fall_time_pulse1_mae: 0.1059 - voltage_fall_time_pulse2_loss: 0.0188 - voltage_fall_time_pulse2_mae: 0.1025 - voltage_rise_time_pulse1_loss: 0.0605 - voltage_rise_time_pulse1_mae: 0.1698 - voltage_rise_time_pulse2_loss: 0.1627 - voltage_rise_time_pulse2_mae: 0.2495 - val_current_fall_time_pulse1_loss: 0.0117 - val_current_fall_time_pulse1_mae: 0.0803 - val_current_fall_time_pulse2_loss: 0.0121 - val_current_fall_time_pulse2_mae: 0.0829 - val_current_rise_time_pulse1_loss: 0.0668 - val_current_rise_time_pulse1_mae: 0.1750 - val_current_rise_time_pulse2_loss: 0.1162 - val_current_rise_time_pulse2_mae: 0.2176 - val_loss: 0.8639 - val_overshoot_pulse_1_loss: 0.1170 - val_overshoot_pulse_1_mae: 0.2264 - val_overshoot_pulse_2_loss: 0.1084 - val_overshoot_pulse_2_mae: 0.2298 - val_ringing_frequency_MHz_loss: 7.2929e-04 - val_ringing_frequency_MHz_mae: 0.0209 - val_undershoot_pulse_1_loss: 0.0364 - val_undershoot_pulse_1_mae: 0.1358 - val_undershoot_pulse_2_loss: 0.0371 - val_undershoot_pulse_2_mae: 0.1374 - val_voltage_fall_time_pulse1_loss: 0.0059 - val_voltage_fall_time_pulse1_mae: 0.0525 - val_voltage_fall_time_pulse2_loss: 0.0060 - val_voltage_fall_time_pulse2_mae: 0.0533 - val_voltage_rise_time_pulse1_loss: 0.0464 - val_voltage_rise_time_pulse1_mae: 0.1360 - val_voltage_rise_time_pulse2_loss: 0.2257 - val_voltage_rise_time_pulse2_mae: 0.2288 - learning_rate: 5.0000e-04
# Epoch 23/120
# ...
# Epoch 71/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - current_fall_time_pulse1_loss: 0.0220 - current_fall_time_pulse1_mae: 0.1118 - current_fall_time_pulse2_loss: 0.0217 - current_fall_time_pulse2_mae: 0.1113 - current_rise_time_pulse1_loss: 0.0728 - current_rise_time_pulse1_mae: 0.1757 - current_rise_time_pulse2_loss: 0.1172 - current_rise_time_pulse2_mae: 0.2137 - loss: 0.6605 - overshoot_pulse_1_loss: 0.0820 - overshoot_pulse_1_mae: 0.2187 - overshoot_pulse_2_loss: 0.0859 - overshoot_pulse_2_mae: 0.2295 - ringing_frequency_MHz_loss: 0.0012 - ringing_frequency_MHz_mae: 0.0243 - undershoot_pulse_1_loss: 0.0455 - undershoot_pulse_1_mae: 0.1537 - undershoot_pulse_2_loss: 0.0458 - undershoot_pulse_2_mae: 0.1550 - voltage_fall_time_pulse1_loss: 0.0093 - voltage_fall_time_pulse1_mae: 0.0696 - voltage_fall_time_pulse2_loss: 0.0093 - voltage_fall_time_pulse2_mae: 0.0707 - voltage_rise_time_pulse1_loss: 0.0344 - voltage_rise_time_pulse1_mae: 0.1215 - voltage_rise_time_pulse2_loss: 0.1018 - voltage_rise_time_pulse2_mae: 0.2086 - val_current_fall_time_pulse1_loss: 0.0057 - val_current_fall_time_pulse1_mae: 0.0528 - val_current_fall_time_pulse2_loss: 0.0058 - val_current_fall_time_pulse2_mae: 0.0538 - val_current_rise_time_pulse1_loss: 0.0651 - val_current_rise_time_pulse1_mae: 0.1554 - val_current_rise_time_pulse2_loss: 0.1010 - val_current_rise_time_pulse2_mae: 0.1806 - val_loss: 0.6677 - val_overshoot_pulse_1_loss: 0.0772 - val_overshoot_pulse_1_mae: 0.1743 - val_overshoot_pulse_2_loss: 0.0941 - val_overshoot_pulse_2_mae: 0.2155 - val_ringing_frequency_MHz_loss: 4.2525e-04 - val_ringing_frequency_MHz_mae: 0.0160 - val_undershoot_pulse_1_loss: 0.0257 - val_undershoot_pulse_1_mae: 0.1079 - val_undershoot_pulse_2_loss: 0.0246 - val_undershoot_pulse_2_mae: 0.1076 - val_voltage_fall_time_pulse1_loss: 0.0026 - val_voltage_fall_time_pulse1_mae: 0.0371 - val_voltage_fall_time_pulse2_loss: 0.0024 - val_voltage_fall_time_pulse2_mae: 0.0338 - val_voltage_rise_time_pulse1_loss: 0.0302 - val_voltage_rise_time_pulse1_mae: 0.1014 - val_voltage_rise_time_pulse2_loss: 0.1782 - val_voltage_rise_time_pulse2_mae: 0.2013 - learning_rate: 4.5000e-05
# Epoch 72/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - current_fall_time_pulse1_loss: 0.0210 - current_fall_time_pulse1_mae: 0.1097 - current_fall_time_pulse2_loss: 0.0205 - current_fall_time_pulse2_mae: 0.1079 - current_rise_time_pulse1_loss: 0.0792 - current_rise_time_pulse1_mae: 0.1798 - current_rise_time_pulse2_loss: 0.1202 - current_rise_time_pulse2_mae: 0.2157 - loss: 0.6748 - overshoot_pulse_1_loss: 0.0877 - overshoot_pulse_1_mae: 0.2218 - overshoot_pulse_2_loss: 0.0871 - overshoot_pulse_2_mae: 0.2317 - ringing_frequency_MHz_loss: 0.0013 - ringing_frequency_MHz_mae: 0.0245 - undershoot_pulse_1_loss: 0.0462 - undershoot_pulse_1_mae: 0.1574 - undershoot_pulse_2_loss: 0.0455 - undershoot_pulse_2_mae: 0.1562 - voltage_fall_time_pulse1_loss: 0.0091 - voltage_fall_time_pulse1_mae: 0.0694 - voltage_fall_time_pulse2_loss: 0.0091 - voltage_fall_time_pulse2_mae: 0.0709 - voltage_rise_time_pulse1_loss: 0.0350 - voltage_rise_time_pulse1_mae: 0.1238 - voltage_rise_time_pulse2_loss: 0.1013 - voltage_rise_time_pulse2_mae: 0.2065 - val_current_fall_time_pulse1_loss: 0.0056 - val_current_fall_time_pulse1_mae: 0.0526 - val_current_fall_time_pulse2_loss: 0.0058 - val_current_fall_time_pulse2_mae: 0.0541 - val_current_rise_time_pulse1_loss: 0.0651 - val_current_rise_time_pulse1_mae: 0.1543 - val_current_rise_time_pulse2_loss: 0.1010 - val_current_rise_time_pulse2_mae: 0.1812 - val_loss: 0.6659 - val_overshoot_pulse_1_loss: 0.0764 - val_overshoot_pulse_1_mae: 0.1742 - val_overshoot_pulse_2_loss: 0.0943 - val_overshoot_pulse_2_mae: 0.2157 - val_ringing_frequency_MHz_loss: 4.2751e-04 - val_ringing_frequency_MHz_mae: 0.0161 - val_undershoot_pulse_1_loss: 0.0255 - val_undershoot_pulse_1_mae: 0.1077 - val_undershoot_pulse_2_loss: 0.0243 - val_undershoot_pulse_2_mae: 0.1072 - val_voltage_fall_time_pulse1_loss: 0.0027 - val_voltage_fall_time_pulse1_mae: 0.0383 - val_voltage_fall_time_pulse2_loss: 0.0025 - val_voltage_fall_time_pulse2_mae: 0.0348 - val_voltage_rise_time_pulse1_loss: 0.0301 - val_voltage_rise_time_pulse1_mae: 0.1011 - val_voltage_rise_time_pulse2_loss: 0.1781 - val_voltage_rise_time_pulse2_mae: 0.2016 - learning_rate: 4.5000e-05
# Epoch 73/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - current_fall_time_pulse1_loss: 0.0218 - current_fall_time_pulse1_mae: 0.1121 - current_fall_time_pulse2_loss: 0.0216 - current_fall_time_pulse2_mae: 0.1120 - current_rise_time_pulse1_loss: 0.0756 - current_rise_time_pulse1_mae: 0.1766 - current_rise_time_pulse2_loss: 0.1192 - current_rise_time_pulse2_mae: 0.2202 - loss: 0.6835 - overshoot_pulse_1_loss: 0.0908 - overshoot_pulse_1_mae: 0.2282 - overshoot_pulse_2_loss: 0.0924 - overshoot_pulse_2_mae: 0.2376 - ringing_frequency_MHz_loss: 0.0012 - ringing_frequency_MHz_mae: 0.0247 - undershoot_pulse_1_loss: 0.0427 - undershoot_pulse_1_mae: 0.1543 - undershoot_pulse_2_loss: 0.0441 - undershoot_pulse_2_mae: 0.1549 - voltage_fall_time_pulse1_loss: 0.0092 - voltage_fall_time_pulse1_mae: 0.0695 - voltage_fall_time_pulse2_loss: 0.0090 - voltage_fall_time_pulse2_mae: 0.0689 - voltage_rise_time_pulse1_loss: 0.0350 - voltage_rise_time_pulse1_mae: 0.1227 - voltage_rise_time_pulse2_loss: 0.1091 - voltage_rise_time_pulse2_mae: 0.2118 - val_current_fall_time_pulse1_loss: 0.0054 - val_current_fall_time_pulse1_mae: 0.0518 - val_current_fall_time_pulse2_loss: 0.0056 - val_current_fall_time_pulse2_mae: 0.0532 - val_current_rise_time_pulse1_loss: 0.0651 - val_current_rise_time_pulse1_mae: 0.1543 - val_current_rise_time_pulse2_loss: 0.1007 - val_current_rise_time_pulse2_mae: 0.1802 - val_loss: 0.6663 - val_overshoot_pulse_1_loss: 0.0765 - val_overshoot_pulse_1_mae: 0.1735 - val_overshoot_pulse_2_loss: 0.0943 - val_overshoot_pulse_2_mae: 0.2154 - val_ringing_frequency_MHz_loss: 4.2843e-04 - val_ringing_frequency_MHz_mae: 0.0160 - val_undershoot_pulse_1_loss: 0.0251 - val_undershoot_pulse_1_mae: 0.1069 - val_undershoot_pulse_2_loss: 0.0239 - val_undershoot_pulse_2_mae: 0.1063 - val_voltage_fall_time_pulse1_loss: 0.0026 - val_voltage_fall_time_pulse1_mae: 0.0374 - val_voltage_fall_time_pulse2_loss: 0.0024 - val_voltage_fall_time_pulse2_mae: 0.0345 - val_voltage_rise_time_pulse1_loss: 0.0300 - val_voltage_rise_time_pulse1_mae: 0.1005 - val_voltage_rise_time_pulse2_loss: 0.1793 - val_voltage_rise_time_pulse2_mae: 0.2010 - learning_rate: 4.5000e-05
# Epoch 74/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - current_fall_time_pulse1_loss: 0.0218 - current_fall_time_pulse1_mae: 0.1117 - current_fall_time_pulse2_loss: 0.0207 - current_fall_time_pulse2_mae: 0.1095 - current_rise_time_pulse1_loss: 0.0723 - current_rise_time_pulse1_mae: 0.1736 - current_rise_time_pulse2_loss: 0.1205 - current_rise_time_pulse2_mae: 0.2179 - loss: 0.6784 - overshoot_pulse_1_loss: 0.0827 - overshoot_pulse_1_mae: 0.2177 - overshoot_pulse_2_loss: 0.0894 - overshoot_pulse_2_mae: 0.2308 - ringing_frequency_MHz_loss: 0.0013 - ringing_frequency_MHz_mae: 0.0248 - undershoot_pulse_1_loss: 0.0441 - undershoot_pulse_1_mae: 0.1545 - undershoot_pulse_2_loss: 0.0426 - undershoot_pulse_2_mae: 0.1525 - voltage_fall_time_pulse1_loss: 0.0090 - voltage_fall_time_pulse1_mae: 0.0693 - voltage_fall_time_pulse2_loss: 0.0092 - voltage_fall_time_pulse2_mae: 0.0701 - voltage_rise_time_pulse1_loss: 0.0345 - voltage_rise_time_pulse1_mae: 0.1210 - voltage_rise_time_pulse2_loss: 0.1187 - voltage_rise_time_pulse2_mae: 0.2148 - val_current_fall_time_pulse1_loss: 0.0054 - val_current_fall_time_pulse1_mae: 0.0522 - val_current_fall_time_pulse2_loss: 0.0055 - val_current_fall_time_pulse2_mae: 0.0532 - val_current_rise_time_pulse1_loss: 0.0650 - val_current_rise_time_pulse1_mae: 0.1546 - val_current_rise_time_pulse2_loss: 0.1006 - val_current_rise_time_pulse2_mae: 0.1801 - val_loss: 0.6652 - val_overshoot_pulse_1_loss: 0.0761 - val_overshoot_pulse_1_mae: 0.1735 - val_overshoot_pulse_2_loss: 0.0941 - val_overshoot_pulse_2_mae: 0.2155 - val_ringing_frequency_MHz_loss: 4.2601e-04 - val_ringing_frequency_MHz_mae: 0.0160 - val_undershoot_pulse_1_loss: 0.0258 - val_undershoot_pulse_1_mae: 0.1085 - val_undershoot_pulse_2_loss: 0.0244 - val_undershoot_pulse_2_mae: 0.1073 - val_voltage_fall_time_pulse1_loss: 0.0027 - val_voltage_fall_time_pulse1_mae: 0.0378 - val_voltage_fall_time_pulse2_loss: 0.0024 - val_voltage_fall_time_pulse2_mae: 0.0348 - val_voltage_rise_time_pulse1_loss: 0.0300 - val_voltage_rise_time_pulse1_mae: 0.1007 - val_voltage_rise_time_pulse2_loss: 0.1781 - val_voltage_rise_time_pulse2_mae: 0.2010 - learning_rate: 4.5000e-05
# Epoch 75/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - current_fall_time_pulse1_loss: 0.0209 - current_fall_time_pulse1_mae: 0.1085 - current_fall_time_pulse2_loss: 0.0213 - current_fall_time_pulse2_mae: 0.1105 - current_rise_time_pulse1_loss: 0.0690 - current_rise_time_pulse1_mae: 0.1718 - current_rise_time_pulse2_loss: 0.1173 - current_rise_time_pulse2_mae: 0.2166 - loss: 0.6526 - overshoot_pulse_1_loss: 0.0855 - overshoot_pulse_1_mae: 0.2209 - overshoot_pulse_2_loss: 0.0889 - overshoot_pulse_2_mae: 0.2330 - ringing_frequency_MHz_loss: 0.0012 - ringing_frequency_MHz_mae: 0.0244 - undershoot_pulse_1_loss: 0.0413 - undershoot_pulse_1_mae: 0.1521 - undershoot_pulse_2_loss: 0.0423 - undershoot_pulse_2_mae: 0.1544 - voltage_fall_time_pulse1_loss: 0.0089 - voltage_fall_time_pulse1_mae: 0.0680 - voltage_fall_time_pulse2_loss: 0.0088 - voltage_fall_time_pulse2_mae: 0.0697 - voltage_rise_time_pulse1_loss: 0.0334 - voltage_rise_time_pulse1_mae: 0.1192 - voltage_rise_time_pulse2_loss: 0.1022 - voltage_rise_time_pulse2_mae: 0.2090 - val_current_fall_time_pulse1_loss: 0.0057 - val_current_fall_time_pulse1_mae: 0.0528 - val_current_fall_time_pulse2_loss: 0.0058 - val_current_fall_time_pulse2_mae: 0.0541 - val_current_rise_time_pulse1_loss: 0.0649 - val_current_rise_time_pulse1_mae: 0.1548 - val_current_rise_time_pulse2_loss: 0.1006 - val_current_rise_time_pulse2_mae: 0.1801 - val_loss: 0.6665 - val_overshoot_pulse_1_loss: 0.0762 - val_overshoot_pulse_1_mae: 0.1732 - val_overshoot_pulse_2_loss: 0.0941 - val_overshoot_pulse_2_mae: 0.2155 - val_ringing_frequency_MHz_loss: 4.2473e-04 - val_ringing_frequency_MHz_mae: 0.0160 - val_undershoot_pulse_1_loss: 0.0259 - val_undershoot_pulse_1_mae: 0.1088 - val_undershoot_pulse_2_loss: 0.0247 - val_undershoot_pulse_2_mae: 0.1081 - val_voltage_fall_time_pulse1_loss: 0.0026 - val_voltage_fall_time_pulse1_mae: 0.0372 - val_voltage_fall_time_pulse2_loss: 0.0025 - val_voltage_fall_time_pulse2_mae: 0.0350 - val_voltage_rise_time_pulse1_loss: 0.0299 - val_voltage_rise_time_pulse1_mae: 0.1005 - val_voltage_rise_time_pulse2_loss: 0.1785 - val_voltage_rise_time_pulse2_mae: 0.2007 - learning_rate: 4.5000e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#
# train:
#                        Target        R2          RMSE
# 3   voltage_fall_time_pulse2  0.998036  3.032721e-10
# 2   voltage_fall_time_pulse1  0.997571  3.377060e-10
# 7   current_fall_time_pulse2  0.994889  8.365179e-10
# 6   current_fall_time_pulse1  0.994884  8.398879e-10
# 12     ringing_frequency_MHz  0.994777  2.374513e+00
# 11        undershoot_pulse_2  0.977702  2.072213e+00
# 10        undershoot_pulse_1  0.976679  2.115020e+00
# 0   voltage_rise_time_pulse1  0.976515  6.174913e-10
# 8          overshoot_pulse_1  0.954413  2.458395e+00
# 4   current_rise_time_pulse1  0.936501  1.230487e-08
# 9          overshoot_pulse_2  0.927821  6.648456e+00
# 1   voltage_rise_time_pulse2  0.911004  1.146221e-09
# 5   current_rise_time_pulse2  0.896020  7.952848e-09
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# val:
#                        Target        R2          RMSE
# 3   voltage_fall_time_pulse2  0.997560  3.483185e-10
# 2   voltage_fall_time_pulse1  0.997188  3.745791e-10
# 6   current_fall_time_pulse1  0.994584  8.779989e-10
# 7   current_fall_time_pulse2  0.994403  8.905473e-10
# 12     ringing_frequency_MHz  0.994326  2.549110e+00
# 11        undershoot_pulse_2  0.970961  2.328800e+00
# 0   voltage_rise_time_pulse1  0.970437  7.261876e-10
# 10        undershoot_pulse_1  0.970337  2.359977e+00
# 4   current_rise_time_pulse1  0.934193  1.278646e-08
# 8          overshoot_pulse_1  0.924558  3.438470e+00
# 9          overshoot_pulse_2  0.915359  7.563039e+00
# 5   current_rise_time_pulse2  0.907164  7.782114e-09
# 1   voltage_rise_time_pulse2  0.827468  1.748256e-09
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# test:
#                        Target        R2          RMSE
# 3   voltage_fall_time_pulse2  0.997961  3.104471e-10
# 2   voltage_fall_time_pulse1  0.997510  3.434903e-10
# 6   current_fall_time_pulse1  0.994838  8.457149e-10
# 7   current_fall_time_pulse2  0.994814  8.448439e-10
# 12     ringing_frequency_MHz  0.994706  2.401516e+00
# 11        undershoot_pulse_2  0.976719  2.112695e+00
# 10        undershoot_pulse_1  0.975746  2.153546e+00
# 0   voltage_rise_time_pulse1  0.975531  6.349857e-10
# 8          overshoot_pulse_1  0.949267  2.628830e+00
# 4   current_rise_time_pulse1  0.936144  1.237832e-08
# 9          overshoot_pulse_2  0.925792  6.793519e+00
# 5   current_rise_time_pulse2  0.897825  7.927469e-09
# 1   voltage_rise_time_pulse2  0.896452  1.255089e-09
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# unseen:
#                        Target        R2          RMSE
# 6   current_fall_time_pulse1  0.931825  2.932103e-09
# 7   current_fall_time_pulse2  0.923373  3.087279e-09
# 8          overshoot_pulse_1  0.544395  8.574716e+00
# 9          overshoot_pulse_2  0.437781  1.489661e+01
# 11        undershoot_pulse_2  0.423919  7.228575e+00
# 10        undershoot_pulse_1  0.407673  7.382952e+00
# 0   voltage_rise_time_pulse1  0.320046  1.437613e-09
# 3   voltage_fall_time_pulse2  0.288584  1.964124e-09
# 5   current_rise_time_pulse2  0.287961  1.400704e-08
# 1   voltage_rise_time_pulse2  0.281665  3.733709e-09
# 2   voltage_fall_time_pulse1  0.249285  2.016612e-09
#                       Target        R2          RMSE
# 6   current_fall_time_pulse1  0.931825  2.932103e-09
# 7   current_fall_time_pulse2  0.923373  3.087279e-09
# 8          overshoot_pulse_1  0.544395  8.574716e+00
# 9          overshoot_pulse_2  0.437781  1.489661e+01
# 11        undershoot_pulse_2  0.423919  7.228575e+00
# 10        undershoot_pulse_1  0.407673  7.382952e+00
# 0   voltage_rise_time_pulse1  0.320046  1.437613e-09
# 3   voltage_fall_time_pulse2  0.288584  1.964124e-09
# 5   current_rise_time_pulse2  0.287961  1.400704e-08
# 1   voltage_rise_time_pulse2  0.281665  3.733709e-09
# 2   voltage_fall_time_pulse1  0.249285  2.016612e-09
