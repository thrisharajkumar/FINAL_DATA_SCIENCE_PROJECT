# %% [markdown]
# ## MASKED ANN

# %% [markdown]
# | Model / Iteration  | Dropout | L2 Reg. | BatchNorm | EarlyStopping | LR Scheduler      | Scaling                       | Physics Features | Notes                             |
# | ------------------ | ------- | ------- | --------- | ------------- | ----------------- | ----------------------------- | ---------------- | --------------------------------- |
# | **Masked ANN**     | 0.2     | 1e-4    | Yes       | Yes           | ReduceLROnPlateau | StdScaler (X), Ringing→MinMax | Yes              | Masked per-target + physics       |

# %%
# ==================== MASKED ANN (All-Best Techniques) ====================
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, regularizers
import matplotlib.pyplot as plt

# ============== SETTINGS ==============
SEED = 42
UNSEEN_PART = 'C2M0040120D'
BASE_DIR = "iteration_masked"
os.makedirs(f"{BASE_DIR}/r2_rmse_tables", exist_ok=True)
os.makedirs(f"{BASE_DIR}/train_val_loss_curves", exist_ok=True)
os.makedirs(f"{BASE_DIR}/models", exist_ok=True)

# ============== LOAD DATA ==============
df = pd.read_csv(
    r"C:\Users\pc\Desktop\Neural_Network_Models\merged_train_5_MOSFETs_10percent_balanced.csv"
)

TARGET_COLUMNS = [
    'voltage_rise_time_pulse1', 'voltage_rise_time_pulse2',
    'voltage_fall_time_pulse1', 'voltage_fall_time_pulse2',
    'current_rise_time_pulse1', 'current_rise_time_pulse2',
    'current_fall_time_pulse1', 'current_fall_time_pulse2',
    'overshoot_pulse_1', 'overshoot_pulse_2',
    'undershoot_pulse_1', 'undershoot_pulse_2',
    'ringing_frequency_MHz'
]
DROP_COLUMNS = ['DeviceID', 'MOSFET', 'Part_Number']

# ============== SPLIT SEEN/UNSEEN DEVICES ==============
seen_parts = [p for p in df['Part_Number'].unique().tolist() if p != UNSEEN_PART]
train_df = df[df['Part_Number'].isin(seen_parts)].copy()
test_df  = df[df['Part_Number'] == UNSEEN_PART].copy()

# ============== PHYSICS FEATURES ==============
def compute_physics_features(row):
    L_eq = row[['Ls4','Ls5','Ls6','Ls7','Ls8','Ls9','Ls10','Ls11']].sum()
    C_eq = row.get("Coss", 1e-12)
    f_res = 1/(2*np.pi*np.sqrt(L_eq*C_eq))/1e6 if L_eq>0 and C_eq>0 else 0
    overshoot_est = row.get("VDS_max",0) - row.get("Vbus",0)
    undershoot_est = - row.get("VGS_th_min",0)
    dVdt_est = row.get("VDS_max",0)/row.get("Tp1",1e-9)
    dIdt_est = row.get("ID_max_25C",0)/row.get("Tp1",1e-9)
    return pd.Series([f_res, overshoot_est, undershoot_est, dVdt_est, dIdt_est])

for df_ in [train_df, test_df]:
    df_[['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est']] = \
        df_.apply(compute_physics_features, axis=1)

physics_features = ['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est']
INPUT_COLUMNS = [c for c in df.columns if c not in TARGET_COLUMNS + DROP_COLUMNS] + physics_features

# ============== SCALE INPUTS ==============
input_scaler = StandardScaler()
input_scaler.fit(pd.concat([train_df[INPUT_COLUMNS], test_df[INPUT_COLUMNS]]))
X_train_all = input_scaler.transform(train_df[INPUT_COLUMNS])
X_test_all  = input_scaler.transform(test_df[INPUT_COLUMNS])

# ============== SCALE OUTPUTS (per target) ==============
output_scalers, y_train_scaled, y_test_scaled = {}, [], []
for col in TARGET_COLUMNS:
    scaler = MinMaxScaler() if col == 'ringing_frequency_MHz' else StandardScaler()
    y_train_scaled.append(scaler.fit_transform(train_df[[col]]).flatten())
    y_test_scaled.append(scaler.transform(test_df[[col]]).flatten())
    output_scalers[col] = scaler
y_train_scaled = np.array(y_train_scaled).T
y_test_scaled  = np.array(y_test_scaled).T

# ============== SPLIT TRAIN/VAL ==============
Xtr, Xval, ytr, yval = train_test_split(
    X_train_all, y_train_scaled, test_size=0.15, random_state=SEED
)

# ============== FEATURE MASKS (toy example: select subsets) ==============
# In practice, you’d compute mutual info or importance scores per target.
# Here we just group physics features + a few indices per target for demonstration.
feature_masks = {
    'voltage_rise_time_pulse1': physics_features[:3],
    'voltage_fall_time_pulse1': physics_features[2:],
    'current_rise_time_pulse1': physics_features[:2],
    'current_fall_time_pulse1': physics_features[1:],
    'overshoot_pulse_1': physics_features,
    'undershoot_pulse_1': physics_features,
    'ringing_frequency_MHz': physics_features
}

# Map feature names to indices
mask_indices = {col: [INPUT_COLUMNS.index(f) for f in feats if f in INPUT_COLUMNS] 
                for col, feats in feature_masks.items()}

# ============== BUILD MASKED ANN ==============
def build_masked_ann(input_dim, output_dim, masks, l2_reg=1e-4, dropout_rate=0.2):
    inp = layers.Input(shape=(input_dim,), name="global_inputs")

    # Shared backbone
    x = layers.Dense(128, kernel_regularizer=regularizers.l2(l2_reg))(inp)
    x = layers.BatchNormalization()(x); x = layers.ReLU()(x)
    x = layers.Dropout(dropout_rate)(x)

    x = layers.Dense(64, kernel_regularizer=regularizers.l2(l2_reg))(x)
    x = layers.BatchNormalization()(x); x = layers.ReLU()(x)
    x = layers.Dropout(dropout_rate)(x)

    outputs = []
    for i, col in enumerate(TARGET_COLUMNS):
        # Mask input branch
        if col in masks and len(masks[col]) > 0:
            masked = layers.Lambda(lambda z, idx=masks[col]: tf.gather(z, idx, axis=1))(inp)
            m = layers.Dense(32, activation="relu")(masked)
        else:
            m = layers.Dense(16, activation="relu")(inp)

        # Combine backbone + masked branch
        h = layers.Concatenate()([x, m])
        h = layers.Dense(64, activation="relu")(h)
        h = layers.Dropout(dropout_rate)(h)
        h = layers.Dense(32, activation="relu")(h)
        out = layers.Dense(1, activation="linear", name=col)(h)
        outputs.append(out)

    model = models.Model(inputs=inp, outputs=outputs)
    return model

model = build_masked_ann(Xtr.shape[1], len(TARGET_COLUMNS), mask_indices)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-4),
    loss=["mse"]*len(TARGET_COLUMNS),
    metrics=["mae"]*len(TARGET_COLUMNS)
)

early_stop = callbacks.EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)
reduce_lr  = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=5)

history = model.fit(
    Xtr, [ytr[:,i] for i in range(len(TARGET_COLUMNS))],
    validation_data=(Xval,[yval[:,i] for i in range(len(TARGET_COLUMNS))]),
    epochs=120, batch_size=256, callbacks=[early_stop, reduce_lr], verbose=1
)

model.save(f"{BASE_DIR}/models/masked_ann.h5")

# ============== LOSS CURVE ==============
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel("Epoch"); plt.ylabel("MSE Loss")
plt.title("Train vs Validation Loss")
plt.legend(); plt.savefig(f"{BASE_DIR}/train_val_loss_curves/loss.png"); plt.close()

# ============== EVALUATION ==============
def evaluate_and_save(X, y_scaled, name, positive_only=False):
    y_pred_scaled_list = model.predict(X)
    results = []
    for i, col in enumerate(TARGET_COLUMNS):
        y_true = output_scalers[col].inverse_transform(y_scaled[:,i].reshape(-1,1)).flatten()
        y_pred = output_scalers[col].inverse_transform(y_pred_scaled_list[i].reshape(-1,1)).flatten()
        r2 = r2_score(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        results.append((col, r2, rmse))
    df_results = pd.DataFrame(results, columns=["Target","R2","RMSE"]).sort_values("R2",ascending=False)
    if positive_only:
        df_results = df_results[df_results["R2"]>0]
    print(f"\n{name}:\n",df_results)
    df_results.to_csv(f"{BASE_DIR}/r2_rmse_tables/{name}.csv", index=False)
    return df_results

evaluate_and_save(Xtr,ytr,"train")
evaluate_and_save(Xval,yval,"val")
evaluate_and_save(X_train_all,y_train_scaled,"test")
evaluate_and_save(X_test_all,y_test_scaled,"unseen",positive_only=True)
# Out:
# WARNING:tensorflow:From c:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend\tensorflow\core.py:216: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 1/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 13s 52ms/step - current_fall_time_pulse1_loss: 2.4923 - current_fall_time_pulse1_mae: 1.3218 - current_fall_time_pulse2_loss: 1.8085 - current_fall_time_pulse2_mae: 1.0985 - current_rise_time_pulse1_loss: 0.7585 - current_rise_time_pulse1_mae: 0.6648 - current_rise_time_pulse2_loss: 0.6667 - current_rise_time_pulse2_mae: 0.6633 - loss: 13.4141 - overshoot_pulse_1_loss: 0.8979 - overshoot_pulse_1_mae: 0.7326 - overshoot_pulse_2_loss: 0.8456 - overshoot_pulse_2_mae: 0.7184 - ringing_frequency_MHz_loss: 0.3998 - ringing_frequency_MHz_mae: 0.4908 - undershoot_pulse_1_loss: 1.0898 - undershoot_pulse_1_mae: 0.8148 - undershoot_pulse_2_loss: 0.9496 - undershoot_pulse_2_mae: 0.7520 - voltage_fall_time_pulse1_loss: 0.6584 - voltage_fall_time_pulse1_mae: 0.6404 - voltage_fall_time_pulse2_loss: 1.0339 - voltage_fall_time_pulse2_mae: 0.7424 - voltage_rise_time_pulse1_loss: 0.8045 - voltage_rise_time_pulse1_mae: 0.7083 - voltage_rise_time_pulse2_loss: 0.9906 - voltage_rise_time_pulse2_mae: 0.7445 - val_current_fall_time_pulse1_loss: 0.8063 - val_current_fall_time_pulse1_mae: 0.7034 - val_current_fall_time_pulse2_loss: 0.5670 - val_current_fall_time_pulse2_mae: 0.5827 - val_current_rise_time_pulse1_loss: 0.3067 - val_current_rise_time_pulse1_mae: 0.4358 - val_current_rise_time_pulse2_loss: 0.4182 - val_current_rise_time_pulse2_mae: 0.5384 - val_loss: 5.2279 - val_overshoot_pulse_1_loss: 0.7449 - val_overshoot_pulse_1_mae: 0.6562 - val_overshoot_pulse_2_loss: 0.4797 - val_overshoot_pulse_2_mae: 0.5469 - val_ringing_frequency_MHz_loss: 0.0679 - val_ringing_frequency_MHz_mae: 0.2104 - val_undershoot_pulse_1_loss: 0.4845 - val_undershoot_pulse_1_mae: 0.5577 - val_undershoot_pulse_2_loss: 0.4088 - val_undershoot_pulse_2_mae: 0.4988 - val_voltage_fall_time_pulse1_loss: 0.1295 - val_voltage_fall_time_pulse1_mae: 0.2985 - val_voltage_fall_time_pulse2_loss: 0.1567 - val_voltage_fall_time_pulse2_mae: 0.3088 - val_voltage_rise_time_pulse1_loss: 0.1930 - val_voltage_rise_time_pulse1_mae: 0.3694 - val_voltage_rise_time_pulse2_loss: 0.4612 - val_voltage_rise_time_pulse2_mae: 0.4608 - learning_rate: 5.0000e-04
# Epoch 2/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.5698 - current_fall_time_pulse1_mae: 0.6157 - current_fall_time_pulse2_loss: 0.4318 - current_fall_time_pulse2_mae: 0.5228 - current_rise_time_pulse1_loss: 0.2985 - current_rise_time_pulse1_mae: 0.4233 - current_rise_time_pulse2_loss: 0.3730 - current_rise_time_pulse2_mae: 0.4941 - loss: 4.5461 - overshoot_pulse_1_loss: 0.5205 - overshoot_pulse_1_mae: 0.5549 - overshoot_pulse_2_loss: 0.3647 - overshoot_pulse_2_mae: 0.4713 - ringing_frequency_MHz_loss: 0.0768 - ringing_frequency_MHz_mae: 0.2175 - undershoot_pulse_1_loss: 0.4719 - undershoot_pulse_1_mae: 0.5386 - undershoot_pulse_2_loss: 0.4503 - undershoot_pulse_2_mae: 0.5263 - voltage_fall_time_pulse1_loss: 0.1654 - voltage_fall_time_pulse1_mae: 0.3005 - voltage_fall_time_pulse2_loss: 0.1886 - voltage_fall_time_pulse2_mae: 0.3237 - voltage_rise_time_pulse1_loss: 0.2438 - voltage_rise_time_pulse1_mae: 0.3680 - voltage_rise_time_pulse2_loss: 0.3763 - voltage_rise_time_pulse2_mae: 0.4515 - val_current_fall_time_pulse1_loss: 0.3626 - val_current_fall_time_pulse1_mae: 0.4734 - val_current_fall_time_pulse2_loss: 0.2943 - val_current_fall_time_pulse2_mae: 0.4180 - val_current_rise_time_pulse1_loss: 0.2340 - val_current_rise_time_pulse1_mae: 0.3839 - val_current_rise_time_pulse2_loss: 0.3512 - val_current_rise_time_pulse2_mae: 0.4985 - val_loss: 3.6696 - val_overshoot_pulse_1_loss: 0.5764 - val_overshoot_pulse_1_mae: 0.5590 - val_overshoot_pulse_2_loss: 0.3222 - val_overshoot_pulse_2_mae: 0.4411 - val_ringing_frequency_MHz_loss: 0.0382 - val_ringing_frequency_MHz_mae: 0.1652 - val_undershoot_pulse_1_loss: 0.3378 - val_undershoot_pulse_1_mae: 0.4742 - val_undershoot_pulse_2_loss: 0.2211 - val_undershoot_pulse_2_mae: 0.3751 - val_voltage_fall_time_pulse1_loss: 0.1618 - val_voltage_fall_time_pulse1_mae: 0.3003 - val_voltage_fall_time_pulse2_loss: 0.1340 - val_voltage_fall_time_pulse2_mae: 0.2995 - val_voltage_rise_time_pulse1_loss: 0.1723 - val_voltage_rise_time_pulse1_mae: 0.3261 - val_voltage_rise_time_pulse2_loss: 0.4177 - val_voltage_rise_time_pulse2_mae: 0.4125 - learning_rate: 5.0000e-04
# Epoch 3/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.2576 - current_fall_time_pulse1_mae: 0.4025 - current_fall_time_pulse2_loss: 0.2610 - current_fall_time_pulse2_mae: 0.4027 - current_rise_time_pulse1_loss: 0.2404 - current_rise_time_pulse1_mae: 0.3773 - current_rise_time_pulse2_loss: 0.3212 - current_rise_time_pulse2_mae: 0.4529 - loss: 3.0669 - overshoot_pulse_1_loss: 0.4107 - overshoot_pulse_1_mae: 0.4876 - overshoot_pulse_2_loss: 0.2624 - overshoot_pulse_2_mae: 0.3971 - ringing_frequency_MHz_loss: 0.0512 - ringing_frequency_MHz_mae: 0.1762 - undershoot_pulse_1_loss: 0.3043 - undershoot_pulse_1_mae: 0.4256 - undershoot_pulse_2_loss: 0.2444 - undershoot_pulse_2_mae: 0.3763 - voltage_fall_time_pulse1_loss: 0.1159 - voltage_fall_time_pulse1_mae: 0.2577 - voltage_fall_time_pulse2_loss: 0.1195 - voltage_fall_time_pulse2_mae: 0.2592 - voltage_rise_time_pulse1_loss: 0.1855 - voltage_rise_time_pulse1_mae: 0.3266 - voltage_rise_time_pulse2_loss: 0.2789 - voltage_rise_time_pulse2_mae: 0.3762 - val_current_fall_time_pulse1_loss: 0.2419 - val_current_fall_time_pulse1_mae: 0.3747 - val_current_fall_time_pulse2_loss: 0.2199 - val_current_fall_time_pulse2_mae: 0.3477 - val_current_rise_time_pulse1_loss: 0.1859 - val_current_rise_time_pulse1_mae: 0.3403 - val_current_rise_time_pulse2_loss: 0.2977 - val_current_rise_time_pulse2_mae: 0.4540 - val_loss: 2.8423 - val_overshoot_pulse_1_loss: 0.4694 - val_overshoot_pulse_1_mae: 0.5035 - val_overshoot_pulse_2_loss: 0.2665 - val_overshoot_pulse_2_mae: 0.4006 - val_ringing_frequency_MHz_loss: 0.0317 - val_ringing_frequency_MHz_mae: 0.1511 - val_undershoot_pulse_1_loss: 0.2387 - val_undershoot_pulse_1_mae: 0.3878 - val_undershoot_pulse_2_loss: 0.1438 - val_undershoot_pulse_2_mae: 0.2968 - val_voltage_fall_time_pulse1_loss: 0.1092 - val_voltage_fall_time_pulse1_mae: 0.2397 - val_voltage_fall_time_pulse2_loss: 0.0793 - val_voltage_fall_time_pulse2_mae: 0.2290 - val_voltage_rise_time_pulse1_loss: 0.1597 - val_voltage_rise_time_pulse1_mae: 0.2894 - val_voltage_rise_time_pulse2_loss: 0.3612 - val_voltage_rise_time_pulse2_mae: 0.3644 - learning_rate: 5.0000e-04
# Epoch 4/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - current_fall_time_pulse1_loss: 0.1867 - current_fall_time_pulse1_mae: 0.3385 - current_fall_time_pulse2_loss: 0.1996 - current_fall_time_pulse2_mae: 0.3487 - current_rise_time_pulse1_loss: 0.2064 - current_rise_time_pulse1_mae: 0.3487 - current_rise_time_pulse2_loss: 0.2727 - current_rise_time_pulse2_mae: 0.4176 - loss: 2.5855 - overshoot_pulse_1_loss: 0.3607 - overshoot_pulse_1_mae: 0.4588 - overshoot_pulse_2_loss: 0.2319 - overshoot_pulse_2_mae: 0.3780 - ringing_frequency_MHz_loss: 0.0390 - ringing_frequency_MHz_mae: 0.1529 - undershoot_pulse_1_loss: 0.2476 - undershoot_pulse_1_mae: 0.3816 - undershoot_pulse_2_loss: 0.1960 - undershoot_pulse_2_mae: 0.3376 - voltage_fall_time_pulse1_loss: 0.0967 - voltage_fall_time_pulse1_mae: 0.2340 - voltage_fall_time_pulse2_loss: 0.1000 - voltage_fall_time_pulse2_mae: 0.2390 - voltage_rise_time_pulse1_loss: 0.1685 - voltage_rise_time_pulse1_mae: 0.3047 - voltage_rise_time_pulse2_loss: 0.2660 - voltage_rise_time_pulse2_mae: 0.3530 - val_current_fall_time_pulse1_loss: 0.1941 - val_current_fall_time_pulse1_mae: 0.3280 - val_current_fall_time_pulse2_loss: 0.1640 - val_current_fall_time_pulse2_mae: 0.2954 - val_current_rise_time_pulse1_loss: 0.1488 - val_current_rise_time_pulse1_mae: 0.2991 - val_current_rise_time_pulse2_loss: 0.2508 - val_current_rise_time_pulse2_mae: 0.4082 - val_loss: 2.2734 - val_overshoot_pulse_1_loss: 0.3691 - val_overshoot_pulse_1_mae: 0.4404 - val_overshoot_pulse_2_loss: 0.2123 - val_overshoot_pulse_2_mae: 0.3520 - val_ringing_frequency_MHz_loss: 0.0279 - val_ringing_frequency_MHz_mae: 0.1422 - val_undershoot_pulse_1_loss: 0.1729 - val_undershoot_pulse_1_mae: 0.3245 - val_undershoot_pulse_2_loss: 0.0998 - val_undershoot_pulse_2_mae: 0.2434 - val_voltage_fall_time_pulse1_loss: 0.0677 - val_voltage_fall_time_pulse1_mae: 0.1966 - val_voltage_fall_time_pulse2_loss: 0.0542 - val_voltage_fall_time_pulse2_mae: 0.1957 - val_voltage_rise_time_pulse1_loss: 0.1231 - val_voltage_rise_time_pulse1_mae: 0.2551 - val_voltage_rise_time_pulse2_loss: 0.3448 - val_voltage_rise_time_pulse2_mae: 0.3481 - learning_rate: 5.0000e-04
# Epoch 5/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - current_fall_time_pulse1_loss: 0.1675 - current_fall_time_pulse1_mae: 0.3188 - current_fall_time_pulse2_loss: 0.1795 - current_fall_time_pulse2_mae: 0.3278 - current_rise_time_pulse1_loss: 0.1843 - current_rise_time_pulse1_mae: 0.3274 - current_rise_time_pulse2_loss: 0.2520 - current_rise_time_pulse2_mae: 0.3986 - loss: 2.2523 - overshoot_pulse_1_loss: 0.3224 - overshoot_pulse_1_mae: 0.4314 - overshoot_pulse_2_loss: 0.2045 - overshoot_pulse_2_mae: 0.3470 - ringing_frequency_MHz_loss: 0.0318 - ringing_frequency_MHz_mae: 0.1387 - undershoot_pulse_1_loss: 0.2057 - undershoot_pulse_1_mae: 0.3478 - undershoot_pulse_2_loss: 0.1537 - undershoot_pulse_2_mae: 0.3027 - voltage_fall_time_pulse1_loss: 0.0809 - voltage_fall_time_pulse1_mae: 0.2155 - voltage_fall_time_pulse2_loss: 0.0812 - voltage_fall_time_pulse2_mae: 0.2137 - voltage_rise_time_pulse1_loss: 0.1429 - voltage_rise_time_pulse1_mae: 0.2839 - voltage_rise_time_pulse2_loss: 0.2325 - voltage_rise_time_pulse2_mae: 0.3291 - val_current_fall_time_pulse1_loss: 0.1456 - val_current_fall_time_pulse1_mae: 0.2817 - val_current_fall_time_pulse2_loss: 0.1194 - val_current_fall_time_pulse2_mae: 0.2499 - val_current_rise_time_pulse1_loss: 0.1319 - val_current_rise_time_pulse1_mae: 0.2766 - val_current_rise_time_pulse2_loss: 0.2205 - val_current_rise_time_pulse2_mae: 0.3702 - val_loss: 1.9021 - val_overshoot_pulse_1_loss: 0.3104 - val_overshoot_pulse_1_mae: 0.4032 - val_overshoot_pulse_2_loss: 0.1779 - val_overshoot_pulse_2_mae: 0.3209 - val_ringing_frequency_MHz_loss: 0.0203 - val_ringing_frequency_MHz_mae: 0.1203 - val_undershoot_pulse_1_loss: 0.1344 - val_undershoot_pulse_1_mae: 0.2861 - val_undershoot_pulse_2_loss: 0.0855 - val_undershoot_pulse_2_mae: 0.2245 - val_voltage_fall_time_pulse1_loss: 0.0499 - val_voltage_fall_time_pulse1_mae: 0.1670 - val_voltage_fall_time_pulse2_loss: 0.0348 - val_voltage_fall_time_pulse2_mae: 0.1537 - val_voltage_rise_time_pulse1_loss: 0.1097 - val_voltage_rise_time_pulse1_mae: 0.2362 - val_voltage_rise_time_pulse2_loss: 0.3132 - val_voltage_rise_time_pulse2_mae: 0.3213 - learning_rate: 5.0000e-04
# Epoch 6/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.1387 - current_fall_time_pulse1_mae: 0.2895 - current_fall_time_pulse2_loss: 0.1449 - current_fall_time_pulse2_mae: 0.2956 - current_rise_time_pulse1_loss: 0.1692 - current_rise_time_pulse1_mae: 0.3134 - current_rise_time_pulse2_loss: 0.2299 - current_rise_time_pulse2_mae: 0.3723 - loss: 2.0084 - overshoot_pulse_1_loss: 0.2663 - overshoot_pulse_1_mae: 0.3970 - overshoot_pulse_2_loss: 0.1876 - overshoot_pulse_2_mae: 0.3365 - ringing_frequency_MHz_loss: 0.0265 - ringing_frequency_MHz_mae: 0.1267 - undershoot_pulse_1_loss: 0.1907 - undershoot_pulse_1_mae: 0.3366 - undershoot_pulse_2_loss: 0.1370 - undershoot_pulse_2_mae: 0.2812 - voltage_fall_time_pulse1_loss: 0.0699 - voltage_fall_time_pulse1_mae: 0.1984 - voltage_fall_time_pulse2_loss: 0.0702 - voltage_fall_time_pulse2_mae: 0.1979 - voltage_rise_time_pulse1_loss: 0.1375 - voltage_rise_time_pulse1_mae: 0.2707 - voltage_rise_time_pulse2_loss: 0.2267 - voltage_rise_time_pulse2_mae: 0.3218 - val_current_fall_time_pulse1_loss: 0.1035 - val_current_fall_time_pulse1_mae: 0.2369 - val_current_fall_time_pulse2_loss: 0.0877 - val_current_fall_time_pulse2_mae: 0.2165 - val_current_rise_time_pulse1_loss: 0.1134 - val_current_rise_time_pulse1_mae: 0.2529 - val_current_rise_time_pulse2_loss: 0.1924 - val_current_rise_time_pulse2_mae: 0.3390 - val_loss: 1.6181 - val_overshoot_pulse_1_loss: 0.2591 - val_overshoot_pulse_1_mae: 0.3650 - val_overshoot_pulse_2_loss: 0.1496 - val_overshoot_pulse_2_mae: 0.2889 - val_ringing_frequency_MHz_loss: 0.0209 - val_ringing_frequency_MHz_mae: 0.1220 - val_undershoot_pulse_1_loss: 0.1169 - val_undershoot_pulse_1_mae: 0.2631 - val_undershoot_pulse_2_loss: 0.0777 - val_undershoot_pulse_2_mae: 0.2130 - val_voltage_fall_time_pulse1_loss: 0.0285 - val_voltage_fall_time_pulse1_mae: 0.1411 - val_voltage_fall_time_pulse2_loss: 0.0232 - val_voltage_fall_time_pulse2_mae: 0.1327 - val_voltage_rise_time_pulse1_loss: 0.0810 - val_voltage_rise_time_pulse1_mae: 0.2138 - val_voltage_rise_time_pulse2_loss: 0.2962 - val_voltage_rise_time_pulse2_mae: 0.3102 - learning_rate: 5.0000e-04
# Epoch 7/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.1290 - current_fall_time_pulse1_mae: 0.2773 - current_fall_time_pulse2_loss: 0.1319 - current_fall_time_pulse2_mae: 0.2800 - current_rise_time_pulse1_loss: 0.1597 - current_rise_time_pulse1_mae: 0.3005 - current_rise_time_pulse2_loss: 0.2165 - current_rise_time_pulse2_mae: 0.3603 - loss: 1.8812 - overshoot_pulse_1_loss: 0.2601 - overshoot_pulse_1_mae: 0.3896 - overshoot_pulse_2_loss: 0.1792 - overshoot_pulse_2_mae: 0.3274 - ringing_frequency_MHz_loss: 0.0224 - ringing_frequency_MHz_mae: 0.1158 - undershoot_pulse_1_loss: 0.1704 - undershoot_pulse_1_mae: 0.3121 - undershoot_pulse_2_loss: 0.1299 - undershoot_pulse_2_mae: 0.2725 - voltage_fall_time_pulse1_loss: 0.0618 - voltage_fall_time_pulse1_mae: 0.1852 - voltage_fall_time_pulse2_loss: 0.0634 - voltage_fall_time_pulse2_mae: 0.1870 - voltage_rise_time_pulse1_loss: 0.1267 - voltage_rise_time_pulse1_mae: 0.2635 - voltage_rise_time_pulse2_loss: 0.2168 - voltage_rise_time_pulse2_mae: 0.3150 - val_current_fall_time_pulse1_loss: 0.1098 - val_current_fall_time_pulse1_mae: 0.2356 - val_current_fall_time_pulse2_loss: 0.0938 - val_current_fall_time_pulse2_mae: 0.2172 - val_current_rise_time_pulse1_loss: 0.1006 - val_current_rise_time_pulse1_mae: 0.2313 - val_current_rise_time_pulse2_loss: 0.1840 - val_current_rise_time_pulse2_mae: 0.3288 - val_loss: 1.5093 - val_overshoot_pulse_1_loss: 0.2240 - val_overshoot_pulse_1_mae: 0.3347 - val_overshoot_pulse_2_loss: 0.1434 - val_overshoot_pulse_2_mae: 0.2805 - val_ringing_frequency_MHz_loss: 0.0154 - val_ringing_frequency_MHz_mae: 0.1037 - val_undershoot_pulse_1_loss: 0.0940 - val_undershoot_pulse_1_mae: 0.2384 - val_undershoot_pulse_2_loss: 0.0676 - val_undershoot_pulse_2_mae: 0.1986 - val_voltage_fall_time_pulse1_loss: 0.0248 - val_voltage_fall_time_pulse1_mae: 0.1279 - val_voltage_fall_time_pulse2_loss: 0.0211 - val_voltage_fall_time_pulse2_mae: 0.1255 - val_voltage_rise_time_pulse1_loss: 0.0841 - val_voltage_rise_time_pulse1_mae: 0.2038 - val_voltage_rise_time_pulse2_loss: 0.2930 - val_voltage_rise_time_pulse2_mae: 0.3010 - learning_rate: 5.0000e-04
# Epoch 8/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - current_fall_time_pulse1_loss: 0.1156 - current_fall_time_pulse1_mae: 0.2660 - current_fall_time_pulse2_loss: 0.1205 - current_fall_time_pulse2_mae: 0.2677 - current_rise_time_pulse1_loss: 0.1479 - current_rise_time_pulse1_mae: 0.2879 - current_rise_time_pulse2_loss: 0.2091 - current_rise_time_pulse2_mae: 0.3518 - loss: 1.7378 - overshoot_pulse_1_loss: 0.2379 - overshoot_pulse_1_mae: 0.3732 - overshoot_pulse_2_loss: 0.1580 - overshoot_pulse_2_mae: 0.3108 - ringing_frequency_MHz_loss: 0.0183 - ringing_frequency_MHz_mae: 0.1049 - undershoot_pulse_1_loss: 0.1587 - undershoot_pulse_1_mae: 0.3043 - undershoot_pulse_2_loss: 0.1207 - undershoot_pulse_2_mae: 0.2599 - voltage_fall_time_pulse1_loss: 0.0542 - voltage_fall_time_pulse1_mae: 0.1737 - voltage_fall_time_pulse2_loss: 0.0560 - voltage_fall_time_pulse2_mae: 0.1753 - voltage_rise_time_pulse1_loss: 0.1202 - voltage_rise_time_pulse1_mae: 0.2549 - voltage_rise_time_pulse2_loss: 0.2077 - voltage_rise_time_pulse2_mae: 0.3009 - val_current_fall_time_pulse1_loss: 0.0944 - val_current_fall_time_pulse1_mae: 0.2181 - val_current_fall_time_pulse2_loss: 0.0804 - val_current_fall_time_pulse2_mae: 0.2005 - val_current_rise_time_pulse1_loss: 0.1000 - val_current_rise_time_pulse1_mae: 0.2346 - val_current_rise_time_pulse2_loss: 0.1654 - val_current_rise_time_pulse2_mae: 0.2980 - val_loss: 1.3579 - val_overshoot_pulse_1_loss: 0.1972 - val_overshoot_pulse_1_mae: 0.3127 - val_overshoot_pulse_2_loss: 0.1285 - val_overshoot_pulse_2_mae: 0.2632 - val_ringing_frequency_MHz_loss: 0.0149 - val_ringing_frequency_MHz_mae: 0.1023 - val_undershoot_pulse_1_loss: 0.0883 - val_undershoot_pulse_1_mae: 0.2313 - val_undershoot_pulse_2_loss: 0.0565 - val_undershoot_pulse_2_mae: 0.1802 - val_voltage_fall_time_pulse1_loss: 0.0167 - val_voltage_fall_time_pulse1_mae: 0.1091 - val_voltage_fall_time_pulse2_loss: 0.0166 - val_voltage_fall_time_pulse2_mae: 0.1108 - val_voltage_rise_time_pulse1_loss: 0.0658 - val_voltage_rise_time_pulse1_mae: 0.1871 - val_voltage_rise_time_pulse2_loss: 0.2767 - val_voltage_rise_time_pulse2_mae: 0.2806 - learning_rate: 5.0000e-04
# Epoch 9/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - current_fall_time_pulse1_loss: 0.1119 - current_fall_time_pulse1_mae: 0.2592 - current_fall_time_pulse2_loss: 0.1101 - current_fall_time_pulse2_mae: 0.2548 - current_rise_time_pulse1_loss: 0.1393 - current_rise_time_pulse1_mae: 0.2799 - current_rise_time_pulse2_loss: 0.2002 - current_rise_time_pulse2_mae: 0.3453 - loss: 1.6582 - overshoot_pulse_1_loss: 0.2318 - overshoot_pulse_1_mae: 0.3642 - overshoot_pulse_2_loss: 0.1480 - overshoot_pulse_2_mae: 0.3002 - ringing_frequency_MHz_loss: 0.0173 - ringing_frequency_MHz_mae: 0.1013 - undershoot_pulse_1_loss: 0.1564 - undershoot_pulse_1_mae: 0.2971 - undershoot_pulse_2_loss: 0.1152 - undershoot_pulse_2_mae: 0.2499 - voltage_fall_time_pulse1_loss: 0.0496 - voltage_fall_time_pulse1_mae: 0.1692 - voltage_fall_time_pulse2_loss: 0.0497 - voltage_fall_time_pulse2_mae: 0.1660 - voltage_rise_time_pulse1_loss: 0.1106 - voltage_rise_time_pulse1_mae: 0.2459 - voltage_rise_time_pulse2_loss: 0.2051 - voltage_rise_time_pulse2_mae: 0.3002 - val_current_fall_time_pulse1_loss: 0.0820 - val_current_fall_time_pulse1_mae: 0.2018 - val_current_fall_time_pulse2_loss: 0.0650 - val_current_fall_time_pulse2_mae: 0.1810 - val_current_rise_time_pulse1_loss: 0.0945 - val_current_rise_time_pulse1_mae: 0.2199 - val_current_rise_time_pulse2_loss: 0.1667 - val_current_rise_time_pulse2_mae: 0.3005 - val_loss: 1.2984 - val_overshoot_pulse_1_loss: 0.1841 - val_overshoot_pulse_1_mae: 0.2982 - val_overshoot_pulse_2_loss: 0.1278 - val_overshoot_pulse_2_mae: 0.2611 - val_ringing_frequency_MHz_loss: 0.0107 - val_ringing_frequency_MHz_mae: 0.0854 - val_undershoot_pulse_1_loss: 0.0775 - val_undershoot_pulse_1_mae: 0.2152 - val_undershoot_pulse_2_loss: 0.0540 - val_undershoot_pulse_2_mae: 0.1773 - val_voltage_fall_time_pulse1_loss: 0.0183 - val_voltage_fall_time_pulse1_mae: 0.1109 - val_voltage_fall_time_pulse2_loss: 0.0167 - val_voltage_fall_time_pulse2_mae: 0.1054 - val_voltage_rise_time_pulse1_loss: 0.0674 - val_voltage_rise_time_pulse1_mae: 0.1793 - val_voltage_rise_time_pulse2_loss: 0.2758 - val_voltage_rise_time_pulse2_mae: 0.2787 - learning_rate: 5.0000e-04
# Epoch 10/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - current_fall_time_pulse1_loss: 0.1046 - current_fall_time_pulse1_mae: 0.2516 - current_fall_time_pulse2_loss: 0.1051 - current_fall_time_pulse2_mae: 0.2459 - current_rise_time_pulse1_loss: 0.1358 - current_rise_time_pulse1_mae: 0.2723 - current_rise_time_pulse2_loss: 0.1945 - current_rise_time_pulse2_mae: 0.3312 - loss: 1.5899 - overshoot_pulse_1_loss: 0.2198 - overshoot_pulse_1_mae: 0.3563 - overshoot_pulse_2_loss: 0.1467 - overshoot_pulse_2_mae: 0.3002 - ringing_frequency_MHz_loss: 0.0152 - ringing_frequency_MHz_mae: 0.0962 - undershoot_pulse_1_loss: 0.1484 - undershoot_pulse_1_mae: 0.2900 - undershoot_pulse_2_loss: 0.1042 - undershoot_pulse_2_mae: 0.2427 - voltage_fall_time_pulse1_loss: 0.0453 - voltage_fall_time_pulse1_mae: 0.1577 - voltage_fall_time_pulse2_loss: 0.0459 - voltage_fall_time_pulse2_mae: 0.1596 - voltage_rise_time_pulse1_loss: 0.1061 - voltage_rise_time_pulse1_mae: 0.2368 - voltage_rise_time_pulse2_loss: 0.2055 - voltage_rise_time_pulse2_mae: 0.2921 - val_current_fall_time_pulse1_loss: 0.0694 - val_current_fall_time_pulse1_mae: 0.1825 - val_current_fall_time_pulse2_loss: 0.0506 - val_current_fall_time_pulse2_mae: 0.1619 - val_current_rise_time_pulse1_loss: 0.0903 - val_current_rise_time_pulse1_mae: 0.2139 - val_current_rise_time_pulse2_loss: 0.1568 - val_current_rise_time_pulse2_mae: 0.2822 - val_loss: 1.2089 - val_overshoot_pulse_1_loss: 0.1746 - val_overshoot_pulse_1_mae: 0.2880 - val_overshoot_pulse_2_loss: 0.1228 - val_overshoot_pulse_2_mae: 0.2541 - val_ringing_frequency_MHz_loss: 0.0117 - val_ringing_frequency_MHz_mae: 0.0900 - val_undershoot_pulse_1_loss: 0.0672 - val_undershoot_pulse_1_mae: 0.2001 - val_undershoot_pulse_2_loss: 0.0490 - val_undershoot_pulse_2_mae: 0.1674 - val_voltage_fall_time_pulse1_loss: 0.0150 - val_voltage_fall_time_pulse1_mae: 0.1027 - val_voltage_fall_time_pulse2_loss: 0.0134 - val_voltage_fall_time_pulse2_mae: 0.0995 - val_voltage_rise_time_pulse1_loss: 0.0604 - val_voltage_rise_time_pulse1_mae: 0.1727 - val_voltage_rise_time_pulse2_loss: 0.2688 - val_voltage_rise_time_pulse2_mae: 0.2695 - learning_rate: 5.0000e-04
# Epoch 11/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.0983 - current_fall_time_pulse1_mae: 0.2440 - current_fall_time_pulse2_loss: 0.0923 - current_fall_time_pulse2_mae: 0.2359 - current_rise_time_pulse1_loss: 0.1278 - current_rise_time_pulse1_mae: 0.2639 - current_rise_time_pulse2_loss: 0.1892 - current_rise_time_pulse2_mae: 0.3257 - loss: 1.4853 - overshoot_pulse_1_loss: 0.2051 - overshoot_pulse_1_mae: 0.3430 - overshoot_pulse_2_loss: 0.1361 - overshoot_pulse_2_mae: 0.2898 - ringing_frequency_MHz_loss: 0.0137 - ringing_frequency_MHz_mae: 0.0903 - undershoot_pulse_1_loss: 0.1263 - undershoot_pulse_1_mae: 0.2721 - undershoot_pulse_2_loss: 0.0886 - undershoot_pulse_2_mae: 0.2237 - voltage_fall_time_pulse1_loss: 0.0416 - voltage_fall_time_pulse1_mae: 0.1527 - voltage_fall_time_pulse2_loss: 0.0391 - voltage_fall_time_pulse2_mae: 0.1466 - voltage_rise_time_pulse1_loss: 0.1020 - voltage_rise_time_pulse1_mae: 0.2307 - voltage_rise_time_pulse2_loss: 0.2122 - voltage_rise_time_pulse2_mae: 0.2950 - val_current_fall_time_pulse1_loss: 0.0695 - val_current_fall_time_pulse1_mae: 0.1814 - val_current_fall_time_pulse2_loss: 0.0495 - val_current_fall_time_pulse2_mae: 0.1599 - val_current_rise_time_pulse1_loss: 0.0900 - val_current_rise_time_pulse1_mae: 0.2157 - val_current_rise_time_pulse2_loss: 0.1451 - val_current_rise_time_pulse2_mae: 0.2669 - val_loss: 1.1476 - val_overshoot_pulse_1_loss: 0.1530 - val_overshoot_pulse_1_mae: 0.2755 - val_overshoot_pulse_2_loss: 0.1132 - val_overshoot_pulse_2_mae: 0.2447 - val_ringing_frequency_MHz_loss: 0.0103 - val_ringing_frequency_MHz_mae: 0.0838 - val_undershoot_pulse_1_loss: 0.0579 - val_undershoot_pulse_1_mae: 0.1860 - val_undershoot_pulse_2_loss: 0.0446 - val_undershoot_pulse_2_mae: 0.1597 - val_voltage_fall_time_pulse1_loss: 0.0156 - val_voltage_fall_time_pulse1_mae: 0.1012 - val_voltage_fall_time_pulse2_loss: 0.0114 - val_voltage_fall_time_pulse2_mae: 0.0906 - val_voltage_rise_time_pulse1_loss: 0.0706 - val_voltage_rise_time_pulse1_mae: 0.1815 - val_voltage_rise_time_pulse2_loss: 0.2627 - val_voltage_rise_time_pulse2_mae: 0.2589 - learning_rate: 5.0000e-04
# Epoch 12/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - current_fall_time_pulse1_loss: 0.0929 - current_fall_time_pulse1_mae: 0.2363 - current_fall_time_pulse2_loss: 0.0899 - current_fall_time_pulse2_mae: 0.2293 - current_rise_time_pulse1_loss: 0.1239 - current_rise_time_pulse1_mae: 0.2592 - current_rise_time_pulse2_loss: 0.1793 - current_rise_time_pulse2_mae: 0.3169 - loss: 1.4335 - overshoot_pulse_1_loss: 0.1871 - overshoot_pulse_1_mae: 0.3334 - overshoot_pulse_2_loss: 0.1336 - overshoot_pulse_2_mae: 0.2867 - ringing_frequency_MHz_loss: 0.0130 - ringing_frequency_MHz_mae: 0.0874 - undershoot_pulse_1_loss: 0.1290 - undershoot_pulse_1_mae: 0.2704 - undershoot_pulse_2_loss: 0.0855 - undershoot_pulse_2_mae: 0.2203 - voltage_fall_time_pulse1_loss: 0.0400 - voltage_fall_time_pulse1_mae: 0.1488 - voltage_fall_time_pulse2_loss: 0.0387 - voltage_fall_time_pulse2_mae: 0.1471 - voltage_rise_time_pulse1_loss: 0.1000 - voltage_rise_time_pulse1_mae: 0.2291 - voltage_rise_time_pulse2_loss: 0.2079 - voltage_rise_time_pulse2_mae: 0.2894 - val_current_fall_time_pulse1_loss: 0.0703 - val_current_fall_time_pulse1_mae: 0.1805 - val_current_fall_time_pulse2_loss: 0.0451 - val_current_fall_time_pulse2_mae: 0.1513 - val_current_rise_time_pulse1_loss: 0.0908 - val_current_rise_time_pulse1_mae: 0.2161 - val_current_rise_time_pulse2_loss: 0.1476 - val_current_rise_time_pulse2_mae: 0.2666 - val_loss: 1.1402 - val_overshoot_pulse_1_loss: 0.1456 - val_overshoot_pulse_1_mae: 0.2602 - val_overshoot_pulse_2_loss: 0.1141 - val_overshoot_pulse_2_mae: 0.2433 - val_ringing_frequency_MHz_loss: 0.0088 - val_ringing_frequency_MHz_mae: 0.0769 - val_undershoot_pulse_1_loss: 0.0621 - val_undershoot_pulse_1_mae: 0.1951 - val_undershoot_pulse_2_loss: 0.0451 - val_undershoot_pulse_2_mae: 0.1611 - val_voltage_fall_time_pulse1_loss: 0.0166 - val_voltage_fall_time_pulse1_mae: 0.1007 - val_voltage_fall_time_pulse2_loss: 0.0149 - val_voltage_fall_time_pulse2_mae: 0.0991 - val_voltage_rise_time_pulse1_loss: 0.0674 - val_voltage_rise_time_pulse1_mae: 0.1740 - val_voltage_rise_time_pulse2_loss: 0.2640 - val_voltage_rise_time_pulse2_mae: 0.2612 - learning_rate: 5.0000e-04
# Epoch 13/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - current_fall_time_pulse1_loss: 0.0943 - current_fall_time_pulse1_mae: 0.2380 - current_fall_time_pulse2_loss: 0.0804 - current_fall_time_pulse2_mae: 0.2208 - current_rise_time_pulse1_loss: 0.1237 - current_rise_time_pulse1_mae: 0.2577 - current_rise_time_pulse2_loss: 0.1764 - current_rise_time_pulse2_mae: 0.3133 - loss: 1.3983 - overshoot_pulse_1_loss: 0.1890 - overshoot_pulse_1_mae: 0.3307 - overshoot_pulse_2_loss: 0.1240 - overshoot_pulse_2_mae: 0.2784 - ringing_frequency_MHz_loss: 0.0114 - ringing_frequency_MHz_mae: 0.0824 - undershoot_pulse_1_loss: 0.1262 - undershoot_pulse_1_mae: 0.2719 - undershoot_pulse_2_loss: 0.0850 - undershoot_pulse_2_mae: 0.2184 - voltage_fall_time_pulse1_loss: 0.0371 - voltage_fall_time_pulse1_mae: 0.1463 - voltage_fall_time_pulse2_loss: 0.0346 - voltage_fall_time_pulse2_mae: 0.1383 - voltage_rise_time_pulse1_loss: 0.0911 - voltage_rise_time_pulse1_mae: 0.2177 - voltage_rise_time_pulse2_loss: 0.2123 - voltage_rise_time_pulse2_mae: 0.2906 - val_current_fall_time_pulse1_loss: 0.0596 - val_current_fall_time_pulse1_mae: 0.1707 - val_current_fall_time_pulse2_loss: 0.0402 - val_current_fall_time_pulse2_mae: 0.1461 - val_current_rise_time_pulse1_loss: 0.0899 - val_current_rise_time_pulse1_mae: 0.2162 - val_current_rise_time_pulse2_loss: 0.1416 - val_current_rise_time_pulse2_mae: 0.2562 - val_loss: 1.0865 - val_overshoot_pulse_1_loss: 0.1434 - val_overshoot_pulse_1_mae: 0.2582 - val_overshoot_pulse_2_loss: 0.1120 - val_overshoot_pulse_2_mae: 0.2409 - val_ringing_frequency_MHz_loss: 0.0092 - val_ringing_frequency_MHz_mae: 0.0788 - val_undershoot_pulse_1_loss: 0.0510 - val_undershoot_pulse_1_mae: 0.1703 - val_undershoot_pulse_2_loss: 0.0403 - val_undershoot_pulse_2_mae: 0.1501 - val_voltage_fall_time_pulse1_loss: 0.0112 - val_voltage_fall_time_pulse1_mae: 0.0887 - val_voltage_fall_time_pulse2_loss: 0.0105 - val_voltage_fall_time_pulse2_mae: 0.0884 - val_voltage_rise_time_pulse1_loss: 0.0592 - val_voltage_rise_time_pulse1_mae: 0.1718 - val_voltage_rise_time_pulse2_loss: 0.2661 - val_voltage_rise_time_pulse2_mae: 0.2628 - learning_rate: 5.0000e-04
# Epoch 14/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - current_fall_time_pulse1_loss: 0.0874 - current_fall_time_pulse1_mae: 0.2281 - current_fall_time_pulse2_loss: 0.0723 - current_fall_time_pulse2_mae: 0.2077 - current_rise_time_pulse1_loss: 0.1221 - current_rise_time_pulse1_mae: 0.2530 - current_rise_time_pulse2_loss: 0.1731 - current_rise_time_pulse2_mae: 0.3073 - loss: 1.3090 - overshoot_pulse_1_loss: 0.1900 - overshoot_pulse_1_mae: 0.3320 - overshoot_pulse_2_loss: 0.1239 - overshoot_pulse_2_mae: 0.2739 - ringing_frequency_MHz_loss: 0.0106 - ringing_frequency_MHz_mae: 0.0793 - undershoot_pulse_1_loss: 0.1152 - undershoot_pulse_1_mae: 0.2570 - undershoot_pulse_2_loss: 0.0777 - undershoot_pulse_2_mae: 0.2098 - voltage_fall_time_pulse1_loss: 0.0353 - voltage_fall_time_pulse1_mae: 0.1408 - voltage_fall_time_pulse2_loss: 0.0336 - voltage_fall_time_pulse2_mae: 0.1368 - voltage_rise_time_pulse1_loss: 0.0894 - voltage_rise_time_pulse1_mae: 0.2168 - voltage_rise_time_pulse2_loss: 0.1658 - voltage_rise_time_pulse2_mae: 0.2706 - val_current_fall_time_pulse1_loss: 0.0597 - val_current_fall_time_pulse1_mae: 0.1687 - val_current_fall_time_pulse2_loss: 0.0336 - val_current_fall_time_pulse2_mae: 0.1355 - val_current_rise_time_pulse1_loss: 0.0897 - val_current_rise_time_pulse1_mae: 0.2174 - val_current_rise_time_pulse2_loss: 0.1364 - val_current_rise_time_pulse2_mae: 0.2464 - val_loss: 1.0552 - val_overshoot_pulse_1_loss: 0.1412 - val_overshoot_pulse_1_mae: 0.2541 - val_overshoot_pulse_2_loss: 0.1108 - val_overshoot_pulse_2_mae: 0.2395 - val_ringing_frequency_MHz_loss: 0.0087 - val_ringing_frequency_MHz_mae: 0.0773 - val_undershoot_pulse_1_loss: 0.0438 - val_undershoot_pulse_1_mae: 0.1610 - val_undershoot_pulse_2_loss: 0.0358 - val_undershoot_pulse_2_mae: 0.1424 - val_voltage_fall_time_pulse1_loss: 0.0137 - val_voltage_fall_time_pulse1_mae: 0.0948 - val_voltage_fall_time_pulse2_loss: 0.0121 - val_voltage_fall_time_pulse2_mae: 0.0930 - val_voltage_rise_time_pulse1_loss: 0.0599 - val_voltage_rise_time_pulse1_mae: 0.1704 - val_voltage_rise_time_pulse2_loss: 0.2554 - val_voltage_rise_time_pulse2_mae: 0.2539 - learning_rate: 5.0000e-04
# Epoch 15/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.0807 - current_fall_time_pulse1_mae: 0.2215 - current_fall_time_pulse2_loss: 0.0692 - current_fall_time_pulse2_mae: 0.2028 - current_rise_time_pulse1_loss: 0.1215 - current_rise_time_pulse1_mae: 0.2585 - current_rise_time_pulse2_loss: 0.1653 - current_rise_time_pulse2_mae: 0.2994 - loss: 1.3115 - overshoot_pulse_1_loss: 0.1940 - overshoot_pulse_1_mae: 0.3316 - overshoot_pulse_2_loss: 0.1255 - overshoot_pulse_2_mae: 0.2774 - ringing_frequency_MHz_loss: 0.0093 - ringing_frequency_MHz_mae: 0.0742 - undershoot_pulse_1_loss: 0.1116 - undershoot_pulse_1_mae: 0.2522 - undershoot_pulse_2_loss: 0.0786 - undershoot_pulse_2_mae: 0.2061 - voltage_fall_time_pulse1_loss: 0.0325 - voltage_fall_time_pulse1_mae: 0.1354 - voltage_fall_time_pulse2_loss: 0.0317 - voltage_fall_time_pulse2_mae: 0.1324 - voltage_rise_time_pulse1_loss: 0.0834 - voltage_rise_time_pulse1_mae: 0.2070 - voltage_rise_time_pulse2_loss: 0.1956 - voltage_rise_time_pulse2_mae: 0.2823 - val_current_fall_time_pulse1_loss: 0.0508 - val_current_fall_time_pulse1_mae: 0.1554 - val_current_fall_time_pulse2_loss: 0.0308 - val_current_fall_time_pulse2_mae: 0.1292 - val_current_rise_time_pulse1_loss: 0.0914 - val_current_rise_time_pulse1_mae: 0.2201 - val_current_rise_time_pulse2_loss: 0.1363 - val_current_rise_time_pulse2_mae: 0.2472 - val_loss: 1.0521 - val_overshoot_pulse_1_loss: 0.1393 - val_overshoot_pulse_1_mae: 0.2501 - val_overshoot_pulse_2_loss: 0.1136 - val_overshoot_pulse_2_mae: 0.2434 - val_ringing_frequency_MHz_loss: 0.0075 - val_ringing_frequency_MHz_mae: 0.0713 - val_undershoot_pulse_1_loss: 0.0441 - val_undershoot_pulse_1_mae: 0.1600 - val_undershoot_pulse_2_loss: 0.0370 - val_undershoot_pulse_2_mae: 0.1443 - val_voltage_fall_time_pulse1_loss: 0.0146 - val_voltage_fall_time_pulse1_mae: 0.0973 - val_voltage_fall_time_pulse2_loss: 0.0128 - val_voltage_fall_time_pulse2_mae: 0.0971 - val_voltage_rise_time_pulse1_loss: 0.0578 - val_voltage_rise_time_pulse1_mae: 0.1718 - val_voltage_rise_time_pulse2_loss: 0.2618 - val_voltage_rise_time_pulse2_mae: 0.2547 - learning_rate: 5.0000e-04
# Epoch 16/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.0773 - current_fall_time_pulse1_mae: 0.2162 - current_fall_time_pulse2_loss: 0.0695 - current_fall_time_pulse2_mae: 0.2003 - current_rise_time_pulse1_loss: 0.1118 - current_rise_time_pulse1_mae: 0.2433 - current_rise_time_pulse2_loss: 0.1646 - current_rise_time_pulse2_mae: 0.2974 - loss: 1.2286 - overshoot_pulse_1_loss: 0.1790 - overshoot_pulse_1_mae: 0.3195 - overshoot_pulse_2_loss: 0.1167 - overshoot_pulse_2_mae: 0.2680 - ringing_frequency_MHz_loss: 0.0089 - ringing_frequency_MHz_mae: 0.0724 - undershoot_pulse_1_loss: 0.1077 - undershoot_pulse_1_mae: 0.2486 - undershoot_pulse_2_loss: 0.0745 - undershoot_pulse_2_mae: 0.2018 - voltage_fall_time_pulse1_loss: 0.0316 - voltage_fall_time_pulse1_mae: 0.1320 - voltage_fall_time_pulse2_loss: 0.0292 - voltage_fall_time_pulse2_mae: 0.1281 - voltage_rise_time_pulse1_loss: 0.0848 - voltage_rise_time_pulse1_mae: 0.2093 - voltage_rise_time_pulse2_loss: 0.1604 - voltage_rise_time_pulse2_mae: 0.2629 - val_current_fall_time_pulse1_loss: 0.0516 - val_current_fall_time_pulse1_mae: 0.1608 - val_current_fall_time_pulse2_loss: 0.0289 - val_current_fall_time_pulse2_mae: 0.1302 - val_current_rise_time_pulse1_loss: 0.0880 - val_current_rise_time_pulse1_mae: 0.2110 - val_current_rise_time_pulse2_loss: 0.1394 - val_current_rise_time_pulse2_mae: 0.2562 - val_loss: 1.0427 - val_overshoot_pulse_1_loss: 0.1300 - val_overshoot_pulse_1_mae: 0.2453 - val_overshoot_pulse_2_loss: 0.1075 - val_overshoot_pulse_2_mae: 0.2365 - val_ringing_frequency_MHz_loss: 0.0076 - val_ringing_frequency_MHz_mae: 0.0720 - val_undershoot_pulse_1_loss: 0.0514 - val_undershoot_pulse_1_mae: 0.1747 - val_undershoot_pulse_2_loss: 0.0381 - val_undershoot_pulse_2_mae: 0.1469 - val_voltage_fall_time_pulse1_loss: 0.0157 - val_voltage_fall_time_pulse1_mae: 0.1063 - val_voltage_fall_time_pulse2_loss: 0.0154 - val_voltage_fall_time_pulse2_mae: 0.1077 - val_voltage_rise_time_pulse1_loss: 0.0532 - val_voltage_rise_time_pulse1_mae: 0.1651 - val_voltage_rise_time_pulse2_loss: 0.2584 - val_voltage_rise_time_pulse2_mae: 0.2541 - learning_rate: 5.0000e-04
# Epoch 17/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.0727 - current_fall_time_pulse1_mae: 0.2094 - current_fall_time_pulse2_loss: 0.0615 - current_fall_time_pulse2_mae: 0.1888 - current_rise_time_pulse1_loss: 0.1081 - current_rise_time_pulse1_mae: 0.2390 - current_rise_time_pulse2_loss: 0.1561 - current_rise_time_pulse2_mae: 0.2928 - loss: 1.2086 - overshoot_pulse_1_loss: 0.1749 - overshoot_pulse_1_mae: 0.3150 - overshoot_pulse_2_loss: 0.1143 - overshoot_pulse_2_mae: 0.2669 - ringing_frequency_MHz_loss: 0.0084 - ringing_frequency_MHz_mae: 0.0700 - undershoot_pulse_1_loss: 0.1102 - undershoot_pulse_1_mae: 0.2461 - undershoot_pulse_2_loss: 0.0700 - undershoot_pulse_2_mae: 0.1955 - voltage_fall_time_pulse1_loss: 0.0307 - voltage_fall_time_pulse1_mae: 0.1317 - voltage_fall_time_pulse2_loss: 0.0272 - voltage_fall_time_pulse2_mae: 0.1223 - voltage_rise_time_pulse1_loss: 0.0802 - voltage_rise_time_pulse1_mae: 0.2038 - voltage_rise_time_pulse2_loss: 0.1816 - voltage_rise_time_pulse2_mae: 0.2731 - val_current_fall_time_pulse1_loss: 0.0623 - val_current_fall_time_pulse1_mae: 0.1663 - val_current_fall_time_pulse2_loss: 0.0294 - val_current_fall_time_pulse2_mae: 0.1281 - val_current_rise_time_pulse1_loss: 0.0868 - val_current_rise_time_pulse1_mae: 0.2072 - val_current_rise_time_pulse2_loss: 0.1418 - val_current_rise_time_pulse2_mae: 0.2568 - val_loss: 1.0402 - val_overshoot_pulse_1_loss: 0.1237 - val_overshoot_pulse_1_mae: 0.2363 - val_overshoot_pulse_2_loss: 0.1043 - val_overshoot_pulse_2_mae: 0.2310 - val_ringing_frequency_MHz_loss: 0.0067 - val_ringing_frequency_MHz_mae: 0.0674 - val_undershoot_pulse_1_loss: 0.0491 - val_undershoot_pulse_1_mae: 0.1709 - val_undershoot_pulse_2_loss: 0.0377 - val_undershoot_pulse_2_mae: 0.1454 - val_voltage_fall_time_pulse1_loss: 0.0140 - val_voltage_fall_time_pulse1_mae: 0.0961 - val_voltage_fall_time_pulse2_loss: 0.0150 - val_voltage_fall_time_pulse2_mae: 0.1039 - val_voltage_rise_time_pulse1_loss: 0.0645 - val_voltage_rise_time_pulse1_mae: 0.1731 - val_voltage_rise_time_pulse2_loss: 0.2578 - val_voltage_rise_time_pulse2_mae: 0.2567 - learning_rate: 5.0000e-04
# Epoch 18/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.0752 - current_fall_time_pulse1_mae: 0.2141 - current_fall_time_pulse2_loss: 0.0597 - current_fall_time_pulse2_mae: 0.1879 - current_rise_time_pulse1_loss: 0.1041 - current_rise_time_pulse1_mae: 0.2345 - current_rise_time_pulse2_loss: 0.1651 - current_rise_time_pulse2_mae: 0.2950 - loss: 1.1964 - overshoot_pulse_1_loss: 0.1714 - overshoot_pulse_1_mae: 0.3133 - overshoot_pulse_2_loss: 0.1150 - overshoot_pulse_2_mae: 0.2661 - ringing_frequency_MHz_loss: 0.0079 - ringing_frequency_MHz_mae: 0.0677 - undershoot_pulse_1_loss: 0.1071 - undershoot_pulse_1_mae: 0.2457 - undershoot_pulse_2_loss: 0.0690 - undershoot_pulse_2_mae: 0.1944 - voltage_fall_time_pulse1_loss: 0.0296 - voltage_fall_time_pulse1_mae: 0.1272 - voltage_fall_time_pulse2_loss: 0.0263 - voltage_fall_time_pulse2_mae: 0.1207 - voltage_rise_time_pulse1_loss: 0.0770 - voltage_rise_time_pulse1_mae: 0.1976 - voltage_rise_time_pulse2_loss: 0.1764 - voltage_rise_time_pulse2_mae: 0.2711 - val_current_fall_time_pulse1_loss: 0.0752 - val_current_fall_time_pulse1_mae: 0.1821 - val_current_fall_time_pulse2_loss: 0.0328 - val_current_fall_time_pulse2_mae: 0.1319 - val_current_rise_time_pulse1_loss: 0.0869 - val_current_rise_time_pulse1_mae: 0.2110 - val_current_rise_time_pulse2_loss: 0.1357 - val_current_rise_time_pulse2_mae: 0.2409 - val_loss: 1.0319 - val_overshoot_pulse_1_loss: 0.1224 - val_overshoot_pulse_1_mae: 0.2374 - val_overshoot_pulse_2_loss: 0.1042 - val_overshoot_pulse_2_mae: 0.2336 - val_ringing_frequency_MHz_loss: 0.0056 - val_ringing_frequency_MHz_mae: 0.0614 - val_undershoot_pulse_1_loss: 0.0467 - val_undershoot_pulse_1_mae: 0.1712 - val_undershoot_pulse_2_loss: 0.0404 - val_undershoot_pulse_2_mae: 0.1554 - val_voltage_fall_time_pulse1_loss: 0.0168 - val_voltage_fall_time_pulse1_mae: 0.0961 - val_voltage_fall_time_pulse2_loss: 0.0136 - val_voltage_fall_time_pulse2_mae: 0.0971 - val_voltage_rise_time_pulse1_loss: 0.0553 - val_voltage_rise_time_pulse1_mae: 0.1564 - val_voltage_rise_time_pulse2_loss: 0.2528 - val_voltage_rise_time_pulse2_mae: 0.2512 - learning_rate: 5.0000e-04
# Epoch 19/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.0711 - current_fall_time_pulse1_mae: 0.2057 - current_fall_time_pulse2_loss: 0.0545 - current_fall_time_pulse2_mae: 0.1808 - current_rise_time_pulse1_loss: 0.1137 - current_rise_time_pulse1_mae: 0.2415 - current_rise_time_pulse2_loss: 0.1514 - current_rise_time_pulse2_mae: 0.2851 - loss: 1.1604 - overshoot_pulse_1_loss: 0.1560 - overshoot_pulse_1_mae: 0.2979 - overshoot_pulse_2_loss: 0.1124 - overshoot_pulse_2_mae: 0.2621 - ringing_frequency_MHz_loss: 0.0079 - ringing_frequency_MHz_mae: 0.0681 - undershoot_pulse_1_loss: 0.1021 - undershoot_pulse_1_mae: 0.2396 - undershoot_pulse_2_loss: 0.0634 - undershoot_pulse_2_mae: 0.1848 - voltage_fall_time_pulse1_loss: 0.0295 - voltage_fall_time_pulse1_mae: 0.1284 - voltage_fall_time_pulse2_loss: 0.0251 - voltage_fall_time_pulse2_mae: 0.1165 - voltage_rise_time_pulse1_loss: 0.0809 - voltage_rise_time_pulse1_mae: 0.2036 - voltage_rise_time_pulse2_loss: 0.1798 - voltage_rise_time_pulse2_mae: 0.2661 - val_current_fall_time_pulse1_loss: 0.0620 - val_current_fall_time_pulse1_mae: 0.1678 - val_current_fall_time_pulse2_loss: 0.0351 - val_current_fall_time_pulse2_mae: 0.1337 - val_current_rise_time_pulse1_loss: 0.0900 - val_current_rise_time_pulse1_mae: 0.2149 - val_current_rise_time_pulse2_loss: 0.1422 - val_current_rise_time_pulse2_mae: 0.2501 - val_loss: 1.0481 - val_overshoot_pulse_1_loss: 0.1341 - val_overshoot_pulse_1_mae: 0.2420 - val_overshoot_pulse_2_loss: 0.1040 - val_overshoot_pulse_2_mae: 0.2302 - val_ringing_frequency_MHz_loss: 0.0061 - val_ringing_frequency_MHz_mae: 0.0641 - val_undershoot_pulse_1_loss: 0.0419 - val_undershoot_pulse_1_mae: 0.1580 - val_undershoot_pulse_2_loss: 0.0350 - val_undershoot_pulse_2_mae: 0.1402 - val_voltage_fall_time_pulse1_loss: 0.0190 - val_voltage_fall_time_pulse1_mae: 0.1039 - val_voltage_fall_time_pulse2_loss: 0.0165 - val_voltage_fall_time_pulse2_mae: 0.1057 - val_voltage_rise_time_pulse1_loss: 0.0647 - val_voltage_rise_time_pulse1_mae: 0.1682 - val_voltage_rise_time_pulse2_loss: 0.2560 - val_voltage_rise_time_pulse2_mae: 0.2520 - learning_rate: 5.0000e-04
# Epoch 20/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.0682 - current_fall_time_pulse1_mae: 0.2037 - current_fall_time_pulse2_loss: 0.0552 - current_fall_time_pulse2_mae: 0.1809 - current_rise_time_pulse1_loss: 0.1048 - current_rise_time_pulse1_mae: 0.2320 - current_rise_time_pulse2_loss: 0.1554 - current_rise_time_pulse2_mae: 0.2873 - loss: 1.1566 - overshoot_pulse_1_loss: 0.1647 - overshoot_pulse_1_mae: 0.3025 - overshoot_pulse_2_loss: 0.1050 - overshoot_pulse_2_mae: 0.2549 - ringing_frequency_MHz_loss: 0.0076 - ringing_frequency_MHz_mae: 0.0655 - undershoot_pulse_1_loss: 0.0973 - undershoot_pulse_1_mae: 0.2363 - undershoot_pulse_2_loss: 0.0619 - undershoot_pulse_2_mae: 0.1838 - voltage_fall_time_pulse1_loss: 0.0259 - voltage_fall_time_pulse1_mae: 0.1198 - voltage_fall_time_pulse2_loss: 0.0225 - voltage_fall_time_pulse2_mae: 0.1122 - voltage_rise_time_pulse1_loss: 0.0732 - voltage_rise_time_pulse1_mae: 0.1940 - voltage_rise_time_pulse2_loss: 0.2023 - voltage_rise_time_pulse2_mae: 0.2748 - val_current_fall_time_pulse1_loss: 0.0487 - val_current_fall_time_pulse1_mae: 0.1536 - val_current_fall_time_pulse2_loss: 0.0256 - val_current_fall_time_pulse2_mae: 0.1186 - val_current_rise_time_pulse1_loss: 0.0874 - val_current_rise_time_pulse1_mae: 0.2154 - val_current_rise_time_pulse2_loss: 0.1332 - val_current_rise_time_pulse2_mae: 0.2417 - val_loss: 1.0034 - val_overshoot_pulse_1_loss: 0.1276 - val_overshoot_pulse_1_mae: 0.2347 - val_overshoot_pulse_2_loss: 0.1022 - val_overshoot_pulse_2_mae: 0.2315 - val_ringing_frequency_MHz_loss: 0.0071 - val_ringing_frequency_MHz_mae: 0.0697 - val_undershoot_pulse_1_loss: 0.0477 - val_undershoot_pulse_1_mae: 0.1663 - val_undershoot_pulse_2_loss: 0.0355 - val_undershoot_pulse_2_mae: 0.1410 - val_voltage_fall_time_pulse1_loss: 0.0166 - val_voltage_fall_time_pulse1_mae: 0.1056 - val_voltage_fall_time_pulse2_loss: 0.0146 - val_voltage_fall_time_pulse2_mae: 0.1041 - val_voltage_rise_time_pulse1_loss: 0.0531 - val_voltage_rise_time_pulse1_mae: 0.1669 - val_voltage_rise_time_pulse2_loss: 0.2574 - val_voltage_rise_time_pulse2_mae: 0.2533 - learning_rate: 5.0000e-04
# Epoch 21/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - current_fall_time_pulse1_loss: 0.0659 - current_fall_time_pulse1_mae: 0.1989 - current_fall_time_pulse2_loss: 0.0517 - current_fall_time_pulse2_mae: 0.1730 - current_rise_time_pulse1_loss: 0.1028 - current_rise_time_pulse1_mae: 0.2291 - current_rise_time_pulse2_loss: 0.1556 - current_rise_time_pulse2_mae: 0.2831 - loss: 1.1216 - overshoot_pulse_1_loss: 0.1597 - overshoot_pulse_1_mae: 0.2973 - overshoot_pulse_2_loss: 0.1067 - overshoot_pulse_2_mae: 0.2565 - ringing_frequency_MHz_loss: 0.0065 - ringing_frequency_MHz_mae: 0.0607 - undershoot_pulse_1_loss: 0.0959 - undershoot_pulse_1_mae: 0.2308 - undershoot_pulse_2_loss: 0.0601 - undershoot_pulse_2_mae: 0.1819 - voltage_fall_time_pulse1_loss: 0.0258 - voltage_fall_time_pulse1_mae: 0.1185 - voltage_fall_time_pulse2_loss: 0.0217 - voltage_fall_time_pulse2_mae: 0.1101 - voltage_rise_time_pulse1_loss: 0.0749 - voltage_rise_time_pulse1_mae: 0.1918 - voltage_rise_time_pulse2_loss: 0.1814 - voltage_rise_time_pulse2_mae: 0.2629 - val_current_fall_time_pulse1_loss: 0.0554 - val_current_fall_time_pulse1_mae: 0.1624 - val_current_fall_time_pulse2_loss: 0.0248 - val_current_fall_time_pulse2_mae: 0.1187 - val_current_rise_time_pulse1_loss: 0.0878 - val_current_rise_time_pulse1_mae: 0.2134 - val_current_rise_time_pulse2_loss: 0.1282 - val_current_rise_time_pulse2_mae: 0.2365 - val_loss: 0.9960 - val_overshoot_pulse_1_loss: 0.1178 - val_overshoot_pulse_1_mae: 0.2355 - val_overshoot_pulse_2_loss: 0.1024 - val_overshoot_pulse_2_mae: 0.2302 - val_ringing_frequency_MHz_loss: 0.0059 - val_ringing_frequency_MHz_mae: 0.0633 - val_undershoot_pulse_1_loss: 0.0439 - val_undershoot_pulse_1_mae: 0.1574 - val_undershoot_pulse_2_loss: 0.0349 - val_undershoot_pulse_2_mae: 0.1400 - val_voltage_fall_time_pulse1_loss: 0.0216 - val_voltage_fall_time_pulse1_mae: 0.1178 - val_voltage_fall_time_pulse2_loss: 0.0173 - val_voltage_fall_time_pulse2_mae: 0.1125 - val_voltage_rise_time_pulse1_loss: 0.0533 - val_voltage_rise_time_pulse1_mae: 0.1602 - val_voltage_rise_time_pulse2_loss: 0.2593 - val_voltage_rise_time_pulse2_mae: 0.2604 - learning_rate: 5.0000e-04
# Epoch 22/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - current_fall_time_pulse1_loss: 0.0651 - current_fall_time_pulse1_mae: 0.1980 - current_fall_time_pulse2_loss: 0.0483 - current_fall_time_pulse2_mae: 0.1677 - current_rise_time_pulse1_loss: 0.1051 - current_rise_time_pulse1_mae: 0.2310 - current_rise_time_pulse2_loss: 0.1570 - current_rise_time_pulse2_mae: 0.2848 - loss: 1.0988 - overshoot_pulse_1_loss: 0.1534 - overshoot_pulse_1_mae: 0.2986 - overshoot_pulse_2_loss: 0.1085 - overshoot_pulse_2_mae: 0.2572 - ringing_frequency_MHz_loss: 0.0065 - ringing_frequency_MHz_mae: 0.0614 - undershoot_pulse_1_loss: 0.0935 - undershoot_pulse_1_mae: 0.2303 - undershoot_pulse_2_loss: 0.0577 - undershoot_pulse_2_mae: 0.1752 - voltage_fall_time_pulse1_loss: 0.0249 - voltage_fall_time_pulse1_mae: 0.1165 - voltage_fall_time_pulse2_loss: 0.0219 - voltage_fall_time_pulse2_mae: 0.1078 - voltage_rise_time_pulse1_loss: 0.0716 - voltage_rise_time_pulse1_mae: 0.1884 - voltage_rise_time_pulse2_loss: 0.1726 - voltage_rise_time_pulse2_mae: 0.2593 - val_current_fall_time_pulse1_loss: 0.0567 - val_current_fall_time_pulse1_mae: 0.1604 - val_current_fall_time_pulse2_loss: 0.0229 - val_current_fall_time_pulse2_mae: 0.1122 - val_current_rise_time_pulse1_loss: 0.0807 - val_current_rise_time_pulse1_mae: 0.2034 - val_current_rise_time_pulse2_loss: 0.1347 - val_current_rise_time_pulse2_mae: 0.2390 - val_loss: 0.9833 - val_overshoot_pulse_1_loss: 0.1192 - val_overshoot_pulse_1_mae: 0.2305 - val_overshoot_pulse_2_loss: 0.1025 - val_overshoot_pulse_2_mae: 0.2284 - val_ringing_frequency_MHz_loss: 0.0066 - val_ringing_frequency_MHz_mae: 0.0672 - val_undershoot_pulse_1_loss: 0.0477 - val_undershoot_pulse_1_mae: 0.1634 - val_undershoot_pulse_2_loss: 0.0325 - val_undershoot_pulse_2_mae: 0.1345 - val_voltage_fall_time_pulse1_loss: 0.0163 - val_voltage_fall_time_pulse1_mae: 0.1026 - val_voltage_fall_time_pulse2_loss: 0.0179 - val_voltage_fall_time_pulse2_mae: 0.1095 - val_voltage_rise_time_pulse1_loss: 0.0517 - val_voltage_rise_time_pulse1_mae: 0.1593 - val_voltage_rise_time_pulse2_loss: 0.2516 - val_voltage_rise_time_pulse2_mae: 0.2569 - learning_rate: 5.0000e-04
# Epoch 23/120
# ...
# Epoch 42/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - current_fall_time_pulse1_loss: 0.0420 - current_fall_time_pulse1_mae: 0.1564 - current_fall_time_pulse2_loss: 0.0247 - current_fall_time_pulse2_mae: 0.1199 - current_rise_time_pulse1_loss: 0.0881 - current_rise_time_pulse1_mae: 0.2034 - current_rise_time_pulse2_loss: 0.1302 - current_rise_time_pulse2_mae: 0.2361 - loss: 0.8227 - overshoot_pulse_1_loss: 0.1187 - overshoot_pulse_1_mae: 0.2634 - overshoot_pulse_2_loss: 0.0864 - overshoot_pulse_2_mae: 0.2299 - ringing_frequency_MHz_loss: 0.0031 - ringing_frequency_MHz_mae: 0.0413 - undershoot_pulse_1_loss: 0.0718 - undershoot_pulse_1_mae: 0.1988 - undershoot_pulse_2_loss: 0.0373 - undershoot_pulse_2_mae: 0.1411 - voltage_fall_time_pulse1_loss: 0.0155 - voltage_fall_time_pulse1_mae: 0.0910 - voltage_fall_time_pulse2_loss: 0.0102 - voltage_fall_time_pulse2_mae: 0.0735 - voltage_rise_time_pulse1_loss: 0.0472 - voltage_rise_time_pulse1_mae: 0.1524 - voltage_rise_time_pulse2_loss: 0.1351 - voltage_rise_time_pulse2_mae: 0.2309 - val_current_fall_time_pulse1_loss: 0.0597 - val_current_fall_time_pulse1_mae: 0.1608 - val_current_fall_time_pulse2_loss: 0.0222 - val_current_fall_time_pulse2_mae: 0.1086 - val_current_rise_time_pulse1_loss: 0.0871 - val_current_rise_time_pulse1_mae: 0.2154 - val_current_rise_time_pulse2_loss: 0.1238 - val_current_rise_time_pulse2_mae: 0.2205 - val_loss: 0.9498 - val_overshoot_pulse_1_loss: 0.1095 - val_overshoot_pulse_1_mae: 0.2169 - val_overshoot_pulse_2_loss: 0.0961 - val_overshoot_pulse_2_mae: 0.2304 - val_ringing_frequency_MHz_loss: 0.0045 - val_ringing_frequency_MHz_mae: 0.0532 - val_undershoot_pulse_1_loss: 0.0521 - val_undershoot_pulse_1_mae: 0.1706 - val_undershoot_pulse_2_loss: 0.0347 - val_undershoot_pulse_2_mae: 0.1424 - val_voltage_fall_time_pulse1_loss: 0.0281 - val_voltage_fall_time_pulse1_mae: 0.1250 - val_voltage_fall_time_pulse2_loss: 0.0295 - val_voltage_fall_time_pulse2_mae: 0.1317 - val_voltage_rise_time_pulse1_loss: 0.0459 - val_voltage_rise_time_pulse1_mae: 0.1473 - val_voltage_rise_time_pulse2_loss: 0.2247 - val_voltage_rise_time_pulse2_mae: 0.2378 - learning_rate: 1.5000e-04
# Epoch 43/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - current_fall_time_pulse1_loss: 0.0439 - current_fall_time_pulse1_mae: 0.1602 - current_fall_time_pulse2_loss: 0.0251 - current_fall_time_pulse2_mae: 0.1198 - current_rise_time_pulse1_loss: 0.0838 - current_rise_time_pulse1_mae: 0.2022 - current_rise_time_pulse2_loss: 0.1267 - current_rise_time_pulse2_mae: 0.2326 - loss: 0.8002 - overshoot_pulse_1_loss: 0.1135 - overshoot_pulse_1_mae: 0.2556 - overshoot_pulse_2_loss: 0.0881 - overshoot_pulse_2_mae: 0.2322 - ringing_frequency_MHz_loss: 0.0029 - ringing_frequency_MHz_mae: 0.0408 - undershoot_pulse_1_loss: 0.0676 - undershoot_pulse_1_mae: 0.1944 - undershoot_pulse_2_loss: 0.0382 - undershoot_pulse_2_mae: 0.1415 - voltage_fall_time_pulse1_loss: 0.0139 - voltage_fall_time_pulse1_mae: 0.0874 - voltage_fall_time_pulse2_loss: 0.0108 - voltage_fall_time_pulse2_mae: 0.0753 - voltage_rise_time_pulse1_loss: 0.0505 - voltage_rise_time_pulse1_mae: 0.1552 - voltage_rise_time_pulse2_loss: 0.1226 - voltage_rise_time_pulse2_mae: 0.2266 - val_current_fall_time_pulse1_loss: 0.0548 - val_current_fall_time_pulse1_mae: 0.1517 - val_current_fall_time_pulse2_loss: 0.0199 - val_current_fall_time_pulse2_mae: 0.1017 - val_current_rise_time_pulse1_loss: 0.0883 - val_current_rise_time_pulse1_mae: 0.2171 - val_current_rise_time_pulse2_loss: 0.1207 - val_current_rise_time_pulse2_mae: 0.2161 - val_loss: 0.9331 - val_overshoot_pulse_1_loss: 0.1135 - val_overshoot_pulse_1_mae: 0.2173 - val_overshoot_pulse_2_loss: 0.0997 - val_overshoot_pulse_2_mae: 0.2356 - val_ringing_frequency_MHz_loss: 0.0051 - val_ringing_frequency_MHz_mae: 0.0569 - val_undershoot_pulse_1_loss: 0.0453 - val_undershoot_pulse_1_mae: 0.1571 - val_undershoot_pulse_2_loss: 0.0313 - val_undershoot_pulse_2_mae: 0.1322 - val_voltage_fall_time_pulse1_loss: 0.0229 - val_voltage_fall_time_pulse1_mae: 0.1168 - val_voltage_fall_time_pulse2_loss: 0.0293 - val_voltage_fall_time_pulse2_mae: 0.1345 - val_voltage_rise_time_pulse1_loss: 0.0458 - val_voltage_rise_time_pulse1_mae: 0.1510 - val_voltage_rise_time_pulse2_loss: 0.2238 - val_voltage_rise_time_pulse2_mae: 0.2402 - learning_rate: 1.5000e-04
# Epoch 44/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - current_fall_time_pulse1_loss: 0.0422 - current_fall_time_pulse1_mae: 0.1559 - current_fall_time_pulse2_loss: 0.0246 - current_fall_time_pulse2_mae: 0.1198 - current_rise_time_pulse1_loss: 0.0878 - current_rise_time_pulse1_mae: 0.2022 - current_rise_time_pulse2_loss: 0.1244 - current_rise_time_pulse2_mae: 0.2343 - loss: 0.8065 - overshoot_pulse_1_loss: 0.1210 - overshoot_pulse_1_mae: 0.2628 - overshoot_pulse_2_loss: 0.0855 - overshoot_pulse_2_mae: 0.2271 - ringing_frequency_MHz_loss: 0.0029 - ringing_frequency_MHz_mae: 0.0400 - undershoot_pulse_1_loss: 0.0694 - undershoot_pulse_1_mae: 0.1988 - undershoot_pulse_2_loss: 0.0374 - undershoot_pulse_2_mae: 0.1416 - voltage_fall_time_pulse1_loss: 0.0149 - voltage_fall_time_pulse1_mae: 0.0893 - voltage_fall_time_pulse2_loss: 0.0107 - voltage_fall_time_pulse2_mae: 0.0741 - voltage_rise_time_pulse1_loss: 0.0494 - voltage_rise_time_pulse1_mae: 0.1534 - voltage_rise_time_pulse2_loss: 0.1239 - voltage_rise_time_pulse2_mae: 0.2267 - val_current_fall_time_pulse1_loss: 0.0501 - val_current_fall_time_pulse1_mae: 0.1502 - val_current_fall_time_pulse2_loss: 0.0205 - val_current_fall_time_pulse2_mae: 0.1068 - val_current_rise_time_pulse1_loss: 0.0874 - val_current_rise_time_pulse1_mae: 0.2149 - val_current_rise_time_pulse2_loss: 0.1239 - val_current_rise_time_pulse2_mae: 0.2195 - val_loss: 0.9320 - val_overshoot_pulse_1_loss: 0.1131 - val_overshoot_pulse_1_mae: 0.2169 - val_overshoot_pulse_2_loss: 0.0995 - val_overshoot_pulse_2_mae: 0.2350 - val_ringing_frequency_MHz_loss: 0.0040 - val_ringing_frequency_MHz_mae: 0.0502 - val_undershoot_pulse_1_loss: 0.0490 - val_undershoot_pulse_1_mae: 0.1630 - val_undershoot_pulse_2_loss: 0.0328 - val_undershoot_pulse_2_mae: 0.1369 - val_voltage_fall_time_pulse1_loss: 0.0217 - val_voltage_fall_time_pulse1_mae: 0.1133 - val_voltage_fall_time_pulse2_loss: 0.0276 - val_voltage_fall_time_pulse2_mae: 0.1308 - val_voltage_rise_time_pulse1_loss: 0.0448 - val_voltage_rise_time_pulse1_mae: 0.1449 - val_voltage_rise_time_pulse2_loss: 0.2223 - val_voltage_rise_time_pulse2_mae: 0.2414 - learning_rate: 1.5000e-04
# Epoch 45/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - current_fall_time_pulse1_loss: 0.0403 - current_fall_time_pulse1_mae: 0.1527 - current_fall_time_pulse2_loss: 0.0256 - current_fall_time_pulse2_mae: 0.1197 - current_rise_time_pulse1_loss: 0.0827 - current_rise_time_pulse1_mae: 0.1988 - current_rise_time_pulse2_loss: 0.1305 - current_rise_time_pulse2_mae: 0.2354 - loss: 0.7954 - overshoot_pulse_1_loss: 0.1173 - overshoot_pulse_1_mae: 0.2574 - overshoot_pulse_2_loss: 0.0856 - overshoot_pulse_2_mae: 0.2280 - ringing_frequency_MHz_loss: 0.0030 - ringing_frequency_MHz_mae: 0.0410 - undershoot_pulse_1_loss: 0.0643 - undershoot_pulse_1_mae: 0.1904 - undershoot_pulse_2_loss: 0.0371 - undershoot_pulse_2_mae: 0.1406 - voltage_fall_time_pulse1_loss: 0.0145 - voltage_fall_time_pulse1_mae: 0.0879 - voltage_fall_time_pulse2_loss: 0.0098 - voltage_fall_time_pulse2_mae: 0.0714 - voltage_rise_time_pulse1_loss: 0.0459 - voltage_rise_time_pulse1_mae: 0.1482 - voltage_rise_time_pulse2_loss: 0.1263 - voltage_rise_time_pulse2_mae: 0.2306 - val_current_fall_time_pulse1_loss: 0.0626 - val_current_fall_time_pulse1_mae: 0.1626 - val_current_fall_time_pulse2_loss: 0.0245 - val_current_fall_time_pulse2_mae: 0.1141 - val_current_rise_time_pulse1_loss: 0.0869 - val_current_rise_time_pulse1_mae: 0.2150 - val_current_rise_time_pulse2_loss: 0.1225 - val_current_rise_time_pulse2_mae: 0.2201 - val_loss: 0.9590 - val_overshoot_pulse_1_loss: 0.1154 - val_overshoot_pulse_1_mae: 0.2196 - val_overshoot_pulse_2_loss: 0.0992 - val_overshoot_pulse_2_mae: 0.2353 - val_ringing_frequency_MHz_loss: 0.0044 - val_ringing_frequency_MHz_mae: 0.0529 - val_undershoot_pulse_1_loss: 0.0498 - val_undershoot_pulse_1_mae: 0.1655 - val_undershoot_pulse_2_loss: 0.0340 - val_undershoot_pulse_2_mae: 0.1407 - val_voltage_fall_time_pulse1_loss: 0.0284 - val_voltage_fall_time_pulse1_mae: 0.1253 - val_voltage_fall_time_pulse2_loss: 0.0297 - val_voltage_fall_time_pulse2_mae: 0.1328 - val_voltage_rise_time_pulse1_loss: 0.0456 - val_voltage_rise_time_pulse1_mae: 0.1483 - val_voltage_rise_time_pulse2_loss: 0.2274 - val_voltage_rise_time_pulse2_mae: 0.2447 - learning_rate: 1.5000e-04
# Epoch 46/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - current_fall_time_pulse1_loss: 0.0417 - current_fall_time_pulse1_mae: 0.1578 - current_fall_time_pulse2_loss: 0.0247 - current_fall_time_pulse2_mae: 0.1188 - current_rise_time_pulse1_loss: 0.0843 - current_rise_time_pulse1_mae: 0.2018 - current_rise_time_pulse2_loss: 0.1253 - current_rise_time_pulse2_mae: 0.2344 - loss: 0.7896 - overshoot_pulse_1_loss: 0.1128 - overshoot_pulse_1_mae: 0.2540 - overshoot_pulse_2_loss: 0.0851 - overshoot_pulse_2_mae: 0.2279 - ringing_frequency_MHz_loss: 0.0031 - ringing_frequency_MHz_mae: 0.0408 - undershoot_pulse_1_loss: 0.0668 - undershoot_pulse_1_mae: 0.1936 - undershoot_pulse_2_loss: 0.0374 - undershoot_pulse_2_mae: 0.1401 - voltage_fall_time_pulse1_loss: 0.0140 - voltage_fall_time_pulse1_mae: 0.0865 - voltage_fall_time_pulse2_loss: 0.0101 - voltage_fall_time_pulse2_mae: 0.0735 - voltage_rise_time_pulse1_loss: 0.0469 - voltage_rise_time_pulse1_mae: 0.1507 - voltage_rise_time_pulse2_loss: 0.1249 - voltage_rise_time_pulse2_mae: 0.2285 - val_current_fall_time_pulse1_loss: 0.0570 - val_current_fall_time_pulse1_mae: 0.1567 - val_current_fall_time_pulse2_loss: 0.0219 - val_current_fall_time_pulse2_mae: 0.1097 - val_current_rise_time_pulse1_loss: 0.0858 - val_current_rise_time_pulse1_mae: 0.2118 - val_current_rise_time_pulse2_loss: 0.1238 - val_current_rise_time_pulse2_mae: 0.2224 - val_loss: 0.9380 - val_overshoot_pulse_1_loss: 0.1094 - val_overshoot_pulse_1_mae: 0.2144 - val_overshoot_pulse_2_loss: 0.0988 - val_overshoot_pulse_2_mae: 0.2349 - val_ringing_frequency_MHz_loss: 0.0047 - val_ringing_frequency_MHz_mae: 0.0548 - val_undershoot_pulse_1_loss: 0.0448 - val_undershoot_pulse_1_mae: 0.1565 - val_undershoot_pulse_2_loss: 0.0345 - val_undershoot_pulse_2_mae: 0.1415 - val_voltage_fall_time_pulse1_loss: 0.0255 - val_voltage_fall_time_pulse1_mae: 0.1207 - val_voltage_fall_time_pulse2_loss: 0.0307 - val_voltage_fall_time_pulse2_mae: 0.1353 - val_voltage_rise_time_pulse1_loss: 0.0468 - val_voltage_rise_time_pulse1_mae: 0.1485 - val_voltage_rise_time_pulse2_loss: 0.2245 - val_voltage_rise_time_pulse2_mae: 0.2442 - learning_rate: 1.5000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#
# train:
#                        Target        R2          RMSE
# 7   current_fall_time_pulse2  0.983588  1.498985e-09
# 3   voltage_fall_time_pulse2  0.982325  9.098929e-10
# 2   voltage_fall_time_pulse1  0.980108  9.663848e-10
# 11        undershoot_pulse_2  0.971810  2.329953e+00
# 10        undershoot_pulse_1  0.965475  2.573389e+00
# 6   current_fall_time_pulse1  0.961037  2.317901e-09
# 0   voltage_rise_time_pulse1  0.960639  7.994149e-10
# 12     ringing_frequency_MHz  0.934445  8.412369e+00
# 8          overshoot_pulse_1  0.921004  3.236195e+00
# 9          overshoot_pulse_2  0.918215  7.077078e+00
# 4   current_rise_time_pulse1  0.915316  1.420996e-08
# 5   current_rise_time_pulse2  0.880416  8.528745e-09
# 1   voltage_rise_time_pulse2  0.879096  1.335990e-09
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# val:
#                        Target        R2          RMSE
# 7   current_fall_time_pulse2  0.983789  1.515622e-09
# 3   voltage_fall_time_pulse2  0.982621  9.295721e-10
# 2   voltage_fall_time_pulse1  0.979452  1.012572e-09
# 11        undershoot_pulse_2  0.965860  2.525049e+00
# 10        undershoot_pulse_1  0.961164  2.700326e+00
# 6   current_fall_time_pulse1  0.960133  2.382125e-09
# 0   voltage_rise_time_pulse1  0.953100  9.146647e-10
# 12     ringing_frequency_MHz  0.934299  8.674316e+00
# 4   current_rise_time_pulse1  0.915151  1.451903e-08
# 9          overshoot_pulse_2  0.908475  7.864582e+00
# 5   current_rise_time_pulse2  0.897350  8.183103e-09
# 8          overshoot_pulse_1  0.885754  4.231359e+00
# 1   voltage_rise_time_pulse2  0.781291  1.968355e-09
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# test:
#                        Target        R2          RMSE
# 7   current_fall_time_pulse2  0.983620  1.501492e-09
# 3   voltage_fall_time_pulse2  0.982373  9.128722e-10
# 2   voltage_fall_time_pulse1  0.980005  9.734537e-10
# 11        undershoot_pulse_2  0.970944  2.360251e+00
# 10        undershoot_pulse_1  0.964843  2.592829e+00
# 6   current_fall_time_pulse1  0.960900  2.327649e-09
# 0   voltage_rise_time_pulse1  0.959420  8.177413e-10
# 12     ringing_frequency_MHz  0.934422  8.452185e+00
# 9          overshoot_pulse_2  0.916629  7.200715e+00
# 4   current_rise_time_pulse1  0.915293  1.425676e-08
# 8          overshoot_pulse_1  0.914932  3.404093e+00
# 5   current_rise_time_pulse2  0.883147  8.477789e-09
# 1   voltage_rise_time_pulse2  0.862066  1.448569e-09
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# unseen:
#                        Target        R2          RMSE
# 2   voltage_fall_time_pulse1  0.875371  8.216623e-10
# 3   voltage_fall_time_pulse2  0.786670  1.075555e-09
# 6   current_fall_time_pulse1  0.727609  5.860866e-09
# 8          overshoot_pulse_1  0.641765  7.603426e+00
# 9          overshoot_pulse_2  0.577482  1.291390e+01
# 11        undershoot_pulse_2  0.567099  6.266214e+00
# 10        undershoot_pulse_1  0.534943  6.541878e+00
# 7   current_fall_time_pulse2  0.462694  8.175133e-09
# 0   voltage_rise_time_pulse1  0.457260  1.284393e-09
# 1   voltage_rise_time_pulse2  0.061485  4.267736e-09
#                       Target        R2          RMSE
# 2   voltage_fall_time_pulse1  0.875371  8.216623e-10
# 3   voltage_fall_time_pulse2  0.786670  1.075555e-09
# 6   current_fall_time_pulse1  0.727609  5.860866e-09
# 8          overshoot_pulse_1  0.641765  7.603426e+00
# 9          overshoot_pulse_2  0.577482  1.291390e+01
# 11        undershoot_pulse_2  0.567099  6.266214e+00
# 10        undershoot_pulse_1  0.534943  6.541878e+00
# 7   current_fall_time_pulse2  0.462694  8.175133e-09
# 0   voltage_rise_time_pulse1  0.457260  1.284393e-09
# 1   voltage_rise_time_pulse2  0.061485  4.267736e-09

# %%
# ==================== MASKED ANN (All-Best Techniques) ====================
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, regularizers
import matplotlib.pyplot as plt

# ============== SETTINGS ==============
SEED = 42
UNSEEN_PART = 'C2M0040120D'
BASE_DIR = "iteration_masked"
os.makedirs(f"{BASE_DIR}/r2_rmse_tables", exist_ok=True)
os.makedirs(f"{BASE_DIR}/train_val_loss_curves", exist_ok=True)
os.makedirs(f"{BASE_DIR}/models", exist_ok=True)

# ============== LOAD DATA ==============
df = pd.read_csv(
    r"C:\Users\pc\Desktop\Neural_Network_Models\merged_train_5_MOSFETs_25percent_balanced.csv"
)

TARGET_COLUMNS = [
    'voltage_rise_time_pulse1', 'voltage_rise_time_pulse2',
    'voltage_fall_time_pulse1', 'voltage_fall_time_pulse2',
    'current_rise_time_pulse1', 'current_rise_time_pulse2',
    'current_fall_time_pulse1', 'current_fall_time_pulse2',
    'overshoot_pulse_1', 'overshoot_pulse_2',
    'undershoot_pulse_1', 'undershoot_pulse_2',
    'ringing_frequency_MHz'
]
DROP_COLUMNS = ['DeviceID', 'MOSFET', 'Part_Number']

# ============== SPLIT SEEN/UNSEEN DEVICES ==============
seen_parts = [p for p in df['Part_Number'].unique().tolist() if p != UNSEEN_PART]
train_df = df[df['Part_Number'].isin(seen_parts)].copy()
test_df  = df[df['Part_Number'] == UNSEEN_PART].copy()

# ============== PHYSICS FEATURES ==============
def compute_physics_features(row):
    L_eq = row[['Ls4','Ls5','Ls6','Ls7','Ls8','Ls9','Ls10','Ls11']].sum()
    C_eq = row.get("Coss", 1e-12)
    f_res = 1/(2*np.pi*np.sqrt(L_eq*C_eq))/1e6 if L_eq>0 and C_eq>0 else 0
    overshoot_est = row.get("VDS_max",0) - row.get("Vbus",0)
    undershoot_est = - row.get("VGS_th_min",0)
    dVdt_est = row.get("VDS_max",0)/row.get("Tp1",1e-9)
    dIdt_est = row.get("ID_max_25C",0)/row.get("Tp1",1e-9)
    return pd.Series([f_res, overshoot_est, undershoot_est, dVdt_est, dIdt_est])

for df_ in [train_df, test_df]:
    df_[['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est']] = \
        df_.apply(compute_physics_features, axis=1)

physics_features = ['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est']
INPUT_COLUMNS = [c for c in df.columns if c not in TARGET_COLUMNS + DROP_COLUMNS] + physics_features

# ============== SCALE INPUTS ==============
input_scaler = StandardScaler()
input_scaler.fit(pd.concat([train_df[INPUT_COLUMNS], test_df[INPUT_COLUMNS]]))
X_train_all = input_scaler.transform(train_df[INPUT_COLUMNS])
X_test_all  = input_scaler.transform(test_df[INPUT_COLUMNS])

# ============== SCALE OUTPUTS (per target) ==============
output_scalers, y_train_scaled, y_test_scaled = {}, [], []
for col in TARGET_COLUMNS:
    scaler = MinMaxScaler() if col == 'ringing_frequency_MHz' else StandardScaler()
    y_train_scaled.append(scaler.fit_transform(train_df[[col]]).flatten())
    y_test_scaled.append(scaler.transform(test_df[[col]]).flatten())
    output_scalers[col] = scaler
y_train_scaled = np.array(y_train_scaled).T
y_test_scaled  = np.array(y_test_scaled).T

# ============== SPLIT TRAIN/VAL ==============
Xtr, Xval, ytr, yval = train_test_split(
    X_train_all, y_train_scaled, test_size=0.15, random_state=SEED
)

# ============== FEATURE MASKS (toy example: select subsets) ==============
# In practice, you’d compute mutual info or importance scores per target.
# Here we just group physics features + a few indices per target for demonstration.
feature_masks = {
    'voltage_rise_time_pulse1': physics_features[:3],
    'voltage_fall_time_pulse1': physics_features[2:],
    'current_rise_time_pulse1': physics_features[:2],
    'current_fall_time_pulse1': physics_features[1:],
    'overshoot_pulse_1': physics_features,
    'undershoot_pulse_1': physics_features,
    'ringing_frequency_MHz': physics_features
}

# Map feature names to indices
mask_indices = {col: [INPUT_COLUMNS.index(f) for f in feats if f in INPUT_COLUMNS] 
                for col, feats in feature_masks.items()}

# ============== BUILD MASKED ANN ==============
def build_masked_ann(input_dim, output_dim, masks, l2_reg=1e-4, dropout_rate=0.2):
    inp = layers.Input(shape=(input_dim,), name="global_inputs")

    # Shared backbone
    x = layers.Dense(128, kernel_regularizer=regularizers.l2(l2_reg))(inp)
    x = layers.BatchNormalization()(x); x = layers.ReLU()(x)
    x = layers.Dropout(dropout_rate)(x)

    x = layers.Dense(64, kernel_regularizer=regularizers.l2(l2_reg))(x)
    x = layers.BatchNormalization()(x); x = layers.ReLU()(x)
    x = layers.Dropout(dropout_rate)(x)

    outputs = []
    for i, col in enumerate(TARGET_COLUMNS):
        # Mask input branch
        if col in masks and len(masks[col]) > 0:
            masked = layers.Lambda(lambda z, idx=masks[col]: tf.gather(z, idx, axis=1))(inp)
            m = layers.Dense(32, activation="relu")(masked)
        else:
            m = layers.Dense(16, activation="relu")(inp)

        # Combine backbone + masked branch
        h = layers.Concatenate()([x, m])
        h = layers.Dense(64, activation="relu")(h)
        h = layers.Dropout(dropout_rate)(h)
        h = layers.Dense(32, activation="relu")(h)
        out = layers.Dense(1, activation="linear", name=col)(h)
        outputs.append(out)

    model = models.Model(inputs=inp, outputs=outputs)
    return model

model = build_masked_ann(Xtr.shape[1], len(TARGET_COLUMNS), mask_indices)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-4),
    loss=["mse"]*len(TARGET_COLUMNS),
    metrics=["mae"]*len(TARGET_COLUMNS)
)

early_stop = callbacks.EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)
reduce_lr  = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=5)

history = model.fit(
    Xtr, [ytr[:,i] for i in range(len(TARGET_COLUMNS))],
    validation_data=(Xval,[yval[:,i] for i in range(len(TARGET_COLUMNS))]),
    epochs=120, batch_size=256, callbacks=[early_stop, reduce_lr], verbose=1
)

model.save(f"{BASE_DIR}/models/masked_ann.h5")

# ============== LOSS CURVE ==============
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel("Epoch"); plt.ylabel("MSE Loss")
plt.title("Train vs Validation Loss")
plt.legend(); plt.savefig(f"{BASE_DIR}/train_val_loss_curves/loss.png"); plt.close()

# ============== EVALUATION ==============
def evaluate_and_save(X, y_scaled, name, positive_only=False):
    y_pred_scaled_list = model.predict(X)
    results = []
    for i, col in enumerate(TARGET_COLUMNS):
        y_true = output_scalers[col].inverse_transform(y_scaled[:,i].reshape(-1,1)).flatten()
        y_pred = output_scalers[col].inverse_transform(y_pred_scaled_list[i].reshape(-1,1)).flatten()
        r2 = r2_score(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        results.append((col, r2, rmse))
    df_results = pd.DataFrame(results, columns=["Target","R2","RMSE"]).sort_values("R2",ascending=False)
    if positive_only:
        df_results = df_results[df_results["R2"]>0]
    print(f"\n{name}:\n",df_results)
    df_results.to_csv(f"{BASE_DIR}/r2_rmse_tables/{name}.csv", index=False)
    return df_results

evaluate_and_save(Xtr,ytr,"train")
evaluate_and_save(Xval,yval,"val")
evaluate_and_save(X_train_all,y_train_scaled,"test")
evaluate_and_save(X_test_all,y_test_scaled,"unseen",positive_only=True)
# Out:
# Epoch 1/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - current_fall_time_pulse1_loss: 0.3948 - current_fall_time_pulse1_mae: 0.4612 - current_fall_time_pulse2_loss: 0.5277 - current_fall_time_pulse2_mae: 0.5331 - current_rise_time_pulse1_loss: 0.3894 - current_rise_time_pulse1_mae: 0.4510 - current_rise_time_pulse2_loss: 0.4073 - current_rise_time_pulse2_mae: 0.4990 - loss: 5.8541 - overshoot_pulse_1_loss: 0.6063 - overshoot_pulse_1_mae: 0.5823 - overshoot_pulse_2_loss: 0.8693 - overshoot_pulse_2_mae: 0.6510 - ringing_frequency_MHz_loss: 0.1603 - ringing_frequency_MHz_mae: 0.2705 - undershoot_pulse_1_loss: 0.4639 - undershoot_pulse_1_mae: 0.5077 - undershoot_pulse_2_loss: 0.4904 - undershoot_pulse_2_mae: 0.5056 - voltage_fall_time_pulse1_loss: 0.3506 - voltage_fall_time_pulse1_mae: 0.3980 - voltage_fall_time_pulse2_loss: 0.3097 - voltage_fall_time_pulse2_mae: 0.3725 - voltage_rise_time_pulse1_loss: 0.3491 - voltage_rise_time_pulse1_mae: 0.4222 - voltage_rise_time_pulse2_loss: 0.5213 - voltage_rise_time_pulse2_mae: 0.4791 - val_current_fall_time_pulse1_loss: 0.0356 - val_current_fall_time_pulse1_mae: 0.1526 - val_current_fall_time_pulse2_loss: 0.0386 - val_current_fall_time_pulse2_mae: 0.1570 - val_current_rise_time_pulse1_loss: 0.0885 - val_current_rise_time_pulse1_mae: 0.2121 - val_current_rise_time_pulse2_loss: 0.1374 - val_current_rise_time_pulse2_mae: 0.2595 - val_loss: 0.9831 - val_overshoot_pulse_1_loss: 0.1177 - val_overshoot_pulse_1_mae: 0.2527 - val_overshoot_pulse_2_loss: 0.1106 - val_overshoot_pulse_2_mae: 0.2578 - val_ringing_frequency_MHz_loss: 0.0100 - val_ringing_frequency_MHz_mae: 0.0814 - val_undershoot_pulse_1_loss: 0.0819 - val_undershoot_pulse_1_mae: 0.2175 - val_undershoot_pulse_2_loss: 0.0654 - val_undershoot_pulse_2_mae: 0.1971 - val_voltage_fall_time_pulse1_loss: 0.0188 - val_voltage_fall_time_pulse1_mae: 0.1154 - val_voltage_fall_time_pulse2_loss: 0.0188 - val_voltage_fall_time_pulse2_mae: 0.1148 - val_voltage_rise_time_pulse1_loss: 0.0589 - val_voltage_rise_time_pulse1_mae: 0.1658 - val_voltage_rise_time_pulse2_loss: 0.1871 - val_voltage_rise_time_pulse2_mae: 0.2645 - learning_rate: 5.0000e-04
# Epoch 2/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - current_fall_time_pulse1_loss: 0.0803 - current_fall_time_pulse1_mae: 0.2157 - current_fall_time_pulse2_loss: 0.0792 - current_fall_time_pulse2_mae: 0.2167 - current_rise_time_pulse1_loss: 0.1234 - current_rise_time_pulse1_mae: 0.2579 - current_rise_time_pulse2_loss: 0.1778 - current_rise_time_pulse2_mae: 0.3116 - loss: 1.5288 - overshoot_pulse_1_loss: 0.2004 - overshoot_pulse_1_mae: 0.3314 - overshoot_pulse_2_loss: 0.1643 - overshoot_pulse_2_mae: 0.3132 - ringing_frequency_MHz_loss: 0.0126 - ringing_frequency_MHz_mae: 0.0867 - undershoot_pulse_1_loss: 0.1283 - undershoot_pulse_1_mae: 0.2687 - undershoot_pulse_2_loss: 0.1012 - undershoot_pulse_2_mae: 0.2359 - voltage_fall_time_pulse1_loss: 0.0489 - voltage_fall_time_pulse1_mae: 0.1648 - voltage_fall_time_pulse2_loss: 0.0341 - voltage_fall_time_pulse2_mae: 0.1383 - voltage_rise_time_pulse1_loss: 0.0898 - voltage_rise_time_pulse1_mae: 0.2208 - voltage_rise_time_pulse2_loss: 0.2755 - voltage_rise_time_pulse2_mae: 0.3092 - val_current_fall_time_pulse1_loss: 0.0229 - val_current_fall_time_pulse1_mae: 0.1222 - val_current_fall_time_pulse2_loss: 0.0245 - val_current_fall_time_pulse2_mae: 0.1240 - val_current_rise_time_pulse1_loss: 0.0813 - val_current_rise_time_pulse1_mae: 0.1965 - val_current_rise_time_pulse2_loss: 0.1291 - val_current_rise_time_pulse2_mae: 0.2524 - val_loss: 0.8162 - val_overshoot_pulse_1_loss: 0.0797 - val_overshoot_pulse_1_mae: 0.2113 - val_overshoot_pulse_2_loss: 0.0939 - val_overshoot_pulse_2_mae: 0.2344 - val_ringing_frequency_MHz_loss: 0.0059 - val_ringing_frequency_MHz_mae: 0.0626 - val_undershoot_pulse_1_loss: 0.0579 - val_undershoot_pulse_1_mae: 0.1798 - val_undershoot_pulse_2_loss: 0.0454 - val_undershoot_pulse_2_mae: 0.1588 - val_voltage_fall_time_pulse1_loss: 0.0176 - val_voltage_fall_time_pulse1_mae: 0.1109 - val_voltage_fall_time_pulse2_loss: 0.0236 - val_voltage_fall_time_pulse2_mae: 0.1309 - val_voltage_rise_time_pulse1_loss: 0.0514 - val_voltage_rise_time_pulse1_mae: 0.1593 - val_voltage_rise_time_pulse2_loss: 0.1693 - val_voltage_rise_time_pulse2_mae: 0.2552 - learning_rate: 5.0000e-04
# Epoch 3/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - current_fall_time_pulse1_loss: 0.0578 - current_fall_time_pulse1_mae: 0.1835 - current_fall_time_pulse2_loss: 0.0459 - current_fall_time_pulse2_mae: 0.1646 - current_rise_time_pulse1_loss: 0.1062 - current_rise_time_pulse1_mae: 0.2335 - current_rise_time_pulse2_loss: 0.1466 - current_rise_time_pulse2_mae: 0.2707 - loss: 1.1636 - overshoot_pulse_1_loss: 0.1599 - overshoot_pulse_1_mae: 0.2953 - overshoot_pulse_2_loss: 0.1286 - overshoot_pulse_2_mae: 0.2779 - ringing_frequency_MHz_loss: 0.0062 - ringing_frequency_MHz_mae: 0.0602 - undershoot_pulse_1_loss: 0.0969 - undershoot_pulse_1_mae: 0.2304 - undershoot_pulse_2_loss: 0.0689 - undershoot_pulse_2_mae: 0.1915 - voltage_fall_time_pulse1_loss: 0.0307 - voltage_fall_time_pulse1_mae: 0.1286 - voltage_fall_time_pulse2_loss: 0.0197 - voltage_fall_time_pulse2_mae: 0.1041 - voltage_rise_time_pulse1_loss: 0.0674 - voltage_rise_time_pulse1_mae: 0.1864 - voltage_rise_time_pulse2_loss: 0.2162 - voltage_rise_time_pulse2_mae: 0.2751 - val_current_fall_time_pulse1_loss: 0.0218 - val_current_fall_time_pulse1_mae: 0.1168 - val_current_fall_time_pulse2_loss: 0.0262 - val_current_fall_time_pulse2_mae: 0.1245 - val_current_rise_time_pulse1_loss: 0.0842 - val_current_rise_time_pulse1_mae: 0.2029 - val_current_rise_time_pulse2_loss: 0.1222 - val_current_rise_time_pulse2_mae: 0.2303 - val_loss: 0.7799 - val_overshoot_pulse_1_loss: 0.0733 - val_overshoot_pulse_1_mae: 0.1989 - val_overshoot_pulse_2_loss: 0.0879 - val_overshoot_pulse_2_mae: 0.2265 - val_ringing_frequency_MHz_loss: 0.0038 - val_ringing_frequency_MHz_mae: 0.0491 - val_undershoot_pulse_1_loss: 0.0592 - val_undershoot_pulse_1_mae: 0.1831 - val_undershoot_pulse_2_loss: 0.0435 - val_undershoot_pulse_2_mae: 0.1545 - val_voltage_fall_time_pulse1_loss: 0.0216 - val_voltage_fall_time_pulse1_mae: 0.1178 - val_voltage_fall_time_pulse2_loss: 0.0243 - val_voltage_fall_time_pulse2_mae: 0.1312 - val_voltage_rise_time_pulse1_loss: 0.0549 - val_voltage_rise_time_pulse1_mae: 0.1597 - val_voltage_rise_time_pulse2_loss: 0.1435 - val_voltage_rise_time_pulse2_mae: 0.2374 - learning_rate: 5.0000e-04
# Epoch 4/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - current_fall_time_pulse1_loss: 0.0462 - current_fall_time_pulse1_mae: 0.1638 - current_fall_time_pulse2_loss: 0.0306 - current_fall_time_pulse2_mae: 0.1336 - current_rise_time_pulse1_loss: 0.0967 - current_rise_time_pulse1_mae: 0.2190 - current_rise_time_pulse2_loss: 0.1301 - current_rise_time_pulse2_mae: 0.2458 - loss: 0.9902 - overshoot_pulse_1_loss: 0.1379 - overshoot_pulse_1_mae: 0.2754 - overshoot_pulse_2_loss: 0.1116 - overshoot_pulse_2_mae: 0.2572 - ringing_frequency_MHz_loss: 0.0040 - ringing_frequency_MHz_mae: 0.0479 - undershoot_pulse_1_loss: 0.0816 - undershoot_pulse_1_mae: 0.2104 - undershoot_pulse_2_loss: 0.0530 - undershoot_pulse_2_mae: 0.1649 - voltage_fall_time_pulse1_loss: 0.0229 - voltage_fall_time_pulse1_mae: 0.1109 - voltage_fall_time_pulse2_loss: 0.0134 - voltage_fall_time_pulse2_mae: 0.0851 - voltage_rise_time_pulse1_loss: 0.0554 - voltage_rise_time_pulse1_mae: 0.1656 - voltage_rise_time_pulse2_loss: 0.1942 - voltage_rise_time_pulse2_mae: 0.2535 - val_current_fall_time_pulse1_loss: 0.0228 - val_current_fall_time_pulse1_mae: 0.1201 - val_current_fall_time_pulse2_loss: 0.0242 - val_current_fall_time_pulse2_mae: 0.1252 - val_current_rise_time_pulse1_loss: 0.0896 - val_current_rise_time_pulse1_mae: 0.2138 - val_current_rise_time_pulse2_loss: 0.1278 - val_current_rise_time_pulse2_mae: 0.2435 - val_loss: 0.7849 - val_overshoot_pulse_1_loss: 0.0729 - val_overshoot_pulse_1_mae: 0.2012 - val_overshoot_pulse_2_loss: 0.0834 - val_overshoot_pulse_2_mae: 0.2217 - val_ringing_frequency_MHz_loss: 0.0041 - val_ringing_frequency_MHz_mae: 0.0506 - val_undershoot_pulse_1_loss: 0.0641 - val_undershoot_pulse_1_mae: 0.1889 - val_undershoot_pulse_2_loss: 0.0451 - val_undershoot_pulse_2_mae: 0.1559 - val_voltage_fall_time_pulse1_loss: 0.0229 - val_voltage_fall_time_pulse1_mae: 0.1248 - val_voltage_fall_time_pulse2_loss: 0.0323 - val_voltage_fall_time_pulse2_mae: 0.1476 - val_voltage_rise_time_pulse1_loss: 0.0488 - val_voltage_rise_time_pulse1_mae: 0.1589 - val_voltage_rise_time_pulse2_loss: 0.1335 - val_voltage_rise_time_pulse2_mae: 0.2425 - learning_rate: 5.0000e-04
# Epoch 5/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - current_fall_time_pulse1_loss: 0.0402 - current_fall_time_pulse1_mae: 0.1529 - current_fall_time_pulse2_loss: 0.0227 - current_fall_time_pulse2_mae: 0.1154 - current_rise_time_pulse1_loss: 0.0919 - current_rise_time_pulse1_mae: 0.2104 - current_rise_time_pulse2_loss: 0.1231 - current_rise_time_pulse2_mae: 0.2315 - loss: 0.8733 - overshoot_pulse_1_loss: 0.1207 - overshoot_pulse_1_mae: 0.2584 - overshoot_pulse_2_loss: 0.0995 - overshoot_pulse_2_mae: 0.2441 - ringing_frequency_MHz_loss: 0.0029 - ringing_frequency_MHz_mae: 0.0405 - undershoot_pulse_1_loss: 0.0752 - undershoot_pulse_1_mae: 0.1998 - undershoot_pulse_2_loss: 0.0452 - undershoot_pulse_2_mae: 0.1506 - voltage_fall_time_pulse1_loss: 0.0191 - voltage_fall_time_pulse1_mae: 0.1007 - voltage_fall_time_pulse2_loss: 0.0104 - voltage_fall_time_pulse2_mae: 0.0739 - voltage_rise_time_pulse1_loss: 0.0496 - voltage_rise_time_pulse1_mae: 0.1543 - voltage_rise_time_pulse2_loss: 0.1602 - voltage_rise_time_pulse2_mae: 0.2382 - val_current_fall_time_pulse1_loss: 0.0190 - val_current_fall_time_pulse1_mae: 0.1072 - val_current_fall_time_pulse2_loss: 0.0208 - val_current_fall_time_pulse2_mae: 0.1167 - val_current_rise_time_pulse1_loss: 0.0928 - val_current_rise_time_pulse1_mae: 0.2184 - val_current_rise_time_pulse2_loss: 0.1144 - val_current_rise_time_pulse2_mae: 0.2176 - val_loss: 0.7331 - val_overshoot_pulse_1_loss: 0.0681 - val_overshoot_pulse_1_mae: 0.1962 - val_overshoot_pulse_2_loss: 0.0838 - val_overshoot_pulse_2_mae: 0.2216 - val_ringing_frequency_MHz_loss: 0.0030 - val_ringing_frequency_MHz_mae: 0.0427 - val_undershoot_pulse_1_loss: 0.0538 - val_undershoot_pulse_1_mae: 0.1722 - val_undershoot_pulse_2_loss: 0.0428 - val_undershoot_pulse_2_mae: 0.1508 - val_voltage_fall_time_pulse1_loss: 0.0208 - val_voltage_fall_time_pulse1_mae: 0.1152 - val_voltage_fall_time_pulse2_loss: 0.0346 - val_voltage_fall_time_pulse2_mae: 0.1495 - val_voltage_rise_time_pulse1_loss: 0.0459 - val_voltage_rise_time_pulse1_mae: 0.1538 - val_voltage_rise_time_pulse2_loss: 0.1199 - val_voltage_rise_time_pulse2_mae: 0.2233 - learning_rate: 5.0000e-04
# Epoch 6/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - current_fall_time_pulse1_loss: 0.0351 - current_fall_time_pulse1_mae: 0.1430 - current_fall_time_pulse2_loss: 0.0178 - current_fall_time_pulse2_mae: 0.1018 - current_rise_time_pulse1_loss: 0.0887 - current_rise_time_pulse1_mae: 0.2049 - current_rise_time_pulse2_loss: 0.1150 - current_rise_time_pulse2_mae: 0.2187 - loss: 0.8092 - overshoot_pulse_1_loss: 0.1123 - overshoot_pulse_1_mae: 0.2482 - overshoot_pulse_2_loss: 0.0937 - overshoot_pulse_2_mae: 0.2366 - ringing_frequency_MHz_loss: 0.0022 - ringing_frequency_MHz_mae: 0.0349 - undershoot_pulse_1_loss: 0.0688 - undershoot_pulse_1_mae: 0.1909 - undershoot_pulse_2_loss: 0.0409 - undershoot_pulse_2_mae: 0.1412 - voltage_fall_time_pulse1_loss: 0.0162 - voltage_fall_time_pulse1_mae: 0.0922 - voltage_fall_time_pulse2_loss: 0.0084 - voltage_fall_time_pulse2_mae: 0.0652 - voltage_rise_time_pulse1_loss: 0.0437 - voltage_rise_time_pulse1_mae: 0.1421 - voltage_rise_time_pulse2_loss: 0.1539 - voltage_rise_time_pulse2_mae: 0.2281 - val_current_fall_time_pulse1_loss: 0.0341 - val_current_fall_time_pulse1_mae: 0.1344 - val_current_fall_time_pulse2_loss: 0.0240 - val_current_fall_time_pulse2_mae: 0.1220 - val_current_rise_time_pulse1_loss: 0.0895 - val_current_rise_time_pulse1_mae: 0.2150 - val_current_rise_time_pulse2_loss: 0.1136 - val_current_rise_time_pulse2_mae: 0.2167 - val_loss: 0.7478 - val_overshoot_pulse_1_loss: 0.0652 - val_overshoot_pulse_1_mae: 0.1871 - val_overshoot_pulse_2_loss: 0.0844 - val_overshoot_pulse_2_mae: 0.2222 - val_ringing_frequency_MHz_loss: 0.0028 - val_ringing_frequency_MHz_mae: 0.0409 - val_undershoot_pulse_1_loss: 0.0595 - val_undershoot_pulse_1_mae: 0.1831 - val_undershoot_pulse_2_loss: 0.0402 - val_undershoot_pulse_2_mae: 0.1466 - val_voltage_fall_time_pulse1_loss: 0.0238 - val_voltage_fall_time_pulse1_mae: 0.1204 - val_voltage_fall_time_pulse2_loss: 0.0362 - val_voltage_fall_time_pulse2_mae: 0.1496 - val_voltage_rise_time_pulse1_loss: 0.0436 - val_voltage_rise_time_pulse1_mae: 0.1452 - val_voltage_rise_time_pulse2_loss: 0.1179 - val_voltage_rise_time_pulse2_mae: 0.2308 - learning_rate: 5.0000e-04
# Epoch 7/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - current_fall_time_pulse1_loss: 0.0331 - current_fall_time_pulse1_mae: 0.1384 - current_fall_time_pulse2_loss: 0.0147 - current_fall_time_pulse2_mae: 0.0918 - current_rise_time_pulse1_loss: 0.0869 - current_rise_time_pulse1_mae: 0.2014 - current_rise_time_pulse2_loss: 0.1104 - current_rise_time_pulse2_mae: 0.2098 - loss: 0.7497 - overshoot_pulse_1_loss: 0.1038 - overshoot_pulse_1_mae: 0.2402 - overshoot_pulse_2_loss: 0.0871 - overshoot_pulse_2_mae: 0.2287 - ringing_frequency_MHz_loss: 0.0018 - ringing_frequency_MHz_mae: 0.0317 - undershoot_pulse_1_loss: 0.0634 - undershoot_pulse_1_mae: 0.1843 - undershoot_pulse_2_loss: 0.0359 - undershoot_pulse_2_mae: 0.1323 - voltage_fall_time_pulse1_loss: 0.0146 - voltage_fall_time_pulse1_mae: 0.0873 - voltage_fall_time_pulse2_loss: 0.0068 - voltage_fall_time_pulse2_mae: 0.0586 - voltage_rise_time_pulse1_loss: 0.0391 - voltage_rise_time_pulse1_mae: 0.1336 - voltage_rise_time_pulse2_loss: 0.1395 - voltage_rise_time_pulse2_mae: 0.2216 - val_current_fall_time_pulse1_loss: 0.0301 - val_current_fall_time_pulse1_mae: 0.1328 - val_current_fall_time_pulse2_loss: 0.0250 - val_current_fall_time_pulse2_mae: 0.1291 - val_current_rise_time_pulse1_loss: 0.0924 - val_current_rise_time_pulse1_mae: 0.2195 - val_current_rise_time_pulse2_loss: 0.1141 - val_current_rise_time_pulse2_mae: 0.2146 - val_loss: 0.7566 - val_overshoot_pulse_1_loss: 0.0742 - val_overshoot_pulse_1_mae: 0.2010 - val_overshoot_pulse_2_loss: 0.0855 - val_overshoot_pulse_2_mae: 0.2242 - val_ringing_frequency_MHz_loss: 0.0037 - val_ringing_frequency_MHz_mae: 0.0465 - val_undershoot_pulse_1_loss: 0.0696 - val_undershoot_pulse_1_mae: 0.1954 - val_undershoot_pulse_2_loss: 0.0398 - val_undershoot_pulse_2_mae: 0.1456 - val_voltage_fall_time_pulse1_loss: 0.0213 - val_voltage_fall_time_pulse1_mae: 0.1156 - val_voltage_fall_time_pulse2_loss: 0.0316 - val_voltage_fall_time_pulse2_mae: 0.1422 - val_voltage_rise_time_pulse1_loss: 0.0469 - val_voltage_rise_time_pulse1_mae: 0.1509 - val_voltage_rise_time_pulse2_loss: 0.1094 - val_voltage_rise_time_pulse2_mae: 0.2206 - learning_rate: 5.0000e-04
# Epoch 8/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - current_fall_time_pulse1_loss: 0.0301 - current_fall_time_pulse1_mae: 0.1320 - current_fall_time_pulse2_loss: 0.0121 - current_fall_time_pulse2_mae: 0.0836 - current_rise_time_pulse1_loss: 0.0842 - current_rise_time_pulse1_mae: 0.1957 - current_rise_time_pulse2_loss: 0.1082 - current_rise_time_pulse2_mae: 0.2032 - loss: 0.7298 - overshoot_pulse_1_loss: 0.1007 - overshoot_pulse_1_mae: 0.2343 - overshoot_pulse_2_loss: 0.0868 - overshoot_pulse_2_mae: 0.2264 - ringing_frequency_MHz_loss: 0.0015 - ringing_frequency_MHz_mae: 0.0285 - undershoot_pulse_1_loss: 0.0626 - undershoot_pulse_1_mae: 0.1807 - undershoot_pulse_2_loss: 0.0341 - undershoot_pulse_2_mae: 0.1274 - voltage_fall_time_pulse1_loss: 0.0128 - voltage_fall_time_pulse1_mae: 0.0823 - voltage_fall_time_pulse2_loss: 0.0058 - voltage_fall_time_pulse2_mae: 0.0534 - voltage_rise_time_pulse1_loss: 0.0360 - voltage_rise_time_pulse1_mae: 0.1268 - voltage_rise_time_pulse2_loss: 0.1426 - voltage_rise_time_pulse2_mae: 0.2177 - val_current_fall_time_pulse1_loss: 0.0235 - val_current_fall_time_pulse1_mae: 0.1172 - val_current_fall_time_pulse2_loss: 0.0235 - val_current_fall_time_pulse2_mae: 0.1249 - val_current_rise_time_pulse1_loss: 0.0937 - val_current_rise_time_pulse1_mae: 0.2215 - val_current_rise_time_pulse2_loss: 0.1088 - val_current_rise_time_pulse2_mae: 0.2067 - val_loss: 0.7325 - val_overshoot_pulse_1_loss: 0.0612 - val_overshoot_pulse_1_mae: 0.1854 - val_overshoot_pulse_2_loss: 0.0824 - val_overshoot_pulse_2_mae: 0.2229 - val_ringing_frequency_MHz_loss: 0.0043 - val_ringing_frequency_MHz_mae: 0.0492 - val_undershoot_pulse_1_loss: 0.0664 - val_undershoot_pulse_1_mae: 0.1882 - val_undershoot_pulse_2_loss: 0.0335 - val_undershoot_pulse_2_mae: 0.1333 - val_voltage_fall_time_pulse1_loss: 0.0278 - val_voltage_fall_time_pulse1_mae: 0.1310 - val_voltage_fall_time_pulse2_loss: 0.0368 - val_voltage_fall_time_pulse2_mae: 0.1503 - val_voltage_rise_time_pulse1_loss: 0.0518 - val_voltage_rise_time_pulse1_mae: 0.1586 - val_voltage_rise_time_pulse2_loss: 0.1059 - val_voltage_rise_time_pulse2_mae: 0.2202 - learning_rate: 5.0000e-04
# Epoch 9/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - current_fall_time_pulse1_loss: 0.0285 - current_fall_time_pulse1_mae: 0.1287 - current_fall_time_pulse2_loss: 0.0104 - current_fall_time_pulse2_mae: 0.0773 - current_rise_time_pulse1_loss: 0.0817 - current_rise_time_pulse1_mae: 0.1919 - current_rise_time_pulse2_loss: 0.1078 - current_rise_time_pulse2_mae: 0.1994 - loss: 0.6930 - overshoot_pulse_1_loss: 0.0941 - overshoot_pulse_1_mae: 0.2281 - overshoot_pulse_2_loss: 0.0831 - overshoot_pulse_2_mae: 0.2227 - ringing_frequency_MHz_loss: 0.0013 - ringing_frequency_MHz_mae: 0.0262 - undershoot_pulse_1_loss: 0.0590 - undershoot_pulse_1_mae: 0.1758 - undershoot_pulse_2_loss: 0.0315 - undershoot_pulse_2_mae: 0.1219 - voltage_fall_time_pulse1_loss: 0.0117 - voltage_fall_time_pulse1_mae: 0.0782 - voltage_fall_time_pulse2_loss: 0.0050 - voltage_fall_time_pulse2_mae: 0.0491 - voltage_rise_time_pulse1_loss: 0.0339 - voltage_rise_time_pulse1_mae: 0.1218 - voltage_rise_time_pulse2_loss: 0.1325 - voltage_rise_time_pulse2_mae: 0.2111 - val_current_fall_time_pulse1_loss: 0.0296 - val_current_fall_time_pulse1_mae: 0.1342 - val_current_fall_time_pulse2_loss: 0.0226 - val_current_fall_time_pulse2_mae: 0.1225 - val_current_rise_time_pulse1_loss: 0.0917 - val_current_rise_time_pulse1_mae: 0.2177 - val_current_rise_time_pulse2_loss: 0.1106 - val_current_rise_time_pulse2_mae: 0.2110 - val_loss: 0.7343 - val_overshoot_pulse_1_loss: 0.0709 - val_overshoot_pulse_1_mae: 0.2012 - val_overshoot_pulse_2_loss: 0.0822 - val_overshoot_pulse_2_mae: 0.2215 - val_ringing_frequency_MHz_loss: 0.0038 - val_ringing_frequency_MHz_mae: 0.0456 - val_undershoot_pulse_1_loss: 0.0696 - val_undershoot_pulse_1_mae: 0.1940 - val_undershoot_pulse_2_loss: 0.0330 - val_undershoot_pulse_2_mae: 0.1284 - val_voltage_fall_time_pulse1_loss: 0.0275 - val_voltage_fall_time_pulse1_mae: 0.1364 - val_voltage_fall_time_pulse2_loss: 0.0341 - val_voltage_fall_time_pulse2_mae: 0.1483 - val_voltage_rise_time_pulse1_loss: 0.0461 - val_voltage_rise_time_pulse1_mae: 0.1479 - val_voltage_rise_time_pulse2_loss: 0.1000 - val_voltage_rise_time_pulse2_mae: 0.2114 - learning_rate: 5.0000e-04
# Epoch 10/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - current_fall_time_pulse1_loss: 0.0268 - current_fall_time_pulse1_mae: 0.1241 - current_fall_time_pulse2_loss: 0.0091 - current_fall_time_pulse2_mae: 0.0722 - current_rise_time_pulse1_loss: 0.0812 - current_rise_time_pulse1_mae: 0.1896 - current_rise_time_pulse2_loss: 0.1030 - current_rise_time_pulse2_mae: 0.1934 - loss: 0.6570 - overshoot_pulse_1_loss: 0.0887 - overshoot_pulse_1_mae: 0.2217 - overshoot_pulse_2_loss: 0.0799 - overshoot_pulse_2_mae: 0.2190 - ringing_frequency_MHz_loss: 0.0011 - ringing_frequency_MHz_mae: 0.0243 - undershoot_pulse_1_loss: 0.0556 - undershoot_pulse_1_mae: 0.1724 - undershoot_pulse_2_loss: 0.0275 - undershoot_pulse_2_mae: 0.1163 - voltage_fall_time_pulse1_loss: 0.0108 - voltage_fall_time_pulse1_mae: 0.0753 - voltage_fall_time_pulse2_loss: 0.0045 - voltage_fall_time_pulse2_mae: 0.0460 - voltage_rise_time_pulse1_loss: 0.0313 - voltage_rise_time_pulse1_mae: 0.1162 - voltage_rise_time_pulse2_loss: 0.1254 - voltage_rise_time_pulse2_mae: 0.2066 - val_current_fall_time_pulse1_loss: 0.0321 - val_current_fall_time_pulse1_mae: 0.1292 - val_current_fall_time_pulse2_loss: 0.0246 - val_current_fall_time_pulse2_mae: 0.1261 - val_current_rise_time_pulse1_loss: 0.0795 - val_current_rise_time_pulse1_mae: 0.1954 - val_current_rise_time_pulse2_loss: 0.1063 - val_current_rise_time_pulse2_mae: 0.1979 - val_loss: 0.7274 - val_overshoot_pulse_1_loss: 0.0578 - val_overshoot_pulse_1_mae: 0.1824 - val_overshoot_pulse_2_loss: 0.0769 - val_overshoot_pulse_2_mae: 0.2148 - val_ringing_frequency_MHz_loss: 0.0042 - val_ringing_frequency_MHz_mae: 0.0476 - val_undershoot_pulse_1_loss: 0.0742 - val_undershoot_pulse_1_mae: 0.2066 - val_undershoot_pulse_2_loss: 0.0375 - val_undershoot_pulse_2_mae: 0.1436 - val_voltage_fall_time_pulse1_loss: 0.0395 - val_voltage_fall_time_pulse1_mae: 0.1562 - val_voltage_fall_time_pulse2_loss: 0.0338 - val_voltage_fall_time_pulse2_mae: 0.1468 - val_voltage_rise_time_pulse1_loss: 0.0464 - val_voltage_rise_time_pulse1_mae: 0.1507 - val_voltage_rise_time_pulse2_loss: 0.1019 - val_voltage_rise_time_pulse2_mae: 0.2091 - learning_rate: 5.0000e-04
# Epoch 11/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - current_fall_time_pulse1_loss: 0.0254 - current_fall_time_pulse1_mae: 0.1212 - current_fall_time_pulse2_loss: 0.0078 - current_fall_time_pulse2_mae: 0.0664 - current_rise_time_pulse1_loss: 0.0788 - current_rise_time_pulse1_mae: 0.1857 - current_rise_time_pulse2_loss: 0.1018 - current_rise_time_pulse2_mae: 0.1878 - loss: 0.6321 - overshoot_pulse_1_loss: 0.0860 - overshoot_pulse_1_mae: 0.2172 - overshoot_pulse_2_loss: 0.0797 - overshoot_pulse_2_mae: 0.2173 - ringing_frequency_MHz_loss: 9.5607e-04 - ringing_frequency_MHz_mae: 0.0227 - undershoot_pulse_1_loss: 0.0533 - undershoot_pulse_1_mae: 0.1676 - undershoot_pulse_2_loss: 0.0269 - undershoot_pulse_2_mae: 0.1128 - voltage_fall_time_pulse1_loss: 0.0101 - voltage_fall_time_pulse1_mae: 0.0729 - voltage_fall_time_pulse2_loss: 0.0038 - voltage_fall_time_pulse2_mae: 0.0425 - voltage_rise_time_pulse1_loss: 0.0298 - voltage_rise_time_pulse1_mae: 0.1133 - voltage_rise_time_pulse2_loss: 0.1156 - voltage_rise_time_pulse2_mae: 0.2045 - val_current_fall_time_pulse1_loss: 0.0367 - val_current_fall_time_pulse1_mae: 0.1527 - val_current_fall_time_pulse2_loss: 0.0277 - val_current_fall_time_pulse2_mae: 0.1360 - val_current_rise_time_pulse1_loss: 0.0865 - val_current_rise_time_pulse1_mae: 0.2081 - val_current_rise_time_pulse2_loss: 0.1043 - val_current_rise_time_pulse2_mae: 0.1952 - val_loss: 0.7595 - val_overshoot_pulse_1_loss: 0.0597 - val_overshoot_pulse_1_mae: 0.1886 - val_overshoot_pulse_2_loss: 0.0768 - val_overshoot_pulse_2_mae: 0.2137 - val_ringing_frequency_MHz_loss: 0.0044 - val_ringing_frequency_MHz_mae: 0.0485 - val_undershoot_pulse_1_loss: 0.0835 - val_undershoot_pulse_1_mae: 0.2143 - val_undershoot_pulse_2_loss: 0.0383 - val_undershoot_pulse_2_mae: 0.1469 - val_voltage_fall_time_pulse1_loss: 0.0405 - val_voltage_fall_time_pulse1_mae: 0.1582 - val_voltage_fall_time_pulse2_loss: 0.0345 - val_voltage_fall_time_pulse2_mae: 0.1513 - val_voltage_rise_time_pulse1_loss: 0.0447 - val_voltage_rise_time_pulse1_mae: 0.1460 - val_voltage_rise_time_pulse2_loss: 0.1092 - val_voltage_rise_time_pulse2_mae: 0.2246 - learning_rate: 5.0000e-04
# Epoch 12/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - current_fall_time_pulse1_loss: 0.0244 - current_fall_time_pulse1_mae: 0.1179 - current_fall_time_pulse2_loss: 0.0069 - current_fall_time_pulse2_mae: 0.0627 - current_rise_time_pulse1_loss: 0.0787 - current_rise_time_pulse1_mae: 0.1849 - current_rise_time_pulse2_loss: 0.0999 - current_rise_time_pulse2_mae: 0.1848 - loss: 0.6241 - overshoot_pulse_1_loss: 0.0833 - overshoot_pulse_1_mae: 0.2146 - overshoot_pulse_2_loss: 0.0779 - overshoot_pulse_2_mae: 0.2143 - ringing_frequency_MHz_loss: 8.5210e-04 - ringing_frequency_MHz_mae: 0.0214 - undershoot_pulse_1_loss: 0.0512 - undershoot_pulse_1_mae: 0.1645 - undershoot_pulse_2_loss: 0.0255 - undershoot_pulse_2_mae: 0.1100 - voltage_fall_time_pulse1_loss: 0.0096 - voltage_fall_time_pulse1_mae: 0.0711 - voltage_fall_time_pulse2_loss: 0.0034 - voltage_fall_time_pulse2_mae: 0.0403 - voltage_rise_time_pulse1_loss: 0.0288 - voltage_rise_time_pulse1_mae: 0.1102 - voltage_rise_time_pulse2_loss: 0.1215 - voltage_rise_time_pulse2_mae: 0.2031 - val_current_fall_time_pulse1_loss: 0.0334 - val_current_fall_time_pulse1_mae: 0.1412 - val_current_fall_time_pulse2_loss: 0.0287 - val_current_fall_time_pulse2_mae: 0.1383 - val_current_rise_time_pulse1_loss: 0.0876 - val_current_rise_time_pulse1_mae: 0.2104 - val_current_rise_time_pulse2_loss: 0.1132 - val_current_rise_time_pulse2_mae: 0.2103 - val_loss: 0.7384 - val_overshoot_pulse_1_loss: 0.0599 - val_overshoot_pulse_1_mae: 0.1879 - val_overshoot_pulse_2_loss: 0.0794 - val_overshoot_pulse_2_mae: 0.2185 - val_ringing_frequency_MHz_loss: 0.0050 - val_ringing_frequency_MHz_mae: 0.0512 - val_undershoot_pulse_1_loss: 0.0695 - val_undershoot_pulse_1_mae: 0.1938 - val_undershoot_pulse_2_loss: 0.0407 - val_undershoot_pulse_2_mae: 0.1503 - val_voltage_fall_time_pulse1_loss: 0.0315 - val_voltage_fall_time_pulse1_mae: 0.1457 - val_voltage_fall_time_pulse2_loss: 0.0325 - val_voltage_fall_time_pulse2_mae: 0.1464 - val_voltage_rise_time_pulse1_loss: 0.0442 - val_voltage_rise_time_pulse1_mae: 0.1466 - val_voltage_rise_time_pulse2_loss: 0.1003 - val_voltage_rise_time_pulse2_mae: 0.2097 - learning_rate: 5.0000e-04
# Epoch 13/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - current_fall_time_pulse1_loss: 0.0229 - current_fall_time_pulse1_mae: 0.1148 - current_fall_time_pulse2_loss: 0.0060 - current_fall_time_pulse2_mae: 0.0575 - current_rise_time_pulse1_loss: 0.0769 - current_rise_time_pulse1_mae: 0.1817 - current_rise_time_pulse2_loss: 0.0973 - current_rise_time_pulse2_mae: 0.1792 - loss: 0.5876 - overshoot_pulse_1_loss: 0.0790 - overshoot_pulse_1_mae: 0.2085 - overshoot_pulse_2_loss: 0.0758 - overshoot_pulse_2_mae: 0.2123 - ringing_frequency_MHz_loss: 7.6155e-04 - ringing_frequency_MHz_mae: 0.0203 - undershoot_pulse_1_loss: 0.0488 - undershoot_pulse_1_mae: 0.1611 - undershoot_pulse_2_loss: 0.0230 - undershoot_pulse_2_mae: 0.1051 - voltage_fall_time_pulse1_loss: 0.0088 - voltage_fall_time_pulse1_mae: 0.0681 - voltage_fall_time_pulse2_loss: 0.0030 - voltage_fall_time_pulse2_mae: 0.0377 - voltage_rise_time_pulse1_loss: 0.0281 - voltage_rise_time_pulse1_mae: 0.1082 - voltage_rise_time_pulse2_loss: 0.1054 - voltage_rise_time_pulse2_mae: 0.1970 - val_current_fall_time_pulse1_loss: 0.0337 - val_current_fall_time_pulse1_mae: 0.1442 - val_current_fall_time_pulse2_loss: 0.0291 - val_current_fall_time_pulse2_mae: 0.1362 - val_current_rise_time_pulse1_loss: 0.0890 - val_current_rise_time_pulse1_mae: 0.2105 - val_current_rise_time_pulse2_loss: 0.1107 - val_current_rise_time_pulse2_mae: 0.2073 - val_loss: 0.7469 - val_overshoot_pulse_1_loss: 0.0667 - val_overshoot_pulse_1_mae: 0.1969 - val_overshoot_pulse_2_loss: 0.0815 - val_overshoot_pulse_2_mae: 0.2217 - val_ringing_frequency_MHz_loss: 0.0045 - val_ringing_frequency_MHz_mae: 0.0487 - val_undershoot_pulse_1_loss: 0.0680 - val_undershoot_pulse_1_mae: 0.1859 - val_undershoot_pulse_2_loss: 0.0436 - val_undershoot_pulse_2_mae: 0.1568 - val_voltage_fall_time_pulse1_loss: 0.0257 - val_voltage_fall_time_pulse1_mae: 0.1300 - val_voltage_fall_time_pulse2_loss: 0.0360 - val_voltage_fall_time_pulse2_mae: 0.1559 - val_voltage_rise_time_pulse1_loss: 0.0408 - val_voltage_rise_time_pulse1_mae: 0.1395 - val_voltage_rise_time_pulse2_loss: 0.1052 - val_voltage_rise_time_pulse2_mae: 0.2221 - learning_rate: 5.0000e-04
# Epoch 14/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - current_fall_time_pulse1_loss: 0.0218 - current_fall_time_pulse1_mae: 0.1124 - current_fall_time_pulse2_loss: 0.0052 - current_fall_time_pulse2_mae: 0.0539 - current_rise_time_pulse1_loss: 0.0769 - current_rise_time_pulse1_mae: 0.1810 - current_rise_time_pulse2_loss: 0.0955 - current_rise_time_pulse2_mae: 0.1769 - loss: 0.5805 - overshoot_pulse_1_loss: 0.0773 - overshoot_pulse_1_mae: 0.2074 - overshoot_pulse_2_loss: 0.0745 - overshoot_pulse_2_mae: 0.2116 - ringing_frequency_MHz_loss: 7.0550e-04 - ringing_frequency_MHz_mae: 0.0196 - undershoot_pulse_1_loss: 0.0472 - undershoot_pulse_1_mae: 0.1585 - undershoot_pulse_2_loss: 0.0228 - undershoot_pulse_2_mae: 0.1040 - voltage_fall_time_pulse1_loss: 0.0083 - voltage_fall_time_pulse1_mae: 0.0664 - voltage_fall_time_pulse2_loss: 0.0026 - voltage_fall_time_pulse2_mae: 0.0351 - voltage_rise_time_pulse1_loss: 0.0268 - voltage_rise_time_pulse1_mae: 0.1054 - voltage_rise_time_pulse2_loss: 0.1091 - voltage_rise_time_pulse2_mae: 0.1978 - val_current_fall_time_pulse1_loss: 0.0323 - val_current_fall_time_pulse1_mae: 0.1363 - val_current_fall_time_pulse2_loss: 0.0339 - val_current_fall_time_pulse2_mae: 0.1492 - val_current_rise_time_pulse1_loss: 0.0864 - val_current_rise_time_pulse1_mae: 0.2093 - val_current_rise_time_pulse2_loss: 0.1100 - val_current_rise_time_pulse2_mae: 0.2011 - val_loss: 0.7341 - val_overshoot_pulse_1_loss: 0.0585 - val_overshoot_pulse_1_mae: 0.1828 - val_overshoot_pulse_2_loss: 0.0828 - val_overshoot_pulse_2_mae: 0.2266 - val_ringing_frequency_MHz_loss: 0.0045 - val_ringing_frequency_MHz_mae: 0.0484 - val_undershoot_pulse_1_loss: 0.0688 - val_undershoot_pulse_1_mae: 0.1954 - val_undershoot_pulse_2_loss: 0.0399 - val_undershoot_pulse_2_mae: 0.1506 - val_voltage_fall_time_pulse1_loss: 0.0241 - val_voltage_fall_time_pulse1_mae: 0.1286 - val_voltage_fall_time_pulse2_loss: 0.0344 - val_voltage_fall_time_pulse2_mae: 0.1508 - val_voltage_rise_time_pulse1_loss: 0.0394 - val_voltage_rise_time_pulse1_mae: 0.1357 - val_voltage_rise_time_pulse2_loss: 0.1070 - val_voltage_rise_time_pulse2_mae: 0.2264 - learning_rate: 5.0000e-04
# Epoch 15/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - current_fall_time_pulse1_loss: 0.0215 - current_fall_time_pulse1_mae: 0.1117 - current_fall_time_pulse2_loss: 0.0047 - current_fall_time_pulse2_mae: 0.0505 - current_rise_time_pulse1_loss: 0.0763 - current_rise_time_pulse1_mae: 0.1791 - current_rise_time_pulse2_loss: 0.0945 - current_rise_time_pulse2_mae: 0.1743 - loss: 0.5683 - overshoot_pulse_1_loss: 0.0750 - overshoot_pulse_1_mae: 0.2049 - overshoot_pulse_2_loss: 0.0743 - overshoot_pulse_2_mae: 0.2102 - ringing_frequency_MHz_loss: 6.5835e-04 - ringing_frequency_MHz_mae: 0.0188 - undershoot_pulse_1_loss: 0.0457 - undershoot_pulse_1_mae: 0.1559 - undershoot_pulse_2_loss: 0.0210 - undershoot_pulse_2_mae: 0.0997 - voltage_fall_time_pulse1_loss: 0.0080 - voltage_fall_time_pulse1_mae: 0.0652 - voltage_fall_time_pulse2_loss: 0.0022 - voltage_fall_time_pulse2_mae: 0.0328 - voltage_rise_time_pulse1_loss: 0.0258 - voltage_rise_time_pulse1_mae: 0.1031 - voltage_rise_time_pulse2_loss: 0.1068 - voltage_rise_time_pulse2_mae: 0.1948 - val_current_fall_time_pulse1_loss: 0.0346 - val_current_fall_time_pulse1_mae: 0.1444 - val_current_fall_time_pulse2_loss: 0.0299 - val_current_fall_time_pulse2_mae: 0.1404 - val_current_rise_time_pulse1_loss: 0.0840 - val_current_rise_time_pulse1_mae: 0.2042 - val_current_rise_time_pulse2_loss: 0.1041 - val_current_rise_time_pulse2_mae: 0.1903 - val_loss: 0.7262 - val_overshoot_pulse_1_loss: 0.0663 - val_overshoot_pulse_1_mae: 0.1954 - val_overshoot_pulse_2_loss: 0.0848 - val_overshoot_pulse_2_mae: 0.2308 - val_ringing_frequency_MHz_loss: 0.0042 - val_ringing_frequency_MHz_mae: 0.0470 - val_undershoot_pulse_1_loss: 0.0690 - val_undershoot_pulse_1_mae: 0.1942 - val_undershoot_pulse_2_loss: 0.0449 - val_undershoot_pulse_2_mae: 0.1608 - val_voltage_fall_time_pulse1_loss: 0.0201 - val_voltage_fall_time_pulse1_mae: 0.1168 - val_voltage_fall_time_pulse2_loss: 0.0357 - val_voltage_fall_time_pulse2_mae: 0.1534 - val_voltage_rise_time_pulse1_loss: 0.0341 - val_voltage_rise_time_pulse1_mae: 0.1262 - val_voltage_rise_time_pulse2_loss: 0.1025 - val_voltage_rise_time_pulse2_mae: 0.2201 - learning_rate: 5.0000e-04
# Epoch 16/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - current_fall_time_pulse1_loss: 0.0203 - current_fall_time_pulse1_mae: 0.1082 - current_fall_time_pulse2_loss: 0.0042 - current_fall_time_pulse2_mae: 0.0472 - current_rise_time_pulse1_loss: 0.0749 - current_rise_time_pulse1_mae: 0.1765 - current_rise_time_pulse2_loss: 0.0945 - current_rise_time_pulse2_mae: 0.1723 - loss: 0.5578 - overshoot_pulse_1_loss: 0.0725 - overshoot_pulse_1_mae: 0.2013 - overshoot_pulse_2_loss: 0.0720 - overshoot_pulse_2_mae: 0.2081 - ringing_frequency_MHz_loss: 6.1348e-04 - ringing_frequency_MHz_mae: 0.0183 - undershoot_pulse_1_loss: 0.0460 - undershoot_pulse_1_mae: 0.1548 - undershoot_pulse_2_loss: 0.0208 - undershoot_pulse_2_mae: 0.0988 - voltage_fall_time_pulse1_loss: 0.0077 - voltage_fall_time_pulse1_mae: 0.0640 - voltage_fall_time_pulse2_loss: 0.0020 - voltage_fall_time_pulse2_mae: 0.0309 - voltage_rise_time_pulse1_loss: 0.0245 - voltage_rise_time_pulse1_mae: 0.0999 - voltage_rise_time_pulse2_loss: 0.1062 - voltage_rise_time_pulse2_mae: 0.1944 - val_current_fall_time_pulse1_loss: 0.0341 - val_current_fall_time_pulse1_mae: 0.1421 - val_current_fall_time_pulse2_loss: 0.0305 - val_current_fall_time_pulse2_mae: 0.1422 - val_current_rise_time_pulse1_loss: 0.0889 - val_current_rise_time_pulse1_mae: 0.2122 - val_current_rise_time_pulse2_loss: 0.1069 - val_current_rise_time_pulse2_mae: 0.1982 - val_loss: 0.7378 - val_overshoot_pulse_1_loss: 0.0601 - val_overshoot_pulse_1_mae: 0.1901 - val_overshoot_pulse_2_loss: 0.0848 - val_overshoot_pulse_2_mae: 0.2315 - val_ringing_frequency_MHz_loss: 0.0047 - val_ringing_frequency_MHz_mae: 0.0497 - val_undershoot_pulse_1_loss: 0.0763 - val_undershoot_pulse_1_mae: 0.2022 - val_undershoot_pulse_2_loss: 0.0416 - val_undershoot_pulse_2_mae: 0.1554 - val_voltage_fall_time_pulse1_loss: 0.0249 - val_voltage_fall_time_pulse1_mae: 0.1300 - val_voltage_fall_time_pulse2_loss: 0.0329 - val_voltage_fall_time_pulse2_mae: 0.1502 - val_voltage_rise_time_pulse1_loss: 0.0376 - val_voltage_rise_time_pulse1_mae: 0.1351 - val_voltage_rise_time_pulse2_loss: 0.1027 - val_voltage_rise_time_pulse2_mae: 0.2102 - learning_rate: 5.0000e-04
# Epoch 17/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - current_fall_time_pulse1_loss: 0.0195 - current_fall_time_pulse1_mae: 0.1059 - current_fall_time_pulse2_loss: 0.0036 - current_fall_time_pulse2_mae: 0.0439 - current_rise_time_pulse1_loss: 0.0744 - current_rise_time_pulse1_mae: 0.1761 - current_rise_time_pulse2_loss: 0.0939 - current_rise_time_pulse2_mae: 0.1711 - loss: 0.5408 - overshoot_pulse_1_loss: 0.0710 - overshoot_pulse_1_mae: 0.2001 - overshoot_pulse_2_loss: 0.0716 - overshoot_pulse_2_mae: 0.2074 - ringing_frequency_MHz_loss: 5.7585e-04 - ringing_frequency_MHz_mae: 0.0177 - undershoot_pulse_1_loss: 0.0433 - undershoot_pulse_1_mae: 0.1509 - undershoot_pulse_2_loss: 0.0196 - undershoot_pulse_2_mae: 0.0960 - voltage_fall_time_pulse1_loss: 0.0072 - voltage_fall_time_pulse1_mae: 0.0617 - voltage_fall_time_pulse2_loss: 0.0019 - voltage_fall_time_pulse2_mae: 0.0299 - voltage_rise_time_pulse1_loss: 0.0239 - voltage_rise_time_pulse1_mae: 0.0987 - voltage_rise_time_pulse2_loss: 0.0988 - voltage_rise_time_pulse2_mae: 0.1905 - val_current_fall_time_pulse1_loss: 0.0361 - val_current_fall_time_pulse1_mae: 0.1467 - val_current_fall_time_pulse2_loss: 0.0374 - val_current_fall_time_pulse2_mae: 0.1567 - val_current_rise_time_pulse1_loss: 0.0831 - val_current_rise_time_pulse1_mae: 0.2007 - val_current_rise_time_pulse2_loss: 0.1067 - val_current_rise_time_pulse2_mae: 0.1957 - val_loss: 0.7486 - val_overshoot_pulse_1_loss: 0.0679 - val_overshoot_pulse_1_mae: 0.1994 - val_overshoot_pulse_2_loss: 0.0880 - val_overshoot_pulse_2_mae: 0.2359 - val_ringing_frequency_MHz_loss: 0.0048 - val_ringing_frequency_MHz_mae: 0.0502 - val_undershoot_pulse_1_loss: 0.0667 - val_undershoot_pulse_1_mae: 0.1886 - val_undershoot_pulse_2_loss: 0.0417 - val_undershoot_pulse_2_mae: 0.1537 - val_voltage_fall_time_pulse1_loss: 0.0252 - val_voltage_fall_time_pulse1_mae: 0.1255 - val_voltage_fall_time_pulse2_loss: 0.0353 - val_voltage_fall_time_pulse2_mae: 0.1564 - val_voltage_rise_time_pulse1_loss: 0.0441 - val_voltage_rise_time_pulse1_mae: 0.1452 - val_voltage_rise_time_pulse2_loss: 0.0997 - val_voltage_rise_time_pulse2_mae: 0.2156 - learning_rate: 5.0000e-04
# Epoch 18/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - current_fall_time_pulse1_loss: 0.0192 - current_fall_time_pulse1_mae: 0.1048 - current_fall_time_pulse2_loss: 0.0034 - current_fall_time_pulse2_mae: 0.0414 - current_rise_time_pulse1_loss: 0.0730 - current_rise_time_pulse1_mae: 0.1734 - current_rise_time_pulse2_loss: 0.0934 - current_rise_time_pulse2_mae: 0.1683 - loss: 0.5325 - overshoot_pulse_1_loss: 0.0698 - overshoot_pulse_1_mae: 0.1970 - overshoot_pulse_2_loss: 0.0702 - overshoot_pulse_2_mae: 0.2042 - ringing_frequency_MHz_loss: 5.6063e-04 - ringing_frequency_MHz_mae: 0.0174 - undershoot_pulse_1_loss: 0.0439 - undershoot_pulse_1_mae: 0.1515 - undershoot_pulse_2_loss: 0.0192 - undershoot_pulse_2_mae: 0.0946 - voltage_fall_time_pulse1_loss: 0.0071 - voltage_fall_time_pulse1_mae: 0.0610 - voltage_fall_time_pulse2_loss: 0.0016 - voltage_fall_time_pulse2_mae: 0.0277 - voltage_rise_time_pulse1_loss: 0.0238 - voltage_rise_time_pulse1_mae: 0.0975 - voltage_rise_time_pulse2_loss: 0.0962 - voltage_rise_time_pulse2_mae: 0.1897 - val_current_fall_time_pulse1_loss: 0.0433 - val_current_fall_time_pulse1_mae: 0.1553 - val_current_fall_time_pulse2_loss: 0.0324 - val_current_fall_time_pulse2_mae: 0.1452 - val_current_rise_time_pulse1_loss: 0.0869 - val_current_rise_time_pulse1_mae: 0.2065 - val_current_rise_time_pulse2_loss: 0.1008 - val_current_rise_time_pulse2_mae: 0.1874 - val_loss: 0.7584 - val_overshoot_pulse_1_loss: 0.0713 - val_overshoot_pulse_1_mae: 0.2050 - val_overshoot_pulse_2_loss: 0.0848 - val_overshoot_pulse_2_mae: 0.2312 - val_ringing_frequency_MHz_loss: 0.0042 - val_ringing_frequency_MHz_mae: 0.0464 - val_undershoot_pulse_1_loss: 0.0747 - val_undershoot_pulse_1_mae: 0.2061 - val_undershoot_pulse_2_loss: 0.0459 - val_undershoot_pulse_2_mae: 0.1640 - val_voltage_fall_time_pulse1_loss: 0.0347 - val_voltage_fall_time_pulse1_mae: 0.1493 - val_voltage_fall_time_pulse2_loss: 0.0343 - val_voltage_fall_time_pulse2_mae: 0.1516 - val_voltage_rise_time_pulse1_loss: 0.0359 - val_voltage_rise_time_pulse1_mae: 0.1329 - val_voltage_rise_time_pulse2_loss: 0.0976 - val_voltage_rise_time_pulse2_mae: 0.2073 - learning_rate: 5.0000e-04
# Epoch 19/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - current_fall_time_pulse1_loss: 0.0184 - current_fall_time_pulse1_mae: 0.1018 - current_fall_time_pulse2_loss: 0.0029 - current_fall_time_pulse2_mae: 0.0382 - current_rise_time_pulse1_loss: 0.0737 - current_rise_time_pulse1_mae: 0.1730 - current_rise_time_pulse2_loss: 0.0906 - current_rise_time_pulse2_mae: 0.1649 - loss: 0.5253 - overshoot_pulse_1_loss: 0.0691 - overshoot_pulse_1_mae: 0.1958 - overshoot_pulse_2_loss: 0.0704 - overshoot_pulse_2_mae: 0.2040 - ringing_frequency_MHz_loss: 5.3188e-04 - ringing_frequency_MHz_mae: 0.0169 - undershoot_pulse_1_loss: 0.0420 - undershoot_pulse_1_mae: 0.1471 - undershoot_pulse_2_loss: 0.0187 - undershoot_pulse_2_mae: 0.0927 - voltage_fall_time_pulse1_loss: 0.0067 - voltage_fall_time_pulse1_mae: 0.0597 - voltage_fall_time_pulse2_loss: 0.0015 - voltage_fall_time_pulse2_mae: 0.0267 - voltage_rise_time_pulse1_loss: 0.0217 - voltage_rise_time_pulse1_mae: 0.0945 - voltage_rise_time_pulse2_loss: 0.0980 - voltage_rise_time_pulse2_mae: 0.1883 - val_current_fall_time_pulse1_loss: 0.0428 - val_current_fall_time_pulse1_mae: 0.1536 - val_current_fall_time_pulse2_loss: 0.0325 - val_current_fall_time_pulse2_mae: 0.1460 - val_current_rise_time_pulse1_loss: 0.0820 - val_current_rise_time_pulse1_mae: 0.2003 - val_current_rise_time_pulse2_loss: 0.1031 - val_current_rise_time_pulse2_mae: 0.1901 - val_loss: 0.7617 - val_overshoot_pulse_1_loss: 0.0653 - val_overshoot_pulse_1_mae: 0.1935 - val_overshoot_pulse_2_loss: 0.0893 - val_overshoot_pulse_2_mae: 0.2361 - val_ringing_frequency_MHz_loss: 0.0047 - val_ringing_frequency_MHz_mae: 0.0491 - val_undershoot_pulse_1_loss: 0.0746 - val_undershoot_pulse_1_mae: 0.2010 - val_undershoot_pulse_2_loss: 0.0427 - val_undershoot_pulse_2_mae: 0.1566 - val_voltage_fall_time_pulse1_loss: 0.0346 - val_voltage_fall_time_pulse1_mae: 0.1488 - val_voltage_fall_time_pulse2_loss: 0.0347 - val_voltage_fall_time_pulse2_mae: 0.1543 - val_voltage_rise_time_pulse1_loss: 0.0383 - val_voltage_rise_time_pulse1_mae: 0.1392 - val_voltage_rise_time_pulse2_loss: 0.1057 - val_voltage_rise_time_pulse2_mae: 0.2247 - learning_rate: 5.0000e-04
# Epoch 20/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - current_fall_time_pulse1_loss: 0.0175 - current_fall_time_pulse1_mae: 0.1003 - current_fall_time_pulse2_loss: 0.0027 - current_fall_time_pulse2_mae: 0.0368 - current_rise_time_pulse1_loss: 0.0737 - current_rise_time_pulse1_mae: 0.1725 - current_rise_time_pulse2_loss: 0.0911 - current_rise_time_pulse2_mae: 0.1652 - loss: 0.5159 - overshoot_pulse_1_loss: 0.0660 - overshoot_pulse_1_mae: 0.1929 - overshoot_pulse_2_loss: 0.0696 - overshoot_pulse_2_mae: 0.2030 - ringing_frequency_MHz_loss: 5.0887e-04 - ringing_frequency_MHz_mae: 0.0166 - undershoot_pulse_1_loss: 0.0419 - undershoot_pulse_1_mae: 0.1479 - undershoot_pulse_2_loss: 0.0172 - undershoot_pulse_2_mae: 0.0900 - voltage_fall_time_pulse1_loss: 0.0063 - voltage_fall_time_pulse1_mae: 0.0579 - voltage_fall_time_pulse2_loss: 0.0014 - voltage_fall_time_pulse2_mae: 0.0256 - voltage_rise_time_pulse1_loss: 0.0219 - voltage_rise_time_pulse1_mae: 0.0928 - voltage_rise_time_pulse2_loss: 0.0951 - voltage_rise_time_pulse2_mae: 0.1867 - val_current_fall_time_pulse1_loss: 0.0356 - val_current_fall_time_pulse1_mae: 0.1425 - val_current_fall_time_pulse2_loss: 0.0322 - val_current_fall_time_pulse2_mae: 0.1470 - val_current_rise_time_pulse1_loss: 0.0837 - val_current_rise_time_pulse1_mae: 0.2012 - val_current_rise_time_pulse2_loss: 0.1027 - val_current_rise_time_pulse2_mae: 0.1917 - val_loss: 0.7447 - val_overshoot_pulse_1_loss: 0.0679 - val_overshoot_pulse_1_mae: 0.2027 - val_overshoot_pulse_2_loss: 0.0919 - val_overshoot_pulse_2_mae: 0.2423 - val_ringing_frequency_MHz_loss: 0.0056 - val_ringing_frequency_MHz_mae: 0.0537 - val_undershoot_pulse_1_loss: 0.0675 - val_undershoot_pulse_1_mae: 0.1934 - val_undershoot_pulse_2_loss: 0.0402 - val_undershoot_pulse_2_mae: 0.1560 - val_voltage_fall_time_pulse1_loss: 0.0280 - val_voltage_fall_time_pulse1_mae: 0.1366 - val_voltage_fall_time_pulse2_loss: 0.0353 - val_voltage_fall_time_pulse2_mae: 0.1562 - val_voltage_rise_time_pulse1_loss: 0.0357 - val_voltage_rise_time_pulse1_mae: 0.1378 - val_voltage_rise_time_pulse2_loss: 0.1070 - val_voltage_rise_time_pulse2_mae: 0.2219 - learning_rate: 5.0000e-04
# Epoch 21/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - current_fall_time_pulse1_loss: 0.0167 - current_fall_time_pulse1_mae: 0.0972 - current_fall_time_pulse2_loss: 0.0025 - current_fall_time_pulse2_mae: 0.0345 - current_rise_time_pulse1_loss: 0.0713 - current_rise_time_pulse1_mae: 0.1695 - current_rise_time_pulse2_loss: 0.0895 - current_rise_time_pulse2_mae: 0.1616 - loss: 0.5066 - overshoot_pulse_1_loss: 0.0656 - overshoot_pulse_1_mae: 0.1915 - overshoot_pulse_2_loss: 0.0688 - overshoot_pulse_2_mae: 0.2016 - ringing_frequency_MHz_loss: 4.8389e-04 - ringing_frequency_MHz_mae: 0.0161 - undershoot_pulse_1_loss: 0.0399 - undershoot_pulse_1_mae: 0.1438 - undershoot_pulse_2_loss: 0.0168 - undershoot_pulse_2_mae: 0.0884 - voltage_fall_time_pulse1_loss: 0.0061 - voltage_fall_time_pulse1_mae: 0.0562 - voltage_fall_time_pulse2_loss: 0.0012 - voltage_fall_time_pulse2_mae: 0.0236 - voltage_rise_time_pulse1_loss: 0.0214 - voltage_rise_time_pulse1_mae: 0.0911 - voltage_rise_time_pulse2_loss: 0.0955 - voltage_rise_time_pulse2_mae: 0.1840 - val_current_fall_time_pulse1_loss: 0.0375 - val_current_fall_time_pulse1_mae: 0.1455 - val_current_fall_time_pulse2_loss: 0.0337 - val_current_fall_time_pulse2_mae: 0.1509 - val_current_rise_time_pulse1_loss: 0.0812 - val_current_rise_time_pulse1_mae: 0.1973 - val_current_rise_time_pulse2_loss: 0.0986 - val_current_rise_time_pulse2_mae: 0.1831 - val_loss: 0.7380 - val_overshoot_pulse_1_loss: 0.0618 - val_overshoot_pulse_1_mae: 0.1919 - val_overshoot_pulse_2_loss: 0.0845 - val_overshoot_pulse_2_mae: 0.2308 - val_ringing_frequency_MHz_loss: 0.0047 - val_ringing_frequency_MHz_mae: 0.0490 - val_undershoot_pulse_1_loss: 0.0736 - val_undershoot_pulse_1_mae: 0.2020 - val_undershoot_pulse_2_loss: 0.0424 - val_undershoot_pulse_2_mae: 0.1585 - val_voltage_fall_time_pulse1_loss: 0.0318 - val_voltage_fall_time_pulse1_mae: 0.1455 - val_voltage_fall_time_pulse2_loss: 0.0355 - val_voltage_fall_time_pulse2_mae: 0.1562 - val_voltage_rise_time_pulse1_loss: 0.0364 - val_voltage_rise_time_pulse1_mae: 0.1348 - val_voltage_rise_time_pulse2_loss: 0.1050 - val_voltage_rise_time_pulse2_mae: 0.2231 - learning_rate: 1.5000e-04
# Epoch 22/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - current_fall_time_pulse1_loss: 0.0167 - current_fall_time_pulse1_mae: 0.0971 - current_fall_time_pulse2_loss: 0.0023 - current_fall_time_pulse2_mae: 0.0336 - current_rise_time_pulse1_loss: 0.0720 - current_rise_time_pulse1_mae: 0.1696 - current_rise_time_pulse2_loss: 0.0871 - current_rise_time_pulse2_mae: 0.1605 - loss: 0.5022 - overshoot_pulse_1_loss: 0.0658 - overshoot_pulse_1_mae: 0.1917 - overshoot_pulse_2_loss: 0.0684 - overshoot_pulse_2_mae: 0.2015 - ringing_frequency_MHz_loss: 4.7414e-04 - ringing_frequency_MHz_mae: 0.0158 - undershoot_pulse_1_loss: 0.0384 - undershoot_pulse_1_mae: 0.1420 - undershoot_pulse_2_loss: 0.0162 - undershoot_pulse_2_mae: 0.0869 - voltage_fall_time_pulse1_loss: 0.0061 - voltage_fall_time_pulse1_mae: 0.0568 - voltage_fall_time_pulse2_loss: 0.0012 - voltage_fall_time_pulse2_mae: 0.0234 - voltage_rise_time_pulse1_loss: 0.0212 - voltage_rise_time_pulse1_mae: 0.0905 - voltage_rise_time_pulse2_loss: 0.0955 - voltage_rise_time_pulse2_mae: 0.1845 - val_current_fall_time_pulse1_loss: 0.0416 - val_current_fall_time_pulse1_mae: 0.1545 - val_current_fall_time_pulse2_loss: 0.0344 - val_current_fall_time_pulse2_mae: 0.1514 - val_current_rise_time_pulse1_loss: 0.0823 - val_current_rise_time_pulse1_mae: 0.1989 - val_current_rise_time_pulse2_loss: 0.1020 - val_current_rise_time_pulse2_mae: 0.1875 - val_loss: 0.7509 - val_overshoot_pulse_1_loss: 0.0669 - val_overshoot_pulse_1_mae: 0.1986 - val_overshoot_pulse_2_loss: 0.0888 - val_overshoot_pulse_2_mae: 0.2378 - val_ringing_frequency_MHz_loss: 0.0048 - val_ringing_frequency_MHz_mae: 0.0496 - val_undershoot_pulse_1_loss: 0.0685 - val_undershoot_pulse_1_mae: 0.1933 - val_undershoot_pulse_2_loss: 0.0417 - val_undershoot_pulse_2_mae: 0.1572 - val_voltage_fall_time_pulse1_loss: 0.0311 - val_voltage_fall_time_pulse1_mae: 0.1423 - val_voltage_fall_time_pulse2_loss: 0.0354 - val_voltage_fall_time_pulse2_mae: 0.1551 - val_voltage_rise_time_pulse1_loss: 0.0376 - val_voltage_rise_time_pulse1_mae: 0.1379 - val_voltage_rise_time_pulse2_loss: 0.1046 - val_voltage_rise_time_pulse2_mae: 0.2238 - learning_rate: 1.5000e-04
# Epoch 23/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - current_fall_time_pulse1_loss: 0.0162 - current_fall_time_pulse1_mae: 0.0957 - current_fall_time_pulse2_loss: 0.0022 - current_fall_time_pulse2_mae: 0.0327 - current_rise_time_pulse1_loss: 0.0719 - current_rise_time_pulse1_mae: 0.1687 - current_rise_time_pulse2_loss: 0.0897 - current_rise_time_pulse2_mae: 0.1606 - loss: 0.5011 - overshoot_pulse_1_loss: 0.0642 - overshoot_pulse_1_mae: 0.1881 - overshoot_pulse_2_loss: 0.0680 - overshoot_pulse_2_mae: 0.2004 - ringing_frequency_MHz_loss: 4.7492e-04 - ringing_frequency_MHz_mae: 0.0159 - undershoot_pulse_1_loss: 0.0380 - undershoot_pulse_1_mae: 0.1414 - undershoot_pulse_2_loss: 0.0163 - undershoot_pulse_2_mae: 0.0870 - voltage_fall_time_pulse1_loss: 0.0058 - voltage_fall_time_pulse1_mae: 0.0557 - voltage_fall_time_pulse2_loss: 0.0011 - voltage_fall_time_pulse2_mae: 0.0230 - voltage_rise_time_pulse1_loss: 0.0207 - voltage_rise_time_pulse1_mae: 0.0894 - voltage_rise_time_pulse2_loss: 0.0956 - voltage_rise_time_pulse2_mae: 0.1848 - val_current_fall_time_pulse1_loss: 0.0427 - val_current_fall_time_pulse1_mae: 0.1553 - val_current_fall_time_pulse2_loss: 0.0354 - val_current_fall_time_pulse2_mae: 0.1541 - val_current_rise_time_pulse1_loss: 0.0815 - val_current_rise_time_pulse1_mae: 0.1985 - val_current_rise_time_pulse2_loss: 0.1004 - val_current_rise_time_pulse2_mae: 0.1889 - val_loss: 0.7463 - val_overshoot_pulse_1_loss: 0.0623 - val_overshoot_pulse_1_mae: 0.1942 - val_overshoot_pulse_2_loss: 0.0880 - val_overshoot_pulse_2_mae: 0.2378 - val_ringing_frequency_MHz_loss: 0.0047 - val_ringing_frequency_MHz_mae: 0.0488 - val_undershoot_pulse_1_loss: 0.0700 - val_undershoot_pulse_1_mae: 0.1990 - val_undershoot_pulse_2_loss: 0.0431 - val_undershoot_pulse_2_mae: 0.1585 - val_voltage_fall_time_pulse1_loss: 0.0339 - val_voltage_fall_time_pulse1_mae: 0.1495 - val_voltage_fall_time_pulse2_loss: 0.0349 - val_voltage_fall_time_pulse2_mae: 0.1549 - val_voltage_rise_time_pulse1_loss: 0.0359 - val_voltage_rise_time_pulse1_mae: 0.1333 - val_voltage_rise_time_pulse2_loss: 0.1024 - val_voltage_rise_time_pulse2_mae: 0.2210 - learning_rate: 1.5000e-04
# Epoch 24/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - current_fall_time_pulse1_loss: 0.0162 - current_fall_time_pulse1_mae: 0.0959 - current_fall_time_pulse2_loss: 0.0023 - current_fall_time_pulse2_mae: 0.0328 - current_rise_time_pulse1_loss: 0.0725 - current_rise_time_pulse1_mae: 0.1691 - current_rise_time_pulse2_loss: 0.0871 - current_rise_time_pulse2_mae: 0.1589 - loss: 0.4891 - overshoot_pulse_1_loss: 0.0618 - overshoot_pulse_1_mae: 0.1860 - overshoot_pulse_2_loss: 0.0674 - overshoot_pulse_2_mae: 0.2007 - ringing_frequency_MHz_loss: 4.6999e-04 - ringing_frequency_MHz_mae: 0.0158 - undershoot_pulse_1_loss: 0.0379 - undershoot_pulse_1_mae: 0.1407 - undershoot_pulse_2_loss: 0.0159 - undershoot_pulse_2_mae: 0.0860 - voltage_fall_time_pulse1_loss: 0.0057 - voltage_fall_time_pulse1_mae: 0.0552 - voltage_fall_time_pulse2_loss: 0.0011 - voltage_fall_time_pulse2_mae: 0.0228 - voltage_rise_time_pulse1_loss: 0.0208 - voltage_rise_time_pulse1_mae: 0.0893 - voltage_rise_time_pulse2_loss: 0.0894 - voltage_rise_time_pulse2_mae: 0.1828 - val_current_fall_time_pulse1_loss: 0.0364 - val_current_fall_time_pulse1_mae: 0.1427 - val_current_fall_time_pulse2_loss: 0.0351 - val_current_fall_time_pulse2_mae: 0.1532 - val_current_rise_time_pulse1_loss: 0.0846 - val_current_rise_time_pulse1_mae: 0.2031 - val_current_rise_time_pulse2_loss: 0.0999 - val_current_rise_time_pulse2_mae: 0.1863 - val_loss: 0.7481 - val_overshoot_pulse_1_loss: 0.0668 - val_overshoot_pulse_1_mae: 0.1979 - val_overshoot_pulse_2_loss: 0.0897 - val_overshoot_pulse_2_mae: 0.2394 - val_ringing_frequency_MHz_loss: 0.0050 - val_ringing_frequency_MHz_mae: 0.0502 - val_undershoot_pulse_1_loss: 0.0735 - val_undershoot_pulse_1_mae: 0.1998 - val_undershoot_pulse_2_loss: 0.0415 - val_undershoot_pulse_2_mae: 0.1555 - val_voltage_fall_time_pulse1_loss: 0.0322 - val_voltage_fall_time_pulse1_mae: 0.1467 - val_voltage_fall_time_pulse2_loss: 0.0349 - val_voltage_fall_time_pulse2_mae: 0.1547 - val_voltage_rise_time_pulse1_loss: 0.0355 - val_voltage_rise_time_pulse1_mae: 0.1320 - val_voltage_rise_time_pulse2_loss: 0.1020 - val_voltage_rise_time_pulse2_mae: 0.2170 - learning_rate: 1.5000e-04
# Epoch 25/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - current_fall_time_pulse1_loss: 0.0159 - current_fall_time_pulse1_mae: 0.0947 - current_fall_time_pulse2_loss: 0.0022 - current_fall_time_pulse2_mae: 0.0322 - current_rise_time_pulse1_loss: 0.0711 - current_rise_time_pulse1_mae: 0.1673 - current_rise_time_pulse2_loss: 0.0876 - current_rise_time_pulse2_mae: 0.1585 - loss: 0.4911 - overshoot_pulse_1_loss: 0.0624 - overshoot_pulse_1_mae: 0.1876 - overshoot_pulse_2_loss: 0.0676 - overshoot_pulse_2_mae: 0.2002 - ringing_frequency_MHz_loss: 4.5433e-04 - ringing_frequency_MHz_mae: 0.0156 - undershoot_pulse_1_loss: 0.0379 - undershoot_pulse_1_mae: 0.1412 - undershoot_pulse_2_loss: 0.0157 - undershoot_pulse_2_mae: 0.0859 - voltage_fall_time_pulse1_loss: 0.0056 - voltage_fall_time_pulse1_mae: 0.0547 - voltage_fall_time_pulse2_loss: 0.0010 - voltage_fall_time_pulse2_mae: 0.0222 - voltage_rise_time_pulse1_loss: 0.0198 - voltage_rise_time_pulse1_mae: 0.0879 - voltage_rise_time_pulse2_loss: 0.0933 - voltage_rise_time_pulse2_mae: 0.1842 - val_current_fall_time_pulse1_loss: 0.0419 - val_current_fall_time_pulse1_mae: 0.1525 - val_current_fall_time_pulse2_loss: 0.0357 - val_current_fall_time_pulse2_mae: 0.1550 - val_current_rise_time_pulse1_loss: 0.0806 - val_current_rise_time_pulse1_mae: 0.1970 - val_current_rise_time_pulse2_loss: 0.1049 - val_current_rise_time_pulse2_mae: 0.1959 - val_loss: 0.7490 - val_overshoot_pulse_1_loss: 0.0655 - val_overshoot_pulse_1_mae: 0.1967 - val_overshoot_pulse_2_loss: 0.0917 - val_overshoot_pulse_2_mae: 0.2434 - val_ringing_frequency_MHz_loss: 0.0048 - val_ringing_frequency_MHz_mae: 0.0499 - val_undershoot_pulse_1_loss: 0.0663 - val_undershoot_pulse_1_mae: 0.1906 - val_undershoot_pulse_2_loss: 0.0389 - val_undershoot_pulse_2_mae: 0.1523 - val_voltage_fall_time_pulse1_loss: 0.0326 - val_voltage_fall_time_pulse1_mae: 0.1459 - val_voltage_fall_time_pulse2_loss: 0.0354 - val_voltage_fall_time_pulse2_mae: 0.1570 - val_voltage_rise_time_pulse1_loss: 0.0318 - val_voltage_rise_time_pulse1_mae: 0.1266 - val_voltage_rise_time_pulse2_loss: 0.1079 - val_voltage_rise_time_pulse2_mae: 0.2248 - learning_rate: 1.5000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
#
# train:
#                        Target        R2          RMSE
# 2   voltage_fall_time_pulse1  0.979575  9.822972e-10
# 7   current_fall_time_pulse2  0.969697  2.047718e-09
# 0   voltage_rise_time_pulse1  0.965786  7.494035e-10
# 6   current_fall_time_pulse1  0.964496  2.223276e-09
# 3   voltage_fall_time_pulse2  0.963984  1.302844e-09
# 11        undershoot_pulse_2  0.955648  2.887048e+00
# 12     ringing_frequency_MHz  0.946555  7.634188e+00
# 8          overshoot_pulse_1  0.931755  3.195004e+00
# 10        undershoot_pulse_1  0.931231  3.592969e+00
# 9          overshoot_pulse_2  0.915597  7.347573e+00
# 4   current_rise_time_pulse1  0.913262  1.447199e-08
# 1   voltage_rise_time_pulse2  0.898962  1.280028e-09
# 5   current_rise_time_pulse2  0.896829  8.067454e-09
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# val:
#                        Target        R2          RMSE
# 2   voltage_fall_time_pulse1  0.979700  9.745329e-10
# 7   current_fall_time_pulse2  0.969667  2.031485e-09
# 0   voltage_rise_time_pulse1  0.965668  7.480212e-10
# 6   current_fall_time_pulse1  0.964968  2.190839e-09
# 3   voltage_fall_time_pulse2  0.964028  1.295697e-09
# 11        undershoot_pulse_2  0.955383  2.905070e+00
# 12     ringing_frequency_MHz  0.946281  7.609848e+00
# 10        undershoot_pulse_1  0.931550  3.598918e+00
# 8          overshoot_pulse_1  0.930238  3.136843e+00
# 4   current_rise_time_pulse1  0.914286  1.421762e-08
# 9          overshoot_pulse_2  0.913276  7.351979e+00
# 1   voltage_rise_time_pulse2  0.894024  1.287953e-09
# 5   current_rise_time_pulse2  0.893774  8.096691e-09
# 2698/2698 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
#
# test:
#                        Target        R2          RMSE
# 2   voltage_fall_time_pulse1  0.979594  9.811364e-10
# 7   current_fall_time_pulse2  0.969693  2.045291e-09
# 0   voltage_rise_time_pulse1  0.965768  7.491963e-10
# 6   current_fall_time_pulse1  0.964566  2.218440e-09
# 3   voltage_fall_time_pulse2  0.963990  1.301775e-09
# 11        undershoot_pulse_2  0.955608  2.889759e+00
# 12     ringing_frequency_MHz  0.946514  7.630542e+00
# 8          overshoot_pulse_1  0.931540  3.186347e+00
# 10        undershoot_pulse_1  0.931279  3.593862e+00
# 9          overshoot_pulse_2  0.915257  7.348234e+00
# 4   current_rise_time_pulse1  0.913413  1.443412e-08
# 1   voltage_rise_time_pulse2  0.898243  1.281220e-09
# 5   current_rise_time_pulse2  0.896383  8.071847e-09
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# unseen:
#                        Target        R2          RMSE
# 7   current_fall_time_pulse2  0.904974  3.437031e-09
# 2   voltage_fall_time_pulse1  0.877816  8.137873e-10
# 6   current_fall_time_pulse1  0.741728  5.705518e-09
# 0   voltage_rise_time_pulse1  0.719622  9.117878e-10
# 11        undershoot_pulse_2  0.556933  6.485151e+00
# 8          overshoot_pulse_1  0.544348  9.128501e+00
# 10        undershoot_pulse_1  0.512488  6.849068e+00
# 1   voltage_rise_time_pulse2  0.289695  3.931928e-09
# 5   current_rise_time_pulse2  0.056906  1.628100e-08
# 9          overshoot_pulse_2  0.031048  2.039334e+01
#                       Target        R2          RMSE
# 7   current_fall_time_pulse2  0.904974  3.437031e-09
# 2   voltage_fall_time_pulse1  0.877816  8.137873e-10
# 6   current_fall_time_pulse1  0.741728  5.705518e-09
# 0   voltage_rise_time_pulse1  0.719622  9.117878e-10
# 11        undershoot_pulse_2  0.556933  6.485151e+00
# 8          overshoot_pulse_1  0.544348  9.128501e+00
# 10        undershoot_pulse_1  0.512488  6.849068e+00
# 1   voltage_rise_time_pulse2  0.289695  3.931928e-09
# 5   current_rise_time_pulse2  0.056906  1.628100e-08
# 9          overshoot_pulse_2  0.031048  2.039334e+01
