# %% [markdown]
# ## MULTI-HEAD ANN

# %% [markdown]
# | Iteration    | Dropout | L2 Reg. | BatchNorm | EarlyStopping | LR Scheduler         | Scaling                     | Physics Features | Notes                          |
# | ------------ | ------- | ------- | --------- | ------------- | -------------------- | --------------------------- | ---------------- | ------------------------------ |
# | **Fast (1)** | —       | 1e-4    | Yes       | Yes (p=7)     | ReduceLRO (0.5, p=3) | StdScaler (X), per-target y | Yes              | Light backbone, quick training |
# | **2**        | 0.2     | 1e-4    | Yes       | Yes (p=10)    | ReduceLRO (0.3, p=5) | StdScaler (X), per-target y | Yes              | Deeper heads, stronger gen.    |
# | **3**        | 0.3     | 1e-4    | Yes       | Yes (p=15)    | ReduceLRO (0.5, p=7) | StdScaler (X), per-target y | Yes              | Even more dropout, robust      |

# %%
# ==================== MULTI-HEAD ANN (FAST MODE) ====================
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, regularizers
import matplotlib.pyplot as plt

# ============== SETTINGS ==============
SEED = 42
UNSEEN_PART = 'C2M0040120D'
BASE_DIR = "multihead_ann_fast"
os.makedirs(f"{BASE_DIR}/r2_rmse_tables", exist_ok=True)
os.makedirs(f"{BASE_DIR}/train_val_loss_curves", exist_ok=True)
os.makedirs(f"{BASE_DIR}/predicted_vs_actual", exist_ok=True)
os.makedirs(f"{BASE_DIR}/models", exist_ok=True)

# ============== LOAD DATA ==============
df = pd.read_csv(
    r"C:\Users\pc\Desktop\Neural_Network_Models\merged_train_5_MOSFETs_10percent_balanced.csv"
)

# ============== TARGETS + DROPS ==============
TARGET_COLUMNS = [
    'voltage_rise_time_pulse1', 'voltage_rise_time_pulse2',
    'voltage_fall_time_pulse1', 'voltage_fall_time_pulse2',
    'current_rise_time_pulse1', 'current_rise_time_pulse2',
    'current_fall_time_pulse1', 'current_fall_time_pulse2',
    'overshoot_pulse_1', 'overshoot_pulse_2',
    'undershoot_pulse_1', 'undershoot_pulse_2',
    'ringing_frequency_MHz'
]
DROP_COLUMNS = ['DeviceID', 'MOSFET', 'Part_Number']

# ============== SPLIT SEEN/UNSEEN DEVICES ==============
seen_parts = [p for p in df['Part_Number'].unique().tolist() if p != UNSEEN_PART]
train_df = df[df['Part_Number'].isin(seen_parts)].copy()
test_df  = df[df['Part_Number'] == UNSEEN_PART].copy()

# ============== PHYSICS FEATURES ==============
def compute_physics_features(row):
    L_eq = row[['Ls4','Ls5','Ls6','Ls7','Ls8','Ls9','Ls10','Ls11']].sum()
    C_eq = row.get("Coss", 1e-12)
    f_res = 1/(2*np.pi*np.sqrt(L_eq*C_eq))/1e6 if L_eq>0 and C_eq>0 else 0
    overshoot_est = row.get("VDS_max",0) - row.get("Vbus",0)
    undershoot_est = - row.get("VGS_th_min",0)
    dVdt_est = row.get("VDS_max",0)/row.get("Tp1",1e-9)
    dIdt_est = row.get("ID_max_25C",0)/row.get("Tp1",1e-9)
    return pd.Series([f_res, overshoot_est, undershoot_est, dVdt_est, dIdt_est])

for df_ in [train_df, test_df]:
    df_[['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est']] = \
        df_.apply(compute_physics_features, axis=1)

physics_features = ['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est']
INPUT_COLUMNS = [c for c in df.columns if c not in TARGET_COLUMNS + DROP_COLUMNS] + physics_features

# ============== SCALE INPUTS ==============
input_scaler = StandardScaler()
input_scaler.fit(pd.concat([train_df[INPUT_COLUMNS], test_df[INPUT_COLUMNS]]))
X_train_all = input_scaler.transform(train_df[INPUT_COLUMNS])
X_test_all  = input_scaler.transform(test_df[INPUT_COLUMNS])

# Separate physics cols
phys_idx = [INPUT_COLUMNS.index(c) for c in physics_features]
X_train_phys = X_train_all[:, phys_idx]
X_test_phys  = X_test_all[:, phys_idx]
X_train_main = np.delete(X_train_all, phys_idx, axis=1)
X_test_main  = np.delete(X_test_all, phys_idx, axis=1)

# ============== SCALE OUTPUTS (per target) ==============
output_scalers, y_train_scaled, y_test_scaled = {}, [], []
for col in TARGET_COLUMNS:
    scaler = MinMaxScaler() if col == 'ringing_frequency_MHz' else StandardScaler()
    y_train_scaled.append(scaler.fit_transform(train_df[[col]]).flatten())
    y_test_scaled.append(scaler.transform(test_df[[col]]).flatten())
    output_scalers[col] = scaler
y_train_scaled = np.array(y_train_scaled).T
y_test_scaled  = np.array(y_test_scaled).T

# ============== SPLIT TRAIN/VAL ==============
Xtr_main, Xval_main, Xtr_phys, Xval_phys, ytr, yval = train_test_split(
    X_train_main, X_train_phys, y_train_scaled,
    test_size=0.15, random_state=SEED
)

# ============== BUILD MULTI-HEAD ANN (FAST BACKBONE) ==============
def build_multihead_ann(input_dim_main, input_dim_phys, output_dim, l2_reg=1e-4):
    inp_main = layers.Input(shape=(input_dim_main,), name="main_inputs")
    inp_phys = layers.Input(shape=(input_dim_phys,), name="physics_inputs")

    # Smaller backbone
    x_main = layers.Dense(128, kernel_regularizer=regularizers.l2(l2_reg))(inp_main)
    x_main = layers.BatchNormalization()(x_main); x_main = layers.ReLU()(x_main)
    x_main = layers.Dense(64, kernel_regularizer=regularizers.l2(l2_reg))(x_main)
    x_main = layers.BatchNormalization()(x_main); x_main = layers.ReLU()(x_main)

    x_phys = layers.Dense(32, activation="relu")(inp_phys)

    shared = layers.concatenate([x_main, x_phys])

    outputs = []
    for i, col in enumerate(TARGET_COLUMNS):
        h = layers.Dense(32, activation="relu")(shared)  # per-head reduced
        out = layers.Dense(1, activation="linear", name=col)(h)
        outputs.append(out)

    model = models.Model(inputs=[inp_main, inp_phys], outputs=outputs)
    return model

model = build_multihead_ann(Xtr_main.shape[1], Xtr_phys.shape[1], len(TARGET_COLUMNS))

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss=["mse"]*len(TARGET_COLUMNS),
    metrics=["mae"]*len(TARGET_COLUMNS)
)

early_stop = callbacks.EarlyStopping(monitor="val_loss", patience=7, restore_best_weights=True)
reduce_lr  = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3)

# ============== TRAIN MODEL (FAST MODE) ==============
history = model.fit(
    [Xtr_main, Xtr_phys],
    [ytr[:,i] for i in range(len(TARGET_COLUMNS))],
    validation_data=([Xval_main,Xval_phys],[yval[:,i] for i in range(len(TARGET_COLUMNS))]),
    epochs=100, batch_size=256,
    callbacks=[early_stop, reduce_lr], verbose=1
)

model.save(f"{BASE_DIR}/models/multihead_ann.h5")

# ============== LOSS CURVE ==============
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel("Epoch"); plt.ylabel("MSE Loss")
plt.title("Train vs Validation Loss")
plt.legend(); plt.savefig(f"{BASE_DIR}/train_val_loss_curves/loss.png"); plt.close()

# ============== EVALUATION ==============
def evaluate_and_save(X_main, X_phys, y_scaled, name, positive_only=False):
    y_pred_scaled_list = model.predict([X_main, X_phys])
    results = []
    for i, col in enumerate(TARGET_COLUMNS):
        y_true = output_scalers[col].inverse_transform(y_scaled[:,i].reshape(-1,1)).flatten()
        y_pred = output_scalers[col].inverse_transform(y_pred_scaled_list[i].reshape(-1,1)).flatten()
        r2 = r2_score(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        results.append((col, r2, rmse))
    df_results = pd.DataFrame(results, columns=["Target","R2","RMSE"]).sort_values("R2",ascending=False)
    if positive_only:
        df_results = df_results[df_results["R2"]>0]
    print(f"\n{name}:\n",df_results)
    df_results.to_csv(f"{BASE_DIR}/r2_rmse_tables/{name}.csv", index=False)
    return df_results

# Run evals
evaluate_and_save(Xtr_main,Xtr_phys,ytr,"train")
evaluate_and_save(Xval_main,Xval_phys,yval,"val")
evaluate_and_save(X_train_main,X_train_phys,y_train_scaled,"test")
evaluate_and_save(X_test_main,X_test_phys,y_test_scaled,"unseen",positive_only=True)
# Out:
# Epoch 1/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - current_fall_time_pulse1_loss: 0.9631 - current_fall_time_pulse1_mae: 0.7438 - current_fall_time_pulse2_loss: 0.6239 - current_fall_time_pulse2_mae: 0.6005 - current_rise_time_pulse1_loss: 1.1404 - current_rise_time_pulse1_mae: 0.7334 - current_rise_time_pulse2_loss: 0.6831 - current_rise_time_pulse2_mae: 0.6702 - loss: 10.2992 - overshoot_pulse_1_loss: 0.9733 - overshoot_pulse_1_mae: 0.7399 - overshoot_pulse_2_loss: 0.9423 - overshoot_pulse_2_mae: 0.6924 - ringing_frequency_MHz_loss: 0.3735 - ringing_frequency_MHz_mae: 0.4427 - undershoot_pulse_1_loss: 0.9582 - undershoot_pulse_1_mae: 0.7879 - undershoot_pulse_2_loss: 0.8307 - undershoot_pulse_2_mae: 0.6643 - voltage_fall_time_pulse1_loss: 0.5286 - voltage_fall_time_pulse1_mae: 0.5607 - voltage_fall_time_pulse2_loss: 0.6468 - voltage_fall_time_pulse2_mae: 0.5839 - voltage_rise_time_pulse1_loss: 0.7268 - voltage_rise_time_pulse1_mae: 0.5984 - voltage_rise_time_pulse2_loss: 0.8914 - voltage_rise_time_pulse2_mae: 0.6755 - val_current_fall_time_pulse1_loss: 0.3326 - val_current_fall_time_pulse1_mae: 0.4355 - val_current_fall_time_pulse2_loss: 0.2739 - val_current_fall_time_pulse2_mae: 0.4008 - val_current_rise_time_pulse1_loss: 0.3273 - val_current_rise_time_pulse1_mae: 0.4882 - val_current_rise_time_pulse2_loss: 0.3998 - val_current_rise_time_pulse2_mae: 0.5343 - val_loss: 3.9089 - val_overshoot_pulse_1_loss: 0.6246 - val_overshoot_pulse_1_mae: 0.5965 - val_overshoot_pulse_2_loss: 0.3377 - val_overshoot_pulse_2_mae: 0.4377 - val_ringing_frequency_MHz_loss: 0.0325 - val_ringing_frequency_MHz_mae: 0.1501 - val_undershoot_pulse_1_loss: 0.3134 - val_undershoot_pulse_1_mae: 0.4616 - val_undershoot_pulse_2_loss: 0.2890 - val_undershoot_pulse_2_mae: 0.4652 - val_voltage_fall_time_pulse1_loss: 0.1427 - val_voltage_fall_time_pulse1_mae: 0.2935 - val_voltage_fall_time_pulse2_loss: 0.1006 - val_voltage_fall_time_pulse2_mae: 0.2519 - val_voltage_rise_time_pulse1_loss: 0.1784 - val_voltage_rise_time_pulse1_mae: 0.3130 - val_voltage_rise_time_pulse2_loss: 0.4566 - val_voltage_rise_time_pulse2_mae: 0.4378 - learning_rate: 0.0010
# Epoch 2/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - current_fall_time_pulse1_loss: 0.0868 - current_fall_time_pulse1_mae: 0.2291 - current_fall_time_pulse2_loss: 0.0743 - current_fall_time_pulse2_mae: 0.2165 - current_rise_time_pulse1_loss: 0.1555 - current_rise_time_pulse1_mae: 0.2991 - current_rise_time_pulse2_loss: 0.2336 - current_rise_time_pulse2_mae: 0.3845 - loss: 1.5963 - overshoot_pulse_1_loss: 0.2147 - overshoot_pulse_1_mae: 0.3534 - overshoot_pulse_2_loss: 0.1448 - overshoot_pulse_2_mae: 0.3010 - ringing_frequency_MHz_loss: 0.0309 - ringing_frequency_MHz_mae: 0.1368 - undershoot_pulse_1_loss: 0.1183 - undershoot_pulse_1_mae: 0.2665 - undershoot_pulse_2_loss: 0.1126 - undershoot_pulse_2_mae: 0.2630 - voltage_fall_time_pulse1_loss: 0.0574 - voltage_fall_time_pulse1_mae: 0.1880 - voltage_fall_time_pulse2_loss: 0.0426 - voltage_fall_time_pulse2_mae: 0.1642 - voltage_rise_time_pulse1_loss: 0.0958 - voltage_rise_time_pulse1_mae: 0.2349 - voltage_rise_time_pulse2_loss: 0.2154 - voltage_rise_time_pulse2_mae: 0.2975 - val_current_fall_time_pulse1_loss: 0.1947 - val_current_fall_time_pulse1_mae: 0.3296 - val_current_fall_time_pulse2_loss: 0.1577 - val_current_fall_time_pulse2_mae: 0.3036 - val_current_rise_time_pulse1_loss: 0.2266 - val_current_rise_time_pulse1_mae: 0.3996 - val_current_rise_time_pulse2_loss: 0.3014 - val_current_rise_time_pulse2_mae: 0.4545 - val_loss: 2.6232 - val_overshoot_pulse_1_loss: 0.4219 - val_overshoot_pulse_1_mae: 0.4823 - val_overshoot_pulse_2_loss: 0.2536 - val_overshoot_pulse_2_mae: 0.3777 - val_ringing_frequency_MHz_loss: 0.0151 - val_ringing_frequency_MHz_mae: 0.1017 - val_undershoot_pulse_1_loss: 0.1726 - val_undershoot_pulse_1_mae: 0.3432 - val_undershoot_pulse_2_loss: 0.1622 - val_undershoot_pulse_2_mae: 0.3338 - val_voltage_fall_time_pulse1_loss: 0.0853 - val_voltage_fall_time_pulse1_mae: 0.2213 - val_voltage_fall_time_pulse2_loss: 0.0635 - val_voltage_fall_time_pulse2_mae: 0.2029 - val_voltage_rise_time_pulse1_loss: 0.1223 - val_voltage_rise_time_pulse1_mae: 0.2399 - val_voltage_rise_time_pulse2_loss: 0.3720 - val_voltage_rise_time_pulse2_mae: 0.3647 - learning_rate: 0.0010
# Epoch 3/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - current_fall_time_pulse1_loss: 0.0383 - current_fall_time_pulse1_mae: 0.1524 - current_fall_time_pulse2_loss: 0.0393 - current_fall_time_pulse2_mae: 0.1569 - current_rise_time_pulse1_loss: 0.1006 - current_rise_time_pulse1_mae: 0.2303 - current_rise_time_pulse2_loss: 0.1671 - current_rise_time_pulse2_mae: 0.3093 - loss: 1.0407 - overshoot_pulse_1_loss: 0.1325 - overshoot_pulse_1_mae: 0.2783 - overshoot_pulse_2_loss: 0.1077 - overshoot_pulse_2_mae: 0.2549 - ringing_frequency_MHz_loss: 0.0147 - ringing_frequency_MHz_mae: 0.0952 - undershoot_pulse_1_loss: 0.0628 - undershoot_pulse_1_mae: 0.1933 - undershoot_pulse_2_loss: 0.0671 - undershoot_pulse_2_mae: 0.1988 - voltage_fall_time_pulse1_loss: 0.0263 - voltage_fall_time_pulse1_mae: 0.1280 - voltage_fall_time_pulse2_loss: 0.0209 - voltage_fall_time_pulse2_mae: 0.1141 - voltage_rise_time_pulse1_loss: 0.0711 - voltage_rise_time_pulse1_mae: 0.1932 - voltage_rise_time_pulse2_loss: 0.1793 - voltage_rise_time_pulse2_mae: 0.2621 - val_current_fall_time_pulse1_loss: 0.1237 - val_current_fall_time_pulse1_mae: 0.2642 - val_current_fall_time_pulse2_loss: 0.1019 - val_current_fall_time_pulse2_mae: 0.2457 - val_current_rise_time_pulse1_loss: 0.1806 - val_current_rise_time_pulse1_mae: 0.3510 - val_current_rise_time_pulse2_loss: 0.2313 - val_current_rise_time_pulse2_mae: 0.3863 - val_loss: 2.0149 - val_overshoot_pulse_1_loss: 0.3217 - val_overshoot_pulse_1_mae: 0.4124 - val_overshoot_pulse_2_loss: 0.2069 - val_overshoot_pulse_2_mae: 0.3350 - val_ringing_frequency_MHz_loss: 0.0096 - val_ringing_frequency_MHz_mae: 0.0816 - val_undershoot_pulse_1_loss: 0.1278 - val_undershoot_pulse_1_mae: 0.2880 - val_undershoot_pulse_2_loss: 0.1197 - val_undershoot_pulse_2_mae: 0.2768 - val_voltage_fall_time_pulse1_loss: 0.0566 - val_voltage_fall_time_pulse1_mae: 0.1769 - val_voltage_fall_time_pulse2_loss: 0.0473 - val_voltage_fall_time_pulse2_mae: 0.1697 - val_voltage_rise_time_pulse1_loss: 0.0948 - val_voltage_rise_time_pulse1_mae: 0.2098 - val_voltage_rise_time_pulse2_loss: 0.3320 - val_voltage_rise_time_pulse2_mae: 0.3288 - learning_rate: 0.0010
# Epoch 4/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - current_fall_time_pulse1_loss: 0.0286 - current_fall_time_pulse1_mae: 0.1320 - current_fall_time_pulse2_loss: 0.0308 - current_fall_time_pulse2_mae: 0.1381 - current_rise_time_pulse1_loss: 0.0873 - current_rise_time_pulse1_mae: 0.2075 - current_rise_time_pulse2_loss: 0.1426 - current_rise_time_pulse2_mae: 0.2754 - loss: 0.8824 - overshoot_pulse_1_loss: 0.1107 - overshoot_pulse_1_mae: 0.2546 - overshoot_pulse_2_loss: 0.0964 - overshoot_pulse_2_mae: 0.2425 - ringing_frequency_MHz_loss: 0.0101 - ringing_frequency_MHz_mae: 0.0789 - undershoot_pulse_1_loss: 0.0507 - undershoot_pulse_1_mae: 0.1713 - undershoot_pulse_2_loss: 0.0526 - undershoot_pulse_2_mae: 0.1748 - voltage_fall_time_pulse1_loss: 0.0182 - voltage_fall_time_pulse1_mae: 0.1057 - voltage_fall_time_pulse2_loss: 0.0151 - voltage_fall_time_pulse2_mae: 0.0964 - voltage_rise_time_pulse1_loss: 0.0596 - voltage_rise_time_pulse1_mae: 0.1725 - voltage_rise_time_pulse2_loss: 0.1669 - voltage_rise_time_pulse2_mae: 0.2486 - val_current_fall_time_pulse1_loss: 0.0857 - val_current_fall_time_pulse1_mae: 0.2182 - val_current_fall_time_pulse2_loss: 0.0674 - val_current_fall_time_pulse2_mae: 0.2029 - val_current_rise_time_pulse1_loss: 0.1513 - val_current_rise_time_pulse1_mae: 0.3146 - val_current_rise_time_pulse2_loss: 0.1850 - val_current_rise_time_pulse2_mae: 0.3317 - val_loss: 1.6143 - val_overshoot_pulse_1_loss: 0.2527 - val_overshoot_pulse_1_mae: 0.3602 - val_overshoot_pulse_2_loss: 0.1712 - val_overshoot_pulse_2_mae: 0.3008 - val_ringing_frequency_MHz_loss: 0.0071 - val_ringing_frequency_MHz_mae: 0.0704 - val_undershoot_pulse_1_loss: 0.0954 - val_undershoot_pulse_1_mae: 0.2446 - val_undershoot_pulse_2_loss: 0.0944 - val_undershoot_pulse_2_mae: 0.2374 - val_voltage_fall_time_pulse1_loss: 0.0371 - val_voltage_fall_time_pulse1_mae: 0.1406 - val_voltage_fall_time_pulse2_loss: 0.0328 - val_voltage_fall_time_pulse2_mae: 0.1404 - val_voltage_rise_time_pulse1_loss: 0.0756 - val_voltage_rise_time_pulse1_mae: 0.1843 - val_voltage_rise_time_pulse2_loss: 0.3027 - val_voltage_rise_time_pulse2_mae: 0.3026 - learning_rate: 0.0010
# Epoch 5/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - current_fall_time_pulse1_loss: 0.0233 - current_fall_time_pulse1_mae: 0.1192 - current_fall_time_pulse2_loss: 0.0261 - current_fall_time_pulse2_mae: 0.1270 - current_rise_time_pulse1_loss: 0.0822 - current_rise_time_pulse1_mae: 0.1974 - current_rise_time_pulse2_loss: 0.1319 - current_rise_time_pulse2_mae: 0.2558 - loss: 0.8009 - overshoot_pulse_1_loss: 0.0994 - overshoot_pulse_1_mae: 0.2416 - overshoot_pulse_2_loss: 0.0904 - overshoot_pulse_2_mae: 0.2348 - ringing_frequency_MHz_loss: 0.0077 - ringing_frequency_MHz_mae: 0.0690 - undershoot_pulse_1_loss: 0.0445 - undershoot_pulse_1_mae: 0.1595 - undershoot_pulse_2_loss: 0.0458 - undershoot_pulse_2_mae: 0.1619 - voltage_fall_time_pulse1_loss: 0.0148 - voltage_fall_time_pulse1_mae: 0.0954 - voltage_fall_time_pulse2_loss: 0.0122 - voltage_fall_time_pulse2_mae: 0.0866 - voltage_rise_time_pulse1_loss: 0.0516 - voltage_rise_time_pulse1_mae: 0.1583 - voltage_rise_time_pulse2_loss: 0.1585 - voltage_rise_time_pulse2_mae: 0.2416 - val_current_fall_time_pulse1_loss: 0.0573 - val_current_fall_time_pulse1_mae: 0.1787 - val_current_fall_time_pulse2_loss: 0.0456 - val_current_fall_time_pulse2_mae: 0.1694 - val_current_rise_time_pulse1_loss: 0.1312 - val_current_rise_time_pulse1_mae: 0.2868 - val_current_rise_time_pulse2_loss: 0.1612 - val_current_rise_time_pulse2_mae: 0.2978 - val_loss: 1.3388 - val_overshoot_pulse_1_loss: 0.2044 - val_overshoot_pulse_1_mae: 0.3187 - val_overshoot_pulse_2_loss: 0.1468 - val_overshoot_pulse_2_mae: 0.2743 - val_ringing_frequency_MHz_loss: 0.0057 - val_ringing_frequency_MHz_mae: 0.0630 - val_undershoot_pulse_1_loss: 0.0733 - val_undershoot_pulse_1_mae: 0.2105 - val_undershoot_pulse_2_loss: 0.0747 - val_undershoot_pulse_2_mae: 0.2055 - val_voltage_fall_time_pulse1_loss: 0.0245 - val_voltage_fall_time_pulse1_mae: 0.1142 - val_voltage_fall_time_pulse2_loss: 0.0225 - val_voltage_fall_time_pulse2_mae: 0.1154 - val_voltage_rise_time_pulse1_loss: 0.0568 - val_voltage_rise_time_pulse1_mae: 0.1624 - val_voltage_rise_time_pulse2_loss: 0.2795 - val_voltage_rise_time_pulse2_mae: 0.2823 - learning_rate: 0.0010
# Epoch 6/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - current_fall_time_pulse1_loss: 0.0203 - current_fall_time_pulse1_mae: 0.1114 - current_fall_time_pulse2_loss: 0.0231 - current_fall_time_pulse2_mae: 0.1193 - current_rise_time_pulse1_loss: 0.0790 - current_rise_time_pulse1_mae: 0.1910 - current_rise_time_pulse2_loss: 0.1255 - current_rise_time_pulse2_mae: 0.2430 - loss: 0.7466 - overshoot_pulse_1_loss: 0.0908 - overshoot_pulse_1_mae: 0.2322 - overshoot_pulse_2_loss: 0.0862 - overshoot_pulse_2_mae: 0.2291 - ringing_frequency_MHz_loss: 0.0063 - ringing_frequency_MHz_mae: 0.0624 - undershoot_pulse_1_loss: 0.0406 - undershoot_pulse_1_mae: 0.1514 - undershoot_pulse_2_loss: 0.0418 - undershoot_pulse_2_mae: 0.1534 - voltage_fall_time_pulse1_loss: 0.0126 - voltage_fall_time_pulse1_mae: 0.0882 - voltage_fall_time_pulse2_loss: 0.0107 - voltage_fall_time_pulse2_mae: 0.0807 - voltage_rise_time_pulse1_loss: 0.0456 - voltage_rise_time_pulse1_mae: 0.1478 - voltage_rise_time_pulse2_loss: 0.1516 - voltage_rise_time_pulse2_mae: 0.2372 - val_current_fall_time_pulse1_loss: 0.0380 - val_current_fall_time_pulse1_mae: 0.1473 - val_current_fall_time_pulse2_loss: 0.0322 - val_current_fall_time_pulse2_mae: 0.1439 - val_current_rise_time_pulse1_loss: 0.1161 - val_current_rise_time_pulse1_mae: 0.2623 - val_current_rise_time_pulse2_loss: 0.1458 - val_current_rise_time_pulse2_mae: 0.2719 - val_loss: 1.1476 - val_overshoot_pulse_1_loss: 0.1693 - val_overshoot_pulse_1_mae: 0.2856 - val_overshoot_pulse_2_loss: 0.1297 - val_overshoot_pulse_2_mae: 0.2546 - val_ringing_frequency_MHz_loss: 0.0048 - val_ringing_frequency_MHz_mae: 0.0571 - val_undershoot_pulse_1_loss: 0.0577 - val_undershoot_pulse_1_mae: 0.1831 - val_undershoot_pulse_2_loss: 0.0602 - val_undershoot_pulse_2_mae: 0.1806 - val_voltage_fall_time_pulse1_loss: 0.0166 - val_voltage_fall_time_pulse1_mae: 0.0957 - val_voltage_fall_time_pulse2_loss: 0.0156 - val_voltage_fall_time_pulse2_mae: 0.0948 - val_voltage_rise_time_pulse1_loss: 0.0471 - val_voltage_rise_time_pulse1_mae: 0.1485 - val_voltage_rise_time_pulse2_loss: 0.2596 - val_voltage_rise_time_pulse2_mae: 0.2645 - learning_rate: 0.0010
# Epoch 7/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - current_fall_time_pulse1_loss: 0.0183 - current_fall_time_pulse1_mae: 0.1056 - current_fall_time_pulse2_loss: 0.0211 - current_fall_time_pulse2_mae: 0.1138 - current_rise_time_pulse1_loss: 0.0764 - current_rise_time_pulse1_mae: 0.1857 - current_rise_time_pulse2_loss: 0.1212 - current_rise_time_pulse2_mae: 0.2339 - loss: 0.7069 - overshoot_pulse_1_loss: 0.0839 - overshoot_pulse_1_mae: 0.2239 - overshoot_pulse_2_loss: 0.0832 - overshoot_pulse_2_mae: 0.2249 - ringing_frequency_MHz_loss: 0.0053 - ringing_frequency_MHz_mae: 0.0575 - undershoot_pulse_1_loss: 0.0378 - undershoot_pulse_1_mae: 0.1455 - undershoot_pulse_2_loss: 0.0391 - undershoot_pulse_2_mae: 0.1479 - voltage_fall_time_pulse1_loss: 0.0112 - voltage_fall_time_pulse1_mae: 0.0830 - voltage_fall_time_pulse2_loss: 0.0097 - voltage_fall_time_pulse2_mae: 0.0766 - voltage_rise_time_pulse1_loss: 0.0420 - voltage_rise_time_pulse1_mae: 0.1406 - voltage_rise_time_pulse2_loss: 0.1454 - voltage_rise_time_pulse2_mae: 0.2337 - val_current_fall_time_pulse1_loss: 0.0257 - val_current_fall_time_pulse1_mae: 0.1236 - val_current_fall_time_pulse2_loss: 0.0241 - val_current_fall_time_pulse2_mae: 0.1258 - val_current_rise_time_pulse1_loss: 0.1057 - val_current_rise_time_pulse1_mae: 0.2432 - val_current_rise_time_pulse2_loss: 0.1359 - val_current_rise_time_pulse2_mae: 0.2531 - val_loss: 1.0161 - val_overshoot_pulse_1_loss: 0.1427 - val_overshoot_pulse_1_mae: 0.2579 - val_overshoot_pulse_2_loss: 0.1178 - val_overshoot_pulse_2_mae: 0.2412 - val_ringing_frequency_MHz_loss: 0.0042 - val_ringing_frequency_MHz_mae: 0.0528 - val_undershoot_pulse_1_loss: 0.0469 - val_undershoot_pulse_1_mae: 0.1620 - val_undershoot_pulse_2_loss: 0.0504 - val_undershoot_pulse_2_mae: 0.1627 - val_voltage_fall_time_pulse1_loss: 0.0115 - val_voltage_fall_time_pulse1_mae: 0.0813 - val_voltage_fall_time_pulse2_loss: 0.0117 - val_voltage_fall_time_pulse2_mae: 0.0802 - val_voltage_rise_time_pulse1_loss: 0.0422 - val_voltage_rise_time_pulse1_mae: 0.1394 - val_voltage_rise_time_pulse2_loss: 0.2428 - val_voltage_rise_time_pulse2_mae: 0.2507 - learning_rate: 0.0010
# Epoch 8/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - current_fall_time_pulse1_loss: 0.0168 - current_fall_time_pulse1_mae: 0.1011 - current_fall_time_pulse2_loss: 0.0195 - current_fall_time_pulse2_mae: 0.1093 - current_rise_time_pulse1_loss: 0.0745 - current_rise_time_pulse1_mae: 0.1818 - current_rise_time_pulse2_loss: 0.1180 - current_rise_time_pulse2_mae: 0.2274 - loss: 0.6753 - overshoot_pulse_1_loss: 0.0781 - overshoot_pulse_1_mae: 0.2163 - overshoot_pulse_2_loss: 0.0808 - overshoot_pulse_2_mae: 0.2217 - ringing_frequency_MHz_loss: 0.0047 - ringing_frequency_MHz_mae: 0.0539 - undershoot_pulse_1_loss: 0.0357 - undershoot_pulse_1_mae: 0.1408 - undershoot_pulse_2_loss: 0.0371 - undershoot_pulse_2_mae: 0.1437 - voltage_fall_time_pulse1_loss: 0.0101 - voltage_fall_time_pulse1_mae: 0.0791 - voltage_fall_time_pulse2_loss: 0.0089 - voltage_fall_time_pulse2_mae: 0.0732 - voltage_rise_time_pulse1_loss: 0.0393 - voltage_rise_time_pulse1_mae: 0.1351 - voltage_rise_time_pulse2_loss: 0.1394 - voltage_rise_time_pulse2_mae: 0.2309 - val_current_fall_time_pulse1_loss: 0.0187 - val_current_fall_time_pulse1_mae: 0.1071 - val_current_fall_time_pulse2_loss: 0.0199 - val_current_fall_time_pulse2_mae: 0.1151 - val_current_rise_time_pulse1_loss: 0.0965 - val_current_rise_time_pulse1_mae: 0.2257 - val_current_rise_time_pulse2_loss: 0.1298 - val_current_rise_time_pulse2_mae: 0.2399 - val_loss: 0.9258 - val_overshoot_pulse_1_loss: 0.1244 - val_overshoot_pulse_1_mae: 0.2380 - val_overshoot_pulse_2_loss: 0.1091 - val_overshoot_pulse_2_mae: 0.2312 - val_ringing_frequency_MHz_loss: 0.0038 - val_ringing_frequency_MHz_mae: 0.0496 - val_undershoot_pulse_1_loss: 0.0395 - val_undershoot_pulse_1_mae: 0.1465 - val_undershoot_pulse_2_loss: 0.0431 - val_undershoot_pulse_2_mae: 0.1490 - val_voltage_fall_time_pulse1_loss: 0.0082 - val_voltage_fall_time_pulse1_mae: 0.0703 - val_voltage_fall_time_pulse2_loss: 0.0093 - val_voltage_fall_time_pulse2_mae: 0.0702 - val_voltage_rise_time_pulse1_loss: 0.0392 - val_voltage_rise_time_pulse1_mae: 0.1327 - val_voltage_rise_time_pulse2_loss: 0.2311 - val_voltage_rise_time_pulse2_mae: 0.2400 - learning_rate: 0.0010
# Epoch 9/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - current_fall_time_pulse1_loss: 0.0157 - current_fall_time_pulse1_mae: 0.0974 - current_fall_time_pulse2_loss: 0.0182 - current_fall_time_pulse2_mae: 0.1055 - current_rise_time_pulse1_loss: 0.0730 - current_rise_time_pulse1_mae: 0.1786 - current_rise_time_pulse2_loss: 0.1154 - current_rise_time_pulse2_mae: 0.2222 - loss: 0.6482 - overshoot_pulse_1_loss: 0.0731 - overshoot_pulse_1_mae: 0.2092 - overshoot_pulse_2_loss: 0.0789 - overshoot_pulse_2_mae: 0.2192 - ringing_frequency_MHz_loss: 0.0042 - ringing_frequency_MHz_mae: 0.0510 - undershoot_pulse_1_loss: 0.0341 - undershoot_pulse_1_mae: 0.1373 - undershoot_pulse_2_loss: 0.0355 - undershoot_pulse_2_mae: 0.1403 - voltage_fall_time_pulse1_loss: 0.0093 - voltage_fall_time_pulse1_mae: 0.0758 - voltage_fall_time_pulse2_loss: 0.0083 - voltage_fall_time_pulse2_mae: 0.0703 - voltage_rise_time_pulse1_loss: 0.0370 - voltage_rise_time_pulse1_mae: 0.1304 - voltage_rise_time_pulse2_loss: 0.1334 - voltage_rise_time_pulse2_mae: 0.2272 - val_current_fall_time_pulse1_loss: 0.0151 - val_current_fall_time_pulse1_mae: 0.0970 - val_current_fall_time_pulse2_loss: 0.0181 - val_current_fall_time_pulse2_mae: 0.1095 - val_current_rise_time_pulse1_loss: 0.0906 - val_current_rise_time_pulse1_mae: 0.2131 - val_current_rise_time_pulse2_loss: 0.1261 - val_current_rise_time_pulse2_mae: 0.2300 - val_loss: 0.8660 - val_overshoot_pulse_1_loss: 0.1106 - val_overshoot_pulse_1_mae: 0.2221 - val_overshoot_pulse_2_loss: 0.1031 - val_overshoot_pulse_2_mae: 0.2239 - val_ringing_frequency_MHz_loss: 0.0035 - val_ringing_frequency_MHz_mae: 0.0474 - val_undershoot_pulse_1_loss: 0.0348 - val_undershoot_pulse_1_mae: 0.1361 - val_undershoot_pulse_2_loss: 0.0386 - val_undershoot_pulse_2_mae: 0.1399 - val_voltage_fall_time_pulse1_loss: 0.0066 - val_voltage_fall_time_pulse1_mae: 0.0632 - val_voltage_fall_time_pulse2_loss: 0.0076 - val_voltage_fall_time_pulse2_mae: 0.0630 - val_voltage_rise_time_pulse1_loss: 0.0372 - val_voltage_rise_time_pulse1_mae: 0.1278 - val_voltage_rise_time_pulse2_loss: 0.2237 - val_voltage_rise_time_pulse2_mae: 0.2341 - learning_rate: 0.0010
# Epoch 10/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - current_fall_time_pulse1_loss: 0.0149 - current_fall_time_pulse1_mae: 0.0945 - current_fall_time_pulse2_loss: 0.0173 - current_fall_time_pulse2_mae: 0.1027 - current_rise_time_pulse1_loss: 0.0717 - current_rise_time_pulse1_mae: 0.1758 - current_rise_time_pulse2_loss: 0.1130 - current_rise_time_pulse2_mae: 0.2182 - loss: 0.6257 - overshoot_pulse_1_loss: 0.0688 - overshoot_pulse_1_mae: 0.2030 - overshoot_pulse_2_loss: 0.0773 - overshoot_pulse_2_mae: 0.2170 - ringing_frequency_MHz_loss: 0.0038 - ringing_frequency_MHz_mae: 0.0487 - undershoot_pulse_1_loss: 0.0328 - undershoot_pulse_1_mae: 0.1344 - undershoot_pulse_2_loss: 0.0342 - undershoot_pulse_2_mae: 0.1373 - voltage_fall_time_pulse1_loss: 0.0086 - voltage_fall_time_pulse1_mae: 0.0733 - voltage_fall_time_pulse2_loss: 0.0078 - voltage_fall_time_pulse2_mae: 0.0677 - voltage_rise_time_pulse1_loss: 0.0349 - voltage_rise_time_pulse1_mae: 0.1261 - voltage_rise_time_pulse2_loss: 0.1283 - voltage_rise_time_pulse2_mae: 0.2233 - val_current_fall_time_pulse1_loss: 0.0135 - val_current_fall_time_pulse1_mae: 0.0923 - val_current_fall_time_pulse2_loss: 0.0176 - val_current_fall_time_pulse2_mae: 0.1071 - val_current_rise_time_pulse1_loss: 0.0859 - val_current_rise_time_pulse1_mae: 0.2032 - val_current_rise_time_pulse2_loss: 0.1234 - val_current_rise_time_pulse2_mae: 0.2226 - val_loss: 0.8255 - val_overshoot_pulse_1_loss: 0.1010 - val_overshoot_pulse_1_mae: 0.2109 - val_overshoot_pulse_2_loss: 0.0990 - val_overshoot_pulse_2_mae: 0.2191 - val_ringing_frequency_MHz_loss: 0.0033 - val_ringing_frequency_MHz_mae: 0.0458 - val_undershoot_pulse_1_loss: 0.0318 - val_undershoot_pulse_1_mae: 0.1288 - val_undershoot_pulse_2_loss: 0.0357 - val_undershoot_pulse_2_mae: 0.1334 - val_voltage_fall_time_pulse1_loss: 0.0057 - val_voltage_fall_time_pulse1_mae: 0.0591 - val_voltage_fall_time_pulse2_loss: 0.0065 - val_voltage_fall_time_pulse2_mae: 0.0580 - val_voltage_rise_time_pulse1_loss: 0.0359 - val_voltage_rise_time_pulse1_mae: 0.1252 - val_voltage_rise_time_pulse2_loss: 0.2180 - val_voltage_rise_time_pulse2_mae: 0.2307 - learning_rate: 0.0010
# Epoch 11/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - current_fall_time_pulse1_loss: 0.0141 - current_fall_time_pulse1_mae: 0.0918 - current_fall_time_pulse2_loss: 0.0166 - current_fall_time_pulse2_mae: 0.1003 - current_rise_time_pulse1_loss: 0.0706 - current_rise_time_pulse1_mae: 0.1733 - current_rise_time_pulse2_loss: 0.1110 - current_rise_time_pulse2_mae: 0.2147 - loss: 0.6064 - overshoot_pulse_1_loss: 0.0651 - overshoot_pulse_1_mae: 0.1977 - overshoot_pulse_2_loss: 0.0760 - overshoot_pulse_2_mae: 0.2152 - ringing_frequency_MHz_loss: 0.0035 - ringing_frequency_MHz_mae: 0.0467 - undershoot_pulse_1_loss: 0.0316 - undershoot_pulse_1_mae: 0.1316 - undershoot_pulse_2_loss: 0.0330 - undershoot_pulse_2_mae: 0.1348 - voltage_fall_time_pulse1_loss: 0.0081 - voltage_fall_time_pulse1_mae: 0.0711 - voltage_fall_time_pulse2_loss: 0.0073 - voltage_fall_time_pulse2_mae: 0.0656 - voltage_rise_time_pulse1_loss: 0.0333 - voltage_rise_time_pulse1_mae: 0.1226 - voltage_rise_time_pulse2_loss: 0.1237 - voltage_rise_time_pulse2_mae: 0.2201 - val_current_fall_time_pulse1_loss: 0.0129 - val_current_fall_time_pulse1_mae: 0.0898 - val_current_fall_time_pulse2_loss: 0.0174 - val_current_fall_time_pulse2_mae: 0.1053 - val_current_rise_time_pulse1_loss: 0.0824 - val_current_rise_time_pulse1_mae: 0.1952 - val_current_rise_time_pulse2_loss: 0.1216 - val_current_rise_time_pulse2_mae: 0.2173 - val_loss: 0.7959 - val_overshoot_pulse_1_loss: 0.0941 - val_overshoot_pulse_1_mae: 0.2023 - val_overshoot_pulse_2_loss: 0.0963 - val_overshoot_pulse_2_mae: 0.2154 - val_ringing_frequency_MHz_loss: 0.0031 - val_ringing_frequency_MHz_mae: 0.0446 - val_undershoot_pulse_1_loss: 0.0297 - val_undershoot_pulse_1_mae: 0.1238 - val_undershoot_pulse_2_loss: 0.0336 - val_undershoot_pulse_2_mae: 0.1286 - val_voltage_fall_time_pulse1_loss: 0.0053 - val_voltage_fall_time_pulse1_mae: 0.0573 - val_voltage_fall_time_pulse2_loss: 0.0058 - val_voltage_fall_time_pulse2_mae: 0.0548 - val_voltage_rise_time_pulse1_loss: 0.0351 - val_voltage_rise_time_pulse1_mae: 0.1234 - val_voltage_rise_time_pulse2_loss: 0.2128 - val_voltage_rise_time_pulse2_mae: 0.2286 - learning_rate: 0.0010
# Epoch 12/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - current_fall_time_pulse1_loss: 0.0134 - current_fall_time_pulse1_mae: 0.0894 - current_fall_time_pulse2_loss: 0.0159 - current_fall_time_pulse2_mae: 0.0977 - current_rise_time_pulse1_loss: 0.0697 - current_rise_time_pulse1_mae: 0.1712 - current_rise_time_pulse2_loss: 0.1093 - current_rise_time_pulse2_mae: 0.2116 - loss: 0.5892 - overshoot_pulse_1_loss: 0.0620 - overshoot_pulse_1_mae: 0.1930 - overshoot_pulse_2_loss: 0.0749 - overshoot_pulse_2_mae: 0.2136 - ringing_frequency_MHz_loss: 0.0033 - ringing_frequency_MHz_mae: 0.0451 - undershoot_pulse_1_loss: 0.0305 - undershoot_pulse_1_mae: 0.1290 - undershoot_pulse_2_loss: 0.0320 - undershoot_pulse_2_mae: 0.1326 - voltage_fall_time_pulse1_loss: 0.0077 - voltage_fall_time_pulse1_mae: 0.0692 - voltage_fall_time_pulse2_loss: 0.0069 - voltage_fall_time_pulse2_mae: 0.0637 - voltage_rise_time_pulse1_loss: 0.0319 - voltage_rise_time_pulse1_mae: 0.1194 - voltage_rise_time_pulse2_loss: 0.1195 - voltage_rise_time_pulse2_mae: 0.2173 - val_current_fall_time_pulse1_loss: 0.0130 - val_current_fall_time_pulse1_mae: 0.0890 - val_current_fall_time_pulse2_loss: 0.0179 - val_current_fall_time_pulse2_mae: 0.1053 - val_current_rise_time_pulse1_loss: 0.0804 - val_current_rise_time_pulse1_mae: 0.1895 - val_current_rise_time_pulse2_loss: 0.1198 - val_current_rise_time_pulse2_mae: 0.2133 - val_loss: 0.7756 - val_overshoot_pulse_1_loss: 0.0891 - val_overshoot_pulse_1_mae: 0.1962 - val_overshoot_pulse_2_loss: 0.0943 - val_overshoot_pulse_2_mae: 0.2131 - val_ringing_frequency_MHz_loss: 0.0030 - val_ringing_frequency_MHz_mae: 0.0437 - val_undershoot_pulse_1_loss: 0.0283 - val_undershoot_pulse_1_mae: 0.1200 - val_undershoot_pulse_2_loss: 0.0325 - val_undershoot_pulse_2_mae: 0.1258 - val_voltage_fall_time_pulse1_loss: 0.0051 - val_voltage_fall_time_pulse1_mae: 0.0568 - val_voltage_fall_time_pulse2_loss: 0.0053 - val_voltage_fall_time_pulse2_mae: 0.0525 - val_voltage_rise_time_pulse1_loss: 0.0345 - val_voltage_rise_time_pulse1_mae: 0.1224 - val_voltage_rise_time_pulse2_loss: 0.2081 - val_voltage_rise_time_pulse2_mae: 0.2259 - learning_rate: 0.0010
# Epoch 13/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - current_fall_time_pulse1_loss: 0.0130 - current_fall_time_pulse1_mae: 0.0876 - current_fall_time_pulse2_loss: 0.0153 - current_fall_time_pulse2_mae: 0.0957 - current_rise_time_pulse1_loss: 0.0689 - current_rise_time_pulse1_mae: 0.1695 - current_rise_time_pulse2_loss: 0.1077 - current_rise_time_pulse2_mae: 0.2090 - loss: 0.5741 - overshoot_pulse_1_loss: 0.0593 - overshoot_pulse_1_mae: 0.1889 - overshoot_pulse_2_loss: 0.0740 - overshoot_pulse_2_mae: 0.2122 - ringing_frequency_MHz_loss: 0.0030 - ringing_frequency_MHz_mae: 0.0436 - undershoot_pulse_1_loss: 0.0295 - undershoot_pulse_1_mae: 0.1268 - undershoot_pulse_2_loss: 0.0311 - undershoot_pulse_2_mae: 0.1306 - voltage_fall_time_pulse1_loss: 0.0074 - voltage_fall_time_pulse1_mae: 0.0676 - voltage_fall_time_pulse2_loss: 0.0066 - voltage_fall_time_pulse2_mae: 0.0621 - voltage_rise_time_pulse1_loss: 0.0307 - voltage_rise_time_pulse1_mae: 0.1166 - voltage_rise_time_pulse2_loss: 0.1154 - voltage_rise_time_pulse2_mae: 0.2144 - val_current_fall_time_pulse1_loss: 0.0131 - val_current_fall_time_pulse1_mae: 0.0879 - val_current_fall_time_pulse2_loss: 0.0180 - val_current_fall_time_pulse2_mae: 0.1050 - val_current_rise_time_pulse1_loss: 0.0789 - val_current_rise_time_pulse1_mae: 0.1851 - val_current_rise_time_pulse2_loss: 0.1184 - val_current_rise_time_pulse2_mae: 0.2104 - val_loss: 0.7609 - val_overshoot_pulse_1_loss: 0.0854 - val_overshoot_pulse_1_mae: 0.1920 - val_overshoot_pulse_2_loss: 0.0927 - val_overshoot_pulse_2_mae: 0.2111 - val_ringing_frequency_MHz_loss: 0.0028 - val_ringing_frequency_MHz_mae: 0.0426 - val_undershoot_pulse_1_loss: 0.0272 - val_undershoot_pulse_1_mae: 0.1168 - val_undershoot_pulse_2_loss: 0.0321 - val_undershoot_pulse_2_mae: 0.1245 - val_voltage_fall_time_pulse1_loss: 0.0049 - val_voltage_fall_time_pulse1_mae: 0.0565 - val_voltage_fall_time_pulse2_loss: 0.0050 - val_voltage_fall_time_pulse2_mae: 0.0511 - val_voltage_rise_time_pulse1_loss: 0.0343 - val_voltage_rise_time_pulse1_mae: 0.1216 - val_voltage_rise_time_pulse2_loss: 0.2045 - val_voltage_rise_time_pulse2_mae: 0.2240 - learning_rate: 0.0010
# Epoch 14/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - current_fall_time_pulse1_loss: 0.0125 - current_fall_time_pulse1_mae: 0.0859 - current_fall_time_pulse2_loss: 0.0148 - current_fall_time_pulse2_mae: 0.0938 - current_rise_time_pulse1_loss: 0.0682 - current_rise_time_pulse1_mae: 0.1680 - current_rise_time_pulse2_loss: 0.1062 - current_rise_time_pulse2_mae: 0.2065 - loss: 0.5604 - overshoot_pulse_1_loss: 0.0570 - overshoot_pulse_1_mae: 0.1852 - overshoot_pulse_2_loss: 0.0732 - overshoot_pulse_2_mae: 0.2110 - ringing_frequency_MHz_loss: 0.0028 - ringing_frequency_MHz_mae: 0.0422 - undershoot_pulse_1_loss: 0.0285 - undershoot_pulse_1_mae: 0.1247 - undershoot_pulse_2_loss: 0.0302 - undershoot_pulse_2_mae: 0.1289 - voltage_fall_time_pulse1_loss: 0.0070 - voltage_fall_time_pulse1_mae: 0.0660 - voltage_fall_time_pulse2_loss: 0.0063 - voltage_fall_time_pulse2_mae: 0.0606 - voltage_rise_time_pulse1_loss: 0.0297 - voltage_rise_time_pulse1_mae: 0.1140 - voltage_rise_time_pulse2_loss: 0.1116 - voltage_rise_time_pulse2_mae: 0.2119 - val_current_fall_time_pulse1_loss: 0.0133 - val_current_fall_time_pulse1_mae: 0.0871 - val_current_fall_time_pulse2_loss: 0.0181 - val_current_fall_time_pulse2_mae: 0.1040 - val_current_rise_time_pulse1_loss: 0.0777 - val_current_rise_time_pulse1_mae: 0.1812 - val_current_rise_time_pulse2_loss: 0.1171 - val_current_rise_time_pulse2_mae: 0.2077 - val_loss: 0.7489 - val_overshoot_pulse_1_loss: 0.0830 - val_overshoot_pulse_1_mae: 0.1890 - val_overshoot_pulse_2_loss: 0.0916 - val_overshoot_pulse_2_mae: 0.2094 - val_ringing_frequency_MHz_loss: 0.0027 - val_ringing_frequency_MHz_mae: 0.0418 - val_undershoot_pulse_1_loss: 0.0265 - val_undershoot_pulse_1_mae: 0.1149 - val_undershoot_pulse_2_loss: 0.0321 - val_undershoot_pulse_2_mae: 0.1240 - val_voltage_fall_time_pulse1_loss: 0.0049 - val_voltage_fall_time_pulse1_mae: 0.0563 - val_voltage_fall_time_pulse2_loss: 0.0048 - val_voltage_fall_time_pulse2_mae: 0.0497 - val_voltage_rise_time_pulse1_loss: 0.0340 - val_voltage_rise_time_pulse1_mae: 0.1206 - val_voltage_rise_time_pulse2_loss: 0.2011 - val_voltage_rise_time_pulse2_mae: 0.2218 - learning_rate: 0.0010
# Epoch 15/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - current_fall_time_pulse1_loss: 0.0120 - current_fall_time_pulse1_mae: 0.0843 - current_fall_time_pulse2_loss: 0.0143 - current_fall_time_pulse2_mae: 0.0921 - current_rise_time_pulse1_loss: 0.0676 - current_rise_time_pulse1_mae: 0.1665 - current_rise_time_pulse2_loss: 0.1048 - current_rise_time_pulse2_mae: 0.2043 - loss: 0.5477 - overshoot_pulse_1_loss: 0.0548 - overshoot_pulse_1_mae: 0.1820 - overshoot_pulse_2_loss: 0.0725 - overshoot_pulse_2_mae: 0.2098 - ringing_frequency_MHz_loss: 0.0027 - ringing_frequency_MHz_mae: 0.0408 - undershoot_pulse_1_loss: 0.0277 - undershoot_pulse_1_mae: 0.1229 - undershoot_pulse_2_loss: 0.0295 - undershoot_pulse_2_mae: 0.1273 - voltage_fall_time_pulse1_loss: 0.0067 - voltage_fall_time_pulse1_mae: 0.0644 - voltage_fall_time_pulse2_loss: 0.0060 - voltage_fall_time_pulse2_mae: 0.0591 - voltage_rise_time_pulse1_loss: 0.0288 - voltage_rise_time_pulse1_mae: 0.1116 - voltage_rise_time_pulse2_loss: 0.1081 - voltage_rise_time_pulse2_mae: 0.2096 - val_current_fall_time_pulse1_loss: 0.0138 - val_current_fall_time_pulse1_mae: 0.0874 - val_current_fall_time_pulse2_loss: 0.0184 - val_current_fall_time_pulse2_mae: 0.1039 - val_current_rise_time_pulse1_loss: 0.0768 - val_current_rise_time_pulse1_mae: 0.1788 - val_current_rise_time_pulse2_loss: 0.1156 - val_current_rise_time_pulse2_mae: 0.2056 - val_loss: 0.7387 - val_overshoot_pulse_1_loss: 0.0809 - val_overshoot_pulse_1_mae: 0.1870 - val_overshoot_pulse_2_loss: 0.0905 - val_overshoot_pulse_2_mae: 0.2080 - val_ringing_frequency_MHz_loss: 0.0025 - val_ringing_frequency_MHz_mae: 0.0405 - val_undershoot_pulse_1_loss: 0.0259 - val_undershoot_pulse_1_mae: 0.1135 - val_undershoot_pulse_2_loss: 0.0322 - val_undershoot_pulse_2_mae: 0.1244 - val_voltage_fall_time_pulse1_loss: 0.0048 - val_voltage_fall_time_pulse1_mae: 0.0559 - val_voltage_fall_time_pulse2_loss: 0.0046 - val_voltage_fall_time_pulse2_mae: 0.0484 - val_voltage_rise_time_pulse1_loss: 0.0334 - val_voltage_rise_time_pulse1_mae: 0.1187 - val_voltage_rise_time_pulse2_loss: 0.1977 - val_voltage_rise_time_pulse2_mae: 0.2199 - learning_rate: 0.0010
# Epoch 16/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - current_fall_time_pulse1_loss: 0.0117 - current_fall_time_pulse1_mae: 0.0830 - current_fall_time_pulse2_loss: 0.0139 - current_fall_time_pulse2_mae: 0.0906 - current_rise_time_pulse1_loss: 0.0670 - current_rise_time_pulse1_mae: 0.1652 - current_rise_time_pulse2_loss: 0.1034 - current_rise_time_pulse2_mae: 0.2020 - loss: 0.5362 - overshoot_pulse_1_loss: 0.0530 - overshoot_pulse_1_mae: 0.1790 - overshoot_pulse_2_loss: 0.0718 - overshoot_pulse_2_mae: 0.2088 - ringing_frequency_MHz_loss: 0.0025 - ringing_frequency_MHz_mae: 0.0395 - undershoot_pulse_1_loss: 0.0269 - undershoot_pulse_1_mae: 0.1212 - undershoot_pulse_2_loss: 0.0289 - undershoot_pulse_2_mae: 0.1261 - voltage_fall_time_pulse1_loss: 0.0064 - voltage_fall_time_pulse1_mae: 0.0629 - voltage_fall_time_pulse2_loss: 0.0058 - voltage_fall_time_pulse2_mae: 0.0577 - voltage_rise_time_pulse1_loss: 0.0280 - voltage_rise_time_pulse1_mae: 0.1092 - voltage_rise_time_pulse2_loss: 0.1047 - voltage_rise_time_pulse2_mae: 0.2072 - val_current_fall_time_pulse1_loss: 0.0143 - val_current_fall_time_pulse1_mae: 0.0884 - val_current_fall_time_pulse2_loss: 0.0186 - val_current_fall_time_pulse2_mae: 0.1036 - val_current_rise_time_pulse1_loss: 0.0762 - val_current_rise_time_pulse1_mae: 0.1769 - val_current_rise_time_pulse2_loss: 0.1141 - val_current_rise_time_pulse2_mae: 0.2037 - val_loss: 0.7286 - val_overshoot_pulse_1_loss: 0.0791 - val_overshoot_pulse_1_mae: 0.1850 - val_overshoot_pulse_2_loss: 0.0899 - val_overshoot_pulse_2_mae: 0.2071 - val_ringing_frequency_MHz_loss: 0.0023 - val_ringing_frequency_MHz_mae: 0.0390 - val_undershoot_pulse_1_loss: 0.0254 - val_undershoot_pulse_1_mae: 0.1124 - val_undershoot_pulse_2_loss: 0.0325 - val_undershoot_pulse_2_mae: 0.1253 - val_voltage_fall_time_pulse1_loss: 0.0047 - val_voltage_fall_time_pulse1_mae: 0.0555 - val_voltage_fall_time_pulse2_loss: 0.0045 - val_voltage_fall_time_pulse2_mae: 0.0473 - val_voltage_rise_time_pulse1_loss: 0.0327 - val_voltage_rise_time_pulse1_mae: 0.1169 - val_voltage_rise_time_pulse2_loss: 0.1940 - val_voltage_rise_time_pulse2_mae: 0.2183 - learning_rate: 0.0010
# Epoch 17/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - current_fall_time_pulse1_loss: 0.0114 - current_fall_time_pulse1_mae: 0.0818 - current_fall_time_pulse2_loss: 0.0134 - current_fall_time_pulse2_mae: 0.0892 - current_rise_time_pulse1_loss: 0.0665 - current_rise_time_pulse1_mae: 0.1640 - current_rise_time_pulse2_loss: 0.1021 - current_rise_time_pulse2_mae: 0.2000 - loss: 0.5255 - overshoot_pulse_1_loss: 0.0512 - overshoot_pulse_1_mae: 0.1762 - overshoot_pulse_2_loss: 0.0711 - overshoot_pulse_2_mae: 0.2077 - ringing_frequency_MHz_loss: 0.0023 - ringing_frequency_MHz_mae: 0.0382 - undershoot_pulse_1_loss: 0.0264 - undershoot_pulse_1_mae: 0.1201 - undershoot_pulse_2_loss: 0.0283 - undershoot_pulse_2_mae: 0.1247 - voltage_fall_time_pulse1_loss: 0.0062 - voltage_fall_time_pulse1_mae: 0.0615 - voltage_fall_time_pulse2_loss: 0.0055 - voltage_fall_time_pulse2_mae: 0.0566 - voltage_rise_time_pulse1_loss: 0.0271 - voltage_rise_time_pulse1_mae: 0.1067 - voltage_rise_time_pulse2_loss: 0.1019 - voltage_rise_time_pulse2_mae: 0.2052 - val_current_fall_time_pulse1_loss: 0.0143 - val_current_fall_time_pulse1_mae: 0.0875 - val_current_fall_time_pulse2_loss: 0.0182 - val_current_fall_time_pulse2_mae: 0.1023 - val_current_rise_time_pulse1_loss: 0.0751 - val_current_rise_time_pulse1_mae: 0.1747 - val_current_rise_time_pulse2_loss: 0.1132 - val_current_rise_time_pulse2_mae: 0.2021 - val_loss: 0.7196 - val_overshoot_pulse_1_loss: 0.0778 - val_overshoot_pulse_1_mae: 0.1835 - val_overshoot_pulse_2_loss: 0.0892 - val_overshoot_pulse_2_mae: 0.2065 - val_ringing_frequency_MHz_loss: 0.0021 - val_ringing_frequency_MHz_mae: 0.0373 - val_undershoot_pulse_1_loss: 0.0248 - val_undershoot_pulse_1_mae: 0.1109 - val_undershoot_pulse_2_loss: 0.0328 - val_undershoot_pulse_2_mae: 0.1260 - val_voltage_fall_time_pulse1_loss: 0.0046 - val_voltage_fall_time_pulse1_mae: 0.0547 - val_voltage_fall_time_pulse2_loss: 0.0044 - val_voltage_fall_time_pulse2_mae: 0.0465 - val_voltage_rise_time_pulse1_loss: 0.0321 - val_voltage_rise_time_pulse1_mae: 0.1148 - val_voltage_rise_time_pulse2_loss: 0.1911 - val_voltage_rise_time_pulse2_mae: 0.2159 - learning_rate: 0.0010
# Epoch 18/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - current_fall_time_pulse1_loss: 0.0110 - current_fall_time_pulse1_mae: 0.0806 - current_fall_time_pulse2_loss: 0.0130 - current_fall_time_pulse2_mae: 0.0879 - current_rise_time_pulse1_loss: 0.0660 - current_rise_time_pulse1_mae: 0.1630 - current_rise_time_pulse2_loss: 0.1009 - current_rise_time_pulse2_mae: 0.1981 - loss: 0.5160 - overshoot_pulse_1_loss: 0.0498 - overshoot_pulse_1_mae: 0.1738 - overshoot_pulse_2_loss: 0.0706 - overshoot_pulse_2_mae: 0.2068 - ringing_frequency_MHz_loss: 0.0022 - ringing_frequency_MHz_mae: 0.0370 - undershoot_pulse_1_loss: 0.0258 - undershoot_pulse_1_mae: 0.1187 - undershoot_pulse_2_loss: 0.0279 - undershoot_pulse_2_mae: 0.1238 - voltage_fall_time_pulse1_loss: 0.0059 - voltage_fall_time_pulse1_mae: 0.0601 - voltage_fall_time_pulse2_loss: 0.0053 - voltage_fall_time_pulse2_mae: 0.0554 - voltage_rise_time_pulse1_loss: 0.0263 - voltage_rise_time_pulse1_mae: 0.1045 - voltage_rise_time_pulse2_loss: 0.0990 - voltage_rise_time_pulse2_mae: 0.2030 - val_current_fall_time_pulse1_loss: 0.0141 - val_current_fall_time_pulse1_mae: 0.0865 - val_current_fall_time_pulse2_loss: 0.0175 - val_current_fall_time_pulse2_mae: 0.1000 - val_current_rise_time_pulse1_loss: 0.0746 - val_current_rise_time_pulse1_mae: 0.1734 - val_current_rise_time_pulse2_loss: 0.1119 - val_current_rise_time_pulse2_mae: 0.1996 - val_loss: 0.7102 - val_overshoot_pulse_1_loss: 0.0764 - val_overshoot_pulse_1_mae: 0.1820 - val_overshoot_pulse_2_loss: 0.0886 - val_overshoot_pulse_2_mae: 0.2059 - val_ringing_frequency_MHz_loss: 0.0020 - val_ringing_frequency_MHz_mae: 0.0357 - val_undershoot_pulse_1_loss: 0.0243 - val_undershoot_pulse_1_mae: 0.1100 - val_undershoot_pulse_2_loss: 0.0330 - val_undershoot_pulse_2_mae: 0.1267 - val_voltage_fall_time_pulse1_loss: 0.0045 - val_voltage_fall_time_pulse1_mae: 0.0539 - val_voltage_fall_time_pulse2_loss: 0.0043 - val_voltage_fall_time_pulse2_mae: 0.0463 - val_voltage_rise_time_pulse1_loss: 0.0313 - val_voltage_rise_time_pulse1_mae: 0.1126 - val_voltage_rise_time_pulse2_loss: 0.1883 - val_voltage_rise_time_pulse2_mae: 0.2138 - learning_rate: 0.0010
# Epoch 19/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - current_fall_time_pulse1_loss: 0.0107 - current_fall_time_pulse1_mae: 0.0795 - current_fall_time_pulse2_loss: 0.0125 - current_fall_time_pulse2_mae: 0.0864 - current_rise_time_pulse1_loss: 0.0656 - current_rise_time_pulse1_mae: 0.1620 - current_rise_time_pulse2_loss: 0.0998 - current_rise_time_pulse2_mae: 0.1965 - loss: 0.5072 - overshoot_pulse_1_loss: 0.0485 - overshoot_pulse_1_mae: 0.1715 - overshoot_pulse_2_loss: 0.0701 - overshoot_pulse_2_mae: 0.2060 - ringing_frequency_MHz_loss: 0.0021 - ringing_frequency_MHz_mae: 0.0359 - undershoot_pulse_1_loss: 0.0253 - undershoot_pulse_1_mae: 0.1175 - undershoot_pulse_2_loss: 0.0274 - undershoot_pulse_2_mae: 0.1229 - voltage_fall_time_pulse1_loss: 0.0057 - voltage_fall_time_pulse1_mae: 0.0588 - voltage_fall_time_pulse2_loss: 0.0052 - voltage_fall_time_pulse2_mae: 0.0545 - voltage_rise_time_pulse1_loss: 0.0256 - voltage_rise_time_pulse1_mae: 0.1025 - voltage_rise_time_pulse2_loss: 0.0965 - voltage_rise_time_pulse2_mae: 0.2008 - val_current_fall_time_pulse1_loss: 0.0138 - val_current_fall_time_pulse1_mae: 0.0857 - val_current_fall_time_pulse2_loss: 0.0168 - val_current_fall_time_pulse2_mae: 0.0976 - val_current_rise_time_pulse1_loss: 0.0739 - val_current_rise_time_pulse1_mae: 0.1718 - val_current_rise_time_pulse2_loss: 0.1110 - val_current_rise_time_pulse2_mae: 0.1974 - val_loss: 0.7015 - val_overshoot_pulse_1_loss: 0.0754 - val_overshoot_pulse_1_mae: 0.1808 - val_overshoot_pulse_2_loss: 0.0882 - val_overshoot_pulse_2_mae: 0.2052 - val_ringing_frequency_MHz_loss: 0.0018 - val_ringing_frequency_MHz_mae: 0.0343 - val_undershoot_pulse_1_loss: 0.0238 - val_undershoot_pulse_1_mae: 0.1088 - val_undershoot_pulse_2_loss: 0.0329 - val_undershoot_pulse_2_mae: 0.1264 - val_voltage_fall_time_pulse1_loss: 0.0043 - val_voltage_fall_time_pulse1_mae: 0.0530 - val_voltage_fall_time_pulse2_loss: 0.0042 - val_voltage_fall_time_pulse2_mae: 0.0457 - val_voltage_rise_time_pulse1_loss: 0.0307 - val_voltage_rise_time_pulse1_mae: 0.1104 - val_voltage_rise_time_pulse2_loss: 0.1858 - val_voltage_rise_time_pulse2_mae: 0.2118 - learning_rate: 0.0010
# Epoch 20/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - current_fall_time_pulse1_loss: 0.0104 - current_fall_time_pulse1_mae: 0.0784 - current_fall_time_pulse2_loss: 0.0121 - current_fall_time_pulse2_mae: 0.0849 - current_rise_time_pulse1_loss: 0.0652 - current_rise_time_pulse1_mae: 0.1612 - current_rise_time_pulse2_loss: 0.0987 - current_rise_time_pulse2_mae: 0.1949 - loss: 0.4989 - overshoot_pulse_1_loss: 0.0473 - overshoot_pulse_1_mae: 0.1695 - overshoot_pulse_2_loss: 0.0697 - overshoot_pulse_2_mae: 0.2053 - ringing_frequency_MHz_loss: 0.0020 - ringing_frequency_MHz_mae: 0.0350 - undershoot_pulse_1_loss: 0.0248 - undershoot_pulse_1_mae: 0.1163 - undershoot_pulse_2_loss: 0.0270 - undershoot_pulse_2_mae: 0.1220 - voltage_fall_time_pulse1_loss: 0.0055 - voltage_fall_time_pulse1_mae: 0.0576 - voltage_fall_time_pulse2_loss: 0.0050 - voltage_fall_time_pulse2_mae: 0.0537 - voltage_rise_time_pulse1_loss: 0.0249 - voltage_rise_time_pulse1_mae: 0.1006 - voltage_rise_time_pulse2_loss: 0.0942 - voltage_rise_time_pulse2_mae: 0.1988 - val_current_fall_time_pulse1_loss: 0.0135 - val_current_fall_time_pulse1_mae: 0.0846 - val_current_fall_time_pulse2_loss: 0.0162 - val_current_fall_time_pulse2_mae: 0.0957 - val_current_rise_time_pulse1_loss: 0.0730 - val_current_rise_time_pulse1_mae: 0.1700 - val_current_rise_time_pulse2_loss: 0.1103 - val_current_rise_time_pulse2_mae: 0.1953 - val_loss: 0.6932 - val_overshoot_pulse_1_loss: 0.0745 - val_overshoot_pulse_1_mae: 0.1796 - val_overshoot_pulse_2_loss: 0.0877 - val_overshoot_pulse_2_mae: 0.2050 - val_ringing_frequency_MHz_loss: 0.0017 - val_ringing_frequency_MHz_mae: 0.0332 - val_undershoot_pulse_1_loss: 0.0237 - val_undershoot_pulse_1_mae: 0.1085 - val_undershoot_pulse_2_loss: 0.0329 - val_undershoot_pulse_2_mae: 0.1267 - val_voltage_fall_time_pulse1_loss: 0.0042 - val_voltage_fall_time_pulse1_mae: 0.0518 - val_voltage_fall_time_pulse2_loss: 0.0040 - val_voltage_fall_time_pulse2_mae: 0.0455 - val_voltage_rise_time_pulse1_loss: 0.0301 - val_voltage_rise_time_pulse1_mae: 0.1082 - val_voltage_rise_time_pulse2_loss: 0.1830 - val_voltage_rise_time_pulse2_mae: 0.2103 - learning_rate: 0.0010
# Epoch 21/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - current_fall_time_pulse1_loss: 0.0102 - current_fall_time_pulse1_mae: 0.0775 - current_fall_time_pulse2_loss: 0.0117 - current_fall_time_pulse2_mae: 0.0837 - current_rise_time_pulse1_loss: 0.0648 - current_rise_time_pulse1_mae: 0.1603 - current_rise_time_pulse2_loss: 0.0976 - current_rise_time_pulse2_mae: 0.1934 - loss: 0.4915 - overshoot_pulse_1_loss: 0.0463 - overshoot_pulse_1_mae: 0.1678 - overshoot_pulse_2_loss: 0.0693 - overshoot_pulse_2_mae: 0.2048 - ringing_frequency_MHz_loss: 0.0019 - ringing_frequency_MHz_mae: 0.0341 - undershoot_pulse_1_loss: 0.0245 - undershoot_pulse_1_mae: 0.1154 - undershoot_pulse_2_loss: 0.0266 - undershoot_pulse_2_mae: 0.1211 - voltage_fall_time_pulse1_loss: 0.0053 - voltage_fall_time_pulse1_mae: 0.0565 - voltage_fall_time_pulse2_loss: 0.0048 - voltage_fall_time_pulse2_mae: 0.0529 - voltage_rise_time_pulse1_loss: 0.0242 - voltage_rise_time_pulse1_mae: 0.0986 - voltage_rise_time_pulse2_loss: 0.0920 - voltage_rise_time_pulse2_mae: 0.1970 - val_current_fall_time_pulse1_loss: 0.0136 - val_current_fall_time_pulse1_mae: 0.0848 - val_current_fall_time_pulse2_loss: 0.0156 - val_current_fall_time_pulse2_mae: 0.0938 - val_current_rise_time_pulse1_loss: 0.0724 - val_current_rise_time_pulse1_mae: 0.1686 - val_current_rise_time_pulse2_loss: 0.1101 - val_current_rise_time_pulse2_mae: 0.1937 - val_loss: 0.6866 - val_overshoot_pulse_1_loss: 0.0736 - val_overshoot_pulse_1_mae: 0.1787 - val_overshoot_pulse_2_loss: 0.0875 - val_overshoot_pulse_2_mae: 0.2047 - val_ringing_frequency_MHz_loss: 0.0016 - val_ringing_frequency_MHz_mae: 0.0322 - val_undershoot_pulse_1_loss: 0.0232 - val_undershoot_pulse_1_mae: 0.1073 - val_undershoot_pulse_2_loss: 0.0322 - val_undershoot_pulse_2_mae: 0.1252 - val_voltage_fall_time_pulse1_loss: 0.0041 - val_voltage_fall_time_pulse1_mae: 0.0513 - val_voltage_fall_time_pulse2_loss: 0.0039 - val_voltage_fall_time_pulse2_mae: 0.0450 - val_voltage_rise_time_pulse1_loss: 0.0295 - val_voltage_rise_time_pulse1_mae: 0.1063 - val_voltage_rise_time_pulse2_loss: 0.1813 - val_voltage_rise_time_pulse2_mae: 0.2087 - learning_rate: 0.0010
# Epoch 22/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - current_fall_time_pulse1_loss: 0.0100 - current_fall_time_pulse1_mae: 0.0767 - current_fall_time_pulse2_loss: 0.0114 - current_fall_time_pulse2_mae: 0.0826 - current_rise_time_pulse1_loss: 0.0645 - current_rise_time_pulse1_mae: 0.1596 - current_rise_time_pulse2_loss: 0.0967 - current_rise_time_pulse2_mae: 0.1919 - loss: 0.4845 - overshoot_pulse_1_loss: 0.0454 - overshoot_pulse_1_mae: 0.1662 - overshoot_pulse_2_loss: 0.0689 - overshoot_pulse_2_mae: 0.2041 - ringing_frequency_MHz_loss: 0.0018 - ringing_frequency_MHz_mae: 0.0333 - undershoot_pulse_1_loss: 0.0240 - undershoot_pulse_1_mae: 0.1142 - undershoot_pulse_2_loss: 0.0262 - undershoot_pulse_2_mae: 0.1202 - voltage_fall_time_pulse1_loss: 0.0051 - voltage_fall_time_pulse1_mae: 0.0554 - voltage_fall_time_pulse2_loss: 0.0047 - voltage_fall_time_pulse2_mae: 0.0523 - voltage_rise_time_pulse1_loss: 0.0235 - voltage_rise_time_pulse1_mae: 0.0969 - voltage_rise_time_pulse2_loss: 0.0901 - voltage_rise_time_pulse2_mae: 0.1952 - val_current_fall_time_pulse1_loss: 0.0131 - val_current_fall_time_pulse1_mae: 0.0835 - val_current_fall_time_pulse2_loss: 0.0151 - val_current_fall_time_pulse2_mae: 0.0922 - val_current_rise_time_pulse1_loss: 0.0718 - val_current_rise_time_pulse1_mae: 0.1676 - val_current_rise_time_pulse2_loss: 0.1096 - val_current_rise_time_pulse2_mae: 0.1924 - val_loss: 0.6795 - val_overshoot_pulse_1_loss: 0.0730 - val_overshoot_pulse_1_mae: 0.1780 - val_overshoot_pulse_2_loss: 0.0871 - val_overshoot_pulse_2_mae: 0.2043 - val_ringing_frequency_MHz_loss: 0.0016 - val_ringing_frequency_MHz_mae: 0.0314 - val_undershoot_pulse_1_loss: 0.0229 - val_undershoot_pulse_1_mae: 0.1066 - val_undershoot_pulse_2_loss: 0.0318 - val_undershoot_pulse_2_mae: 0.1243 - val_voltage_fall_time_pulse1_loss: 0.0040 - val_voltage_fall_time_pulse1_mae: 0.0503 - val_voltage_fall_time_pulse2_loss: 0.0038 - val_voltage_fall_time_pulse2_mae: 0.0449 - val_voltage_rise_time_pulse1_loss: 0.0290 - val_voltage_rise_time_pulse1_mae: 0.1047 - val_voltage_rise_time_pulse2_loss: 0.1794 - val_voltage_rise_time_pulse2_mae: 0.2075 - learning_rate: 0.0010
# Epoch 23/100
# ...
# Epoch 88/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - current_fall_time_pulse1_loss: 0.0036 - current_fall_time_pulse1_mae: 0.0461 - current_fall_time_pulse2_loss: 0.0037 - current_fall_time_pulse2_mae: 0.0469 - current_rise_time_pulse1_loss: 0.0562 - current_rise_time_pulse1_mae: 0.1454 - current_rise_time_pulse2_loss: 0.0648 - current_rise_time_pulse2_mae: 0.1436 - loss: 0.3206 - overshoot_pulse_1_loss: 0.0272 - overshoot_pulse_1_mae: 0.1289 - overshoot_pulse_2_loss: 0.0562 - overshoot_pulse_2_mae: 0.1836 - ringing_frequency_MHz_loss: 4.9617e-04 - ringing_frequency_MHz_mae: 0.0175 - undershoot_pulse_1_loss: 0.0145 - undershoot_pulse_1_mae: 0.0863 - undershoot_pulse_2_loss: 0.0137 - undershoot_pulse_2_mae: 0.0857 - voltage_fall_time_pulse1_loss: 0.0014 - voltage_fall_time_pulse1_mae: 0.0291 - voltage_fall_time_pulse2_loss: 0.0015 - voltage_fall_time_pulse2_mae: 0.0288 - voltage_rise_time_pulse1_loss: 0.0101 - voltage_rise_time_pulse1_mae: 0.0551 - voltage_rise_time_pulse2_loss: 0.0555 - voltage_rise_time_pulse2_mae: 0.1590 - val_current_fall_time_pulse1_loss: 0.0025 - val_current_fall_time_pulse1_mae: 0.0381 - val_current_fall_time_pulse2_loss: 0.0029 - val_current_fall_time_pulse2_mae: 0.0409 - val_current_rise_time_pulse1_loss: 0.0648 - val_current_rise_time_pulse1_mae: 0.1585 - val_current_rise_time_pulse2_loss: 0.1017 - val_current_rise_time_pulse2_mae: 0.1530 - val_loss: 0.5396 - val_overshoot_pulse_1_loss: 0.0543 - val_overshoot_pulse_1_mae: 0.1449 - val_overshoot_pulse_2_loss: 0.0785 - val_overshoot_pulse_2_mae: 0.1970 - val_ringing_frequency_MHz_loss: 4.4124e-04 - val_ringing_frequency_MHz_mae: 0.0174 - val_undershoot_pulse_1_loss: 0.0148 - val_undershoot_pulse_1_mae: 0.0838 - val_undershoot_pulse_2_loss: 0.0158 - val_undershoot_pulse_2_mae: 0.0867 - val_voltage_fall_time_pulse1_loss: 0.0014 - val_voltage_fall_time_pulse1_mae: 0.0275 - val_voltage_fall_time_pulse2_loss: 0.0016 - val_voltage_fall_time_pulse2_mae: 0.0282 - val_voltage_rise_time_pulse1_loss: 0.0140 - val_voltage_rise_time_pulse1_mae: 0.0626 - val_voltage_rise_time_pulse2_loss: 0.1537 - val_voltage_rise_time_pulse2_mae: 0.1874 - learning_rate: 3.1250e-05
# Epoch 89/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - current_fall_time_pulse1_loss: 0.0036 - current_fall_time_pulse1_mae: 0.0461 - current_fall_time_pulse2_loss: 0.0037 - current_fall_time_pulse2_mae: 0.0469 - current_rise_time_pulse1_loss: 0.0562 - current_rise_time_pulse1_mae: 0.1452 - current_rise_time_pulse2_loss: 0.0648 - current_rise_time_pulse2_mae: 0.1435 - loss: 0.3200 - overshoot_pulse_1_loss: 0.0269 - overshoot_pulse_1_mae: 0.1283 - overshoot_pulse_2_loss: 0.0561 - overshoot_pulse_2_mae: 0.1833 - ringing_frequency_MHz_loss: 4.9451e-04 - ringing_frequency_MHz_mae: 0.0175 - undershoot_pulse_1_loss: 0.0145 - undershoot_pulse_1_mae: 0.0862 - undershoot_pulse_2_loss: 0.0137 - undershoot_pulse_2_mae: 0.0856 - voltage_fall_time_pulse1_loss: 0.0014 - voltage_fall_time_pulse1_mae: 0.0290 - voltage_fall_time_pulse2_loss: 0.0015 - voltage_fall_time_pulse2_mae: 0.0288 - voltage_rise_time_pulse1_loss: 0.0100 - voltage_rise_time_pulse1_mae: 0.0550 - voltage_rise_time_pulse2_loss: 0.0554 - voltage_rise_time_pulse2_mae: 0.1588 - val_current_fall_time_pulse1_loss: 0.0025 - val_current_fall_time_pulse1_mae: 0.0381 - val_current_fall_time_pulse2_loss: 0.0029 - val_current_fall_time_pulse2_mae: 0.0409 - val_current_rise_time_pulse1_loss: 0.0649 - val_current_rise_time_pulse1_mae: 0.1585 - val_current_rise_time_pulse2_loss: 0.1018 - val_current_rise_time_pulse2_mae: 0.1530 - val_loss: 0.5393 - val_overshoot_pulse_1_loss: 0.0543 - val_overshoot_pulse_1_mae: 0.1450 - val_overshoot_pulse_2_loss: 0.0786 - val_overshoot_pulse_2_mae: 0.1971 - val_ringing_frequency_MHz_loss: 4.4121e-04 - val_ringing_frequency_MHz_mae: 0.0173 - val_undershoot_pulse_1_loss: 0.0148 - val_undershoot_pulse_1_mae: 0.0838 - val_undershoot_pulse_2_loss: 0.0158 - val_undershoot_pulse_2_mae: 0.0867 - val_voltage_fall_time_pulse1_loss: 0.0014 - val_voltage_fall_time_pulse1_mae: 0.0276 - val_voltage_fall_time_pulse2_loss: 0.0016 - val_voltage_fall_time_pulse2_mae: 0.0282 - val_voltage_rise_time_pulse1_loss: 0.0140 - val_voltage_rise_time_pulse1_mae: 0.0625 - val_voltage_rise_time_pulse2_loss: 0.1535 - val_voltage_rise_time_pulse2_mae: 0.1874 - learning_rate: 3.1250e-05
# Epoch 90/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - current_fall_time_pulse1_loss: 0.0036 - current_fall_time_pulse1_mae: 0.0461 - current_fall_time_pulse2_loss: 0.0037 - current_fall_time_pulse2_mae: 0.0469 - current_rise_time_pulse1_loss: 0.0562 - current_rise_time_pulse1_mae: 0.1452 - current_rise_time_pulse2_loss: 0.0647 - current_rise_time_pulse2_mae: 0.1434 - loss: 0.3200 - overshoot_pulse_1_loss: 0.0269 - overshoot_pulse_1_mae: 0.1283 - overshoot_pulse_2_loss: 0.0561 - overshoot_pulse_2_mae: 0.1833 - ringing_frequency_MHz_loss: 4.9369e-04 - ringing_frequency_MHz_mae: 0.0175 - undershoot_pulse_1_loss: 0.0145 - undershoot_pulse_1_mae: 0.0862 - undershoot_pulse_2_loss: 0.0137 - undershoot_pulse_2_mae: 0.0856 - voltage_fall_time_pulse1_loss: 0.0014 - voltage_fall_time_pulse1_mae: 0.0290 - voltage_fall_time_pulse2_loss: 0.0015 - voltage_fall_time_pulse2_mae: 0.0288 - voltage_rise_time_pulse1_loss: 0.0100 - voltage_rise_time_pulse1_mae: 0.0550 - voltage_rise_time_pulse2_loss: 0.0554 - voltage_rise_time_pulse2_mae: 0.1588 - val_current_fall_time_pulse1_loss: 0.0025 - val_current_fall_time_pulse1_mae: 0.0381 - val_current_fall_time_pulse2_loss: 0.0029 - val_current_fall_time_pulse2_mae: 0.0410 - val_current_rise_time_pulse1_loss: 0.0649 - val_current_rise_time_pulse1_mae: 0.1584 - val_current_rise_time_pulse2_loss: 0.1017 - val_current_rise_time_pulse2_mae: 0.1530 - val_loss: 0.5394 - val_overshoot_pulse_1_loss: 0.0543 - val_overshoot_pulse_1_mae: 0.1450 - val_overshoot_pulse_2_loss: 0.0785 - val_overshoot_pulse_2_mae: 0.1971 - val_ringing_frequency_MHz_loss: 4.4113e-04 - val_ringing_frequency_MHz_mae: 0.0174 - val_undershoot_pulse_1_loss: 0.0148 - val_undershoot_pulse_1_mae: 0.0838 - val_undershoot_pulse_2_loss: 0.0158 - val_undershoot_pulse_2_mae: 0.0867 - val_voltage_fall_time_pulse1_loss: 0.0014 - val_voltage_fall_time_pulse1_mae: 0.0276 - val_voltage_fall_time_pulse2_loss: 0.0016 - val_voltage_fall_time_pulse2_mae: 0.0282 - val_voltage_rise_time_pulse1_loss: 0.0140 - val_voltage_rise_time_pulse1_mae: 0.0625 - val_voltage_rise_time_pulse2_loss: 0.1535 - val_voltage_rise_time_pulse2_mae: 0.1874 - learning_rate: 3.1250e-05
# Epoch 91/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - current_fall_time_pulse1_loss: 0.0035 - current_fall_time_pulse1_mae: 0.0460 - current_fall_time_pulse2_loss: 0.0037 - current_fall_time_pulse2_mae: 0.0468 - current_rise_time_pulse1_loss: 0.0562 - current_rise_time_pulse1_mae: 0.1453 - current_rise_time_pulse2_loss: 0.0647 - current_rise_time_pulse2_mae: 0.1433 - loss: 0.3196 - overshoot_pulse_1_loss: 0.0269 - overshoot_pulse_1_mae: 0.1282 - overshoot_pulse_2_loss: 0.0561 - overshoot_pulse_2_mae: 0.1833 - ringing_frequency_MHz_loss: 4.9293e-04 - ringing_frequency_MHz_mae: 0.0175 - undershoot_pulse_1_loss: 0.0145 - undershoot_pulse_1_mae: 0.0861 - undershoot_pulse_2_loss: 0.0137 - undershoot_pulse_2_mae: 0.0855 - voltage_fall_time_pulse1_loss: 0.0014 - voltage_fall_time_pulse1_mae: 0.0290 - voltage_fall_time_pulse2_loss: 0.0015 - voltage_fall_time_pulse2_mae: 0.0288 - voltage_rise_time_pulse1_loss: 0.0100 - voltage_rise_time_pulse1_mae: 0.0549 - voltage_rise_time_pulse2_loss: 0.0553 - voltage_rise_time_pulse2_mae: 0.1588 - val_current_fall_time_pulse1_loss: 0.0025 - val_current_fall_time_pulse1_mae: 0.0381 - val_current_fall_time_pulse2_loss: 0.0029 - val_current_fall_time_pulse2_mae: 0.0409 - val_current_rise_time_pulse1_loss: 0.0649 - val_current_rise_time_pulse1_mae: 0.1584 - val_current_rise_time_pulse2_loss: 0.1017 - val_current_rise_time_pulse2_mae: 0.1530 - val_loss: 0.5398 - val_overshoot_pulse_1_loss: 0.0543 - val_overshoot_pulse_1_mae: 0.1448 - val_overshoot_pulse_2_loss: 0.0785 - val_overshoot_pulse_2_mae: 0.1969 - val_ringing_frequency_MHz_loss: 4.4117e-04 - val_ringing_frequency_MHz_mae: 0.0173 - val_undershoot_pulse_1_loss: 0.0148 - val_undershoot_pulse_1_mae: 0.0838 - val_undershoot_pulse_2_loss: 0.0158 - val_undershoot_pulse_2_mae: 0.0867 - val_voltage_fall_time_pulse1_loss: 0.0014 - val_voltage_fall_time_pulse1_mae: 0.0275 - val_voltage_fall_time_pulse2_loss: 0.0016 - val_voltage_fall_time_pulse2_mae: 0.0282 - val_voltage_rise_time_pulse1_loss: 0.0140 - val_voltage_rise_time_pulse1_mae: 0.0625 - val_voltage_rise_time_pulse2_loss: 0.1539 - val_voltage_rise_time_pulse2_mae: 0.1874 - learning_rate: 1.5625e-05
# Epoch 92/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - current_fall_time_pulse1_loss: 0.0036 - current_fall_time_pulse1_mae: 0.0460 - current_fall_time_pulse2_loss: 0.0037 - current_fall_time_pulse2_mae: 0.0468 - current_rise_time_pulse1_loss: 0.0562 - current_rise_time_pulse1_mae: 0.1452 - current_rise_time_pulse2_loss: 0.0646 - current_rise_time_pulse2_mae: 0.1433 - loss: 0.3194 - overshoot_pulse_1_loss: 0.0268 - overshoot_pulse_1_mae: 0.1281 - overshoot_pulse_2_loss: 0.0560 - overshoot_pulse_2_mae: 0.1832 - ringing_frequency_MHz_loss: 4.9177e-04 - ringing_frequency_MHz_mae: 0.0174 - undershoot_pulse_1_loss: 0.0145 - undershoot_pulse_1_mae: 0.0861 - undershoot_pulse_2_loss: 0.0137 - undershoot_pulse_2_mae: 0.0854 - voltage_fall_time_pulse1_loss: 0.0014 - voltage_fall_time_pulse1_mae: 0.0290 - voltage_fall_time_pulse2_loss: 0.0014 - voltage_fall_time_pulse2_mae: 0.0287 - voltage_rise_time_pulse1_loss: 0.0100 - voltage_rise_time_pulse1_mae: 0.0549 - voltage_rise_time_pulse2_loss: 0.0553 - voltage_rise_time_pulse2_mae: 0.1587 - val_current_fall_time_pulse1_loss: 0.0025 - val_current_fall_time_pulse1_mae: 0.0381 - val_current_fall_time_pulse2_loss: 0.0029 - val_current_fall_time_pulse2_mae: 0.0409 - val_current_rise_time_pulse1_loss: 0.0649 - val_current_rise_time_pulse1_mae: 0.1583 - val_current_rise_time_pulse2_loss: 0.1017 - val_current_rise_time_pulse2_mae: 0.1530 - val_loss: 0.5399 - val_overshoot_pulse_1_loss: 0.0543 - val_overshoot_pulse_1_mae: 0.1447 - val_overshoot_pulse_2_loss: 0.0784 - val_overshoot_pulse_2_mae: 0.1969 - val_ringing_frequency_MHz_loss: 4.4094e-04 - val_ringing_frequency_MHz_mae: 0.0173 - val_undershoot_pulse_1_loss: 0.0148 - val_undershoot_pulse_1_mae: 0.0838 - val_undershoot_pulse_2_loss: 0.0158 - val_undershoot_pulse_2_mae: 0.0867 - val_voltage_fall_time_pulse1_loss: 0.0014 - val_voltage_fall_time_pulse1_mae: 0.0275 - val_voltage_fall_time_pulse2_loss: 0.0016 - val_voltage_fall_time_pulse2_mae: 0.0282 - val_voltage_rise_time_pulse1_loss: 0.0140 - val_voltage_rise_time_pulse1_mae: 0.0625 - val_voltage_rise_time_pulse2_loss: 0.1540 - val_voltage_rise_time_pulse2_mae: 0.1874 - learning_rate: 1.5625e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# train:
#                        Target        R2          RMSE
# 3   voltage_fall_time_pulse2  0.998909  2.260635e-10
# 2   voltage_fall_time_pulse1  0.998872  2.301607e-10
# 6   current_fall_time_pulse1  0.997892  5.391787e-10
# 7   current_fall_time_pulse2  0.997673  5.643914e-10
# 12     ringing_frequency_MHz  0.993974  2.550473e+00
# 0   voltage_rise_time_pulse1  0.991178  3.784552e-10
# 11        undershoot_pulse_2  0.988818  1.467432e+00
# 10        undershoot_pulse_1  0.988205  1.504162e+00
# 8          overshoot_pulse_1  0.975838  1.789765e+00
# 4   current_rise_time_pulse1  0.944083  1.154686e-08
# 9          overshoot_pulse_2  0.942570  5.930406e+00
# 1   voltage_rise_time_pulse2  0.939287  9.467240e-10
# 5   current_rise_time_pulse2  0.928856  6.578344e-09
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# val:
#                        Target        R2          RMSE
# 2   voltage_fall_time_pulse1  0.998578  2.663749e-10
# 3   voltage_fall_time_pulse2  0.998438  2.787195e-10
# 6   current_fall_time_pulse1  0.997296  6.204040e-10
# 7   current_fall_time_pulse2  0.997004  6.515983e-10
# 12     ringing_frequency_MHz  0.994011  2.619037e+00
# 0   voltage_rise_time_pulse1  0.985347  5.112591e-10
# 10        undershoot_pulse_1  0.983249  1.773476e+00
# 11        undershoot_pulse_2  0.981291  1.869239e+00
# 8          overshoot_pulse_1  0.947265  2.874802e+00
# 4   current_rise_time_pulse1  0.932617  1.293860e-08
# 9          overshoot_pulse_2  0.928856  6.933884e+00
# 5   current_rise_time_pulse2  0.921568  7.152976e-09
# 1   voltage_rise_time_pulse2  0.849013  1.635460e-09
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# test:
#                        Target        R2          RMSE
# 3   voltage_fall_time_pulse2  0.998835  2.347175e-10
# 2   voltage_fall_time_pulse1  0.998825  2.359484e-10
# 6   current_fall_time_pulse1  0.997800  5.521268e-10
# 7   current_fall_time_pulse2  0.997570  5.783135e-10
# 12     ringing_frequency_MHz  0.993980  2.560876e+00
# 0   voltage_rise_time_pulse1  0.990232  4.011916e-10
# 11        undershoot_pulse_2  0.987719  1.534435e+00
# 10        undershoot_pulse_1  0.987475  1.547556e+00
# 8          overshoot_pulse_1  0.970910  1.990618e+00
# 4   current_rise_time_pulse1  0.942304  1.176616e-08
# 9          overshoot_pulse_2  0.940336  6.091500e+00
# 5   current_rise_time_pulse2  0.927719  6.667710e-09
# 1   voltage_rise_time_pulse2  0.923544  1.078468e-09
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# unseen:
#                        Target        R2          RMSE
# 7   current_fall_time_pulse2  0.976606  1.705820e-09
# 6   current_fall_time_pulse1  0.916178  3.251214e-09
# 2   voltage_fall_time_pulse1  0.766286  1.125194e-09
# 9          overshoot_pulse_2  0.708183  1.073223e+01
# 3   voltage_fall_time_pulse2  0.698288  1.279096e-09
# 8          overshoot_pulse_1  0.668247  7.316996e+00
# 11        undershoot_pulse_2  0.549278  6.393890e+00
# 0   voltage_rise_time_pulse1  0.427653  1.318961e-09
# 10        undershoot_pulse_1  0.308612  7.976464e+00
# 5   current_rise_time_pulse2  0.022475  1.641188e-08
#                       Target        R2          RMSE
# 7   current_fall_time_pulse2  0.976606  1.705820e-09
# 6   current_fall_time_pulse1  0.916178  3.251214e-09
# 2   voltage_fall_time_pulse1  0.766286  1.125194e-09
# 9          overshoot_pulse_2  0.708183  1.073223e+01
# 3   voltage_fall_time_pulse2  0.698288  1.279096e-09
# 8          overshoot_pulse_1  0.668247  7.316996e+00
# 11        undershoot_pulse_2  0.549278  6.393890e+00
# 0   voltage_rise_time_pulse1  0.427653  1.318961e-09
# 10        undershoot_pulse_1  0.308612  7.976464e+00
# 5   current_rise_time_pulse2  0.022475  1.641188e-08

# %%
# ==================== MULTI-HEAD ANN (FAST MODE) ====================
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, regularizers
import matplotlib.pyplot as plt

# ============== SETTINGS ==============
SEED = 42
UNSEEN_PART = 'C2M0040120D'
BASE_DIR = "iteration_2"
os.makedirs(f"{BASE_DIR}/r2_rmse_tables", exist_ok=True)
os.makedirs(f"{BASE_DIR}/train_val_loss_curves", exist_ok=True)
os.makedirs(f"{BASE_DIR}/predicted_vs_actual", exist_ok=True)
os.makedirs(f"{BASE_DIR}/models", exist_ok=True)

# ============== LOAD DATA ==============
df = pd.read_csv(
    r"C:\Users\pc\Desktop\Neural_Network_Models\merged_train_5_MOSFETs_10percent_balanced.csv"
)

# ============== TARGETS + DROPS ==============
TARGET_COLUMNS = [
    'voltage_rise_time_pulse1', 'voltage_rise_time_pulse2',
    'voltage_fall_time_pulse1', 'voltage_fall_time_pulse2',
    'current_rise_time_pulse1', 'current_rise_time_pulse2',
    'current_fall_time_pulse1', 'current_fall_time_pulse2',
    'overshoot_pulse_1', 'overshoot_pulse_2',
    'undershoot_pulse_1', 'undershoot_pulse_2',
    'ringing_frequency_MHz'
]
DROP_COLUMNS = ['DeviceID', 'MOSFET', 'Part_Number']

# ============== SPLIT SEEN/UNSEEN DEVICES ==============
seen_parts = [p for p in df['Part_Number'].unique().tolist() if p != UNSEEN_PART]
train_df = df[df['Part_Number'].isin(seen_parts)].copy()
test_df  = df[df['Part_Number'] == UNSEEN_PART].copy()

# ============== PHYSICS FEATURES ==============
def compute_physics_features(row):
    L_eq = row[['Ls4','Ls5','Ls6','Ls7','Ls8','Ls9','Ls10','Ls11']].sum()
    C_eq = row.get("Coss", 1e-12)
    f_res = 1/(2*np.pi*np.sqrt(L_eq*C_eq))/1e6 if L_eq>0 and C_eq>0 else 0
    overshoot_est = row.get("VDS_max",0) - row.get("Vbus",0)
    undershoot_est = - row.get("VGS_th_min",0)
    dVdt_est = row.get("VDS_max",0)/row.get("Tp1",1e-9)
    dIdt_est = row.get("ID_max_25C",0)/row.get("Tp1",1e-9)
    return pd.Series([f_res, overshoot_est, undershoot_est, dVdt_est, dIdt_est])

for df_ in [train_df, test_df]:
    df_[['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est']] = \
        df_.apply(compute_physics_features, axis=1)

physics_features = ['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est']
INPUT_COLUMNS = [c for c in df.columns if c not in TARGET_COLUMNS + DROP_COLUMNS] + physics_features

# ============== SCALE INPUTS ==============
input_scaler = StandardScaler()
input_scaler.fit(pd.concat([train_df[INPUT_COLUMNS], test_df[INPUT_COLUMNS]]))
X_train_all = input_scaler.transform(train_df[INPUT_COLUMNS])
X_test_all  = input_scaler.transform(test_df[INPUT_COLUMNS])

# Separate physics cols
phys_idx = [INPUT_COLUMNS.index(c) for c in physics_features]
X_train_phys = X_train_all[:, phys_idx]
X_test_phys  = X_test_all[:, phys_idx]
X_train_main = np.delete(X_train_all, phys_idx, axis=1)
X_test_main  = np.delete(X_test_all, phys_idx, axis=1)

# ============== SCALE OUTPUTS (per target) ==============
output_scalers, y_train_scaled, y_test_scaled = {}, [], []
for col in TARGET_COLUMNS:
    scaler = MinMaxScaler() if col == 'ringing_frequency_MHz' else StandardScaler()
    y_train_scaled.append(scaler.fit_transform(train_df[[col]]).flatten())
    y_test_scaled.append(scaler.transform(test_df[[col]]).flatten())
    output_scalers[col] = scaler
y_train_scaled = np.array(y_train_scaled).T
y_test_scaled  = np.array(y_test_scaled).T

# ============== SPLIT TRAIN/VAL ==============
Xtr_main, Xval_main, Xtr_phys, Xval_phys, ytr, yval = train_test_split(
    X_train_main, X_train_phys, y_train_scaled,
    test_size=0.15, random_state=SEED
)

# ============== BUILD MULTI-HEAD ANN (FAST BACKBONE) ==============
def build_multihead_ann(input_dim_main, input_dim_phys, output_dim, l2_reg=1e-4, dropout_rate=0.2):
    inp_main = layers.Input(shape=(input_dim_main,), name="main_inputs")
    inp_phys = layers.Input(shape=(input_dim_phys,), name="physics_inputs")

    # Shared backbone
    x_main = layers.Dense(128, kernel_regularizer=regularizers.l2(l2_reg))(inp_main)
    x_main = layers.BatchNormalization()(x_main); x_main = layers.ReLU()(x_main)
    x_main = layers.Dropout(dropout_rate)(x_main)

    x_main = layers.Dense(64, kernel_regularizer=regularizers.l2(l2_reg))(x_main)
    x_main = layers.BatchNormalization()(x_main); x_main = layers.ReLU()(x_main)
    x_main = layers.Dropout(dropout_rate)(x_main)

    x_phys = layers.Dense(32, activation="relu")(inp_phys)

    shared = layers.concatenate([x_main, x_phys])

    # Multi-head outputs (deeper per-head)
    outputs = []
    for i, col in enumerate(TARGET_COLUMNS):
        h = layers.Dense(64, activation="relu")(shared)
        h = layers.Dropout(dropout_rate)(h)
        h = layers.Dense(32, activation="relu")(h)
        out = layers.Dense(1, activation="linear", name=col)(h)
        outputs.append(out)

    model = models.Model(inputs=[inp_main, inp_phys], outputs=outputs)
    return model

model = build_multihead_ann(Xtr_main.shape[1], Xtr_phys.shape[1], len(TARGET_COLUMNS))

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-4),
    loss=["mse"]*len(TARGET_COLUMNS),
    metrics=["mae"]*len(TARGET_COLUMNS)
)

early_stop = callbacks.EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)
reduce_lr  = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=5)

history = model.fit(
    [Xtr_main, Xtr_phys],
    [ytr[:,i] for i in range(len(TARGET_COLUMNS))],
    validation_data=([Xval_main,Xval_phys],[yval[:,i] for i in range(len(TARGET_COLUMNS))]),
    epochs=120, batch_size=256, callbacks=[early_stop, reduce_lr], verbose=1
)


model.save(f"{BASE_DIR}/models/multihead_ann.h5")

# ============== LOSS CURVE ==============
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel("Epoch"); plt.ylabel("MSE Loss")
plt.title("Train vs Validation Loss")
plt.legend(); plt.savefig(f"{BASE_DIR}/train_val_loss_curves/loss.png"); plt.close()

# ============== EVALUATION ==============
def evaluate_and_save(X_main, X_phys, y_scaled, name, positive_only=False):
    y_pred_scaled_list = model.predict([X_main, X_phys])
    results = []
    for i, col in enumerate(TARGET_COLUMNS):
        y_true = output_scalers[col].inverse_transform(y_scaled[:,i].reshape(-1,1)).flatten()
        y_pred = output_scalers[col].inverse_transform(y_pred_scaled_list[i].reshape(-1,1)).flatten()
        r2 = r2_score(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        results.append((col, r2, rmse))
    df_results = pd.DataFrame(results, columns=["Target","R2","RMSE"]).sort_values("R2",ascending=False)
    if positive_only:
        df_results = df_results[df_results["R2"]>0]
    print(f"\n{name}:\n",df_results)
    df_results.to_csv(f"{BASE_DIR}/r2_rmse_tables/{name}.csv", index=False)
    return df_results

# Run evals
evaluate_and_save(Xtr_main,Xtr_phys,ytr,"train")
evaluate_and_save(Xval_main,Xval_phys,yval,"val")
evaluate_and_save(X_train_main,X_train_phys,y_train_scaled,"test")
evaluate_and_save(X_test_main,X_test_phys,y_test_scaled,"unseen",positive_only=True)
# Out:
# Epoch 1/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 11s 44ms/step - current_fall_time_pulse1_loss: 1.8545 - current_fall_time_pulse1_mae: 1.0631 - current_fall_time_pulse2_loss: 0.9453 - current_fall_time_pulse2_mae: 0.7743 - current_rise_time_pulse1_loss: 0.7775 - current_rise_time_pulse1_mae: 0.6624 - current_rise_time_pulse2_loss: 0.9183 - current_rise_time_pulse2_mae: 0.7812 - loss: 11.8151 - overshoot_pulse_1_loss: 0.9212 - overshoot_pulse_1_mae: 0.7356 - overshoot_pulse_2_loss: 1.0398 - overshoot_pulse_2_mae: 0.8038 - ringing_frequency_MHz_loss: 0.1362 - ringing_frequency_MHz_mae: 0.2772 - undershoot_pulse_1_loss: 0.9903 - undershoot_pulse_1_mae: 0.7538 - undershoot_pulse_2_loss: 1.1218 - undershoot_pulse_2_mae: 0.8164 - voltage_fall_time_pulse1_loss: 0.7839 - voltage_fall_time_pulse1_mae: 0.6971 - voltage_fall_time_pulse2_loss: 0.7918 - voltage_fall_time_pulse2_mae: 0.7050 - voltage_rise_time_pulse1_loss: 0.8400 - voltage_rise_time_pulse1_mae: 0.6760 - voltage_rise_time_pulse2_loss: 0.6780 - voltage_rise_time_pulse2_mae: 0.6185 - val_current_fall_time_pulse1_loss: 0.6760 - val_current_fall_time_pulse1_mae: 0.6608 - val_current_fall_time_pulse2_loss: 0.5488 - val_current_fall_time_pulse2_mae: 0.5457 - val_current_rise_time_pulse1_loss: 0.3524 - val_current_rise_time_pulse1_mae: 0.4833 - val_current_rise_time_pulse2_loss: 0.3965 - val_current_rise_time_pulse2_mae: 0.5130 - val_loss: 5.1784 - val_overshoot_pulse_1_loss: 0.7689 - val_overshoot_pulse_1_mae: 0.6660 - val_overshoot_pulse_2_loss: 0.4107 - val_overshoot_pulse_2_mae: 0.4862 - val_ringing_frequency_MHz_loss: 0.0508 - val_ringing_frequency_MHz_mae: 0.2046 - val_undershoot_pulse_1_loss: 0.4741 - val_undershoot_pulse_1_mae: 0.5755 - val_undershoot_pulse_2_loss: 0.4466 - val_undershoot_pulse_2_mae: 0.5495 - val_voltage_fall_time_pulse1_loss: 0.1637 - val_voltage_fall_time_pulse1_mae: 0.2556 - val_voltage_fall_time_pulse2_loss: 0.1902 - val_voltage_fall_time_pulse2_mae: 0.3032 - val_voltage_rise_time_pulse1_loss: 0.2029 - val_voltage_rise_time_pulse1_mae: 0.2920 - val_voltage_rise_time_pulse2_loss: 0.4652 - val_voltage_rise_time_pulse2_mae: 0.4284 - learning_rate: 5.0000e-04
# Epoch 2/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - current_fall_time_pulse1_loss: 0.5353 - current_fall_time_pulse1_mae: 0.5795 - current_fall_time_pulse2_loss: 0.4116 - current_fall_time_pulse2_mae: 0.5035 - current_rise_time_pulse1_loss: 0.3067 - current_rise_time_pulse1_mae: 0.4243 - current_rise_time_pulse2_loss: 0.4200 - current_rise_time_pulse2_mae: 0.5281 - loss: 4.5612 - overshoot_pulse_1_loss: 0.5846 - overshoot_pulse_1_mae: 0.5863 - overshoot_pulse_2_loss: 0.3840 - overshoot_pulse_2_mae: 0.4850 - ringing_frequency_MHz_loss: 0.0427 - ringing_frequency_MHz_mae: 0.1598 - undershoot_pulse_1_loss: 0.4754 - undershoot_pulse_1_mae: 0.5379 - undershoot_pulse_2_loss: 0.4627 - undershoot_pulse_2_mae: 0.5333 - voltage_fall_time_pulse1_loss: 0.1822 - voltage_fall_time_pulse1_mae: 0.3186 - voltage_fall_time_pulse2_loss: 0.2025 - voltage_fall_time_pulse2_mae: 0.3484 - voltage_rise_time_pulse1_loss: 0.2009 - voltage_rise_time_pulse1_mae: 0.3431 - voltage_rise_time_pulse2_loss: 0.3384 - voltage_rise_time_pulse2_mae: 0.4198 - val_current_fall_time_pulse1_loss: 0.3808 - val_current_fall_time_pulse1_mae: 0.4903 - val_current_fall_time_pulse2_loss: 0.3464 - val_current_fall_time_pulse2_mae: 0.4292 - val_current_rise_time_pulse1_loss: 0.2687 - val_current_rise_time_pulse1_mae: 0.4147 - val_current_rise_time_pulse2_loss: 0.3307 - val_current_rise_time_pulse2_mae: 0.4785 - val_loss: 3.8865 - val_overshoot_pulse_1_loss: 0.6007 - val_overshoot_pulse_1_mae: 0.5797 - val_overshoot_pulse_2_loss: 0.3347 - val_overshoot_pulse_2_mae: 0.4252 - val_ringing_frequency_MHz_loss: 0.0367 - val_ringing_frequency_MHz_mae: 0.1714 - val_undershoot_pulse_1_loss: 0.2912 - val_undershoot_pulse_1_mae: 0.4495 - val_undershoot_pulse_2_loss: 0.3266 - val_undershoot_pulse_2_mae: 0.4662 - val_voltage_fall_time_pulse1_loss: 0.1717 - val_voltage_fall_time_pulse1_mae: 0.3109 - val_voltage_fall_time_pulse2_loss: 0.1505 - val_voltage_fall_time_pulse2_mae: 0.2772 - val_voltage_rise_time_pulse1_loss: 0.1503 - val_voltage_rise_time_pulse1_mae: 0.2766 - val_voltage_rise_time_pulse2_loss: 0.4458 - val_voltage_rise_time_pulse2_mae: 0.4095 - learning_rate: 5.0000e-04
# Epoch 3/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.3047 - current_fall_time_pulse1_mae: 0.4308 - current_fall_time_pulse2_loss: 0.2429 - current_fall_time_pulse2_mae: 0.3802 - current_rise_time_pulse1_loss: 0.2386 - current_rise_time_pulse1_mae: 0.3659 - current_rise_time_pulse2_loss: 0.3465 - current_rise_time_pulse2_mae: 0.4741 - loss: 3.2049 - overshoot_pulse_1_loss: 0.4551 - overshoot_pulse_1_mae: 0.5090 - overshoot_pulse_2_loss: 0.2865 - overshoot_pulse_2_mae: 0.4170 - ringing_frequency_MHz_loss: 0.0301 - ringing_frequency_MHz_mae: 0.1339 - undershoot_pulse_1_loss: 0.2862 - undershoot_pulse_1_mae: 0.4147 - undershoot_pulse_2_loss: 0.2814 - undershoot_pulse_2_mae: 0.4133 - voltage_fall_time_pulse1_loss: 0.1194 - voltage_fall_time_pulse1_mae: 0.2614 - voltage_fall_time_pulse2_loss: 0.1490 - voltage_fall_time_pulse2_mae: 0.2928 - voltage_rise_time_pulse1_loss: 0.1594 - voltage_rise_time_pulse1_mae: 0.2980 - voltage_rise_time_pulse2_loss: 0.2913 - voltage_rise_time_pulse2_mae: 0.3689 - val_current_fall_time_pulse1_loss: 0.2449 - val_current_fall_time_pulse1_mae: 0.3959 - val_current_fall_time_pulse2_loss: 0.2261 - val_current_fall_time_pulse2_mae: 0.3481 - val_current_rise_time_pulse1_loss: 0.2000 - val_current_rise_time_pulse1_mae: 0.3506 - val_current_rise_time_pulse2_loss: 0.2932 - val_current_rise_time_pulse2_mae: 0.4455 - val_loss: 2.9095 - val_overshoot_pulse_1_loss: 0.4524 - val_overshoot_pulse_1_mae: 0.4998 - val_overshoot_pulse_2_loss: 0.2606 - val_overshoot_pulse_2_mae: 0.3729 - val_ringing_frequency_MHz_loss: 0.0214 - val_ringing_frequency_MHz_mae: 0.1297 - val_undershoot_pulse_1_loss: 0.1755 - val_undershoot_pulse_1_mae: 0.3387 - val_undershoot_pulse_2_loss: 0.2315 - val_undershoot_pulse_2_mae: 0.3857 - val_voltage_fall_time_pulse1_loss: 0.1304 - val_voltage_fall_time_pulse1_mae: 0.2650 - val_voltage_fall_time_pulse2_loss: 0.0956 - val_voltage_fall_time_pulse2_mae: 0.2209 - val_voltage_rise_time_pulse1_loss: 0.1236 - val_voltage_rise_time_pulse1_mae: 0.2468 - val_voltage_rise_time_pulse2_loss: 0.3988 - val_voltage_rise_time_pulse2_mae: 0.3739 - learning_rate: 5.0000e-04
# Epoch 4/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.2173 - current_fall_time_pulse1_mae: 0.3595 - current_fall_time_pulse2_loss: 0.1702 - current_fall_time_pulse2_mae: 0.3192 - current_rise_time_pulse1_loss: 0.2011 - current_rise_time_pulse1_mae: 0.3397 - current_rise_time_pulse2_loss: 0.3022 - current_rise_time_pulse2_mae: 0.4384 - loss: 2.5899 - overshoot_pulse_1_loss: 0.3522 - overshoot_pulse_1_mae: 0.4457 - overshoot_pulse_2_loss: 0.2398 - overshoot_pulse_2_mae: 0.3808 - ringing_frequency_MHz_loss: 0.0225 - ringing_frequency_MHz_mae: 0.1163 - undershoot_pulse_1_loss: 0.2143 - undershoot_pulse_1_mae: 0.3583 - undershoot_pulse_2_loss: 0.2279 - undershoot_pulse_2_mae: 0.3721 - voltage_fall_time_pulse1_loss: 0.0973 - voltage_fall_time_pulse1_mae: 0.2317 - voltage_fall_time_pulse2_loss: 0.1139 - voltage_fall_time_pulse2_mae: 0.2577 - voltage_rise_time_pulse1_loss: 0.1460 - voltage_rise_time_pulse1_mae: 0.2878 - voltage_rise_time_pulse2_loss: 0.2718 - voltage_rise_time_pulse2_mae: 0.3501 - val_current_fall_time_pulse1_loss: 0.1653 - val_current_fall_time_pulse1_mae: 0.3301 - val_current_fall_time_pulse2_loss: 0.1634 - val_current_fall_time_pulse2_mae: 0.3031 - val_current_rise_time_pulse1_loss: 0.1607 - val_current_rise_time_pulse1_mae: 0.3108 - val_current_rise_time_pulse2_loss: 0.2561 - val_current_rise_time_pulse2_mae: 0.4053 - val_loss: 2.3639 - val_overshoot_pulse_1_loss: 0.3611 - val_overshoot_pulse_1_mae: 0.4462 - val_overshoot_pulse_2_loss: 0.2174 - val_overshoot_pulse_2_mae: 0.3383 - val_ringing_frequency_MHz_loss: 0.0138 - val_ringing_frequency_MHz_mae: 0.1015 - val_undershoot_pulse_1_loss: 0.1258 - val_undershoot_pulse_1_mae: 0.2794 - val_undershoot_pulse_2_loss: 0.1765 - val_undershoot_pulse_2_mae: 0.3333 - val_voltage_fall_time_pulse1_loss: 0.1087 - val_voltage_fall_time_pulse1_mae: 0.2428 - val_voltage_fall_time_pulse2_loss: 0.0726 - val_voltage_fall_time_pulse2_mae: 0.2014 - val_voltage_rise_time_pulse1_loss: 0.1178 - val_voltage_rise_time_pulse1_mae: 0.2376 - val_voltage_rise_time_pulse2_loss: 0.3670 - val_voltage_rise_time_pulse2_mae: 0.3481 - learning_rate: 5.0000e-04
# Epoch 5/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - current_fall_time_pulse1_loss: 0.1754 - current_fall_time_pulse1_mae: 0.3244 - current_fall_time_pulse2_loss: 0.1343 - current_fall_time_pulse2_mae: 0.2854 - current_rise_time_pulse1_loss: 0.1770 - current_rise_time_pulse1_mae: 0.3193 - current_rise_time_pulse2_loss: 0.2667 - current_rise_time_pulse2_mae: 0.4098 - loss: 2.2291 - overshoot_pulse_1_loss: 0.3031 - overshoot_pulse_1_mae: 0.4155 - overshoot_pulse_2_loss: 0.2020 - overshoot_pulse_2_mae: 0.3499 - ringing_frequency_MHz_loss: 0.0185 - ringing_frequency_MHz_mae: 0.1043 - undershoot_pulse_1_loss: 0.1870 - undershoot_pulse_1_mae: 0.3329 - undershoot_pulse_2_loss: 0.1916 - undershoot_pulse_2_mae: 0.3373 - voltage_fall_time_pulse1_loss: 0.0794 - voltage_fall_time_pulse1_mae: 0.2104 - voltage_fall_time_pulse2_loss: 0.0959 - voltage_fall_time_pulse2_mae: 0.2336 - voltage_rise_time_pulse1_loss: 0.1349 - voltage_rise_time_pulse1_mae: 0.2723 - voltage_rise_time_pulse2_loss: 0.2501 - voltage_rise_time_pulse2_mae: 0.3334 - val_current_fall_time_pulse1_loss: 0.1268 - val_current_fall_time_pulse1_mae: 0.2875 - val_current_fall_time_pulse2_loss: 0.1204 - val_current_fall_time_pulse2_mae: 0.2602 - val_current_rise_time_pulse1_loss: 0.1364 - val_current_rise_time_pulse1_mae: 0.2801 - val_current_rise_time_pulse2_loss: 0.2377 - val_current_rise_time_pulse2_mae: 0.3815 - val_loss: 2.0253 - val_overshoot_pulse_1_loss: 0.3032 - val_overshoot_pulse_1_mae: 0.4009 - val_overshoot_pulse_2_loss: 0.1854 - val_overshoot_pulse_2_mae: 0.3099 - val_ringing_frequency_MHz_loss: 0.0122 - val_ringing_frequency_MHz_mae: 0.0934 - val_undershoot_pulse_1_loss: 0.0959 - val_undershoot_pulse_1_mae: 0.2444 - val_undershoot_pulse_2_loss: 0.1343 - val_undershoot_pulse_2_mae: 0.2888 - val_voltage_fall_time_pulse1_loss: 0.0892 - val_voltage_fall_time_pulse1_mae: 0.2185 - val_voltage_fall_time_pulse2_loss: 0.0647 - val_voltage_fall_time_pulse2_mae: 0.1943 - val_voltage_rise_time_pulse1_loss: 0.1123 - val_voltage_rise_time_pulse1_mae: 0.2293 - val_voltage_rise_time_pulse2_loss: 0.3571 - val_voltage_rise_time_pulse2_mae: 0.3390 - learning_rate: 5.0000e-04
# Epoch 6/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - current_fall_time_pulse1_loss: 0.1453 - current_fall_time_pulse1_mae: 0.2945 - current_fall_time_pulse2_loss: 0.1218 - current_fall_time_pulse2_mae: 0.2659 - current_rise_time_pulse1_loss: 0.1604 - current_rise_time_pulse1_mae: 0.2972 - current_rise_time_pulse2_loss: 0.2565 - current_rise_time_pulse2_mae: 0.3986 - loss: 1.9951 - overshoot_pulse_1_loss: 0.2642 - overshoot_pulse_1_mae: 0.3891 - overshoot_pulse_2_loss: 0.1838 - overshoot_pulse_2_mae: 0.3382 - ringing_frequency_MHz_loss: 0.0149 - ringing_frequency_MHz_mae: 0.0944 - undershoot_pulse_1_loss: 0.1621 - undershoot_pulse_1_mae: 0.3083 - undershoot_pulse_2_loss: 0.1696 - undershoot_pulse_2_mae: 0.3165 - voltage_fall_time_pulse1_loss: 0.0690 - voltage_fall_time_pulse1_mae: 0.1970 - voltage_fall_time_pulse2_loss: 0.0805 - voltage_fall_time_pulse2_mae: 0.2151 - voltage_rise_time_pulse1_loss: 0.1242 - voltage_rise_time_pulse1_mae: 0.2602 - voltage_rise_time_pulse2_loss: 0.2300 - voltage_rise_time_pulse2_mae: 0.3177 - val_current_fall_time_pulse1_loss: 0.0899 - val_current_fall_time_pulse1_mae: 0.2414 - val_current_fall_time_pulse2_loss: 0.0926 - val_current_fall_time_pulse2_mae: 0.2333 - val_current_rise_time_pulse1_loss: 0.1240 - val_current_rise_time_pulse1_mae: 0.2655 - val_current_rise_time_pulse2_loss: 0.2124 - val_current_rise_time_pulse2_mae: 0.3541 - val_loss: 1.7700 - val_overshoot_pulse_1_loss: 0.2605 - val_overshoot_pulse_1_mae: 0.3652 - val_overshoot_pulse_2_loss: 0.1671 - val_overshoot_pulse_2_mae: 0.2921 - val_ringing_frequency_MHz_loss: 0.0104 - val_ringing_frequency_MHz_mae: 0.0858 - val_undershoot_pulse_1_loss: 0.0790 - val_undershoot_pulse_1_mae: 0.2179 - val_undershoot_pulse_2_loss: 0.1150 - val_undershoot_pulse_2_mae: 0.2645 - val_voltage_fall_time_pulse1_loss: 0.0691 - val_voltage_fall_time_pulse1_mae: 0.1985 - val_voltage_fall_time_pulse2_loss: 0.0503 - val_voltage_fall_time_pulse2_mae: 0.1798 - val_voltage_rise_time_pulse1_loss: 0.1029 - val_voltage_rise_time_pulse1_mae: 0.2219 - val_voltage_rise_time_pulse2_loss: 0.3395 - val_voltage_rise_time_pulse2_mae: 0.3283 - learning_rate: 5.0000e-04
# Epoch 7/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.1297 - current_fall_time_pulse1_mae: 0.2787 - current_fall_time_pulse2_loss: 0.1055 - current_fall_time_pulse2_mae: 0.2520 - current_rise_time_pulse1_loss: 0.1527 - current_rise_time_pulse1_mae: 0.2910 - current_rise_time_pulse2_loss: 0.2414 - current_rise_time_pulse2_mae: 0.3813 - loss: 1.8710 - overshoot_pulse_1_loss: 0.2572 - overshoot_pulse_1_mae: 0.3811 - overshoot_pulse_2_loss: 0.1719 - overshoot_pulse_2_mae: 0.3259 - ringing_frequency_MHz_loss: 0.0133 - ringing_frequency_MHz_mae: 0.0892 - undershoot_pulse_1_loss: 0.1540 - undershoot_pulse_1_mae: 0.3004 - undershoot_pulse_2_loss: 0.1488 - undershoot_pulse_2_mae: 0.2941 - voltage_fall_time_pulse1_loss: 0.0655 - voltage_fall_time_pulse1_mae: 0.1916 - voltage_fall_time_pulse2_loss: 0.0728 - voltage_fall_time_pulse2_mae: 0.2051 - voltage_rise_time_pulse1_loss: 0.1141 - voltage_rise_time_pulse1_mae: 0.2468 - voltage_rise_time_pulse2_loss: 0.2313 - voltage_rise_time_pulse2_mae: 0.3131 - val_current_fall_time_pulse1_loss: 0.0713 - val_current_fall_time_pulse1_mae: 0.2136 - val_current_fall_time_pulse2_loss: 0.0716 - val_current_fall_time_pulse2_mae: 0.2056 - val_current_rise_time_pulse1_loss: 0.1139 - val_current_rise_time_pulse1_mae: 0.2511 - val_current_rise_time_pulse2_loss: 0.1966 - val_current_rise_time_pulse2_mae: 0.3340 - val_loss: 1.5772 - val_overshoot_pulse_1_loss: 0.2316 - val_overshoot_pulse_1_mae: 0.3419 - val_overshoot_pulse_2_loss: 0.1533 - val_overshoot_pulse_2_mae: 0.2786 - val_ringing_frequency_MHz_loss: 0.0099 - val_ringing_frequency_MHz_mae: 0.0826 - val_undershoot_pulse_1_loss: 0.0694 - val_undershoot_pulse_1_mae: 0.2040 - val_undershoot_pulse_2_loss: 0.0916 - val_undershoot_pulse_2_mae: 0.2356 - val_voltage_fall_time_pulse1_loss: 0.0538 - val_voltage_fall_time_pulse1_mae: 0.1767 - val_voltage_fall_time_pulse2_loss: 0.0416 - val_voltage_fall_time_pulse2_mae: 0.1619 - val_voltage_rise_time_pulse1_loss: 0.0946 - val_voltage_rise_time_pulse1_mae: 0.2131 - val_voltage_rise_time_pulse2_loss: 0.3230 - val_voltage_rise_time_pulse2_mae: 0.3121 - learning_rate: 5.0000e-04
# Epoch 8/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.1147 - current_fall_time_pulse1_mae: 0.2614 - current_fall_time_pulse2_loss: 0.0962 - current_fall_time_pulse2_mae: 0.2407 - current_rise_time_pulse1_loss: 0.1465 - current_rise_time_pulse1_mae: 0.2835 - current_rise_time_pulse2_loss: 0.2196 - current_rise_time_pulse2_mae: 0.3587 - loss: 1.7017 - overshoot_pulse_1_loss: 0.2369 - overshoot_pulse_1_mae: 0.3670 - overshoot_pulse_2_loss: 0.1629 - overshoot_pulse_2_mae: 0.3179 - ringing_frequency_MHz_loss: 0.0117 - ringing_frequency_MHz_mae: 0.0828 - undershoot_pulse_1_loss: 0.1318 - undershoot_pulse_1_mae: 0.2789 - undershoot_pulse_2_loss: 0.1347 - undershoot_pulse_2_mae: 0.2814 - voltage_fall_time_pulse1_loss: 0.0549 - voltage_fall_time_pulse1_mae: 0.1743 - voltage_fall_time_pulse2_loss: 0.0627 - voltage_fall_time_pulse2_mae: 0.1887 - voltage_rise_time_pulse1_loss: 0.1059 - voltage_rise_time_pulse1_mae: 0.2380 - voltage_rise_time_pulse2_loss: 0.2106 - voltage_rise_time_pulse2_mae: 0.3004 - val_current_fall_time_pulse1_loss: 0.0581 - val_current_fall_time_pulse1_mae: 0.1935 - val_current_fall_time_pulse2_loss: 0.0551 - val_current_fall_time_pulse2_mae: 0.1821 - val_current_rise_time_pulse1_loss: 0.1037 - val_current_rise_time_pulse1_mae: 0.2346 - val_current_rise_time_pulse2_loss: 0.1785 - val_current_rise_time_pulse2_mae: 0.3131 - val_loss: 1.4083 - val_overshoot_pulse_1_loss: 0.2108 - val_overshoot_pulse_1_mae: 0.3195 - val_overshoot_pulse_2_loss: 0.1399 - val_overshoot_pulse_2_mae: 0.2646 - val_ringing_frequency_MHz_loss: 0.0081 - val_ringing_frequency_MHz_mae: 0.0743 - val_undershoot_pulse_1_loss: 0.0576 - val_undershoot_pulse_1_mae: 0.1876 - val_undershoot_pulse_2_loss: 0.0753 - val_undershoot_pulse_2_mae: 0.2145 - val_voltage_fall_time_pulse1_loss: 0.0413 - val_voltage_fall_time_pulse1_mae: 0.1608 - val_voltage_fall_time_pulse2_loss: 0.0325 - val_voltage_fall_time_pulse2_mae: 0.1440 - val_voltage_rise_time_pulse1_loss: 0.0829 - val_voltage_rise_time_pulse1_mae: 0.2005 - val_voltage_rise_time_pulse2_loss: 0.3030 - val_voltage_rise_time_pulse2_mae: 0.2959 - learning_rate: 5.0000e-04
# Epoch 9/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - current_fall_time_pulse1_loss: 0.1055 - current_fall_time_pulse1_mae: 0.2492 - current_fall_time_pulse2_loss: 0.0855 - current_fall_time_pulse2_mae: 0.2249 - current_rise_time_pulse1_loss: 0.1370 - current_rise_time_pulse1_mae: 0.2744 - current_rise_time_pulse2_loss: 0.2057 - current_rise_time_pulse2_mae: 0.3463 - loss: 1.6085 - overshoot_pulse_1_loss: 0.2170 - overshoot_pulse_1_mae: 0.3490 - overshoot_pulse_2_loss: 0.1571 - overshoot_pulse_2_mae: 0.3097 - ringing_frequency_MHz_loss: 0.0097 - ringing_frequency_MHz_mae: 0.0753 - undershoot_pulse_1_loss: 0.1293 - undershoot_pulse_1_mae: 0.2740 - undershoot_pulse_2_loss: 0.1327 - undershoot_pulse_2_mae: 0.2796 - voltage_fall_time_pulse1_loss: 0.0525 - voltage_fall_time_pulse1_mae: 0.1700 - voltage_fall_time_pulse2_loss: 0.0555 - voltage_fall_time_pulse2_mae: 0.1770 - voltage_rise_time_pulse1_loss: 0.0986 - voltage_rise_time_pulse1_mae: 0.2277 - voltage_rise_time_pulse2_loss: 0.2097 - voltage_rise_time_pulse2_mae: 0.2992 - val_current_fall_time_pulse1_loss: 0.0459 - val_current_fall_time_pulse1_mae: 0.1707 - val_current_fall_time_pulse2_loss: 0.0464 - val_current_fall_time_pulse2_mae: 0.1663 - val_current_rise_time_pulse1_loss: 0.0979 - val_current_rise_time_pulse1_mae: 0.2216 - val_current_rise_time_pulse2_loss: 0.1667 - val_current_rise_time_pulse2_mae: 0.2977 - val_loss: 1.3015 - val_overshoot_pulse_1_loss: 0.1845 - val_overshoot_pulse_1_mae: 0.2968 - val_overshoot_pulse_2_loss: 0.1325 - val_overshoot_pulse_2_mae: 0.2566 - val_ringing_frequency_MHz_loss: 0.0077 - val_ringing_frequency_MHz_mae: 0.0727 - val_undershoot_pulse_1_loss: 0.0520 - val_undershoot_pulse_1_mae: 0.1750 - val_undershoot_pulse_2_loss: 0.0659 - val_undershoot_pulse_2_mae: 0.2005 - val_voltage_fall_time_pulse1_loss: 0.0327 - val_voltage_fall_time_pulse1_mae: 0.1463 - val_voltage_fall_time_pulse2_loss: 0.0312 - val_voltage_fall_time_pulse2_mae: 0.1441 - val_voltage_rise_time_pulse1_loss: 0.0814 - val_voltage_rise_time_pulse1_mae: 0.2017 - val_voltage_rise_time_pulse2_loss: 0.2991 - val_voltage_rise_time_pulse2_mae: 0.2945 - learning_rate: 5.0000e-04
# Epoch 10/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - current_fall_time_pulse1_loss: 0.1028 - current_fall_time_pulse1_mae: 0.2434 - current_fall_time_pulse2_loss: 0.0819 - current_fall_time_pulse2_mae: 0.2213 - current_rise_time_pulse1_loss: 0.1337 - current_rise_time_pulse1_mae: 0.2689 - current_rise_time_pulse2_loss: 0.2035 - current_rise_time_pulse2_mae: 0.3414 - loss: 1.5644 - overshoot_pulse_1_loss: 0.2287 - overshoot_pulse_1_mae: 0.3542 - overshoot_pulse_2_loss: 0.1444 - overshoot_pulse_2_mae: 0.2972 - ringing_frequency_MHz_loss: 0.0089 - ringing_frequency_MHz_mae: 0.0721 - undershoot_pulse_1_loss: 0.1238 - undershoot_pulse_1_mae: 0.2662 - undershoot_pulse_2_loss: 0.1260 - undershoot_pulse_2_mae: 0.2723 - voltage_fall_time_pulse1_loss: 0.0497 - voltage_fall_time_pulse1_mae: 0.1652 - voltage_fall_time_pulse2_loss: 0.0531 - voltage_fall_time_pulse2_mae: 0.1738 - voltage_rise_time_pulse1_loss: 0.0955 - voltage_rise_time_pulse1_mae: 0.2233 - voltage_rise_time_pulse2_loss: 0.1997 - voltage_rise_time_pulse2_mae: 0.2897 - val_current_fall_time_pulse1_loss: 0.0458 - val_current_fall_time_pulse1_mae: 0.1699 - val_current_fall_time_pulse2_loss: 0.0461 - val_current_fall_time_pulse2_mae: 0.1670 - val_current_rise_time_pulse1_loss: 0.0935 - val_current_rise_time_pulse1_mae: 0.2143 - val_current_rise_time_pulse2_loss: 0.1592 - val_current_rise_time_pulse2_mae: 0.2880 - val_loss: 1.2549 - val_overshoot_pulse_1_loss: 0.1802 - val_overshoot_pulse_1_mae: 0.2928 - val_overshoot_pulse_2_loss: 0.1241 - val_overshoot_pulse_2_mae: 0.2495 - val_ringing_frequency_MHz_loss: 0.0063 - val_ringing_frequency_MHz_mae: 0.0658 - val_undershoot_pulse_1_loss: 0.0493 - val_undershoot_pulse_1_mae: 0.1708 - val_undershoot_pulse_2_loss: 0.0617 - val_undershoot_pulse_2_mae: 0.1931 - val_voltage_fall_time_pulse1_loss: 0.0371 - val_voltage_fall_time_pulse1_mae: 0.1533 - val_voltage_fall_time_pulse2_loss: 0.0306 - val_voltage_fall_time_pulse2_mae: 0.1425 - val_voltage_rise_time_pulse1_loss: 0.0718 - val_voltage_rise_time_pulse1_mae: 0.1893 - val_voltage_rise_time_pulse2_loss: 0.2942 - val_voltage_rise_time_pulse2_mae: 0.2926 - learning_rate: 5.0000e-04
# Epoch 11/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - current_fall_time_pulse1_loss: 0.0898 - current_fall_time_pulse1_mae: 0.2294 - current_fall_time_pulse2_loss: 0.0770 - current_fall_time_pulse2_mae: 0.2111 - current_rise_time_pulse1_loss: 0.1259 - current_rise_time_pulse1_mae: 0.2630 - current_rise_time_pulse2_loss: 0.1971 - current_rise_time_pulse2_mae: 0.3323 - loss: 1.4923 - overshoot_pulse_1_loss: 0.2134 - overshoot_pulse_1_mae: 0.3475 - overshoot_pulse_2_loss: 0.1467 - overshoot_pulse_2_mae: 0.2992 - ringing_frequency_MHz_loss: 0.0074 - ringing_frequency_MHz_mae: 0.0658 - undershoot_pulse_1_loss: 0.1226 - undershoot_pulse_1_mae: 0.2664 - undershoot_pulse_2_loss: 0.1187 - undershoot_pulse_2_mae: 0.2639 - voltage_fall_time_pulse1_loss: 0.0459 - voltage_fall_time_pulse1_mae: 0.1579 - voltage_fall_time_pulse2_loss: 0.0508 - voltage_fall_time_pulse2_mae: 0.1676 - voltage_rise_time_pulse1_loss: 0.0879 - voltage_rise_time_pulse1_mae: 0.2139 - voltage_rise_time_pulse2_loss: 0.1966 - voltage_rise_time_pulse2_mae: 0.2895 - val_current_fall_time_pulse1_loss: 0.0328 - val_current_fall_time_pulse1_mae: 0.1467 - val_current_fall_time_pulse2_loss: 0.0359 - val_current_fall_time_pulse2_mae: 0.1498 - val_current_rise_time_pulse1_loss: 0.0901 - val_current_rise_time_pulse1_mae: 0.2095 - val_current_rise_time_pulse2_loss: 0.1507 - val_current_rise_time_pulse2_mae: 0.2756 - val_loss: 1.1655 - val_overshoot_pulse_1_loss: 0.1738 - val_overshoot_pulse_1_mae: 0.2820 - val_overshoot_pulse_2_loss: 0.1216 - val_overshoot_pulse_2_mae: 0.2460 - val_ringing_frequency_MHz_loss: 0.0061 - val_ringing_frequency_MHz_mae: 0.0636 - val_undershoot_pulse_1_loss: 0.0439 - val_undershoot_pulse_1_mae: 0.1620 - val_undershoot_pulse_2_loss: 0.0530 - val_undershoot_pulse_2_mae: 0.1795 - val_voltage_fall_time_pulse1_loss: 0.0286 - val_voltage_fall_time_pulse1_mae: 0.1368 - val_voltage_fall_time_pulse2_loss: 0.0255 - val_voltage_fall_time_pulse2_mae: 0.1323 - val_voltage_rise_time_pulse1_loss: 0.0647 - val_voltage_rise_time_pulse1_mae: 0.1822 - val_voltage_rise_time_pulse2_loss: 0.2820 - val_voltage_rise_time_pulse2_mae: 0.2822 - learning_rate: 5.0000e-04
# Epoch 12/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - current_fall_time_pulse1_loss: 0.0916 - current_fall_time_pulse1_mae: 0.2317 - current_fall_time_pulse2_loss: 0.0747 - current_fall_time_pulse2_mae: 0.2093 - current_rise_time_pulse1_loss: 0.1221 - current_rise_time_pulse1_mae: 0.2577 - current_rise_time_pulse2_loss: 0.1911 - current_rise_time_pulse2_mae: 0.3254 - loss: 1.4327 - overshoot_pulse_1_loss: 0.2019 - overshoot_pulse_1_mae: 0.3381 - overshoot_pulse_2_loss: 0.1426 - overshoot_pulse_2_mae: 0.2962 - ringing_frequency_MHz_loss: 0.0072 - ringing_frequency_MHz_mae: 0.0648 - undershoot_pulse_1_loss: 0.1143 - undershoot_pulse_1_mae: 0.2546 - undershoot_pulse_2_loss: 0.1124 - undershoot_pulse_2_mae: 0.2560 - voltage_fall_time_pulse1_loss: 0.0393 - voltage_fall_time_pulse1_mae: 0.1475 - voltage_fall_time_pulse2_loss: 0.0440 - voltage_fall_time_pulse2_mae: 0.1580 - voltage_rise_time_pulse1_loss: 0.0864 - voltage_rise_time_pulse1_mae: 0.2119 - voltage_rise_time_pulse2_loss: 0.1927 - voltage_rise_time_pulse2_mae: 0.2846 - val_current_fall_time_pulse1_loss: 0.0313 - val_current_fall_time_pulse1_mae: 0.1436 - val_current_fall_time_pulse2_loss: 0.0299 - val_current_fall_time_pulse2_mae: 0.1391 - val_current_rise_time_pulse1_loss: 0.0896 - val_current_rise_time_pulse1_mae: 0.2067 - val_current_rise_time_pulse2_loss: 0.1448 - val_current_rise_time_pulse2_mae: 0.2667 - val_loss: 1.1246 - val_overshoot_pulse_1_loss: 0.1594 - val_overshoot_pulse_1_mae: 0.2731 - val_overshoot_pulse_2_loss: 0.1201 - val_overshoot_pulse_2_mae: 0.2442 - val_ringing_frequency_MHz_loss: 0.0054 - val_ringing_frequency_MHz_mae: 0.0600 - val_undershoot_pulse_1_loss: 0.0409 - val_undershoot_pulse_1_mae: 0.1543 - val_undershoot_pulse_2_loss: 0.0512 - val_undershoot_pulse_2_mae: 0.1755 - val_voltage_fall_time_pulse1_loss: 0.0244 - val_voltage_fall_time_pulse1_mae: 0.1291 - val_voltage_fall_time_pulse2_loss: 0.0231 - val_voltage_fall_time_pulse2_mae: 0.1264 - val_voltage_rise_time_pulse1_loss: 0.0644 - val_voltage_rise_time_pulse1_mae: 0.1796 - val_voltage_rise_time_pulse2_loss: 0.2806 - val_voltage_rise_time_pulse2_mae: 0.2857 - learning_rate: 5.0000e-04
# Epoch 13/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - current_fall_time_pulse1_loss: 0.0801 - current_fall_time_pulse1_mae: 0.2175 - current_fall_time_pulse2_loss: 0.0705 - current_fall_time_pulse2_mae: 0.2016 - current_rise_time_pulse1_loss: 0.1175 - current_rise_time_pulse1_mae: 0.2501 - current_rise_time_pulse2_loss: 0.1851 - current_rise_time_pulse2_mae: 0.3190 - loss: 1.3721 - overshoot_pulse_1_loss: 0.1959 - overshoot_pulse_1_mae: 0.3324 - overshoot_pulse_2_loss: 0.1346 - overshoot_pulse_2_mae: 0.2880 - ringing_frequency_MHz_loss: 0.0069 - ringing_frequency_MHz_mae: 0.0628 - undershoot_pulse_1_loss: 0.1140 - undershoot_pulse_1_mae: 0.2507 - undershoot_pulse_2_loss: 0.1075 - undershoot_pulse_2_mae: 0.2463 - voltage_fall_time_pulse1_loss: 0.0385 - voltage_fall_time_pulse1_mae: 0.1460 - voltage_fall_time_pulse2_loss: 0.0425 - voltage_fall_time_pulse2_mae: 0.1530 - voltage_rise_time_pulse1_loss: 0.0828 - voltage_rise_time_pulse1_mae: 0.2055 - voltage_rise_time_pulse2_loss: 0.1837 - voltage_rise_time_pulse2_mae: 0.2777 - val_current_fall_time_pulse1_loss: 0.0282 - val_current_fall_time_pulse1_mae: 0.1354 - val_current_fall_time_pulse2_loss: 0.0335 - val_current_fall_time_pulse2_mae: 0.1426 - val_current_rise_time_pulse1_loss: 0.0855 - val_current_rise_time_pulse1_mae: 0.1971 - val_current_rise_time_pulse2_loss: 0.1472 - val_current_rise_time_pulse2_mae: 0.2696 - val_loss: 1.1093 - val_overshoot_pulse_1_loss: 0.1572 - val_overshoot_pulse_1_mae: 0.2688 - val_overshoot_pulse_2_loss: 0.1145 - val_overshoot_pulse_2_mae: 0.2390 - val_ringing_frequency_MHz_loss: 0.0044 - val_ringing_frequency_MHz_mae: 0.0540 - val_undershoot_pulse_1_loss: 0.0409 - val_undershoot_pulse_1_mae: 0.1547 - val_undershoot_pulse_2_loss: 0.0468 - val_undershoot_pulse_2_mae: 0.1680 - val_voltage_fall_time_pulse1_loss: 0.0312 - val_voltage_fall_time_pulse1_mae: 0.1444 - val_voltage_fall_time_pulse2_loss: 0.0244 - val_voltage_fall_time_pulse2_mae: 0.1311 - val_voltage_rise_time_pulse1_loss: 0.0619 - val_voltage_rise_time_pulse1_mae: 0.1778 - val_voltage_rise_time_pulse2_loss: 0.2812 - val_voltage_rise_time_pulse2_mae: 0.2905 - learning_rate: 5.0000e-04
# Epoch 14/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.0732 - current_fall_time_pulse1_mae: 0.2082 - current_fall_time_pulse2_loss: 0.0640 - current_fall_time_pulse2_mae: 0.1942 - current_rise_time_pulse1_loss: 0.1129 - current_rise_time_pulse1_mae: 0.2468 - current_rise_time_pulse2_loss: 0.1788 - current_rise_time_pulse2_mae: 0.3127 - loss: 1.3311 - overshoot_pulse_1_loss: 0.1912 - overshoot_pulse_1_mae: 0.3268 - overshoot_pulse_2_loss: 0.1365 - overshoot_pulse_2_mae: 0.2895 - ringing_frequency_MHz_loss: 0.0061 - ringing_frequency_MHz_mae: 0.0592 - undershoot_pulse_1_loss: 0.1058 - undershoot_pulse_1_mae: 0.2471 - undershoot_pulse_2_loss: 0.1051 - undershoot_pulse_2_mae: 0.2447 - voltage_fall_time_pulse1_loss: 0.0359 - voltage_fall_time_pulse1_mae: 0.1404 - voltage_fall_time_pulse2_loss: 0.0394 - voltage_fall_time_pulse2_mae: 0.1471 - voltage_rise_time_pulse1_loss: 0.0801 - voltage_rise_time_pulse1_mae: 0.2007 - voltage_rise_time_pulse2_loss: 0.1897 - voltage_rise_time_pulse2_mae: 0.2790 - val_current_fall_time_pulse1_loss: 0.0267 - val_current_fall_time_pulse1_mae: 0.1310 - val_current_fall_time_pulse2_loss: 0.0328 - val_current_fall_time_pulse2_mae: 0.1392 - val_current_rise_time_pulse1_loss: 0.0827 - val_current_rise_time_pulse1_mae: 0.1962 - val_current_rise_time_pulse2_loss: 0.1446 - val_current_rise_time_pulse2_mae: 0.2644 - val_loss: 1.0949 - val_overshoot_pulse_1_loss: 0.1529 - val_overshoot_pulse_1_mae: 0.2634 - val_overshoot_pulse_2_loss: 0.1142 - val_overshoot_pulse_2_mae: 0.2411 - val_ringing_frequency_MHz_loss: 0.0045 - val_ringing_frequency_MHz_mae: 0.0547 - val_undershoot_pulse_1_loss: 0.0399 - val_undershoot_pulse_1_mae: 0.1511 - val_undershoot_pulse_2_loss: 0.0479 - val_undershoot_pulse_2_mae: 0.1695 - val_voltage_fall_time_pulse1_loss: 0.0297 - val_voltage_fall_time_pulse1_mae: 0.1430 - val_voltage_fall_time_pulse2_loss: 0.0281 - val_voltage_fall_time_pulse2_mae: 0.1401 - val_voltage_rise_time_pulse1_loss: 0.0615 - val_voltage_rise_time_pulse1_mae: 0.1784 - val_voltage_rise_time_pulse2_loss: 0.2749 - val_voltage_rise_time_pulse2_mae: 0.2839 - learning_rate: 5.0000e-04
# Epoch 15/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.0783 - current_fall_time_pulse1_mae: 0.2145 - current_fall_time_pulse2_loss: 0.0623 - current_fall_time_pulse2_mae: 0.1910 - current_rise_time_pulse1_loss: 0.1102 - current_rise_time_pulse1_mae: 0.2407 - current_rise_time_pulse2_loss: 0.1739 - current_rise_time_pulse2_mae: 0.3086 - loss: 1.2810 - overshoot_pulse_1_loss: 0.1864 - overshoot_pulse_1_mae: 0.3196 - overshoot_pulse_2_loss: 0.1302 - overshoot_pulse_2_mae: 0.2821 - ringing_frequency_MHz_loss: 0.0056 - ringing_frequency_MHz_mae: 0.0566 - undershoot_pulse_1_loss: 0.0969 - undershoot_pulse_1_mae: 0.2346 - undershoot_pulse_2_loss: 0.0956 - undershoot_pulse_2_mae: 0.2349 - voltage_fall_time_pulse1_loss: 0.0338 - voltage_fall_time_pulse1_mae: 0.1370 - voltage_fall_time_pulse2_loss: 0.0378 - voltage_fall_time_pulse2_mae: 0.1454 - voltage_rise_time_pulse1_loss: 0.0791 - voltage_rise_time_pulse1_mae: 0.1994 - voltage_rise_time_pulse2_loss: 0.1786 - voltage_rise_time_pulse2_mae: 0.2684 - val_current_fall_time_pulse1_loss: 0.0245 - val_current_fall_time_pulse1_mae: 0.1268 - val_current_fall_time_pulse2_loss: 0.0270 - val_current_fall_time_pulse2_mae: 0.1300 - val_current_rise_time_pulse1_loss: 0.0824 - val_current_rise_time_pulse1_mae: 0.1959 - val_current_rise_time_pulse2_loss: 0.1358 - val_current_rise_time_pulse2_mae: 0.2484 - val_loss: 1.0567 - val_overshoot_pulse_1_loss: 0.1495 - val_overshoot_pulse_1_mae: 0.2602 - val_overshoot_pulse_2_loss: 0.1137 - val_overshoot_pulse_2_mae: 0.2398 - val_ringing_frequency_MHz_loss: 0.0035 - val_ringing_frequency_MHz_mae: 0.0485 - val_undershoot_pulse_1_loss: 0.0398 - val_undershoot_pulse_1_mae: 0.1518 - val_undershoot_pulse_2_loss: 0.0425 - val_undershoot_pulse_2_mae: 0.1585 - val_voltage_fall_time_pulse1_loss: 0.0313 - val_voltage_fall_time_pulse1_mae: 0.1451 - val_voltage_fall_time_pulse2_loss: 0.0241 - val_voltage_fall_time_pulse2_mae: 0.1290 - val_voltage_rise_time_pulse1_loss: 0.0589 - val_voltage_rise_time_pulse1_mae: 0.1748 - val_voltage_rise_time_pulse2_loss: 0.2673 - val_voltage_rise_time_pulse2_mae: 0.2806 - learning_rate: 5.0000e-04
# Epoch 16/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.0717 - current_fall_time_pulse1_mae: 0.2050 - current_fall_time_pulse2_loss: 0.0573 - current_fall_time_pulse2_mae: 0.1824 - current_rise_time_pulse1_loss: 0.1093 - current_rise_time_pulse1_mae: 0.2391 - current_rise_time_pulse2_loss: 0.1720 - current_rise_time_pulse2_mae: 0.3032 - loss: 1.2305 - overshoot_pulse_1_loss: 0.1783 - overshoot_pulse_1_mae: 0.3141 - overshoot_pulse_2_loss: 0.1300 - overshoot_pulse_2_mae: 0.2830 - ringing_frequency_MHz_loss: 0.0051 - ringing_frequency_MHz_mae: 0.0545 - undershoot_pulse_1_loss: 0.0919 - undershoot_pulse_1_mae: 0.2259 - undershoot_pulse_2_loss: 0.0892 - undershoot_pulse_2_mae: 0.2280 - voltage_fall_time_pulse1_loss: 0.0312 - voltage_fall_time_pulse1_mae: 0.1307 - voltage_fall_time_pulse2_loss: 0.0351 - voltage_fall_time_pulse2_mae: 0.1391 - voltage_rise_time_pulse1_loss: 0.0757 - voltage_rise_time_pulse1_mae: 0.1933 - voltage_rise_time_pulse2_loss: 0.1713 - voltage_rise_time_pulse2_mae: 0.2670 - val_current_fall_time_pulse1_loss: 0.0257 - val_current_fall_time_pulse1_mae: 0.1296 - val_current_fall_time_pulse2_loss: 0.0259 - val_current_fall_time_pulse2_mae: 0.1275 - val_current_rise_time_pulse1_loss: 0.0777 - val_current_rise_time_pulse1_mae: 0.1893 - val_current_rise_time_pulse2_loss: 0.1363 - val_current_rise_time_pulse2_mae: 0.2495 - val_loss: 1.0293 - val_overshoot_pulse_1_loss: 0.1458 - val_overshoot_pulse_1_mae: 0.2547 - val_overshoot_pulse_2_loss: 0.1091 - val_overshoot_pulse_2_mae: 0.2354 - val_ringing_frequency_MHz_loss: 0.0039 - val_ringing_frequency_MHz_mae: 0.0507 - val_undershoot_pulse_1_loss: 0.0359 - val_undershoot_pulse_1_mae: 0.1426 - val_undershoot_pulse_2_loss: 0.0418 - val_undershoot_pulse_2_mae: 0.1575 - val_voltage_fall_time_pulse1_loss: 0.0299 - val_voltage_fall_time_pulse1_mae: 0.1422 - val_voltage_fall_time_pulse2_loss: 0.0213 - val_voltage_fall_time_pulse2_mae: 0.1220 - val_voltage_rise_time_pulse1_loss: 0.0571 - val_voltage_rise_time_pulse1_mae: 0.1716 - val_voltage_rise_time_pulse2_loss: 0.2616 - val_voltage_rise_time_pulse2_mae: 0.2758 - learning_rate: 5.0000e-04
# Epoch 17/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.0705 - current_fall_time_pulse1_mae: 0.2032 - current_fall_time_pulse2_loss: 0.0574 - current_fall_time_pulse2_mae: 0.1817 - current_rise_time_pulse1_loss: 0.1066 - current_rise_time_pulse1_mae: 0.2367 - current_rise_time_pulse2_loss: 0.1715 - current_rise_time_pulse2_mae: 0.3014 - loss: 1.2022 - overshoot_pulse_1_loss: 0.1701 - overshoot_pulse_1_mae: 0.3105 - overshoot_pulse_2_loss: 0.1247 - overshoot_pulse_2_mae: 0.2762 - ringing_frequency_MHz_loss: 0.0049 - ringing_frequency_MHz_mae: 0.0530 - undershoot_pulse_1_loss: 0.0915 - undershoot_pulse_1_mae: 0.2306 - undershoot_pulse_2_loss: 0.0892 - undershoot_pulse_2_mae: 0.2276 - voltage_fall_time_pulse1_loss: 0.0300 - voltage_fall_time_pulse1_mae: 0.1275 - voltage_fall_time_pulse2_loss: 0.0329 - voltage_fall_time_pulse2_mae: 0.1343 - voltage_rise_time_pulse1_loss: 0.0699 - voltage_rise_time_pulse1_mae: 0.1886 - voltage_rise_time_pulse2_loss: 0.1705 - voltage_rise_time_pulse2_mae: 0.2669 - val_current_fall_time_pulse1_loss: 0.0233 - val_current_fall_time_pulse1_mae: 0.1212 - val_current_fall_time_pulse2_loss: 0.0232 - val_current_fall_time_pulse2_mae: 0.1221 - val_current_rise_time_pulse1_loss: 0.0810 - val_current_rise_time_pulse1_mae: 0.1930 - val_current_rise_time_pulse2_loss: 0.1378 - val_current_rise_time_pulse2_mae: 0.2506 - val_loss: 1.0238 - val_overshoot_pulse_1_loss: 0.1456 - val_overshoot_pulse_1_mae: 0.2546 - val_overshoot_pulse_2_loss: 0.1116 - val_overshoot_pulse_2_mae: 0.2379 - val_ringing_frequency_MHz_loss: 0.0035 - val_ringing_frequency_MHz_mae: 0.0478 - val_undershoot_pulse_1_loss: 0.0369 - val_undershoot_pulse_1_mae: 0.1457 - val_undershoot_pulse_2_loss: 0.0430 - val_undershoot_pulse_2_mae: 0.1600 - val_voltage_fall_time_pulse1_loss: 0.0240 - val_voltage_fall_time_pulse1_mae: 0.1291 - val_voltage_fall_time_pulse2_loss: 0.0229 - val_voltage_fall_time_pulse2_mae: 0.1259 - val_voltage_rise_time_pulse1_loss: 0.0551 - val_voltage_rise_time_pulse1_mae: 0.1678 - val_voltage_rise_time_pulse2_loss: 0.2596 - val_voltage_rise_time_pulse2_mae: 0.2748 - learning_rate: 5.0000e-04
# Epoch 18/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - current_fall_time_pulse1_loss: 0.0650 - current_fall_time_pulse1_mae: 0.1930 - current_fall_time_pulse2_loss: 0.0556 - current_fall_time_pulse2_mae: 0.1793 - current_rise_time_pulse1_loss: 0.1060 - current_rise_time_pulse1_mae: 0.2338 - current_rise_time_pulse2_loss: 0.1673 - current_rise_time_pulse2_mae: 0.2962 - loss: 1.1716 - overshoot_pulse_1_loss: 0.1701 - overshoot_pulse_1_mae: 0.3116 - overshoot_pulse_2_loss: 0.1215 - overshoot_pulse_2_mae: 0.2747 - ringing_frequency_MHz_loss: 0.0046 - ringing_frequency_MHz_mae: 0.0508 - undershoot_pulse_1_loss: 0.0875 - undershoot_pulse_1_mae: 0.2255 - undershoot_pulse_2_loss: 0.0873 - undershoot_pulse_2_mae: 0.2245 - voltage_fall_time_pulse1_loss: 0.0291 - voltage_fall_time_pulse1_mae: 0.1244 - voltage_fall_time_pulse2_loss: 0.0315 - voltage_fall_time_pulse2_mae: 0.1309 - voltage_rise_time_pulse1_loss: 0.0692 - voltage_rise_time_pulse1_mae: 0.1863 - voltage_rise_time_pulse2_loss: 0.1645 - voltage_rise_time_pulse2_mae: 0.2630 - val_current_fall_time_pulse1_loss: 0.0216 - val_current_fall_time_pulse1_mae: 0.1176 - val_current_fall_time_pulse2_loss: 0.0209 - val_current_fall_time_pulse2_mae: 0.1167 - val_current_rise_time_pulse1_loss: 0.0786 - val_current_rise_time_pulse1_mae: 0.1890 - val_current_rise_time_pulse2_loss: 0.1348 - val_current_rise_time_pulse2_mae: 0.2485 - val_loss: 0.9901 - val_overshoot_pulse_1_loss: 0.1363 - val_overshoot_pulse_1_mae: 0.2499 - val_overshoot_pulse_2_loss: 0.1092 - val_overshoot_pulse_2_mae: 0.2365 - val_ringing_frequency_MHz_loss: 0.0033 - val_ringing_frequency_MHz_mae: 0.0459 - val_undershoot_pulse_1_loss: 0.0360 - val_undershoot_pulse_1_mae: 0.1432 - val_undershoot_pulse_2_loss: 0.0388 - val_undershoot_pulse_2_mae: 0.1517 - val_voltage_fall_time_pulse1_loss: 0.0235 - val_voltage_fall_time_pulse1_mae: 0.1284 - val_voltage_fall_time_pulse2_loss: 0.0195 - val_voltage_fall_time_pulse2_mae: 0.1161 - val_voltage_rise_time_pulse1_loss: 0.0523 - val_voltage_rise_time_pulse1_mae: 0.1650 - val_voltage_rise_time_pulse2_loss: 0.2569 - val_voltage_rise_time_pulse2_mae: 0.2735 - learning_rate: 5.0000e-04
# Epoch 19/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.0658 - current_fall_time_pulse1_mae: 0.1948 - current_fall_time_pulse2_loss: 0.0561 - current_fall_time_pulse2_mae: 0.1813 - current_rise_time_pulse1_loss: 0.1036 - current_rise_time_pulse1_mae: 0.2315 - current_rise_time_pulse2_loss: 0.1627 - current_rise_time_pulse2_mae: 0.2922 - loss: 1.1509 - overshoot_pulse_1_loss: 0.1607 - overshoot_pulse_1_mae: 0.3023 - overshoot_pulse_2_loss: 0.1262 - overshoot_pulse_2_mae: 0.2787 - ringing_frequency_MHz_loss: 0.0044 - ringing_frequency_MHz_mae: 0.0501 - undershoot_pulse_1_loss: 0.0853 - undershoot_pulse_1_mae: 0.2214 - undershoot_pulse_2_loss: 0.0847 - undershoot_pulse_2_mae: 0.2216 - voltage_fall_time_pulse1_loss: 0.0268 - voltage_fall_time_pulse1_mae: 0.1212 - voltage_fall_time_pulse2_loss: 0.0277 - voltage_fall_time_pulse2_mae: 0.1243 - voltage_rise_time_pulse1_loss: 0.0660 - voltage_rise_time_pulse1_mae: 0.1817 - voltage_rise_time_pulse2_loss: 0.1685 - voltage_rise_time_pulse2_mae: 0.2606 - val_current_fall_time_pulse1_loss: 0.0233 - val_current_fall_time_pulse1_mae: 0.1207 - val_current_fall_time_pulse2_loss: 0.0238 - val_current_fall_time_pulse2_mae: 0.1209 - val_current_rise_time_pulse1_loss: 0.0779 - val_current_rise_time_pulse1_mae: 0.1907 - val_current_rise_time_pulse2_loss: 0.1326 - val_current_rise_time_pulse2_mae: 0.2444 - val_loss: 1.0042 - val_overshoot_pulse_1_loss: 0.1353 - val_overshoot_pulse_1_mae: 0.2494 - val_overshoot_pulse_2_loss: 0.1077 - val_overshoot_pulse_2_mae: 0.2346 - val_ringing_frequency_MHz_loss: 0.0036 - val_ringing_frequency_MHz_mae: 0.0475 - val_undershoot_pulse_1_loss: 0.0385 - val_undershoot_pulse_1_mae: 0.1469 - val_undershoot_pulse_2_loss: 0.0459 - val_undershoot_pulse_2_mae: 0.1656 - val_voltage_fall_time_pulse1_loss: 0.0256 - val_voltage_fall_time_pulse1_mae: 0.1332 - val_voltage_fall_time_pulse2_loss: 0.0199 - val_voltage_fall_time_pulse2_mae: 0.1179 - val_voltage_rise_time_pulse1_loss: 0.0538 - val_voltage_rise_time_pulse1_mae: 0.1694 - val_voltage_rise_time_pulse2_loss: 0.2568 - val_voltage_rise_time_pulse2_mae: 0.2749 - learning_rate: 5.0000e-04
# Epoch 20/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - current_fall_time_pulse1_loss: 0.0634 - current_fall_time_pulse1_mae: 0.1923 - current_fall_time_pulse2_loss: 0.0508 - current_fall_time_pulse2_mae: 0.1728 - current_rise_time_pulse1_loss: 0.1024 - current_rise_time_pulse1_mae: 0.2286 - current_rise_time_pulse2_loss: 0.1589 - current_rise_time_pulse2_mae: 0.2848 - loss: 1.1377 - overshoot_pulse_1_loss: 0.1582 - overshoot_pulse_1_mae: 0.3008 - overshoot_pulse_2_loss: 0.1211 - overshoot_pulse_2_mae: 0.2730 - ringing_frequency_MHz_loss: 0.0040 - ringing_frequency_MHz_mae: 0.0478 - undershoot_pulse_1_loss: 0.0878 - undershoot_pulse_1_mae: 0.2238 - undershoot_pulse_2_loss: 0.0835 - undershoot_pulse_2_mae: 0.2172 - voltage_fall_time_pulse1_loss: 0.0269 - voltage_fall_time_pulse1_mae: 0.1213 - voltage_fall_time_pulse2_loss: 0.0290 - voltage_fall_time_pulse2_mae: 0.1270 - voltage_rise_time_pulse1_loss: 0.0692 - voltage_rise_time_pulse1_mae: 0.1829 - voltage_rise_time_pulse2_loss: 0.1700 - voltage_rise_time_pulse2_mae: 0.2640 - val_current_fall_time_pulse1_loss: 0.0230 - val_current_fall_time_pulse1_mae: 0.1183 - val_current_fall_time_pulse2_loss: 0.0264 - val_current_fall_time_pulse2_mae: 0.1265 - val_current_rise_time_pulse1_loss: 0.0782 - val_current_rise_time_pulse1_mae: 0.1895 - val_current_rise_time_pulse2_loss: 0.1395 - val_current_rise_time_pulse2_mae: 0.2539 - val_loss: 0.9936 - val_overshoot_pulse_1_loss: 0.1362 - val_overshoot_pulse_1_mae: 0.2505 - val_overshoot_pulse_2_loss: 0.1071 - val_overshoot_pulse_2_mae: 0.2358 - val_ringing_frequency_MHz_loss: 0.0029 - val_ringing_frequency_MHz_mae: 0.0434 - val_undershoot_pulse_1_loss: 0.0357 - val_undershoot_pulse_1_mae: 0.1413 - val_undershoot_pulse_2_loss: 0.0390 - val_undershoot_pulse_2_mae: 0.1505 - val_voltage_fall_time_pulse1_loss: 0.0266 - val_voltage_fall_time_pulse1_mae: 0.1353 - val_voltage_fall_time_pulse2_loss: 0.0187 - val_voltage_fall_time_pulse2_mae: 0.1123 - val_voltage_rise_time_pulse1_loss: 0.0535 - val_voltage_rise_time_pulse1_mae: 0.1692 - val_voltage_rise_time_pulse2_loss: 0.2502 - val_voltage_rise_time_pulse2_mae: 0.2704 - learning_rate: 5.0000e-04
# Epoch 21/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - current_fall_time_pulse1_loss: 0.0578 - current_fall_time_pulse1_mae: 0.1841 - current_fall_time_pulse2_loss: 0.0498 - current_fall_time_pulse2_mae: 0.1720 - current_rise_time_pulse1_loss: 0.1023 - current_rise_time_pulse1_mae: 0.2269 - current_rise_time_pulse2_loss: 0.1596 - current_rise_time_pulse2_mae: 0.2840 - loss: 1.0971 - overshoot_pulse_1_loss: 0.1549 - overshoot_pulse_1_mae: 0.2966 - overshoot_pulse_2_loss: 0.1162 - overshoot_pulse_2_mae: 0.2674 - ringing_frequency_MHz_loss: 0.0038 - ringing_frequency_MHz_mae: 0.0465 - undershoot_pulse_1_loss: 0.0835 - undershoot_pulse_1_mae: 0.2166 - undershoot_pulse_2_loss: 0.0831 - undershoot_pulse_2_mae: 0.2187 - voltage_fall_time_pulse1_loss: 0.0249 - voltage_fall_time_pulse1_mae: 0.1155 - voltage_fall_time_pulse2_loss: 0.0271 - voltage_fall_time_pulse2_mae: 0.1215 - voltage_rise_time_pulse1_loss: 0.0635 - voltage_rise_time_pulse1_mae: 0.1765 - voltage_rise_time_pulse2_loss: 0.1581 - voltage_rise_time_pulse2_mae: 0.2565 - val_current_fall_time_pulse1_loss: 0.0214 - val_current_fall_time_pulse1_mae: 0.1144 - val_current_fall_time_pulse2_loss: 0.0242 - val_current_fall_time_pulse2_mae: 0.1235 - val_current_rise_time_pulse1_loss: 0.0761 - val_current_rise_time_pulse1_mae: 0.1824 - val_current_rise_time_pulse2_loss: 0.1378 - val_current_rise_time_pulse2_mae: 0.2503 - val_loss: 0.9798 - val_overshoot_pulse_1_loss: 0.1322 - val_overshoot_pulse_1_mae: 0.2410 - val_overshoot_pulse_2_loss: 0.1060 - val_overshoot_pulse_2_mae: 0.2326 - val_ringing_frequency_MHz_loss: 0.0030 - val_ringing_frequency_MHz_mae: 0.0437 - val_undershoot_pulse_1_loss: 0.0337 - val_undershoot_pulse_1_mae: 0.1360 - val_undershoot_pulse_2_loss: 0.0367 - val_undershoot_pulse_2_mae: 0.1450 - val_voltage_fall_time_pulse1_loss: 0.0247 - val_voltage_fall_time_pulse1_mae: 0.1286 - val_voltage_fall_time_pulse2_loss: 0.0191 - val_voltage_fall_time_pulse2_mae: 0.1151 - val_voltage_rise_time_pulse1_loss: 0.0532 - val_voltage_rise_time_pulse1_mae: 0.1715 - val_voltage_rise_time_pulse2_loss: 0.2570 - val_voltage_rise_time_pulse2_mae: 0.2776 - learning_rate: 5.0000e-04
# Epoch 22/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - current_fall_time_pulse1_loss: 0.0543 - current_fall_time_pulse1_mae: 0.1781 - current_fall_time_pulse2_loss: 0.0490 - current_fall_time_pulse2_mae: 0.1722 - current_rise_time_pulse1_loss: 0.0964 - current_rise_time_pulse1_mae: 0.2192 - current_rise_time_pulse2_loss: 0.1554 - current_rise_time_pulse2_mae: 0.2808 - loss: 1.0892 - overshoot_pulse_1_loss: 0.1579 - overshoot_pulse_1_mae: 0.2992 - overshoot_pulse_2_loss: 0.1153 - overshoot_pulse_2_mae: 0.2637 - ringing_frequency_MHz_loss: 0.0034 - ringing_frequency_MHz_mae: 0.0435 - undershoot_pulse_1_loss: 0.0808 - undershoot_pulse_1_mae: 0.2139 - undershoot_pulse_2_loss: 0.0820 - undershoot_pulse_2_mae: 0.2167 - voltage_fall_time_pulse1_loss: 0.0248 - voltage_fall_time_pulse1_mae: 0.1151 - voltage_fall_time_pulse2_loss: 0.0252 - voltage_fall_time_pulse2_mae: 0.1183 - voltage_rise_time_pulse1_loss: 0.0648 - voltage_rise_time_pulse1_mae: 0.1760 - voltage_rise_time_pulse2_loss: 0.1676 - voltage_rise_time_pulse2_mae: 0.2566 - val_current_fall_time_pulse1_loss: 0.0204 - val_current_fall_time_pulse1_mae: 0.1123 - val_current_fall_time_pulse2_loss: 0.0222 - val_current_fall_time_pulse2_mae: 0.1192 - val_current_rise_time_pulse1_loss: 0.0758 - val_current_rise_time_pulse1_mae: 0.1847 - val_current_rise_time_pulse2_loss: 0.1322 - val_current_rise_time_pulse2_mae: 0.2430 - val_loss: 0.9576 - val_overshoot_pulse_1_loss: 0.1266 - val_overshoot_pulse_1_mae: 0.2405 - val_overshoot_pulse_2_loss: 0.1044 - val_overshoot_pulse_2_mae: 0.2318 - val_ringing_frequency_MHz_loss: 0.0032 - val_ringing_frequency_MHz_mae: 0.0442 - val_undershoot_pulse_1_loss: 0.0338 - val_undershoot_pulse_1_mae: 0.1384 - val_undershoot_pulse_2_loss: 0.0352 - val_undershoot_pulse_2_mae: 0.1414 - val_voltage_fall_time_pulse1_loss: 0.0234 - val_voltage_fall_time_pulse1_mae: 0.1285 - val_voltage_fall_time_pulse2_loss: 0.0162 - val_voltage_fall_time_pulse2_mae: 0.1050 - val_voltage_rise_time_pulse1_loss: 0.0529 - val_voltage_rise_time_pulse1_mae: 0.1712 - val_voltage_rise_time_pulse2_loss: 0.2525 - val_voltage_rise_time_pulse2_mae: 0.2735 - learning_rate: 5.0000e-04
# Epoch 23/120
# ...
# Epoch 51/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - current_fall_time_pulse1_loss: 0.0322 - current_fall_time_pulse1_mae: 0.1366 - current_fall_time_pulse2_loss: 0.0274 - current_fall_time_pulse2_mae: 0.1257 - current_rise_time_pulse1_loss: 0.0778 - current_rise_time_pulse1_mae: 0.1867 - current_rise_time_pulse2_loss: 0.1250 - current_rise_time_pulse2_mae: 0.2376 - loss: 0.7733 - overshoot_pulse_1_loss: 0.1052 - overshoot_pulse_1_mae: 0.2437 - overshoot_pulse_2_loss: 0.0943 - overshoot_pulse_2_mae: 0.2406 - ringing_frequency_MHz_loss: 0.0016 - ringing_frequency_MHz_mae: 0.0290 - undershoot_pulse_1_loss: 0.0558 - undershoot_pulse_1_mae: 0.1782 - undershoot_pulse_2_loss: 0.0537 - undershoot_pulse_2_mae: 0.1742 - voltage_fall_time_pulse1_loss: 0.0123 - voltage_fall_time_pulse1_mae: 0.0798 - voltage_fall_time_pulse2_loss: 0.0131 - voltage_fall_time_pulse2_mae: 0.0835 - voltage_rise_time_pulse1_loss: 0.0387 - voltage_rise_time_pulse1_mae: 0.1312 - voltage_rise_time_pulse2_loss: 0.1240 - voltage_rise_time_pulse2_mae: 0.2234 - val_current_fall_time_pulse1_loss: 0.0213 - val_current_fall_time_pulse1_mae: 0.1189 - val_current_fall_time_pulse2_loss: 0.0276 - val_current_fall_time_pulse2_mae: 0.1293 - val_current_rise_time_pulse1_loss: 0.0776 - val_current_rise_time_pulse1_mae: 0.1978 - val_current_rise_time_pulse2_loss: 0.1259 - val_current_rise_time_pulse2_mae: 0.2243 - val_loss: 0.9303 - val_overshoot_pulse_1_loss: 0.1038 - val_overshoot_pulse_1_mae: 0.2124 - val_overshoot_pulse_2_loss: 0.1006 - val_overshoot_pulse_2_mae: 0.2336 - val_ringing_frequency_MHz_loss: 0.0029 - val_ringing_frequency_MHz_mae: 0.0421 - val_undershoot_pulse_1_loss: 0.0502 - val_undershoot_pulse_1_mae: 0.1700 - val_undershoot_pulse_2_loss: 0.0482 - val_undershoot_pulse_2_mae: 0.1694 - val_voltage_fall_time_pulse1_loss: 0.0316 - val_voltage_fall_time_pulse1_mae: 0.1381 - val_voltage_fall_time_pulse2_loss: 0.0231 - val_voltage_fall_time_pulse2_mae: 0.1163 - val_voltage_rise_time_pulse1_loss: 0.0415 - val_voltage_rise_time_pulse1_mae: 0.1553 - val_voltage_rise_time_pulse2_loss: 0.2221 - val_voltage_rise_time_pulse2_mae: 0.2541 - learning_rate: 1.5000e-04
# Epoch 52/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - current_fall_time_pulse1_loss: 0.0312 - current_fall_time_pulse1_mae: 0.1324 - current_fall_time_pulse2_loss: 0.0274 - current_fall_time_pulse2_mae: 0.1270 - current_rise_time_pulse1_loss: 0.0776 - current_rise_time_pulse1_mae: 0.1881 - current_rise_time_pulse2_loss: 0.1287 - current_rise_time_pulse2_mae: 0.2410 - loss: 0.7714 - overshoot_pulse_1_loss: 0.1086 - overshoot_pulse_1_mae: 0.2496 - overshoot_pulse_2_loss: 0.0941 - overshoot_pulse_2_mae: 0.2409 - ringing_frequency_MHz_loss: 0.0016 - ringing_frequency_MHz_mae: 0.0288 - undershoot_pulse_1_loss: 0.0560 - undershoot_pulse_1_mae: 0.1774 - undershoot_pulse_2_loss: 0.0563 - undershoot_pulse_2_mae: 0.1782 - voltage_fall_time_pulse1_loss: 0.0116 - voltage_fall_time_pulse1_mae: 0.0778 - voltage_fall_time_pulse2_loss: 0.0122 - voltage_fall_time_pulse2_mae: 0.0806 - voltage_rise_time_pulse1_loss: 0.0388 - voltage_rise_time_pulse1_mae: 0.1290 - voltage_rise_time_pulse2_loss: 0.1152 - voltage_rise_time_pulse2_mae: 0.2202 - val_current_fall_time_pulse1_loss: 0.0200 - val_current_fall_time_pulse1_mae: 0.1150 - val_current_fall_time_pulse2_loss: 0.0268 - val_current_fall_time_pulse2_mae: 0.1292 - val_current_rise_time_pulse1_loss: 0.0772 - val_current_rise_time_pulse1_mae: 0.1966 - val_current_rise_time_pulse2_loss: 0.1271 - val_current_rise_time_pulse2_mae: 0.2269 - val_loss: 0.9365 - val_overshoot_pulse_1_loss: 0.1087 - val_overshoot_pulse_1_mae: 0.2156 - val_overshoot_pulse_2_loss: 0.1009 - val_overshoot_pulse_2_mae: 0.2339 - val_ringing_frequency_MHz_loss: 0.0028 - val_ringing_frequency_MHz_mae: 0.0410 - val_undershoot_pulse_1_loss: 0.0489 - val_undershoot_pulse_1_mae: 0.1682 - val_undershoot_pulse_2_loss: 0.0517 - val_undershoot_pulse_2_mae: 0.1763 - val_voltage_fall_time_pulse1_loss: 0.0306 - val_voltage_fall_time_pulse1_mae: 0.1365 - val_voltage_fall_time_pulse2_loss: 0.0254 - val_voltage_fall_time_pulse2_mae: 0.1193 - val_voltage_rise_time_pulse1_loss: 0.0425 - val_voltage_rise_time_pulse1_mae: 0.1572 - val_voltage_rise_time_pulse2_loss: 0.2206 - val_voltage_rise_time_pulse2_mae: 0.2544 - learning_rate: 1.5000e-04
# Epoch 53/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - current_fall_time_pulse1_loss: 0.0311 - current_fall_time_pulse1_mae: 0.1343 - current_fall_time_pulse2_loss: 0.0272 - current_fall_time_pulse2_mae: 0.1263 - current_rise_time_pulse1_loss: 0.0783 - current_rise_time_pulse1_mae: 0.1886 - current_rise_time_pulse2_loss: 0.1252 - current_rise_time_pulse2_mae: 0.2353 - loss: 0.7584 - overshoot_pulse_1_loss: 0.1012 - overshoot_pulse_1_mae: 0.2422 - overshoot_pulse_2_loss: 0.0967 - overshoot_pulse_2_mae: 0.2443 - ringing_frequency_MHz_loss: 0.0014 - ringing_frequency_MHz_mae: 0.0282 - undershoot_pulse_1_loss: 0.0539 - undershoot_pulse_1_mae: 0.1750 - undershoot_pulse_2_loss: 0.0544 - undershoot_pulse_2_mae: 0.1760 - voltage_fall_time_pulse1_loss: 0.0113 - voltage_fall_time_pulse1_mae: 0.0760 - voltage_fall_time_pulse2_loss: 0.0128 - voltage_fall_time_pulse2_mae: 0.0826 - voltage_rise_time_pulse1_loss: 0.0374 - voltage_rise_time_pulse1_mae: 0.1283 - voltage_rise_time_pulse2_loss: 0.1151 - voltage_rise_time_pulse2_mae: 0.2211 - val_current_fall_time_pulse1_loss: 0.0208 - val_current_fall_time_pulse1_mae: 0.1171 - val_current_fall_time_pulse2_loss: 0.0274 - val_current_fall_time_pulse2_mae: 0.1294 - val_current_rise_time_pulse1_loss: 0.0768 - val_current_rise_time_pulse1_mae: 0.1966 - val_current_rise_time_pulse2_loss: 0.1273 - val_current_rise_time_pulse2_mae: 0.2262 - val_loss: 0.9357 - val_overshoot_pulse_1_loss: 0.1047 - val_overshoot_pulse_1_mae: 0.2125 - val_overshoot_pulse_2_loss: 0.1023 - val_overshoot_pulse_2_mae: 0.2359 - val_ringing_frequency_MHz_loss: 0.0028 - val_ringing_frequency_MHz_mae: 0.0408 - val_undershoot_pulse_1_loss: 0.0505 - val_undershoot_pulse_1_mae: 0.1708 - val_undershoot_pulse_2_loss: 0.0515 - val_undershoot_pulse_2_mae: 0.1761 - val_voltage_fall_time_pulse1_loss: 0.0310 - val_voltage_fall_time_pulse1_mae: 0.1370 - val_voltage_fall_time_pulse2_loss: 0.0237 - val_voltage_fall_time_pulse2_mae: 0.1159 - val_voltage_rise_time_pulse1_loss: 0.0431 - val_voltage_rise_time_pulse1_mae: 0.1591 - val_voltage_rise_time_pulse2_loss: 0.2209 - val_voltage_rise_time_pulse2_mae: 0.2547 - learning_rate: 1.5000e-04
# Epoch 54/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - current_fall_time_pulse1_loss: 0.0297 - current_fall_time_pulse1_mae: 0.1312 - current_fall_time_pulse2_loss: 0.0267 - current_fall_time_pulse2_mae: 0.1249 - current_rise_time_pulse1_loss: 0.0787 - current_rise_time_pulse1_mae: 0.1891 - current_rise_time_pulse2_loss: 0.1248 - current_rise_time_pulse2_mae: 0.2373 - loss: 0.7625 - overshoot_pulse_1_loss: 0.1065 - overshoot_pulse_1_mae: 0.2478 - overshoot_pulse_2_loss: 0.0951 - overshoot_pulse_2_mae: 0.2407 - ringing_frequency_MHz_loss: 0.0015 - ringing_frequency_MHz_mae: 0.0282 - undershoot_pulse_1_loss: 0.0535 - undershoot_pulse_1_mae: 0.1726 - undershoot_pulse_2_loss: 0.0557 - undershoot_pulse_2_mae: 0.1753 - voltage_fall_time_pulse1_loss: 0.0112 - voltage_fall_time_pulse1_mae: 0.0761 - voltage_fall_time_pulse2_loss: 0.0117 - voltage_fall_time_pulse2_mae: 0.0791 - voltage_rise_time_pulse1_loss: 0.0359 - voltage_rise_time_pulse1_mae: 0.1256 - voltage_rise_time_pulse2_loss: 0.1191 - voltage_rise_time_pulse2_mae: 0.2230 - val_current_fall_time_pulse1_loss: 0.0213 - val_current_fall_time_pulse1_mae: 0.1188 - val_current_fall_time_pulse2_loss: 0.0262 - val_current_fall_time_pulse2_mae: 0.1263 - val_current_rise_time_pulse1_loss: 0.0782 - val_current_rise_time_pulse1_mae: 0.2000 - val_current_rise_time_pulse2_loss: 0.1297 - val_current_rise_time_pulse2_mae: 0.2285 - val_loss: 0.9291 - val_overshoot_pulse_1_loss: 0.1063 - val_overshoot_pulse_1_mae: 0.2153 - val_overshoot_pulse_2_loss: 0.0995 - val_overshoot_pulse_2_mae: 0.2324 - val_ringing_frequency_MHz_loss: 0.0032 - val_ringing_frequency_MHz_mae: 0.0437 - val_undershoot_pulse_1_loss: 0.0495 - val_undershoot_pulse_1_mae: 0.1674 - val_undershoot_pulse_2_loss: 0.0517 - val_undershoot_pulse_2_mae: 0.1746 - val_voltage_fall_time_pulse1_loss: 0.0277 - val_voltage_fall_time_pulse1_mae: 0.1310 - val_voltage_fall_time_pulse2_loss: 0.0222 - val_voltage_fall_time_pulse2_mae: 0.1146 - val_voltage_rise_time_pulse1_loss: 0.0420 - val_voltage_rise_time_pulse1_mae: 0.1562 - val_voltage_rise_time_pulse2_loss: 0.2167 - val_voltage_rise_time_pulse2_mae: 0.2512 - learning_rate: 1.5000e-04
# Epoch 55/120
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - current_fall_time_pulse1_loss: 0.0318 - current_fall_time_pulse1_mae: 0.1340 - current_fall_time_pulse2_loss: 0.0279 - current_fall_time_pulse2_mae: 0.1271 - current_rise_time_pulse1_loss: 0.0798 - current_rise_time_pulse1_mae: 0.1920 - current_rise_time_pulse2_loss: 0.1261 - current_rise_time_pulse2_mae: 0.2365 - loss: 0.7603 - overshoot_pulse_1_loss: 0.1061 - overshoot_pulse_1_mae: 0.2469 - overshoot_pulse_2_loss: 0.0923 - overshoot_pulse_2_mae: 0.2386 - ringing_frequency_MHz_loss: 0.0015 - ringing_frequency_MHz_mae: 0.0278 - undershoot_pulse_1_loss: 0.0548 - undershoot_pulse_1_mae: 0.1752 - undershoot_pulse_2_loss: 0.0535 - undershoot_pulse_2_mae: 0.1740 - voltage_fall_time_pulse1_loss: 0.0111 - voltage_fall_time_pulse1_mae: 0.0765 - voltage_fall_time_pulse2_loss: 0.0120 - voltage_fall_time_pulse2_mae: 0.0806 - voltage_rise_time_pulse1_loss: 0.0364 - voltage_rise_time_pulse1_mae: 0.1266 - voltage_rise_time_pulse2_loss: 0.1148 - voltage_rise_time_pulse2_mae: 0.2226 - val_current_fall_time_pulse1_loss: 0.0205 - val_current_fall_time_pulse1_mae: 0.1167 - val_current_fall_time_pulse2_loss: 0.0267 - val_current_fall_time_pulse2_mae: 0.1279 - val_current_rise_time_pulse1_loss: 0.0763 - val_current_rise_time_pulse1_mae: 0.1952 - val_current_rise_time_pulse2_loss: 0.1286 - val_current_rise_time_pulse2_mae: 0.2277 - val_loss: 0.9377 - val_overshoot_pulse_1_loss: 0.1122 - val_overshoot_pulse_1_mae: 0.2213 - val_overshoot_pulse_2_loss: 0.1036 - val_overshoot_pulse_2_mae: 0.2379 - val_ringing_frequency_MHz_loss: 0.0031 - val_ringing_frequency_MHz_mae: 0.0431 - val_undershoot_pulse_1_loss: 0.0502 - val_undershoot_pulse_1_mae: 0.1694 - val_undershoot_pulse_2_loss: 0.0504 - val_undershoot_pulse_2_mae: 0.1726 - val_voltage_fall_time_pulse1_loss: 0.0298 - val_voltage_fall_time_pulse1_mae: 0.1343 - val_voltage_fall_time_pulse2_loss: 0.0221 - val_voltage_fall_time_pulse2_mae: 0.1144 - val_voltage_rise_time_pulse1_loss: 0.0407 - val_voltage_rise_time_pulse1_mae: 0.1539 - val_voltage_rise_time_pulse2_loss: 0.2188 - val_voltage_rise_time_pulse2_mae: 0.2539 - learning_rate: 1.5000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# train:
#                        Target        R2          RMSE
# 3   voltage_fall_time_pulse2  0.983004  8.922442e-10
# 6   current_fall_time_pulse1  0.979457  1.683065e-09
# 2   voltage_fall_time_pulse1  0.979013  9.926192e-10
# 7   current_fall_time_pulse2  0.977487  1.755638e-09
# 0   voltage_rise_time_pulse1  0.965301  7.505865e-10
# 10        undershoot_pulse_1  0.962893  2.667893e+00
# 11        undershoot_pulse_2  0.961716  2.715258e+00
# 12     ringing_frequency_MHz  0.956772  6.831207e+00
# 8          overshoot_pulse_1  0.928850  3.071269e+00
# 4   current_rise_time_pulse1  0.925359  1.334075e-08
# 9          overshoot_pulse_2  0.920271  6.987537e+00
# 1   voltage_rise_time_pulse2  0.885704  1.298965e-09
# 5   current_rise_time_pulse2  0.876248  8.676113e-09
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# val:
#                        Target        R2          RMSE
# 3   voltage_fall_time_pulse2  0.983327  9.104943e-10
# 6   current_fall_time_pulse1  0.979415  1.711724e-09
# 2   voltage_fall_time_pulse1  0.979345  1.015209e-09
# 7   current_fall_time_pulse2  0.977130  1.800208e-09
# 10        undershoot_pulse_1  0.959220  2.767082e+00
# 0   voltage_rise_time_pulse1  0.957313  8.726127e-10
# 11        undershoot_pulse_2  0.956445  2.852053e+00
# 12     ringing_frequency_MHz  0.955836  7.111877e+00
# 4   current_rise_time_pulse1  0.924382  1.370648e-08
# 9          overshoot_pulse_2  0.907347  7.912891e+00
# 8          overshoot_pulse_1  0.898011  3.997931e+00
# 5   current_rise_time_pulse2  0.887281  8.575083e-09
# 1   voltage_rise_time_pulse2  0.783689  1.957533e-09
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# test:
#                        Target        R2          RMSE
# 3   voltage_fall_time_pulse2  0.983056  8.950059e-10
# 6   current_fall_time_pulse1  0.979452  1.687396e-09
# 2   voltage_fall_time_pulse1  0.979067  9.960409e-10
# 7   current_fall_time_pulse2  0.977433  1.762397e-09
# 0   voltage_rise_time_pulse1  0.964008  7.701270e-10
# 10        undershoot_pulse_1  0.962354  2.683008e+00
# 11        undershoot_pulse_2  0.960950  2.736217e+00
# 12     ringing_frequency_MHz  0.956625  6.874045e+00
# 4   current_rise_time_pulse1  0.925210  1.339626e-08
# 8          overshoot_pulse_1  0.923538  3.227299e+00
# 9          overshoot_pulse_2  0.918166  7.134018e+00
# 5   current_rise_time_pulse2  0.878041  8.661031e-09
# 1   voltage_rise_time_pulse2  0.867936  1.417411e-09
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# unseen:
#                        Target        R2          RMSE
# 2   voltage_fall_time_pulse1  0.917634  6.679715e-10
# 3   voltage_fall_time_pulse2  0.909963  6.987443e-10
# 6   current_fall_time_pulse1  0.804093  4.970398e-09
# 7   current_fall_time_pulse2  0.766219  5.392481e-09
# 8          overshoot_pulse_1  0.685330  7.126120e+00
# 0   voltage_rise_time_pulse1  0.640810  1.044874e-09
# 9          overshoot_pulse_2  0.600541  1.255656e+01
# 11        undershoot_pulse_2  0.564682  6.283679e+00
# 10        undershoot_pulse_1  0.511808  6.702620e+00
# 1   voltage_rise_time_pulse2  0.470281  3.206266e-09
# 5   current_rise_time_pulse2  0.248828  1.438680e-08
# 12     ringing_frequency_MHz  0.115443  3.426897e+00
#                       Target        R2          RMSE
# 2   voltage_fall_time_pulse1  0.917634  6.679715e-10
# 3   voltage_fall_time_pulse2  0.909963  6.987443e-10
# 6   current_fall_time_pulse1  0.804093  4.970398e-09
# 7   current_fall_time_pulse2  0.766219  5.392481e-09
# 8          overshoot_pulse_1  0.685330  7.126120e+00
# 0   voltage_rise_time_pulse1  0.640810  1.044874e-09
# 9          overshoot_pulse_2  0.600541  1.255656e+01
# 11        undershoot_pulse_2  0.564682  6.283679e+00
# 10        undershoot_pulse_1  0.511808  6.702620e+00
# 1   voltage_rise_time_pulse2  0.470281  3.206266e-09
# 5   current_rise_time_pulse2  0.248828  1.438680e-08
# 12     ringing_frequency_MHz  0.115443  3.426897e+00

# %%
# ==================== MULTI-HEAD ANN (FAST MODE) ====================
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, regularizers
import matplotlib.pyplot as plt

# ============== SETTINGS ==============
SEED = 42
UNSEEN_PART = 'C2M0040120D'
BASE_DIR = "iteration_3"
os.makedirs(f"{BASE_DIR}/r2_rmse_tables", exist_ok=True)
os.makedirs(f"{BASE_DIR}/train_val_loss_curves", exist_ok=True)
os.makedirs(f"{BASE_DIR}/predicted_vs_actual", exist_ok=True)
os.makedirs(f"{BASE_DIR}/models", exist_ok=True)

# ============== LOAD DATA ==============
df = pd.read_csv(
    r"C:\Users\pc\Desktop\Neural_Network_Models\merged_train_5_MOSFETs_25percent_balanced.csv"
)

# ============== TARGETS + DROPS ==============
TARGET_COLUMNS = [
    'voltage_rise_time_pulse1', 'voltage_rise_time_pulse2',
    'voltage_fall_time_pulse1', 'voltage_fall_time_pulse2',
    'current_rise_time_pulse1', 'current_rise_time_pulse2',
    'current_fall_time_pulse1', 'current_fall_time_pulse2',
    'overshoot_pulse_1', 'overshoot_pulse_2',
    'undershoot_pulse_1', 'undershoot_pulse_2',
    'ringing_frequency_MHz'
]
DROP_COLUMNS = ['DeviceID', 'MOSFET', 'Part_Number']

# ============== SPLIT SEEN/UNSEEN DEVICES ==============
seen_parts = [p for p in df['Part_Number'].unique().tolist() if p != UNSEEN_PART]
train_df = df[df['Part_Number'].isin(seen_parts)].copy()
test_df  = df[df['Part_Number'] == UNSEEN_PART].copy()

# ============== PHYSICS FEATURES ==============
def compute_physics_features(row):
    L_eq = row[['Ls4','Ls5','Ls6','Ls7','Ls8','Ls9','Ls10','Ls11']].sum()
    C_eq = row.get("Coss", 1e-12)
    f_res = 1/(2*np.pi*np.sqrt(L_eq*C_eq))/1e6 if L_eq>0 and C_eq>0 else 0
    overshoot_est = row.get("VDS_max",0) - row.get("Vbus",0)
    undershoot_est = - row.get("VGS_th_min",0)
    dVdt_est = row.get("VDS_max",0)/row.get("Tp1",1e-9)
    dIdt_est = row.get("ID_max_25C",0)/row.get("Tp1",1e-9)
    return pd.Series([f_res, overshoot_est, undershoot_est, dVdt_est, dIdt_est])

for df_ in [train_df, test_df]:
    df_[['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est']] = \
        df_.apply(compute_physics_features, axis=1)

physics_features = ['f_resonance','overshoot_est','undershoot_est','dVdt_est','dIdt_est']
INPUT_COLUMNS = [c for c in df.columns if c not in TARGET_COLUMNS + DROP_COLUMNS] + physics_features

# ============== SCALE INPUTS ==============
input_scaler = StandardScaler()
input_scaler.fit(pd.concat([train_df[INPUT_COLUMNS], test_df[INPUT_COLUMNS]]))
X_train_all = input_scaler.transform(train_df[INPUT_COLUMNS])
X_test_all  = input_scaler.transform(test_df[INPUT_COLUMNS])

# Separate physics cols
phys_idx = [INPUT_COLUMNS.index(c) for c in physics_features]
X_train_phys = X_train_all[:, phys_idx]
X_test_phys  = X_test_all[:, phys_idx]
X_train_main = np.delete(X_train_all, phys_idx, axis=1)
X_test_main  = np.delete(X_test_all, phys_idx, axis=1)

# ============== SCALE OUTPUTS (per target) ==============
output_scalers, y_train_scaled, y_test_scaled = {}, [], []
for col in TARGET_COLUMNS:
    scaler = MinMaxScaler() if col == 'ringing_frequency_MHz' else StandardScaler()
    y_train_scaled.append(scaler.fit_transform(train_df[[col]]).flatten())
    y_test_scaled.append(scaler.transform(test_df[[col]]).flatten())
    output_scalers[col] = scaler
y_train_scaled = np.array(y_train_scaled).T
y_test_scaled  = np.array(y_test_scaled).T

# ============== SPLIT TRAIN/VAL ==============
Xtr_main, Xval_main, Xtr_phys, Xval_phys, ytr, yval = train_test_split(
    X_train_main, X_train_phys, y_train_scaled,
    test_size=0.15, random_state=SEED
)

# ============== BUILD MULTI-HEAD ANN (FAST BACKBONE) ==============
def build_multihead_ann(input_dim_main, input_dim_phys, output_dim, l2_reg=1e-4, dropout_rate=0.2):
    inp_main = layers.Input(shape=(input_dim_main,), name="main_inputs")
    inp_phys = layers.Input(shape=(input_dim_phys,), name="physics_inputs")

    # Shared backbone
    x_main = layers.Dense(128, kernel_regularizer=regularizers.l2(l2_reg))(inp_main)
    x_main = layers.BatchNormalization()(x_main); x_main = layers.ReLU()(x_main)
    x_main = layers.Dropout(dropout_rate)(x_main)

    x_main = layers.Dense(64, kernel_regularizer=regularizers.l2(l2_reg))(x_main)
    x_main = layers.BatchNormalization()(x_main); x_main = layers.ReLU()(x_main)
    x_main = layers.Dropout(dropout_rate)(x_main)

    x_phys = layers.Dense(32, activation="relu")(inp_phys)

    shared = layers.concatenate([x_main, x_phys])

    # Multi-head outputs (deeper per-head)
    outputs = []
    for i, col in enumerate(TARGET_COLUMNS):
        h = layers.Dense(64, activation="relu")(shared)
        h = layers.Dropout(dropout_rate)(h)
        h = layers.Dense(32, activation="relu")(h)
        out = layers.Dense(1, activation="linear", name=col)(h)
        outputs.append(out)

    model = models.Model(inputs=[inp_main, inp_phys], outputs=outputs)
    return model

model = build_multihead_ann(Xtr_main.shape[1], Xtr_phys.shape[1], len(TARGET_COLUMNS))

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-4),
    loss=["mse"]*len(TARGET_COLUMNS),
    metrics=["mae"]*len(TARGET_COLUMNS)
)

early_stop = callbacks.EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)
reduce_lr  = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=5)

history = model.fit(
    [Xtr_main, Xtr_phys],
    [ytr[:,i] for i in range(len(TARGET_COLUMNS))],
    validation_data=([Xval_main,Xval_phys],[yval[:,i] for i in range(len(TARGET_COLUMNS))]),
    epochs=120, batch_size=256, callbacks=[early_stop, reduce_lr], verbose=1
)


model.save(f"{BASE_DIR}/models/multihead_ann.h5")

# ============== LOSS CURVE ==============
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel("Epoch"); plt.ylabel("MSE Loss")
plt.title("Train vs Validation Loss")
plt.legend(); plt.savefig(f"{BASE_DIR}/train_val_loss_curves/loss.png"); plt.close()

# ============== EVALUATION ==============
def evaluate_and_save(X_main, X_phys, y_scaled, name, positive_only=False):
    y_pred_scaled_list = model.predict([X_main, X_phys])
    results = []
    for i, col in enumerate(TARGET_COLUMNS):
        y_true = output_scalers[col].inverse_transform(y_scaled[:,i].reshape(-1,1)).flatten()
        y_pred = output_scalers[col].inverse_transform(y_pred_scaled_list[i].reshape(-1,1)).flatten()
        r2 = r2_score(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        results.append((col, r2, rmse))
    df_results = pd.DataFrame(results, columns=["Target","R2","RMSE"]).sort_values("R2",ascending=False)
    if positive_only:
        df_results = df_results[df_results["R2"]>0]
    print(f"\n{name}:\n",df_results)
    df_results.to_csv(f"{BASE_DIR}/r2_rmse_tables/{name}.csv", index=False)
    return df_results

# Run evals
evaluate_and_save(Xtr_main,Xtr_phys,ytr,"train")
evaluate_and_save(Xval_main,Xval_phys,yval,"val")
evaluate_and_save(X_train_main,X_train_phys,y_train_scaled,"test")
evaluate_and_save(X_test_main,X_test_phys,y_test_scaled,"unseen",positive_only=True)
# Out:
# Epoch 1/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - current_fall_time_pulse1_loss: 0.3721 - current_fall_time_pulse1_mae: 0.4432 - current_fall_time_pulse2_loss: 0.3732 - current_fall_time_pulse2_mae: 0.4416 - current_rise_time_pulse1_loss: 0.3775 - current_rise_time_pulse1_mae: 0.4446 - current_rise_time_pulse2_loss: 0.4416 - current_rise_time_pulse2_mae: 0.5135 - loss: 5.3318 - overshoot_pulse_1_loss: 0.5704 - overshoot_pulse_1_mae: 0.5558 - overshoot_pulse_2_loss: 0.5662 - overshoot_pulse_2_mae: 0.5493 - ringing_frequency_MHz_loss: 0.1719 - ringing_frequency_MHz_mae: 0.2796 - undershoot_pulse_1_loss: 0.4616 - undershoot_pulse_1_mae: 0.4957 - undershoot_pulse_2_loss: 0.5062 - undershoot_pulse_2_mae: 0.5051 - voltage_fall_time_pulse1_loss: 0.2384 - voltage_fall_time_pulse1_mae: 0.3428 - voltage_fall_time_pulse2_loss: 0.3590 - voltage_fall_time_pulse2_mae: 0.4276 - voltage_rise_time_pulse1_loss: 0.3986 - voltage_rise_time_pulse1_mae: 0.4199 - voltage_rise_time_pulse2_loss: 0.4818 - voltage_rise_time_pulse2_mae: 0.4675 - val_current_fall_time_pulse1_loss: 0.0386 - val_current_fall_time_pulse1_mae: 0.1543 - val_current_fall_time_pulse2_loss: 0.0307 - val_current_fall_time_pulse2_mae: 0.1421 - val_current_rise_time_pulse1_loss: 0.0939 - val_current_rise_time_pulse1_mae: 0.2101 - val_current_rise_time_pulse2_loss: 0.1552 - val_current_rise_time_pulse2_mae: 0.2902 - val_loss: 1.0235 - val_overshoot_pulse_1_loss: 0.1319 - val_overshoot_pulse_1_mae: 0.2737 - val_overshoot_pulse_2_loss: 0.1250 - val_overshoot_pulse_2_mae: 0.2668 - val_ringing_frequency_MHz_loss: 0.0073 - val_ringing_frequency_MHz_mae: 0.0723 - val_undershoot_pulse_1_loss: 0.0557 - val_undershoot_pulse_1_mae: 0.1745 - val_undershoot_pulse_2_loss: 0.0679 - val_undershoot_pulse_2_mae: 0.2042 - val_voltage_fall_time_pulse1_loss: 0.0196 - val_voltage_fall_time_pulse1_mae: 0.1188 - val_voltage_fall_time_pulse2_loss: 0.0252 - val_voltage_fall_time_pulse2_mae: 0.1195 - val_voltage_rise_time_pulse1_loss: 0.0700 - val_voltage_rise_time_pulse1_mae: 0.1938 - val_voltage_rise_time_pulse2_loss: 0.1893 - val_voltage_rise_time_pulse2_mae: 0.2703 - learning_rate: 5.0000e-04
# Epoch 2/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - current_fall_time_pulse1_loss: 0.0733 - current_fall_time_pulse1_mae: 0.2069 - current_fall_time_pulse2_loss: 0.0701 - current_fall_time_pulse2_mae: 0.2013 - current_rise_time_pulse1_loss: 0.1169 - current_rise_time_pulse1_mae: 0.2478 - current_rise_time_pulse2_loss: 0.1790 - current_rise_time_pulse2_mae: 0.3103 - loss: 1.4440 - overshoot_pulse_1_loss: 0.1945 - overshoot_pulse_1_mae: 0.3299 - overshoot_pulse_2_loss: 0.1555 - overshoot_pulse_2_mae: 0.3038 - ringing_frequency_MHz_loss: 0.0114 - ringing_frequency_MHz_mae: 0.0821 - undershoot_pulse_1_loss: 0.1101 - undershoot_pulse_1_mae: 0.2475 - undershoot_pulse_2_loss: 0.1143 - undershoot_pulse_2_mae: 0.2512 - voltage_fall_time_pulse1_loss: 0.0421 - voltage_fall_time_pulse1_mae: 0.1529 - voltage_fall_time_pulse2_loss: 0.0413 - voltage_fall_time_pulse2_mae: 0.1533 - voltage_rise_time_pulse1_loss: 0.0907 - voltage_rise_time_pulse1_mae: 0.2166 - voltage_rise_time_pulse2_loss: 0.2326 - voltage_rise_time_pulse2_mae: 0.2937 - val_current_fall_time_pulse1_loss: 0.0266 - val_current_fall_time_pulse1_mae: 0.1295 - val_current_fall_time_pulse2_loss: 0.0171 - val_current_fall_time_pulse2_mae: 0.1053 - val_current_rise_time_pulse1_loss: 0.0804 - val_current_rise_time_pulse1_mae: 0.1877 - val_current_rise_time_pulse2_loss: 0.1331 - val_current_rise_time_pulse2_mae: 0.2531 - val_loss: 0.8139 - val_overshoot_pulse_1_loss: 0.0921 - val_overshoot_pulse_1_mae: 0.2295 - val_overshoot_pulse_2_loss: 0.0965 - val_overshoot_pulse_2_mae: 0.2378 - val_ringing_frequency_MHz_loss: 0.0032 - val_ringing_frequency_MHz_mae: 0.0470 - val_undershoot_pulse_1_loss: 0.0405 - val_undershoot_pulse_1_mae: 0.1429 - val_undershoot_pulse_2_loss: 0.0506 - val_undershoot_pulse_2_mae: 0.1672 - val_voltage_fall_time_pulse1_loss: 0.0196 - val_voltage_fall_time_pulse1_mae: 0.1187 - val_voltage_fall_time_pulse2_loss: 0.0194 - val_voltage_fall_time_pulse2_mae: 0.1049 - val_voltage_rise_time_pulse1_loss: 0.0579 - val_voltage_rise_time_pulse1_mae: 0.1756 - val_voltage_rise_time_pulse2_loss: 0.1640 - val_voltage_rise_time_pulse2_mae: 0.2559 - learning_rate: 5.0000e-04
# Epoch 3/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - current_fall_time_pulse1_loss: 0.0516 - current_fall_time_pulse1_mae: 0.1718 - current_fall_time_pulse2_loss: 0.0490 - current_fall_time_pulse2_mae: 0.1686 - current_rise_time_pulse1_loss: 0.1007 - current_rise_time_pulse1_mae: 0.2237 - current_rise_time_pulse2_loss: 0.1544 - current_rise_time_pulse2_mae: 0.2753 - loss: 1.1483 - overshoot_pulse_1_loss: 0.1575 - overshoot_pulse_1_mae: 0.2951 - overshoot_pulse_2_loss: 0.1277 - overshoot_pulse_2_mae: 0.2752 - ringing_frequency_MHz_loss: 0.0061 - ringing_frequency_MHz_mae: 0.0593 - undershoot_pulse_1_loss: 0.0841 - undershoot_pulse_1_mae: 0.2140 - undershoot_pulse_2_loss: 0.0859 - undershoot_pulse_2_mae: 0.2158 - voltage_fall_time_pulse1_loss: 0.0254 - voltage_fall_time_pulse1_mae: 0.1174 - voltage_fall_time_pulse2_loss: 0.0246 - voltage_fall_time_pulse2_mae: 0.1175 - voltage_rise_time_pulse1_loss: 0.0668 - voltage_rise_time_pulse1_mae: 0.1818 - voltage_rise_time_pulse2_loss: 0.2026 - voltage_rise_time_pulse2_mae: 0.2677 - val_current_fall_time_pulse1_loss: 0.0291 - val_current_fall_time_pulse1_mae: 0.1371 - val_current_fall_time_pulse2_loss: 0.0223 - val_current_fall_time_pulse2_mae: 0.1203 - val_current_rise_time_pulse1_loss: 0.0779 - val_current_rise_time_pulse1_mae: 0.1808 - val_current_rise_time_pulse2_loss: 0.1279 - val_current_rise_time_pulse2_mae: 0.2447 - val_loss: 0.7621 - val_overshoot_pulse_1_loss: 0.0812 - val_overshoot_pulse_1_mae: 0.2153 - val_overshoot_pulse_2_loss: 0.0910 - val_overshoot_pulse_2_mae: 0.2310 - val_ringing_frequency_MHz_loss: 0.0026 - val_ringing_frequency_MHz_mae: 0.0418 - val_undershoot_pulse_1_loss: 0.0396 - val_undershoot_pulse_1_mae: 0.1386 - val_undershoot_pulse_2_loss: 0.0460 - val_undershoot_pulse_2_mae: 0.1570 - val_voltage_fall_time_pulse1_loss: 0.0214 - val_voltage_fall_time_pulse1_mae: 0.1223 - val_voltage_fall_time_pulse2_loss: 0.0174 - val_voltage_fall_time_pulse2_mae: 0.1013 - val_voltage_rise_time_pulse1_loss: 0.0504 - val_voltage_rise_time_pulse1_mae: 0.1654 - val_voltage_rise_time_pulse2_loss: 0.1424 - val_voltage_rise_time_pulse2_mae: 0.2383 - learning_rate: 5.0000e-04
# Epoch 4/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - current_fall_time_pulse1_loss: 0.0395 - current_fall_time_pulse1_mae: 0.1509 - current_fall_time_pulse2_loss: 0.0391 - current_fall_time_pulse2_mae: 0.1505 - current_rise_time_pulse1_loss: 0.0921 - current_rise_time_pulse1_mae: 0.2105 - current_rise_time_pulse2_loss: 0.1431 - current_rise_time_pulse2_mae: 0.2581 - loss: 0.9991 - overshoot_pulse_1_loss: 0.1346 - overshoot_pulse_1_mae: 0.2727 - overshoot_pulse_2_loss: 0.1137 - overshoot_pulse_2_mae: 0.2612 - ringing_frequency_MHz_loss: 0.0042 - ringing_frequency_MHz_mae: 0.0488 - undershoot_pulse_1_loss: 0.0732 - undershoot_pulse_1_mae: 0.1984 - undershoot_pulse_2_loss: 0.0751 - undershoot_pulse_2_mae: 0.2007 - voltage_fall_time_pulse1_loss: 0.0185 - voltage_fall_time_pulse1_mae: 0.1000 - voltage_fall_time_pulse2_loss: 0.0181 - voltage_fall_time_pulse2_mae: 0.1004 - voltage_rise_time_pulse1_loss: 0.0561 - voltage_rise_time_pulse1_mae: 0.1640 - voltage_rise_time_pulse2_loss: 0.1795 - voltage_rise_time_pulse2_mae: 0.2504 - val_current_fall_time_pulse1_loss: 0.0347 - val_current_fall_time_pulse1_mae: 0.1483 - val_current_fall_time_pulse2_loss: 0.0213 - val_current_fall_time_pulse2_mae: 0.1175 - val_current_rise_time_pulse1_loss: 0.0776 - val_current_rise_time_pulse1_mae: 0.1873 - val_current_rise_time_pulse2_loss: 0.1258 - val_current_rise_time_pulse2_mae: 0.2388 - val_loss: 0.7402 - val_overshoot_pulse_1_loss: 0.0727 - val_overshoot_pulse_1_mae: 0.2038 - val_overshoot_pulse_2_loss: 0.0911 - val_overshoot_pulse_2_mae: 0.2334 - val_ringing_frequency_MHz_loss: 0.0024 - val_ringing_frequency_MHz_mae: 0.0403 - val_undershoot_pulse_1_loss: 0.0418 - val_undershoot_pulse_1_mae: 0.1435 - val_undershoot_pulse_2_loss: 0.0489 - val_undershoot_pulse_2_mae: 0.1631 - val_voltage_fall_time_pulse1_loss: 0.0188 - val_voltage_fall_time_pulse1_mae: 0.1140 - val_voltage_fall_time_pulse2_loss: 0.0184 - val_voltage_fall_time_pulse2_mae: 0.1011 - val_voltage_rise_time_pulse1_loss: 0.0427 - val_voltage_rise_time_pulse1_mae: 0.1514 - val_voltage_rise_time_pulse2_loss: 0.1313 - val_voltage_rise_time_pulse2_mae: 0.2357 - learning_rate: 5.0000e-04
# Epoch 5/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - current_fall_time_pulse1_loss: 0.0334 - current_fall_time_pulse1_mae: 0.1389 - current_fall_time_pulse2_loss: 0.0340 - current_fall_time_pulse2_mae: 0.1408 - current_rise_time_pulse1_loss: 0.0880 - current_rise_time_pulse1_mae: 0.2024 - current_rise_time_pulse2_loss: 0.1352 - current_rise_time_pulse2_mae: 0.2454 - loss: 0.9165 - overshoot_pulse_1_loss: 0.1230 - overshoot_pulse_1_mae: 0.2605 - overshoot_pulse_2_loss: 0.1077 - overshoot_pulse_2_mae: 0.2542 - ringing_frequency_MHz_loss: 0.0031 - ringing_frequency_MHz_mae: 0.0417 - undershoot_pulse_1_loss: 0.0668 - undershoot_pulse_1_mae: 0.1886 - undershoot_pulse_2_loss: 0.0674 - undershoot_pulse_2_mae: 0.1896 - voltage_fall_time_pulse1_loss: 0.0148 - voltage_fall_time_pulse1_mae: 0.0884 - voltage_fall_time_pulse2_loss: 0.0146 - voltage_fall_time_pulse2_mae: 0.0901 - voltage_rise_time_pulse1_loss: 0.0486 - voltage_rise_time_pulse1_mae: 0.1501 - voltage_rise_time_pulse2_loss: 0.1680 - voltage_rise_time_pulse2_mae: 0.2373 - val_current_fall_time_pulse1_loss: 0.0355 - val_current_fall_time_pulse1_mae: 0.1500 - val_current_fall_time_pulse2_loss: 0.0254 - val_current_fall_time_pulse2_mae: 0.1280 - val_current_rise_time_pulse1_loss: 0.0832 - val_current_rise_time_pulse1_mae: 0.2017 - val_current_rise_time_pulse2_loss: 0.1232 - val_current_rise_time_pulse2_mae: 0.2361 - val_loss: 0.7296 - val_overshoot_pulse_1_loss: 0.0658 - val_overshoot_pulse_1_mae: 0.1938 - val_overshoot_pulse_2_loss: 0.0907 - val_overshoot_pulse_2_mae: 0.2352 - val_ringing_frequency_MHz_loss: 0.0028 - val_ringing_frequency_MHz_mae: 0.0422 - val_undershoot_pulse_1_loss: 0.0427 - val_undershoot_pulse_1_mae: 0.1443 - val_undershoot_pulse_2_loss: 0.0441 - val_undershoot_pulse_2_mae: 0.1533 - val_voltage_fall_time_pulse1_loss: 0.0203 - val_voltage_fall_time_pulse1_mae: 0.1154 - val_voltage_fall_time_pulse2_loss: 0.0209 - val_voltage_fall_time_pulse2_mae: 0.1101 - val_voltage_rise_time_pulse1_loss: 0.0421 - val_voltage_rise_time_pulse1_mae: 0.1551 - val_voltage_rise_time_pulse2_loss: 0.1203 - val_voltage_rise_time_pulse2_mae: 0.2261 - learning_rate: 5.0000e-04
# Epoch 6/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - current_fall_time_pulse1_loss: 0.0300 - current_fall_time_pulse1_mae: 0.1313 - current_fall_time_pulse2_loss: 0.0303 - current_fall_time_pulse2_mae: 0.1319 - current_rise_time_pulse1_loss: 0.0837 - current_rise_time_pulse1_mae: 0.1945 - current_rise_time_pulse2_loss: 0.1304 - current_rise_time_pulse2_mae: 0.2362 - loss: 0.8581 - overshoot_pulse_1_loss: 0.1132 - overshoot_pulse_1_mae: 0.2510 - overshoot_pulse_2_loss: 0.1021 - overshoot_pulse_2_mae: 0.2474 - ringing_frequency_MHz_loss: 0.0025 - ringing_frequency_MHz_mae: 0.0369 - undershoot_pulse_1_loss: 0.0625 - undershoot_pulse_1_mae: 0.1816 - undershoot_pulse_2_loss: 0.0630 - undershoot_pulse_2_mae: 0.1830 - voltage_fall_time_pulse1_loss: 0.0124 - voltage_fall_time_pulse1_mae: 0.0805 - voltage_fall_time_pulse2_loss: 0.0124 - voltage_fall_time_pulse2_mae: 0.0825 - voltage_rise_time_pulse1_loss: 0.0428 - voltage_rise_time_pulse1_mae: 0.1389 - voltage_rise_time_pulse2_loss: 0.1608 - voltage_rise_time_pulse2_mae: 0.2303 - val_current_fall_time_pulse1_loss: 0.0378 - val_current_fall_time_pulse1_mae: 0.1532 - val_current_fall_time_pulse2_loss: 0.0289 - val_current_fall_time_pulse2_mae: 0.1365 - val_current_rise_time_pulse1_loss: 0.0837 - val_current_rise_time_pulse1_mae: 0.2026 - val_current_rise_time_pulse2_loss: 0.1187 - val_current_rise_time_pulse2_mae: 0.2289 - val_loss: 0.7381 - val_overshoot_pulse_1_loss: 0.0619 - val_overshoot_pulse_1_mae: 0.1896 - val_overshoot_pulse_2_loss: 0.0916 - val_overshoot_pulse_2_mae: 0.2399 - val_ringing_frequency_MHz_loss: 0.0026 - val_ringing_frequency_MHz_mae: 0.0401 - val_undershoot_pulse_1_loss: 0.0496 - val_undershoot_pulse_1_mae: 0.1593 - val_undershoot_pulse_2_loss: 0.0517 - val_undershoot_pulse_2_mae: 0.1694 - val_voltage_fall_time_pulse1_loss: 0.0259 - val_voltage_fall_time_pulse1_mae: 0.1292 - val_voltage_fall_time_pulse2_loss: 0.0210 - val_voltage_fall_time_pulse2_mae: 0.1127 - val_voltage_rise_time_pulse1_loss: 0.0378 - val_voltage_rise_time_pulse1_mae: 0.1476 - val_voltage_rise_time_pulse2_loss: 0.1144 - val_voltage_rise_time_pulse2_mae: 0.2270 - learning_rate: 5.0000e-04
# Epoch 7/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - current_fall_time_pulse1_loss: 0.0271 - current_fall_time_pulse1_mae: 0.1253 - current_fall_time_pulse2_loss: 0.0272 - current_fall_time_pulse2_mae: 0.1257 - current_rise_time_pulse1_loss: 0.0815 - current_rise_time_pulse1_mae: 0.1900 - current_rise_time_pulse2_loss: 0.1266 - current_rise_time_pulse2_mae: 0.2293 - loss: 0.8089 - overshoot_pulse_1_loss: 0.1068 - overshoot_pulse_1_mae: 0.2431 - overshoot_pulse_2_loss: 0.0980 - overshoot_pulse_2_mae: 0.2425 - ringing_frequency_MHz_loss: 0.0019 - ringing_frequency_MHz_mae: 0.0319 - undershoot_pulse_1_loss: 0.0589 - undershoot_pulse_1_mae: 0.1758 - undershoot_pulse_2_loss: 0.0595 - undershoot_pulse_2_mae: 0.1772 - voltage_fall_time_pulse1_loss: 0.0107 - voltage_fall_time_pulse1_mae: 0.0747 - voltage_fall_time_pulse2_loss: 0.0109 - voltage_fall_time_pulse2_mae: 0.0768 - voltage_rise_time_pulse1_loss: 0.0378 - voltage_rise_time_pulse1_mae: 0.1286 - voltage_rise_time_pulse2_loss: 0.1500 - voltage_rise_time_pulse2_mae: 0.2247 - val_current_fall_time_pulse1_loss: 0.0404 - val_current_fall_time_pulse1_mae: 0.1551 - val_current_fall_time_pulse2_loss: 0.0286 - val_current_fall_time_pulse2_mae: 0.1359 - val_current_rise_time_pulse1_loss: 0.0899 - val_current_rise_time_pulse1_mae: 0.2129 - val_current_rise_time_pulse2_loss: 0.1203 - val_current_rise_time_pulse2_mae: 0.2292 - val_loss: 0.7501 - val_overshoot_pulse_1_loss: 0.0619 - val_overshoot_pulse_1_mae: 0.1892 - val_overshoot_pulse_2_loss: 0.0953 - val_overshoot_pulse_2_mae: 0.2464 - val_ringing_frequency_MHz_loss: 0.0027 - val_ringing_frequency_MHz_mae: 0.0400 - val_undershoot_pulse_1_loss: 0.0511 - val_undershoot_pulse_1_mae: 0.1619 - val_undershoot_pulse_2_loss: 0.0508 - val_undershoot_pulse_2_mae: 0.1697 - val_voltage_fall_time_pulse1_loss: 0.0282 - val_voltage_fall_time_pulse1_mae: 0.1351 - val_voltage_fall_time_pulse2_loss: 0.0247 - val_voltage_fall_time_pulse2_mae: 0.1199 - val_voltage_rise_time_pulse1_loss: 0.0346 - val_voltage_rise_time_pulse1_mae: 0.1421 - val_voltage_rise_time_pulse2_loss: 0.1092 - val_voltage_rise_time_pulse2_mae: 0.2233 - learning_rate: 5.0000e-04
# Epoch 8/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - current_fall_time_pulse1_loss: 0.0250 - current_fall_time_pulse1_mae: 0.1199 - current_fall_time_pulse2_loss: 0.0250 - current_fall_time_pulse2_mae: 0.1200 - current_rise_time_pulse1_loss: 0.0798 - current_rise_time_pulse1_mae: 0.1860 - current_rise_time_pulse2_loss: 0.1218 - current_rise_time_pulse2_mae: 0.2221 - loss: 0.7667 - overshoot_pulse_1_loss: 0.0998 - overshoot_pulse_1_mae: 0.2360 - overshoot_pulse_2_loss: 0.0934 - overshoot_pulse_2_mae: 0.2371 - ringing_frequency_MHz_loss: 0.0015 - ringing_frequency_MHz_mae: 0.0283 - undershoot_pulse_1_loss: 0.0554 - undershoot_pulse_1_mae: 0.1710 - undershoot_pulse_2_loss: 0.0560 - undershoot_pulse_2_mae: 0.1717 - voltage_fall_time_pulse1_loss: 0.0098 - voltage_fall_time_pulse1_mae: 0.0714 - voltage_fall_time_pulse2_loss: 0.0097 - voltage_fall_time_pulse2_mae: 0.0728 - voltage_rise_time_pulse1_loss: 0.0346 - voltage_rise_time_pulse1_mae: 0.1218 - voltage_rise_time_pulse2_loss: 0.1431 - voltage_rise_time_pulse2_mae: 0.2191 - val_current_fall_time_pulse1_loss: 0.0353 - val_current_fall_time_pulse1_mae: 0.1453 - val_current_fall_time_pulse2_loss: 0.0276 - val_current_fall_time_pulse2_mae: 0.1326 - val_current_rise_time_pulse1_loss: 0.0887 - val_current_rise_time_pulse1_mae: 0.2103 - val_current_rise_time_pulse2_loss: 0.1174 - val_current_rise_time_pulse2_mae: 0.2236 - val_loss: 0.7237 - val_overshoot_pulse_1_loss: 0.0599 - val_overshoot_pulse_1_mae: 0.1870 - val_overshoot_pulse_2_loss: 0.0965 - val_overshoot_pulse_2_mae: 0.2488 - val_ringing_frequency_MHz_loss: 0.0029 - val_ringing_frequency_MHz_mae: 0.0412 - val_undershoot_pulse_1_loss: 0.0419 - val_undershoot_pulse_1_mae: 0.1454 - val_undershoot_pulse_2_loss: 0.0441 - val_undershoot_pulse_2_mae: 0.1550 - val_voltage_fall_time_pulse1_loss: 0.0272 - val_voltage_fall_time_pulse1_mae: 0.1308 - val_voltage_fall_time_pulse2_loss: 0.0270 - val_voltage_fall_time_pulse2_mae: 0.1248 - val_voltage_rise_time_pulse1_loss: 0.0339 - val_voltage_rise_time_pulse1_mae: 0.1385 - val_voltage_rise_time_pulse2_loss: 0.1090 - val_voltage_rise_time_pulse2_mae: 0.2247 - learning_rate: 5.0000e-04
# Epoch 9/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - current_fall_time_pulse1_loss: 0.0233 - current_fall_time_pulse1_mae: 0.1158 - current_fall_time_pulse2_loss: 0.0231 - current_fall_time_pulse2_mae: 0.1153 - current_rise_time_pulse1_loss: 0.0784 - current_rise_time_pulse1_mae: 0.1837 - current_rise_time_pulse2_loss: 0.1202 - current_rise_time_pulse2_mae: 0.2184 - loss: 0.7406 - overshoot_pulse_1_loss: 0.0955 - overshoot_pulse_1_mae: 0.2304 - overshoot_pulse_2_loss: 0.0915 - overshoot_pulse_2_mae: 0.2342 - ringing_frequency_MHz_loss: 0.0012 - ringing_frequency_MHz_mae: 0.0256 - undershoot_pulse_1_loss: 0.0527 - undershoot_pulse_1_mae: 0.1660 - undershoot_pulse_2_loss: 0.0534 - undershoot_pulse_2_mae: 0.1671 - voltage_fall_time_pulse1_loss: 0.0086 - voltage_fall_time_pulse1_mae: 0.0664 - voltage_fall_time_pulse2_loss: 0.0085 - voltage_fall_time_pulse2_mae: 0.0682 - voltage_rise_time_pulse1_loss: 0.0319 - voltage_rise_time_pulse1_mae: 0.1153 - voltage_rise_time_pulse2_loss: 0.1406 - voltage_rise_time_pulse2_mae: 0.2161 - val_current_fall_time_pulse1_loss: 0.0347 - val_current_fall_time_pulse1_mae: 0.1450 - val_current_fall_time_pulse2_loss: 0.0267 - val_current_fall_time_pulse2_mae: 0.1314 - val_current_rise_time_pulse1_loss: 0.0856 - val_current_rise_time_pulse1_mae: 0.2052 - val_current_rise_time_pulse2_loss: 0.1171 - val_current_rise_time_pulse2_mae: 0.2198 - val_loss: 0.7214 - val_overshoot_pulse_1_loss: 0.0535 - val_overshoot_pulse_1_mae: 0.1776 - val_overshoot_pulse_2_loss: 0.0902 - val_overshoot_pulse_2_mae: 0.2413 - val_ringing_frequency_MHz_loss: 0.0037 - val_ringing_frequency_MHz_mae: 0.0463 - val_undershoot_pulse_1_loss: 0.0493 - val_undershoot_pulse_1_mae: 0.1581 - val_undershoot_pulse_2_loss: 0.0470 - val_undershoot_pulse_2_mae: 0.1604 - val_voltage_fall_time_pulse1_loss: 0.0278 - val_voltage_fall_time_pulse1_mae: 0.1340 - val_voltage_fall_time_pulse2_loss: 0.0273 - val_voltage_fall_time_pulse2_mae: 0.1264 - val_voltage_rise_time_pulse1_loss: 0.0367 - val_voltage_rise_time_pulse1_mae: 0.1475 - val_voltage_rise_time_pulse2_loss: 0.1095 - val_voltage_rise_time_pulse2_mae: 0.2264 - learning_rate: 5.0000e-04
# Epoch 10/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - current_fall_time_pulse1_loss: 0.0218 - current_fall_time_pulse1_mae: 0.1112 - current_fall_time_pulse2_loss: 0.0215 - current_fall_time_pulse2_mae: 0.1114 - current_rise_time_pulse1_loss: 0.0770 - current_rise_time_pulse1_mae: 0.1808 - current_rise_time_pulse2_loss: 0.1175 - current_rise_time_pulse2_mae: 0.2145 - loss: 0.7109 - overshoot_pulse_1_loss: 0.0900 - overshoot_pulse_1_mae: 0.2237 - overshoot_pulse_2_loss: 0.0900 - overshoot_pulse_2_mae: 0.2325 - ringing_frequency_MHz_loss: 0.0011 - ringing_frequency_MHz_mae: 0.0234 - undershoot_pulse_1_loss: 0.0506 - undershoot_pulse_1_mae: 0.1631 - undershoot_pulse_2_loss: 0.0508 - undershoot_pulse_2_mae: 0.1637 - voltage_fall_time_pulse1_loss: 0.0078 - voltage_fall_time_pulse1_mae: 0.0637 - voltage_fall_time_pulse2_loss: 0.0080 - voltage_fall_time_pulse2_mae: 0.0659 - voltage_rise_time_pulse1_loss: 0.0297 - voltage_rise_time_pulse1_mae: 0.1102 - voltage_rise_time_pulse2_loss: 0.1335 - voltage_rise_time_pulse2_mae: 0.2128 - val_current_fall_time_pulse1_loss: 0.0393 - val_current_fall_time_pulse1_mae: 0.1534 - val_current_fall_time_pulse2_loss: 0.0295 - val_current_fall_time_pulse2_mae: 0.1379 - val_current_rise_time_pulse1_loss: 0.0829 - val_current_rise_time_pulse1_mae: 0.2007 - val_current_rise_time_pulse2_loss: 0.1189 - val_current_rise_time_pulse2_mae: 0.2237 - val_loss: 0.7537 - val_overshoot_pulse_1_loss: 0.0558 - val_overshoot_pulse_1_mae: 0.1792 - val_overshoot_pulse_2_loss: 0.0937 - val_overshoot_pulse_2_mae: 0.2464 - val_ringing_frequency_MHz_loss: 0.0047 - val_ringing_frequency_MHz_mae: 0.0523 - val_undershoot_pulse_1_loss: 0.0611 - val_undershoot_pulse_1_mae: 0.1742 - val_undershoot_pulse_2_loss: 0.0515 - val_undershoot_pulse_2_mae: 0.1701 - val_voltage_fall_time_pulse1_loss: 0.0304 - val_voltage_fall_time_pulse1_mae: 0.1378 - val_voltage_fall_time_pulse2_loss: 0.0295 - val_voltage_fall_time_pulse2_mae: 0.1280 - val_voltage_rise_time_pulse1_loss: 0.0373 - val_voltage_rise_time_pulse1_mae: 0.1466 - val_voltage_rise_time_pulse2_loss: 0.1069 - val_voltage_rise_time_pulse2_mae: 0.2262 - learning_rate: 5.0000e-04
# Epoch 11/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - current_fall_time_pulse1_loss: 0.0203 - current_fall_time_pulse1_mae: 0.1077 - current_fall_time_pulse2_loss: 0.0204 - current_fall_time_pulse2_mae: 0.1082 - current_rise_time_pulse1_loss: 0.0765 - current_rise_time_pulse1_mae: 0.1789 - current_rise_time_pulse2_loss: 0.1168 - current_rise_time_pulse2_mae: 0.2115 - loss: 0.6904 - overshoot_pulse_1_loss: 0.0874 - overshoot_pulse_1_mae: 0.2201 - overshoot_pulse_2_loss: 0.0887 - overshoot_pulse_2_mae: 0.2308 - ringing_frequency_MHz_loss: 9.3419e-04 - ringing_frequency_MHz_mae: 0.0220 - undershoot_pulse_1_loss: 0.0483 - undershoot_pulse_1_mae: 0.1587 - undershoot_pulse_2_loss: 0.0492 - undershoot_pulse_2_mae: 0.1602 - voltage_fall_time_pulse1_loss: 0.0071 - voltage_fall_time_pulse1_mae: 0.0607 - voltage_fall_time_pulse2_loss: 0.0073 - voltage_fall_time_pulse2_mae: 0.0629 - voltage_rise_time_pulse1_loss: 0.0285 - voltage_rise_time_pulse1_mae: 0.1066 - voltage_rise_time_pulse2_loss: 0.1274 - voltage_rise_time_pulse2_mae: 0.2099 - val_current_fall_time_pulse1_loss: 0.0414 - val_current_fall_time_pulse1_mae: 0.1573 - val_current_fall_time_pulse2_loss: 0.0339 - val_current_fall_time_pulse2_mae: 0.1477 - val_current_rise_time_pulse1_loss: 0.0826 - val_current_rise_time_pulse1_mae: 0.2012 - val_current_rise_time_pulse2_loss: 0.1164 - val_current_rise_time_pulse2_mae: 0.2220 - val_loss: 0.7670 - val_overshoot_pulse_1_loss: 0.0590 - val_overshoot_pulse_1_mae: 0.1869 - val_overshoot_pulse_2_loss: 0.0955 - val_overshoot_pulse_2_mae: 0.2486 - val_ringing_frequency_MHz_loss: 0.0048 - val_ringing_frequency_MHz_mae: 0.0525 - val_undershoot_pulse_1_loss: 0.0615 - val_undershoot_pulse_1_mae: 0.1748 - val_undershoot_pulse_2_loss: 0.0522 - val_undershoot_pulse_2_mae: 0.1717 - val_voltage_fall_time_pulse1_loss: 0.0303 - val_voltage_fall_time_pulse1_mae: 0.1395 - val_voltage_fall_time_pulse2_loss: 0.0329 - val_voltage_fall_time_pulse2_mae: 0.1345 - val_voltage_rise_time_pulse1_loss: 0.0356 - val_voltage_rise_time_pulse1_mae: 0.1447 - val_voltage_rise_time_pulse2_loss: 0.1088 - val_voltage_rise_time_pulse2_mae: 0.2271 - learning_rate: 5.0000e-04
# Epoch 12/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - current_fall_time_pulse1_loss: 0.0193 - current_fall_time_pulse1_mae: 0.1048 - current_fall_time_pulse2_loss: 0.0196 - current_fall_time_pulse2_mae: 0.1055 - current_rise_time_pulse1_loss: 0.0750 - current_rise_time_pulse1_mae: 0.1757 - current_rise_time_pulse2_loss: 0.1153 - current_rise_time_pulse2_mae: 0.2090 - loss: 0.6785 - overshoot_pulse_1_loss: 0.0834 - overshoot_pulse_1_mae: 0.2169 - overshoot_pulse_2_loss: 0.0868 - overshoot_pulse_2_mae: 0.2283 - ringing_frequency_MHz_loss: 8.6929e-04 - ringing_frequency_MHz_mae: 0.0210 - undershoot_pulse_1_loss: 0.0473 - undershoot_pulse_1_mae: 0.1571 - undershoot_pulse_2_loss: 0.0480 - undershoot_pulse_2_mae: 0.1581 - voltage_fall_time_pulse1_loss: 0.0067 - voltage_fall_time_pulse1_mae: 0.0586 - voltage_fall_time_pulse2_loss: 0.0067 - voltage_fall_time_pulse2_mae: 0.0602 - voltage_rise_time_pulse1_loss: 0.0269 - voltage_rise_time_pulse1_mae: 0.1025 - voltage_rise_time_pulse2_loss: 0.1311 - voltage_rise_time_pulse2_mae: 0.2090 - val_current_fall_time_pulse1_loss: 0.0444 - val_current_fall_time_pulse1_mae: 0.1634 - val_current_fall_time_pulse2_loss: 0.0324 - val_current_fall_time_pulse2_mae: 0.1445 - val_current_rise_time_pulse1_loss: 0.0834 - val_current_rise_time_pulse1_mae: 0.2016 - val_current_rise_time_pulse2_loss: 0.1187 - val_current_rise_time_pulse2_mae: 0.2226 - val_loss: 0.7765 - val_overshoot_pulse_1_loss: 0.0579 - val_overshoot_pulse_1_mae: 0.1831 - val_overshoot_pulse_2_loss: 0.1014 - val_overshoot_pulse_2_mae: 0.2562 - val_ringing_frequency_MHz_loss: 0.0048 - val_ringing_frequency_MHz_mae: 0.0522 - val_undershoot_pulse_1_loss: 0.0634 - val_undershoot_pulse_1_mae: 0.1751 - val_undershoot_pulse_2_loss: 0.0546 - val_undershoot_pulse_2_mae: 0.1731 - val_voltage_fall_time_pulse1_loss: 0.0311 - val_voltage_fall_time_pulse1_mae: 0.1399 - val_voltage_fall_time_pulse2_loss: 0.0305 - val_voltage_fall_time_pulse2_mae: 0.1306 - val_voltage_rise_time_pulse1_loss: 0.0350 - val_voltage_rise_time_pulse1_mae: 0.1432 - val_voltage_rise_time_pulse2_loss: 0.1066 - val_voltage_rise_time_pulse2_mae: 0.2230 - learning_rate: 5.0000e-04
# Epoch 13/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - current_fall_time_pulse1_loss: 0.0185 - current_fall_time_pulse1_mae: 0.1030 - current_fall_time_pulse2_loss: 0.0182 - current_fall_time_pulse2_mae: 0.1022 - current_rise_time_pulse1_loss: 0.0745 - current_rise_time_pulse1_mae: 0.1743 - current_rise_time_pulse2_loss: 0.1133 - current_rise_time_pulse2_mae: 0.2052 - loss: 0.6554 - overshoot_pulse_1_loss: 0.0804 - overshoot_pulse_1_mae: 0.2120 - overshoot_pulse_2_loss: 0.0857 - overshoot_pulse_2_mae: 0.2265 - ringing_frequency_MHz_loss: 7.6784e-04 - ringing_frequency_MHz_mae: 0.0197 - undershoot_pulse_1_loss: 0.0453 - undershoot_pulse_1_mae: 0.1534 - undershoot_pulse_2_loss: 0.0458 - undershoot_pulse_2_mae: 0.1542 - voltage_fall_time_pulse1_loss: 0.0061 - voltage_fall_time_pulse1_mae: 0.0561 - voltage_fall_time_pulse2_loss: 0.0064 - voltage_fall_time_pulse2_mae: 0.0582 - voltage_rise_time_pulse1_loss: 0.0264 - voltage_rise_time_pulse1_mae: 0.1001 - voltage_rise_time_pulse2_loss: 0.1225 - voltage_rise_time_pulse2_mae: 0.2071 - val_current_fall_time_pulse1_loss: 0.0420 - val_current_fall_time_pulse1_mae: 0.1600 - val_current_fall_time_pulse2_loss: 0.0362 - val_current_fall_time_pulse2_mae: 0.1528 - val_current_rise_time_pulse1_loss: 0.0843 - val_current_rise_time_pulse1_mae: 0.2024 - val_current_rise_time_pulse2_loss: 0.1212 - val_current_rise_time_pulse2_mae: 0.2225 - val_loss: 0.7846 - val_overshoot_pulse_1_loss: 0.0570 - val_overshoot_pulse_1_mae: 0.1825 - val_overshoot_pulse_2_loss: 0.0960 - val_overshoot_pulse_2_mae: 0.2487 - val_ringing_frequency_MHz_loss: 0.0045 - val_ringing_frequency_MHz_mae: 0.0503 - val_undershoot_pulse_1_loss: 0.0642 - val_undershoot_pulse_1_mae: 0.1821 - val_undershoot_pulse_2_loss: 0.0578 - val_undershoot_pulse_2_mae: 0.1820 - val_voltage_fall_time_pulse1_loss: 0.0335 - val_voltage_fall_time_pulse1_mae: 0.1467 - val_voltage_fall_time_pulse2_loss: 0.0312 - val_voltage_fall_time_pulse2_mae: 0.1358 - val_voltage_rise_time_pulse1_loss: 0.0356 - val_voltage_rise_time_pulse1_mae: 0.1483 - val_voltage_rise_time_pulse2_loss: 0.1092 - val_voltage_rise_time_pulse2_mae: 0.2328 - learning_rate: 5.0000e-04
# Epoch 14/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - current_fall_time_pulse1_loss: 0.0179 - current_fall_time_pulse1_mae: 0.1012 - current_fall_time_pulse2_loss: 0.0175 - current_fall_time_pulse2_mae: 0.1000 - current_rise_time_pulse1_loss: 0.0734 - current_rise_time_pulse1_mae: 0.1723 - current_rise_time_pulse2_loss: 0.1123 - current_rise_time_pulse2_mae: 0.2045 - loss: 0.6464 - overshoot_pulse_1_loss: 0.0794 - overshoot_pulse_1_mae: 0.2108 - overshoot_pulse_2_loss: 0.0851 - overshoot_pulse_2_mae: 0.2262 - ringing_frequency_MHz_loss: 7.1989e-04 - ringing_frequency_MHz_mae: 0.0191 - undershoot_pulse_1_loss: 0.0449 - undershoot_pulse_1_mae: 0.1522 - undershoot_pulse_2_loss: 0.0457 - undershoot_pulse_2_mae: 0.1535 - voltage_fall_time_pulse1_loss: 0.0059 - voltage_fall_time_pulse1_mae: 0.0547 - voltage_fall_time_pulse2_loss: 0.0058 - voltage_fall_time_pulse2_mae: 0.0554 - voltage_rise_time_pulse1_loss: 0.0244 - voltage_rise_time_pulse1_mae: 0.0962 - voltage_rise_time_pulse2_loss: 0.1220 - voltage_rise_time_pulse2_mae: 0.2044 - val_current_fall_time_pulse1_loss: 0.0413 - val_current_fall_time_pulse1_mae: 0.1571 - val_current_fall_time_pulse2_loss: 0.0349 - val_current_fall_time_pulse2_mae: 0.1502 - val_current_rise_time_pulse1_loss: 0.0824 - val_current_rise_time_pulse1_mae: 0.1995 - val_current_rise_time_pulse2_loss: 0.1156 - val_current_rise_time_pulse2_mae: 0.2128 - val_loss: 0.7637 - val_overshoot_pulse_1_loss: 0.0569 - val_overshoot_pulse_1_mae: 0.1814 - val_overshoot_pulse_2_loss: 0.0949 - val_overshoot_pulse_2_mae: 0.2476 - val_ringing_frequency_MHz_loss: 0.0047 - val_ringing_frequency_MHz_mae: 0.0511 - val_undershoot_pulse_1_loss: 0.0607 - val_undershoot_pulse_1_mae: 0.1752 - val_undershoot_pulse_2_loss: 0.0525 - val_undershoot_pulse_2_mae: 0.1713 - val_voltage_fall_time_pulse1_loss: 0.0323 - val_voltage_fall_time_pulse1_mae: 0.1425 - val_voltage_fall_time_pulse2_loss: 0.0312 - val_voltage_fall_time_pulse2_mae: 0.1344 - val_voltage_rise_time_pulse1_loss: 0.0367 - val_voltage_rise_time_pulse1_mae: 0.1512 - val_voltage_rise_time_pulse2_loss: 0.1079 - val_voltage_rise_time_pulse2_mae: 0.2294 - learning_rate: 5.0000e-04
# Epoch 15/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - current_fall_time_pulse1_loss: 0.0167 - current_fall_time_pulse1_mae: 0.0972 - current_fall_time_pulse2_loss: 0.0163 - current_fall_time_pulse2_mae: 0.0965 - current_rise_time_pulse1_loss: 0.0721 - current_rise_time_pulse1_mae: 0.1693 - current_rise_time_pulse2_loss: 0.1115 - current_rise_time_pulse2_mae: 0.2008 - loss: 0.6282 - overshoot_pulse_1_loss: 0.0762 - overshoot_pulse_1_mae: 0.2064 - overshoot_pulse_2_loss: 0.0828 - overshoot_pulse_2_mae: 0.2231 - ringing_frequency_MHz_loss: 6.8297e-04 - ringing_frequency_MHz_mae: 0.0184 - undershoot_pulse_1_loss: 0.0428 - undershoot_pulse_1_mae: 0.1491 - undershoot_pulse_2_loss: 0.0433 - undershoot_pulse_2_mae: 0.1498 - voltage_fall_time_pulse1_loss: 0.0053 - voltage_fall_time_pulse1_mae: 0.0519 - voltage_fall_time_pulse2_loss: 0.0054 - voltage_fall_time_pulse2_mae: 0.0528 - voltage_rise_time_pulse1_loss: 0.0242 - voltage_rise_time_pulse1_mae: 0.0940 - voltage_rise_time_pulse2_loss: 0.1196 - voltage_rise_time_pulse2_mae: 0.2014 - val_current_fall_time_pulse1_loss: 0.0448 - val_current_fall_time_pulse1_mae: 0.1593 - val_current_fall_time_pulse2_loss: 0.0364 - val_current_fall_time_pulse2_mae: 0.1518 - val_current_rise_time_pulse1_loss: 0.0820 - val_current_rise_time_pulse1_mae: 0.1989 - val_current_rise_time_pulse2_loss: 0.1143 - val_current_rise_time_pulse2_mae: 0.2116 - val_loss: 0.7657 - val_overshoot_pulse_1_loss: 0.0545 - val_overshoot_pulse_1_mae: 0.1806 - val_overshoot_pulse_2_loss: 0.0949 - val_overshoot_pulse_2_mae: 0.2482 - val_ringing_frequency_MHz_loss: 0.0040 - val_ringing_frequency_MHz_mae: 0.0474 - val_undershoot_pulse_1_loss: 0.0638 - val_undershoot_pulse_1_mae: 0.1846 - val_undershoot_pulse_2_loss: 0.0529 - val_undershoot_pulse_2_mae: 0.1739 - val_voltage_fall_time_pulse1_loss: 0.0319 - val_voltage_fall_time_pulse1_mae: 0.1429 - val_voltage_fall_time_pulse2_loss: 0.0331 - val_voltage_fall_time_pulse2_mae: 0.1387 - val_voltage_rise_time_pulse1_loss: 0.0329 - val_voltage_rise_time_pulse1_mae: 0.1430 - val_voltage_rise_time_pulse2_loss: 0.1084 - val_voltage_rise_time_pulse2_mae: 0.2320 - learning_rate: 1.5000e-04
# Epoch 16/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - current_fall_time_pulse1_loss: 0.0164 - current_fall_time_pulse1_mae: 0.0965 - current_fall_time_pulse2_loss: 0.0161 - current_fall_time_pulse2_mae: 0.0957 - current_rise_time_pulse1_loss: 0.0718 - current_rise_time_pulse1_mae: 0.1686 - current_rise_time_pulse2_loss: 0.1118 - current_rise_time_pulse2_mae: 0.2001 - loss: 0.6215 - overshoot_pulse_1_loss: 0.0752 - overshoot_pulse_1_mae: 0.2054 - overshoot_pulse_2_loss: 0.0829 - overshoot_pulse_2_mae: 0.2232 - ringing_frequency_MHz_loss: 6.5143e-04 - ringing_frequency_MHz_mae: 0.0181 - undershoot_pulse_1_loss: 0.0420 - undershoot_pulse_1_mae: 0.1483 - undershoot_pulse_2_loss: 0.0424 - undershoot_pulse_2_mae: 0.1489 - voltage_fall_time_pulse1_loss: 0.0051 - voltage_fall_time_pulse1_mae: 0.0514 - voltage_fall_time_pulse2_loss: 0.0052 - voltage_fall_time_pulse2_mae: 0.0523 - voltage_rise_time_pulse1_loss: 0.0234 - voltage_rise_time_pulse1_mae: 0.0922 - voltage_rise_time_pulse2_loss: 0.1172 - voltage_rise_time_pulse2_mae: 0.2017 - val_current_fall_time_pulse1_loss: 0.0403 - val_current_fall_time_pulse1_mae: 0.1524 - val_current_fall_time_pulse2_loss: 0.0342 - val_current_fall_time_pulse2_mae: 0.1484 - val_current_rise_time_pulse1_loss: 0.0832 - val_current_rise_time_pulse1_mae: 0.2013 - val_current_rise_time_pulse2_loss: 0.1142 - val_current_rise_time_pulse2_mae: 0.2122 - val_loss: 0.7550 - val_overshoot_pulse_1_loss: 0.0538 - val_overshoot_pulse_1_mae: 0.1798 - val_overshoot_pulse_2_loss: 0.0941 - val_overshoot_pulse_2_mae: 0.2472 - val_ringing_frequency_MHz_loss: 0.0042 - val_ringing_frequency_MHz_mae: 0.0485 - val_undershoot_pulse_1_loss: 0.0619 - val_undershoot_pulse_1_mae: 0.1820 - val_undershoot_pulse_2_loss: 0.0515 - val_undershoot_pulse_2_mae: 0.1728 - val_voltage_fall_time_pulse1_loss: 0.0314 - val_voltage_fall_time_pulse1_mae: 0.1416 - val_voltage_fall_time_pulse2_loss: 0.0337 - val_voltage_fall_time_pulse2_mae: 0.1415 - val_voltage_rise_time_pulse1_loss: 0.0342 - val_voltage_rise_time_pulse1_mae: 0.1457 - val_voltage_rise_time_pulse2_loss: 0.1066 - val_voltage_rise_time_pulse2_mae: 0.2298 - learning_rate: 1.5000e-04
# Epoch 17/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - current_fall_time_pulse1_loss: 0.0159 - current_fall_time_pulse1_mae: 0.0954 - current_fall_time_pulse2_loss: 0.0156 - current_fall_time_pulse2_mae: 0.0946 - current_rise_time_pulse1_loss: 0.0721 - current_rise_time_pulse1_mae: 0.1689 - current_rise_time_pulse2_loss: 0.1096 - current_rise_time_pulse2_mae: 0.1984 - loss: 0.6051 - overshoot_pulse_1_loss: 0.0725 - overshoot_pulse_1_mae: 0.2028 - overshoot_pulse_2_loss: 0.0817 - overshoot_pulse_2_mae: 0.2223 - ringing_frequency_MHz_loss: 6.4064e-04 - ringing_frequency_MHz_mae: 0.0179 - undershoot_pulse_1_loss: 0.0419 - undershoot_pulse_1_mae: 0.1474 - undershoot_pulse_2_loss: 0.0420 - undershoot_pulse_2_mae: 0.1481 - voltage_fall_time_pulse1_loss: 0.0051 - voltage_fall_time_pulse1_mae: 0.0511 - voltage_fall_time_pulse2_loss: 0.0050 - voltage_fall_time_pulse2_mae: 0.0514 - voltage_rise_time_pulse1_loss: 0.0230 - voltage_rise_time_pulse1_mae: 0.0914 - voltage_rise_time_pulse2_loss: 0.1088 - voltage_rise_time_pulse2_mae: 0.1988 - val_current_fall_time_pulse1_loss: 0.0425 - val_current_fall_time_pulse1_mae: 0.1552 - val_current_fall_time_pulse2_loss: 0.0340 - val_current_fall_time_pulse2_mae: 0.1475 - val_current_rise_time_pulse1_loss: 0.0832 - val_current_rise_time_pulse1_mae: 0.2008 - val_current_rise_time_pulse2_loss: 0.1137 - val_current_rise_time_pulse2_mae: 0.2115 - val_loss: 0.7512 - val_overshoot_pulse_1_loss: 0.0539 - val_overshoot_pulse_1_mae: 0.1799 - val_overshoot_pulse_2_loss: 0.0930 - val_overshoot_pulse_2_mae: 0.2456 - val_ringing_frequency_MHz_loss: 0.0042 - val_ringing_frequency_MHz_mae: 0.0485 - val_undershoot_pulse_1_loss: 0.0611 - val_undershoot_pulse_1_mae: 0.1797 - val_undershoot_pulse_2_loss: 0.0497 - val_undershoot_pulse_2_mae: 0.1698 - val_voltage_fall_time_pulse1_loss: 0.0333 - val_voltage_fall_time_pulse1_mae: 0.1454 - val_voltage_fall_time_pulse2_loss: 0.0327 - val_voltage_fall_time_pulse2_mae: 0.1392 - val_voltage_rise_time_pulse1_loss: 0.0322 - val_voltage_rise_time_pulse1_mae: 0.1419 - val_voltage_rise_time_pulse2_loss: 0.1060 - val_voltage_rise_time_pulse2_mae: 0.2273 - learning_rate: 1.5000e-04
# Epoch 18/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - current_fall_time_pulse1_loss: 0.0160 - current_fall_time_pulse1_mae: 0.0955 - current_fall_time_pulse2_loss: 0.0159 - current_fall_time_pulse2_mae: 0.0951 - current_rise_time_pulse1_loss: 0.0720 - current_rise_time_pulse1_mae: 0.1686 - current_rise_time_pulse2_loss: 0.1091 - current_rise_time_pulse2_mae: 0.1982 - loss: 0.6074 - overshoot_pulse_1_loss: 0.0734 - overshoot_pulse_1_mae: 0.2042 - overshoot_pulse_2_loss: 0.0819 - overshoot_pulse_2_mae: 0.2220 - ringing_frequency_MHz_loss: 6.1909e-04 - ringing_frequency_MHz_mae: 0.0176 - undershoot_pulse_1_loss: 0.0414 - undershoot_pulse_1_mae: 0.1468 - undershoot_pulse_2_loss: 0.0413 - undershoot_pulse_2_mae: 0.1474 - voltage_fall_time_pulse1_loss: 0.0050 - voltage_fall_time_pulse1_mae: 0.0502 - voltage_fall_time_pulse2_loss: 0.0049 - voltage_fall_time_pulse2_mae: 0.0504 - voltage_rise_time_pulse1_loss: 0.0229 - voltage_rise_time_pulse1_mae: 0.0909 - voltage_rise_time_pulse2_loss: 0.1117 - voltage_rise_time_pulse2_mae: 0.1993 - val_current_fall_time_pulse1_loss: 0.0393 - val_current_fall_time_pulse1_mae: 0.1502 - val_current_fall_time_pulse2_loss: 0.0336 - val_current_fall_time_pulse2_mae: 0.1462 - val_current_rise_time_pulse1_loss: 0.0829 - val_current_rise_time_pulse1_mae: 0.1996 - val_current_rise_time_pulse2_loss: 0.1142 - val_current_rise_time_pulse2_mae: 0.2132 - val_loss: 0.7517 - val_overshoot_pulse_1_loss: 0.0545 - val_overshoot_pulse_1_mae: 0.1815 - val_overshoot_pulse_2_loss: 0.0940 - val_overshoot_pulse_2_mae: 0.2473 - val_ringing_frequency_MHz_loss: 0.0041 - val_ringing_frequency_MHz_mae: 0.0479 - val_undershoot_pulse_1_loss: 0.0602 - val_undershoot_pulse_1_mae: 0.1779 - val_undershoot_pulse_2_loss: 0.0529 - val_undershoot_pulse_2_mae: 0.1748 - val_voltage_fall_time_pulse1_loss: 0.0332 - val_voltage_fall_time_pulse1_mae: 0.1463 - val_voltage_fall_time_pulse2_loss: 0.0323 - val_voltage_fall_time_pulse2_mae: 0.1393 - val_voltage_rise_time_pulse1_loss: 0.0328 - val_voltage_rise_time_pulse1_mae: 0.1424 - val_voltage_rise_time_pulse2_loss: 0.1060 - val_voltage_rise_time_pulse2_mae: 0.2266 - learning_rate: 1.5000e-04
# Epoch 19/120
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - current_fall_time_pulse1_loss: 0.0158 - current_fall_time_pulse1_mae: 0.0948 - current_fall_time_pulse2_loss: 0.0154 - current_fall_time_pulse2_mae: 0.0937 - current_rise_time_pulse1_loss: 0.0718 - current_rise_time_pulse1_mae: 0.1680 - current_rise_time_pulse2_loss: 0.1090 - current_rise_time_pulse2_mae: 0.1972 - loss: 0.6000 - overshoot_pulse_1_loss: 0.0729 - overshoot_pulse_1_mae: 0.2029 - overshoot_pulse_2_loss: 0.0809 - overshoot_pulse_2_mae: 0.2209 - ringing_frequency_MHz_loss: 5.9950e-04 - ringing_frequency_MHz_mae: 0.0173 - undershoot_pulse_1_loss: 0.0404 - undershoot_pulse_1_mae: 0.1452 - undershoot_pulse_2_loss: 0.0410 - undershoot_pulse_2_mae: 0.1458 - voltage_fall_time_pulse1_loss: 0.0049 - voltage_fall_time_pulse1_mae: 0.0497 - voltage_fall_time_pulse2_loss: 0.0048 - voltage_fall_time_pulse2_mae: 0.0499 - voltage_rise_time_pulse1_loss: 0.0227 - voltage_rise_time_pulse1_mae: 0.0897 - voltage_rise_time_pulse2_loss: 0.1087 - voltage_rise_time_pulse2_mae: 0.1984 - val_current_fall_time_pulse1_loss: 0.0416 - val_current_fall_time_pulse1_mae: 0.1549 - val_current_fall_time_pulse2_loss: 0.0366 - val_current_fall_time_pulse2_mae: 0.1523 - val_current_rise_time_pulse1_loss: 0.0814 - val_current_rise_time_pulse1_mae: 0.1974 - val_current_rise_time_pulse2_loss: 0.1132 - val_current_rise_time_pulse2_mae: 0.2102 - val_loss: 0.7581 - val_overshoot_pulse_1_loss: 0.0555 - val_overshoot_pulse_1_mae: 0.1831 - val_overshoot_pulse_2_loss: 0.0956 - val_overshoot_pulse_2_mae: 0.2492 - val_ringing_frequency_MHz_loss: 0.0044 - val_ringing_frequency_MHz_mae: 0.0496 - val_undershoot_pulse_1_loss: 0.0619 - val_undershoot_pulse_1_mae: 0.1819 - val_undershoot_pulse_2_loss: 0.0520 - val_undershoot_pulse_2_mae: 0.1740 - val_voltage_fall_time_pulse1_loss: 0.0324 - val_voltage_fall_time_pulse1_mae: 0.1453 - val_voltage_fall_time_pulse2_loss: 0.0324 - val_voltage_fall_time_pulse2_mae: 0.1396 - val_voltage_rise_time_pulse1_loss: 0.0322 - val_voltage_rise_time_pulse1_mae: 0.1421 - val_voltage_rise_time_pulse2_loss: 0.1073 - val_voltage_rise_time_pulse2_mae: 0.2295 - learning_rate: 1.5000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2294/2294 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
#
# train:
#                        Target        R2          RMSE
# 7   current_fall_time_pulse2  0.972783  1.940674e-09
# 3   voltage_fall_time_pulse2  0.972357  1.141393e-09
# 2   voltage_fall_time_pulse1  0.971768  1.154872e-09
# 6   current_fall_time_pulse1  0.964456  2.224513e-09
# 0   voltage_rise_time_pulse1  0.963585  7.731276e-10
# 12     ringing_frequency_MHz  0.952935  7.164022e+00
# 11        undershoot_pulse_2  0.952548  2.986254e+00
# 10        undershoot_pulse_1  0.949866  3.067763e+00
# 8          overshoot_pulse_1  0.944745  2.874877e+00
# 4   current_rise_time_pulse1  0.911510  1.461749e-08
# 9          overshoot_pulse_2  0.910612  7.561471e+00
# 1   voltage_rise_time_pulse2  0.883570  1.374071e-09
# 5   current_rise_time_pulse2  0.883250  8.581928e-09
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# val:
#                        Target        R2          RMSE
# 7   current_fall_time_pulse2  0.972971  1.917639e-09
# 3   voltage_fall_time_pulse2  0.972452  1.133872e-09
# 2   voltage_fall_time_pulse1  0.971986  1.144816e-09
# 6   current_fall_time_pulse1  0.964858  2.194276e-09
# 0   voltage_rise_time_pulse1  0.963036  7.761686e-10
# 11        undershoot_pulse_2  0.953273  2.972971e+00
# 12     ringing_frequency_MHz  0.952746  7.137267e+00
# 10        undershoot_pulse_1  0.951013  3.044561e+00
# 8          overshoot_pulse_1  0.943647  2.819306e+00
# 4   current_rise_time_pulse1  0.912601  1.435667e-08
# 9          overshoot_pulse_2  0.907744  7.582855e+00
# 1   voltage_rise_time_pulse2  0.886747  1.331436e-09
# 5   current_rise_time_pulse2  0.880620  8.583362e-09
# 2698/2698 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
#
# test:
#                        Target        R2          RMSE
# 7   current_fall_time_pulse2  0.972811  1.937236e-09
# 3   voltage_fall_time_pulse2  0.972371  1.140268e-09
# 2   voltage_fall_time_pulse1  0.971800  1.153369e-09
# 6   current_fall_time_pulse1  0.964516  2.220004e-09
# 0   voltage_rise_time_pulse1  0.963503  7.735846e-10
# 12     ringing_frequency_MHz  0.952907  7.160015e+00
# 11        undershoot_pulse_2  0.952657  2.984266e+00
# 10        undershoot_pulse_1  0.950039  3.064293e+00
# 8          overshoot_pulse_1  0.944590  2.866610e+00
# 4   current_rise_time_pulse1  0.911671  1.457866e-08
# 9          overshoot_pulse_2  0.910191  7.564682e+00
# 1   voltage_rise_time_pulse2  0.884033  1.367761e-09
# 5   current_rise_time_pulse2  0.882867  8.582143e-09
# 675/675 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# unseen:
#                        Target        R2          RMSE
# 2   voltage_fall_time_pulse1  0.917023  6.706297e-10
# 7   current_fall_time_pulse2  0.914252  3.264926e-09
# 3   voltage_fall_time_pulse2  0.907579  7.081463e-10
# 6   current_fall_time_pulse1  0.883044  3.839445e-09
# 8          overshoot_pulse_1  0.708823  7.297281e+00
# 11        undershoot_pulse_2  0.490496  6.954391e+00
# 1   voltage_rise_time_pulse2  0.474846  3.380852e-09
# 10        undershoot_pulse_1  0.425873  7.432636e+00
# 9          overshoot_pulse_2  0.394913  1.611558e+01
# 5   current_rise_time_pulse2  0.122039  1.570873e-08
# 0   voltage_rise_time_pulse1  0.120581  1.614804e-09
#                       Target        R2          RMSE
# 2   voltage_fall_time_pulse1  0.917023  6.706297e-10
# 7   current_fall_time_pulse2  0.914252  3.264926e-09
# 3   voltage_fall_time_pulse2  0.907579  7.081463e-10
# 6   current_fall_time_pulse1  0.883044  3.839445e-09
# 8          overshoot_pulse_1  0.708823  7.297281e+00
# 11        undershoot_pulse_2  0.490496  6.954391e+00
# 1   voltage_rise_time_pulse2  0.474846  3.380852e-09
# 10        undershoot_pulse_1  0.425873  7.432636e+00
# 9          overshoot_pulse_2  0.394913  1.611558e+01
# 5   current_rise_time_pulse2  0.122039  1.570873e-08
# 0   voltage_rise_time_pulse1  0.120581  1.614804e-09
